# %%
# Downloading libraries for web-scraping
# !pip install requests
# !pip install beautifulsoup4==4.9.3
# !pip install bs4
# !pip install html5lib
# !pip install num2words
# !pip install vaderSentiment

# Importing libraries for web-scraping and tokenization purposes
from bs4 import BeautifulSoup as bs
import requests
import nltk
import pandas as pd
import re
from textblob import TextBlob
from num2words import num2words
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# The list of common words such as "a", "an", etc.
nltk.download('stopwords')
# Download a collection of popular resources from the NLTK library
nltk.download('popular', quiet=True)
# Sentence tokenization (Splitting a text into individual senteces)
nltk.download('punkt')
# English vocabulary database
nltk.download('wordnet')
# Used for training language models or evaluating nlp algothms
nltk.download('brown')
# Used for performing sentiment analysis on text
nltk.download('vader_lexicon')

from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize

lemmatizer = WordNetLemmatizer()
analyzer = SentimentIntensityAnalyzer()
stemmer = SnowballStemmer("english")
stop_words = stopwords.words("english")
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Collecting beautifulsoup4==4.9.3
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.8/115.8 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4==4.9.3) (2.5)
# Installing collected packages: beautifulsoup4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.3
#     Uninstalling beautifulsoup4-4.12.3:
#       Successfully uninstalled beautifulsoup4-4.12.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yfinance 0.2.37 requires beautifulsoup4>=4.11.1, but you have beautifulsoup4 4.9.3 which is incompatible.
# Successfully installed beautifulsoup4-4.9.3
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib) (0.5.1)
# Collecting num2words
#   Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 4.5 MB/s eta 0:00:00
# Collecting docopt>=0.6.2 (from num2words)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=6c50090cb2de7b49886fe2168db6e532f69d65e0b761523bc749fba0703f274e
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: docopt, num2words
# Successfully installed docopt-0.6.2 num2words-0.5.13
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2024.2.2)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
sentences = []

def scrape_clean (url, div_class):
  # Load the website
  website = requests.get(url).text
  soup = bs(website,'html.parser')

  # Find the div section that is the parent of all paragraphs
  div = soup.find_all('div', attrs={'class':div_class})

  # Get the text from paragraphs
  extracted_text = []
  for div in div:
      paragraphs = div.find_all('p')
      for paragraph in paragraphs:
          extracted_text.append(paragraph.get_text(strip=True))  # Remove leading/trailing whitespace

  # Splitting the text into sentences, remove the stopwords and punctuations, and save the cleaned version in a list
  sentences = []
  for text in extracted_text:
    sentence = sent_tokenize(text)
    for item in sentence:
      # Convert to lowercase
      text_lowercase = item.lower()
      # Remove punctuation
      text_without_punctuation = re.sub(r"[^\w\s]", "", text_lowercase)
      # Remove stopwords and stem words
      tokens = word_tokenize(text_without_punctuation)
      new_tokens = []
      for word in tokens:
        if word.isnumeric():
          word = num2words(word)
          new_tokens.append(lemmatizer.lemmatize(word))
          continue
        elif word not in stop_words:
          new_tokens.append(lemmatizer.lemmatize(word))
          continue
      # Join tokens back into a string
      cleaned_text = " ".join(new_tokens)
      sentences.append(cleaned_text)

  return sentences

# %%
website1 = 'https://www.forrester.com/blogs/focus-on-gen-ai-will-drive-core-modernization-and-saas-adoption-in-2024/?utm_source=google&utm_medium=cpc&utm_campaign=generative-ai/'
class1 = 'col-lg-10 order-lg-1'
text1 = scrape_clean(website1, class1)
sentences.extend(text1)
text1
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know']

# %%
website2 = 'https://www.forrester.com/blogs/genais-world-changing-power-is-putting-knowledge-to-work/?utm_source=google&utm_medium=cpc&utm_campaign=generative-ai'
class2 = 'col-lg-8 order-lg-2'
text2 = scrape_clean(website2, class2)
sentences.extend(text2)
text2
# Out:
# ['brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk']

# %%
website3 = 'https://www.forrester.com/blogs/genai-will-shatter-and-reconstruct-every-company-and-industry/?utm_source=google&utm_medium=cpc&utm_campaign=generative-ai/'
class3 = 'post-content post-body__item'
text3 = scrape_clean(website3, class3)
sentences.extend(text3)
text3
# Out:
# ['brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom']

# %%
website4 = 'https://news.sky.com/story/ai-risks-up-to-eight-million-uk-job-losses-with-low-skilled-worst-hit-report-warns-13102214'
class4 = 'sdc-site-layout__col sdc-site-layout__col1'
text4 = scrape_clean(website4, class4)
sentences.extend(text4)
text4
# Out:
# ['eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy']

# %%
website5 = 'https://www.prnewswire.com/news-releases/50-billion-opportunity-emerges-for-insurers-worldwide-from-generative-ais-potential-to-boost-revenues-and-take-out-costs-302103876.html'
class5 = 'col-lg-10 col-lg-offset-1'
text5 = scrape_clean(website5, class5)
sentences.extend(text5)
text5
# Out:
# ['ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics']

# %%
website6 = 'https://venturebeat.com/ai/the-risks-and-rewards-of-generative-ai-in-software-development/'
class6 = 'article-content'
text6 = scrape_clean(website6, class6)
sentences.extend(text6)
text6
# Out:
# []

# %%
website7 = 'https://thecorner.eu/news-spain/spain-economy/significant-growth-and-revenue-capture-opportunity-for-companies-serving-generative-ai-energy-needs-including-iberdrola/113769/'
class7 = 'entry-content clearfix'
text7 = scrape_clean(website7, class7)
sentences.extend(text7)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe']

# %%
website8 = 'https://www.ox.ac.uk/news/2024-02-22-experts-call-responsible-use-generative-ai-adult-social-care'
class8 = 'field field-name-field-body field-type-text-with-summary field-label-hidden'
text8 = scrape_clean(website8, class8)
sentences.extend(text8)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe',
#  'adult social care supporting people live independently protect fundamental human right',
#  'generative ai offer many potential benefit opportunity adult social care',
#  'however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately',
#  'therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college',
#  'artificial intelligence offer many opportunity potential benefit adult social care',
#  'generative ai large language model llm power ai chatbots aid various task social care',
#  'however many activity social care directly touch people human right wellbeing',
#  'currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail',
#  'aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case',
#  'core focus would constitute responsible ethical use emerging technology',
#  'following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care',
#  'addition commits group engaging coproduction consultation process drawing people organisation social care',
#  'full statement endorsed twenty-three participating organisation beread']

# %%
website9 = 'https://theconversation.com/generative-ai-is-changing-the-legal-profession-future-lawyers-need-to-know-how-to-use-it-225730'
class9 = 'grid-ten large-grid-nine grid-last content-body content entry-content instapaper_body inline-promos'
text9 = scrape_clean(website9, class9)
sentences.extend(text9)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe',
#  'adult social care supporting people live independently protect fundamental human right',
#  'generative ai offer many potential benefit opportunity adult social care',
#  'however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately',
#  'therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college',
#  'artificial intelligence offer many opportunity potential benefit adult social care',
#  'generative ai large language model llm power ai chatbots aid various task social care',
#  'however many activity social care directly touch people human right wellbeing',
#  'currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail',
#  'aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case',
#  'core focus would constitute responsible ethical use emerging technology',
#  'following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care',
#  'addition commits group engaging coproduction consultation process drawing people organisation social care',
#  'full statement endorsed twenty-three participating organisation beread']

# %%
website10 = 'https://economymiddleeast.com/news/why-businesses-are-approaching-generative-ai-with-caution/'
class10 = 'brxe-post-content'
text10 = scrape_clean(website10, class10)
sentences.extend(text10)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe',
#  'adult social care supporting people live independently protect fundamental human right',
#  'generative ai offer many potential benefit opportunity adult social care',
#  'however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately',
#  'therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college',
#  'artificial intelligence offer many opportunity potential benefit adult social care',
#  'generative ai large language model llm power ai chatbots aid various task social care',
#  'however many activity social care directly touch people human right wellbeing',
#  'currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail',
#  'aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case',
#  'core focus would constitute responsible ethical use emerging technology',
#  'following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care',
#  'addition commits group engaging coproduction consultation process drawing people organisation social care',
#  'full statement endorsed twenty-three participating organisation beread',
#  'according recent global report business agree generative ai gen ai substantial impact industry',
#  'however despite fanfare adoption rate technology remained abysmally low business',
#  'three quarter surveyed company experimented gen ai lowly nine percent admitted adopted technology',
#  'based survey conducted mit technology review insight telecom company telstrathe reportcovered three hundred csuite executive vice president director across asiapacific america europe',
#  'report question participant company using plan use gen ai technology',
#  'addition gauging interest technology report also highlight barrier adoption gen ai business',
#  'readgenerative ai market projected reach one trillion two thousand and thirty-one',
#  'misconception easy run mature enterpriseready generative ai said stela solar inaugural director australia national artificial intelligence centre report',
#  'agreeing solars assessment brian prince founder ceo top ai tool say investing gen ai expensive',
#  'argues beyond software business likely need also invest training infrastructure upgrade ongoing maintenance',
#  'especially true small medium enterprise may find challenging allocate sufficient budget without guaranteed shortterm return',
#  'telstra survey showed skill training company culture major impediment adoption say prince',
#  'integrating ai existing workflow system complex',
#  'speaking experience paolo danese ceo storya say observed tangible disconnect theoretical allure gen ai practical reality faced business',
#  'divergence technology encompasses broader concern readiness infrastructure steep learning curve effective deployment ethical consideration surrounding ai use say danese',
#  'building sukhdeep sohal senior consultant glue affinity reply say business apprehension towards gen ai often traced back series strategic operational disconnect',
#  'belief crux issue lie alignment lack thereof ai initiative overarching business strategy',
#  'ai strategy perceived standalone experiment rather integral part business growth disconnect breed reluctance say sohal',
#  'additionally delivery ai foundation piecemeal rather holistically fails instil confidence technology comprehensive benefit',
#  'report highlighted evolving regulatory compliance data privacy environment leading nontechnological barrier rapid gen ai adoption business',
#  'danese agrees saying business navigating uncharted water need balance push digital transformation adhering strict privacy standard',
#  'according prince especially true sector like healthcare finance legal data sensitivity critical concern',
#  'burden compliance becomes significant deterrent say',
#  'read5 way make money generative ai',
#  'peter john alexander chief business officer meetkai highlight nontechnical factor business must take consideration',
#  'say company likely fear potential data breach ethical misuse high implementation usage cost unreliable output risk falling behind competitor',
#  'apprehension highlight need careful consideration benefit risk generative ai deployment alongside proactive measure address security compliance ethical operational challenge say alexander',
#  'according report seventy-eight percent business look gen ai competitive opportunity',
#  'many expect number function deploying gen ai double two thousand and twenty-four',
#  'term actual use sixty-five percent respondent say business actively considering new innovative way use gen ai unlock hidden opportunity data',
#  'doesnt surprise sohal',
#  'say gen ai aligned wellarticulated strategy fit best leverage predictive power data stream identified rigorous data audit',
#  'suggests analysis especially predictive analytics prime area application directly amplifies strategic decisionmaking capability',
#  'read42 percent uae company adopt ai business operation say study',
#  'alexander agrees saying ai excels rapidly analyzing vast amount data surface pattern making prediction uncovering actionable insight',
#  'say could include customer analytics identify trend segment financial analysis forecasting operation optimization',
#  'leveraging ai business make smarter datadriven decision much faster manual analysis say alexander',
#  'according report rather confined specific sector gen ai likely transform specific function across economy customer service',
#  'also point two thousand and twenty-three national bureau economic research working paper predicts gen ai customer service could raise productivity fourteen percent',
#  'generative ai prowess natural language understanding generation position linchpin customer service revolution offering personalized efficient engaging user experience say danese',
#  'alexander belief business must approach gen ai transformative business capability scattershot set project',
#  'readmeta roll new generative ai feature uae saudi',
#  'ultimately best fit gen ai depends company unique need available data strategic priority say alexander',
#  'company align ai initiative overarching business goal start focused experiment prove value scale success',
#  'ensure readiness maximize benefit sohal suggests organization seek use case depending level ai maturity',
#  'additionally recommends business also look industry precedent validate inform approach',
#  'integrative strategy promise yield tangible business value elevating gen ai technological experiment cornerstone enterprise capability say sohal',
#  'technology news clickhere']

# %%
website11 = 'https://www.globalvillagespace.com/tech/understanding-the-potential-benefits-and-dangers-of-generative-ai-in-software-development/'
class11 = 'tdb-block-inner td-fix-index'
text11 = scrape_clean(website11, class11)
sentences.extend(text11)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe',
#  'adult social care supporting people live independently protect fundamental human right',
#  'generative ai offer many potential benefit opportunity adult social care',
#  'however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately',
#  'therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college',
#  'artificial intelligence offer many opportunity potential benefit adult social care',
#  'generative ai large language model llm power ai chatbots aid various task social care',
#  'however many activity social care directly touch people human right wellbeing',
#  'currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail',
#  'aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case',
#  'core focus would constitute responsible ethical use emerging technology',
#  'following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care',
#  'addition commits group engaging coproduction consultation process drawing people organisation social care',
#  'full statement endorsed twenty-three participating organisation beread',
#  'according recent global report business agree generative ai gen ai substantial impact industry',
#  'however despite fanfare adoption rate technology remained abysmally low business',
#  'three quarter surveyed company experimented gen ai lowly nine percent admitted adopted technology',
#  'based survey conducted mit technology review insight telecom company telstrathe reportcovered three hundred csuite executive vice president director across asiapacific america europe',
#  'report question participant company using plan use gen ai technology',
#  'addition gauging interest technology report also highlight barrier adoption gen ai business',
#  'readgenerative ai market projected reach one trillion two thousand and thirty-one',
#  'misconception easy run mature enterpriseready generative ai said stela solar inaugural director australia national artificial intelligence centre report',
#  'agreeing solars assessment brian prince founder ceo top ai tool say investing gen ai expensive',
#  'argues beyond software business likely need also invest training infrastructure upgrade ongoing maintenance',
#  'especially true small medium enterprise may find challenging allocate sufficient budget without guaranteed shortterm return',
#  'telstra survey showed skill training company culture major impediment adoption say prince',
#  'integrating ai existing workflow system complex',
#  'speaking experience paolo danese ceo storya say observed tangible disconnect theoretical allure gen ai practical reality faced business',
#  'divergence technology encompasses broader concern readiness infrastructure steep learning curve effective deployment ethical consideration surrounding ai use say danese',
#  'building sukhdeep sohal senior consultant glue affinity reply say business apprehension towards gen ai often traced back series strategic operational disconnect',
#  'belief crux issue lie alignment lack thereof ai initiative overarching business strategy',
#  'ai strategy perceived standalone experiment rather integral part business growth disconnect breed reluctance say sohal',
#  'additionally delivery ai foundation piecemeal rather holistically fails instil confidence technology comprehensive benefit',
#  'report highlighted evolving regulatory compliance data privacy environment leading nontechnological barrier rapid gen ai adoption business',
#  'danese agrees saying business navigating uncharted water need balance push digital transformation adhering strict privacy standard',
#  'according prince especially true sector like healthcare finance legal data sensitivity critical concern',
#  'burden compliance becomes significant deterrent say',
#  'read5 way make money generative ai',
#  'peter john alexander chief business officer meetkai highlight nontechnical factor business must take consideration',
#  'say company likely fear potential data breach ethical misuse high implementation usage cost unreliable output risk falling behind competitor',
#  'apprehension highlight need careful consideration benefit risk generative ai deployment alongside proactive measure address security compliance ethical operational challenge say alexander',
#  'according report seventy-eight percent business look gen ai competitive opportunity',
#  'many expect number function deploying gen ai double two thousand and twenty-four',
#  'term actual use sixty-five percent respondent say business actively considering new innovative way use gen ai unlock hidden opportunity data',
#  'doesnt surprise sohal',
#  'say gen ai aligned wellarticulated strategy fit best leverage predictive power data stream identified rigorous data audit',
#  'suggests analysis especially predictive analytics prime area application directly amplifies strategic decisionmaking capability',
#  'read42 percent uae company adopt ai business operation say study',
#  'alexander agrees saying ai excels rapidly analyzing vast amount data surface pattern making prediction uncovering actionable insight',
#  'say could include customer analytics identify trend segment financial analysis forecasting operation optimization',
#  'leveraging ai business make smarter datadriven decision much faster manual analysis say alexander',
#  'according report rather confined specific sector gen ai likely transform specific function across economy customer service',
#  'also point two thousand and twenty-three national bureau economic research working paper predicts gen ai customer service could raise productivity fourteen percent',
#  'generative ai prowess natural language understanding generation position linchpin customer service revolution offering personalized efficient engaging user experience say danese',
#  'alexander belief business must approach gen ai transformative business capability scattershot set project',
#  'readmeta roll new generative ai feature uae saudi',
#  'ultimately best fit gen ai depends company unique need available data strategic priority say alexander',
#  'company align ai initiative overarching business goal start focused experiment prove value scale success',
#  'ensure readiness maximize benefit sohal suggests organization seek use case depending level ai maturity',
#  'additionally recommends business also look industry precedent validate inform approach',
#  'integrative strategy promise yield tangible business value elevating gen ai technological experiment cornerstone enterprise capability say sohal',
#  'technology news clickhere',
#  'world software development emergence generative ai sparked excitement skepticism',
#  'predict ai render many software development skill obsolete others cautious potential impact',
#  '20year veteran field ceo company serving software developer keith pitt share insight potential benefit danger generative ai software development',
#  'one significant positive impact generative ai potential eliminate grunt work developer',
#  'developer often spend considerable amount time detail like syntax punctuation automated ai',
#  'instead poring manual searching code snippet developer describe desired outcome receive perfectly formatted code response',
#  'additionally large language model llm help identify typo punctuation mistake detail tedious developer',
#  'generative ai also potential reinvent software framework',
#  'framework like spring expressjs django already increased productivity abstracting mundane aspect software development',
#  'help gen ai framework enhance value creating boilerplate code automating repetitive task suggesting code optimization',
#  'ai also assist customizing framework component specific project',
#  'another significant change brought generative ai rise generalist developer',
#  'traditionally developer specialized specific language backend skill',
#  'however machine capable generating code language language proficiency may become le important',
#  'valuable skill machine replicate building user interface translating user requirement specification inventing new way support customer',
#  'shift put spotlight developer excel area',
#  'generative ai also hold great potential revolutionizing software testing',
#  'developer write code bot generate numerous test script quickly efficiently',
#  'according recent idc survey anticipated benefit generative ai software development software quality assurance security testing',
#  'disruption devops practice continuous integrationdeployment may lead testing specialist seeking new opportunity',
#  'lowcodenocode development tool already made software development accessible generative ai take next level',
#  'currently tool require individual piece together workflow whiteboard translating code',
#  'future developer able provide handdrawn sketch desired workflow ai model generate necessary code second',
#  'however essential recognize generative ai panacea',
#  'potential downside need considered',
#  'one concern risk overtesting',
#  'ai model capable generating test quickly possibility ending test necessary',
#  'overtesting slow project create bottleneck development pipeline',
#  'ai recommendation remove test could help address issue',
#  'skill degradation another potential danger associated generative ai',
#  'lazy developer may rely ai find shortcut leading bloated inefficient poorly performing code',
#  'reliance existing pattern data may limit innovative potential developer think outside box explore new solution',
#  'trust crucial come generative ai',
#  'quality data used train ai model significantly impact performance',
#  'poor quality data training shortcut inadequate prompt engineering result aigenerated code meet quality standard fails fulfill intended function',
#  'organization must trust quality generative ai fully benefit potential',
#  'despite potential benefit danger unlikely ai make software developer obsolete',
#  'historical precedent show technological advancement consistently made developer productive without diminishing demand skill',
#  'generative ai may affect market lowend basic coding skill push entire profession focus innovation highervalue task',
#  'creative problemsolving skill developer remain high demand',
#  'rather resisting change brought generative ai developer embrace',
#  'prospect eliminating tedious task software development excite everyone',
#  'certain function may disappear serve incentive developer upskill focus area machine yet capable',
#  'highquality developer translate business requirement elegant performant software always demand',
#  'developer adapt skill ride wave generative ai thrive evolving software development landscape',
#  'conclusion generative ai potential revolutionize software development eliminating grunt work reinventing framework promoting generalist skill revolutionizing testing enhancing lowcodenocode development tool',
#  'however potential risk overtesting skill degradation trust deficit need addressed',
#  'although ai make software developer obsolete push profession towards highervalue task innovation',
#  'developer embrace change brought generative ai focus upskilling remain valuable evolving landscape']

# %%
website12 = 'https://www.ox.ac.uk/news/2023-09-25-generative-ai-could-transform-work-boosting-productivity-and-democratising'
class12 = 'field field-name-field-body field-type-text-with-summary field-label-hidden'
text12 = scrape_clean(website12, class12)
sentences.extend(text12)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe',
#  'adult social care supporting people live independently protect fundamental human right',
#  'generative ai offer many potential benefit opportunity adult social care',
#  'however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately',
#  'therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college',
#  'artificial intelligence offer many opportunity potential benefit adult social care',
#  'generative ai large language model llm power ai chatbots aid various task social care',
#  'however many activity social care directly touch people human right wellbeing',
#  'currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail',
#  'aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case',
#  'core focus would constitute responsible ethical use emerging technology',
#  'following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care',
#  'addition commits group engaging coproduction consultation process drawing people organisation social care',
#  'full statement endorsed twenty-three participating organisation beread',
#  'according recent global report business agree generative ai gen ai substantial impact industry',
#  'however despite fanfare adoption rate technology remained abysmally low business',
#  'three quarter surveyed company experimented gen ai lowly nine percent admitted adopted technology',
#  'based survey conducted mit technology review insight telecom company telstrathe reportcovered three hundred csuite executive vice president director across asiapacific america europe',
#  'report question participant company using plan use gen ai technology',
#  'addition gauging interest technology report also highlight barrier adoption gen ai business',
#  'readgenerative ai market projected reach one trillion two thousand and thirty-one',
#  'misconception easy run mature enterpriseready generative ai said stela solar inaugural director australia national artificial intelligence centre report',
#  'agreeing solars assessment brian prince founder ceo top ai tool say investing gen ai expensive',
#  'argues beyond software business likely need also invest training infrastructure upgrade ongoing maintenance',
#  'especially true small medium enterprise may find challenging allocate sufficient budget without guaranteed shortterm return',
#  'telstra survey showed skill training company culture major impediment adoption say prince',
#  'integrating ai existing workflow system complex',
#  'speaking experience paolo danese ceo storya say observed tangible disconnect theoretical allure gen ai practical reality faced business',
#  'divergence technology encompasses broader concern readiness infrastructure steep learning curve effective deployment ethical consideration surrounding ai use say danese',
#  'building sukhdeep sohal senior consultant glue affinity reply say business apprehension towards gen ai often traced back series strategic operational disconnect',
#  'belief crux issue lie alignment lack thereof ai initiative overarching business strategy',
#  'ai strategy perceived standalone experiment rather integral part business growth disconnect breed reluctance say sohal',
#  'additionally delivery ai foundation piecemeal rather holistically fails instil confidence technology comprehensive benefit',
#  'report highlighted evolving regulatory compliance data privacy environment leading nontechnological barrier rapid gen ai adoption business',
#  'danese agrees saying business navigating uncharted water need balance push digital transformation adhering strict privacy standard',
#  'according prince especially true sector like healthcare finance legal data sensitivity critical concern',
#  'burden compliance becomes significant deterrent say',
#  'read5 way make money generative ai',
#  'peter john alexander chief business officer meetkai highlight nontechnical factor business must take consideration',
#  'say company likely fear potential data breach ethical misuse high implementation usage cost unreliable output risk falling behind competitor',
#  'apprehension highlight need careful consideration benefit risk generative ai deployment alongside proactive measure address security compliance ethical operational challenge say alexander',
#  'according report seventy-eight percent business look gen ai competitive opportunity',
#  'many expect number function deploying gen ai double two thousand and twenty-four',
#  'term actual use sixty-five percent respondent say business actively considering new innovative way use gen ai unlock hidden opportunity data',
#  'doesnt surprise sohal',
#  'say gen ai aligned wellarticulated strategy fit best leverage predictive power data stream identified rigorous data audit',
#  'suggests analysis especially predictive analytics prime area application directly amplifies strategic decisionmaking capability',
#  'read42 percent uae company adopt ai business operation say study',
#  'alexander agrees saying ai excels rapidly analyzing vast amount data surface pattern making prediction uncovering actionable insight',
#  'say could include customer analytics identify trend segment financial analysis forecasting operation optimization',
#  'leveraging ai business make smarter datadriven decision much faster manual analysis say alexander',
#  'according report rather confined specific sector gen ai likely transform specific function across economy customer service',
#  'also point two thousand and twenty-three national bureau economic research working paper predicts gen ai customer service could raise productivity fourteen percent',
#  'generative ai prowess natural language understanding generation position linchpin customer service revolution offering personalized efficient engaging user experience say danese',
#  'alexander belief business must approach gen ai transformative business capability scattershot set project',
#  'readmeta roll new generative ai feature uae saudi',
#  'ultimately best fit gen ai depends company unique need available data strategic priority say alexander',
#  'company align ai initiative overarching business goal start focused experiment prove value scale success',
#  'ensure readiness maximize benefit sohal suggests organization seek use case depending level ai maturity',
#  'additionally recommends business also look industry precedent validate inform approach',
#  'integrative strategy promise yield tangible business value elevating gen ai technological experiment cornerstone enterprise capability say sohal',
#  'technology news clickhere',
#  'world software development emergence generative ai sparked excitement skepticism',
#  'predict ai render many software development skill obsolete others cautious potential impact',
#  '20year veteran field ceo company serving software developer keith pitt share insight potential benefit danger generative ai software development',
#  'one significant positive impact generative ai potential eliminate grunt work developer',
#  'developer often spend considerable amount time detail like syntax punctuation automated ai',
#  'instead poring manual searching code snippet developer describe desired outcome receive perfectly formatted code response',
#  'additionally large language model llm help identify typo punctuation mistake detail tedious developer',
#  'generative ai also potential reinvent software framework',
#  'framework like spring expressjs django already increased productivity abstracting mundane aspect software development',
#  'help gen ai framework enhance value creating boilerplate code automating repetitive task suggesting code optimization',
#  'ai also assist customizing framework component specific project',
#  'another significant change brought generative ai rise generalist developer',
#  'traditionally developer specialized specific language backend skill',
#  'however machine capable generating code language language proficiency may become le important',
#  'valuable skill machine replicate building user interface translating user requirement specification inventing new way support customer',
#  'shift put spotlight developer excel area',
#  'generative ai also hold great potential revolutionizing software testing',
#  'developer write code bot generate numerous test script quickly efficiently',
#  'according recent idc survey anticipated benefit generative ai software development software quality assurance security testing',
#  'disruption devops practice continuous integrationdeployment may lead testing specialist seeking new opportunity',
#  'lowcodenocode development tool already made software development accessible generative ai take next level',
#  'currently tool require individual piece together workflow whiteboard translating code',
#  'future developer able provide handdrawn sketch desired workflow ai model generate necessary code second',
#  'however essential recognize generative ai panacea',
#  'potential downside need considered',
#  'one concern risk overtesting',
#  'ai model capable generating test quickly possibility ending test necessary',
#  'overtesting slow project create bottleneck development pipeline',
#  'ai recommendation remove test could help address issue',
#  'skill degradation another potential danger associated generative ai',
#  'lazy developer may rely ai find shortcut leading bloated inefficient poorly performing code',
#  'reliance existing pattern data may limit innovative potential developer think outside box explore new solution',
#  'trust crucial come generative ai',
#  'quality data used train ai model significantly impact performance',
#  'poor quality data training shortcut inadequate prompt engineering result aigenerated code meet quality standard fails fulfill intended function',
#  'organization must trust quality generative ai fully benefit potential',
#  'despite potential benefit danger unlikely ai make software developer obsolete',
#  'historical precedent show technological advancement consistently made developer productive without diminishing demand skill',
#  'generative ai may affect market lowend basic coding skill push entire profession focus innovation highervalue task',
#  'creative problemsolving skill developer remain high demand',
#  'rather resisting change brought generative ai developer embrace',
#  'prospect eliminating tedious task software development excite everyone',
#  'certain function may disappear serve incentive developer upskill focus area machine yet capable',
#  'highquality developer translate business requirement elegant performant software always demand',
#  'developer adapt skill ride wave generative ai thrive evolving software development landscape',
#  'conclusion generative ai potential revolutionize software development eliminating grunt work reinventing framework promoting generalist skill revolutionizing testing enhancing lowcodenocode development tool',
#  'however potential risk overtesting skill degradation trust deficit need addressed',
#  'although ai make software developer obsolete push profession towards highervalue task innovation',
#  'developer embrace change brought generative ai focus upskilling remain valuable evolving landscape',
#  'ian goldinprofessor globalisation development oxford martin schooland report coauthor said generative ai dualedged sword offer enormous potential accelerate solution number world greatest challenge new health cure energy innovation',
#  'also could destroy job undermine democracy widen inequality division within society country',
#  'challenge develop regulatory framework guardrail required ensure benefit widely shared sustained',
#  'generative aioffers enormous potential accelerate solution number world greatest challengesbut also could destroy job undermine democracy widen inequality',
#  'professor ian goldin',
#  'contribution tounleashing ai citi investment bank oxford martin team explores opportunity challenge generative artificial intelligence found potential opportunity',
#  'dr pantelis koutroumpisdirector oxford martin programme technological economic change report coauthor said generative ai already shown impressive potential across range application recent month',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'beyond data better computing resource model excel fed highquality human generated input',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'dr pantelis koutroumpis',
#  'report also highlight series challenge including',
#  'report concludes world ai arm race country striving establish scientific technological dominance research output patenting']

# %%
website13 = 'https://www.cnbc.com/2024/03/30/fomo-drives-tech-heavyweights-to-invest-billions-in-generative-ai-.html'
class13 = 'ArticleBody-articleBody'
text13 = scrape_clean(website13, class13)
sentences.extend(text13)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe',
#  'adult social care supporting people live independently protect fundamental human right',
#  'generative ai offer many potential benefit opportunity adult social care',
#  'however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately',
#  'therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college',
#  'artificial intelligence offer many opportunity potential benefit adult social care',
#  'generative ai large language model llm power ai chatbots aid various task social care',
#  'however many activity social care directly touch people human right wellbeing',
#  'currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail',
#  'aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case',
#  'core focus would constitute responsible ethical use emerging technology',
#  'following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care',
#  'addition commits group engaging coproduction consultation process drawing people organisation social care',
#  'full statement endorsed twenty-three participating organisation beread',
#  'according recent global report business agree generative ai gen ai substantial impact industry',
#  'however despite fanfare adoption rate technology remained abysmally low business',
#  'three quarter surveyed company experimented gen ai lowly nine percent admitted adopted technology',
#  'based survey conducted mit technology review insight telecom company telstrathe reportcovered three hundred csuite executive vice president director across asiapacific america europe',
#  'report question participant company using plan use gen ai technology',
#  'addition gauging interest technology report also highlight barrier adoption gen ai business',
#  'readgenerative ai market projected reach one trillion two thousand and thirty-one',
#  'misconception easy run mature enterpriseready generative ai said stela solar inaugural director australia national artificial intelligence centre report',
#  'agreeing solars assessment brian prince founder ceo top ai tool say investing gen ai expensive',
#  'argues beyond software business likely need also invest training infrastructure upgrade ongoing maintenance',
#  'especially true small medium enterprise may find challenging allocate sufficient budget without guaranteed shortterm return',
#  'telstra survey showed skill training company culture major impediment adoption say prince',
#  'integrating ai existing workflow system complex',
#  'speaking experience paolo danese ceo storya say observed tangible disconnect theoretical allure gen ai practical reality faced business',
#  'divergence technology encompasses broader concern readiness infrastructure steep learning curve effective deployment ethical consideration surrounding ai use say danese',
#  'building sukhdeep sohal senior consultant glue affinity reply say business apprehension towards gen ai often traced back series strategic operational disconnect',
#  'belief crux issue lie alignment lack thereof ai initiative overarching business strategy',
#  'ai strategy perceived standalone experiment rather integral part business growth disconnect breed reluctance say sohal',
#  'additionally delivery ai foundation piecemeal rather holistically fails instil confidence technology comprehensive benefit',
#  'report highlighted evolving regulatory compliance data privacy environment leading nontechnological barrier rapid gen ai adoption business',
#  'danese agrees saying business navigating uncharted water need balance push digital transformation adhering strict privacy standard',
#  'according prince especially true sector like healthcare finance legal data sensitivity critical concern',
#  'burden compliance becomes significant deterrent say',
#  'read5 way make money generative ai',
#  'peter john alexander chief business officer meetkai highlight nontechnical factor business must take consideration',
#  'say company likely fear potential data breach ethical misuse high implementation usage cost unreliable output risk falling behind competitor',
#  'apprehension highlight need careful consideration benefit risk generative ai deployment alongside proactive measure address security compliance ethical operational challenge say alexander',
#  'according report seventy-eight percent business look gen ai competitive opportunity',
#  'many expect number function deploying gen ai double two thousand and twenty-four',
#  'term actual use sixty-five percent respondent say business actively considering new innovative way use gen ai unlock hidden opportunity data',
#  'doesnt surprise sohal',
#  'say gen ai aligned wellarticulated strategy fit best leverage predictive power data stream identified rigorous data audit',
#  'suggests analysis especially predictive analytics prime area application directly amplifies strategic decisionmaking capability',
#  'read42 percent uae company adopt ai business operation say study',
#  'alexander agrees saying ai excels rapidly analyzing vast amount data surface pattern making prediction uncovering actionable insight',
#  'say could include customer analytics identify trend segment financial analysis forecasting operation optimization',
#  'leveraging ai business make smarter datadriven decision much faster manual analysis say alexander',
#  'according report rather confined specific sector gen ai likely transform specific function across economy customer service',
#  'also point two thousand and twenty-three national bureau economic research working paper predicts gen ai customer service could raise productivity fourteen percent',
#  'generative ai prowess natural language understanding generation position linchpin customer service revolution offering personalized efficient engaging user experience say danese',
#  'alexander belief business must approach gen ai transformative business capability scattershot set project',
#  'readmeta roll new generative ai feature uae saudi',
#  'ultimately best fit gen ai depends company unique need available data strategic priority say alexander',
#  'company align ai initiative overarching business goal start focused experiment prove value scale success',
#  'ensure readiness maximize benefit sohal suggests organization seek use case depending level ai maturity',
#  'additionally recommends business also look industry precedent validate inform approach',
#  'integrative strategy promise yield tangible business value elevating gen ai technological experiment cornerstone enterprise capability say sohal',
#  'technology news clickhere',
#  'world software development emergence generative ai sparked excitement skepticism',
#  'predict ai render many software development skill obsolete others cautious potential impact',
#  '20year veteran field ceo company serving software developer keith pitt share insight potential benefit danger generative ai software development',
#  'one significant positive impact generative ai potential eliminate grunt work developer',
#  'developer often spend considerable amount time detail like syntax punctuation automated ai',
#  'instead poring manual searching code snippet developer describe desired outcome receive perfectly formatted code response',
#  'additionally large language model llm help identify typo punctuation mistake detail tedious developer',
#  'generative ai also potential reinvent software framework',
#  'framework like spring expressjs django already increased productivity abstracting mundane aspect software development',
#  'help gen ai framework enhance value creating boilerplate code automating repetitive task suggesting code optimization',
#  'ai also assist customizing framework component specific project',
#  'another significant change brought generative ai rise generalist developer',
#  'traditionally developer specialized specific language backend skill',
#  'however machine capable generating code language language proficiency may become le important',
#  'valuable skill machine replicate building user interface translating user requirement specification inventing new way support customer',
#  'shift put spotlight developer excel area',
#  'generative ai also hold great potential revolutionizing software testing',
#  'developer write code bot generate numerous test script quickly efficiently',
#  'according recent idc survey anticipated benefit generative ai software development software quality assurance security testing',
#  'disruption devops practice continuous integrationdeployment may lead testing specialist seeking new opportunity',
#  'lowcodenocode development tool already made software development accessible generative ai take next level',
#  'currently tool require individual piece together workflow whiteboard translating code',
#  'future developer able provide handdrawn sketch desired workflow ai model generate necessary code second',
#  'however essential recognize generative ai panacea',
#  'potential downside need considered',
#  'one concern risk overtesting',
#  'ai model capable generating test quickly possibility ending test necessary',
#  'overtesting slow project create bottleneck development pipeline',
#  'ai recommendation remove test could help address issue',
#  'skill degradation another potential danger associated generative ai',
#  'lazy developer may rely ai find shortcut leading bloated inefficient poorly performing code',
#  'reliance existing pattern data may limit innovative potential developer think outside box explore new solution',
#  'trust crucial come generative ai',
#  'quality data used train ai model significantly impact performance',
#  'poor quality data training shortcut inadequate prompt engineering result aigenerated code meet quality standard fails fulfill intended function',
#  'organization must trust quality generative ai fully benefit potential',
#  'despite potential benefit danger unlikely ai make software developer obsolete',
#  'historical precedent show technological advancement consistently made developer productive without diminishing demand skill',
#  'generative ai may affect market lowend basic coding skill push entire profession focus innovation highervalue task',
#  'creative problemsolving skill developer remain high demand',
#  'rather resisting change brought generative ai developer embrace',
#  'prospect eliminating tedious task software development excite everyone',
#  'certain function may disappear serve incentive developer upskill focus area machine yet capable',
#  'highquality developer translate business requirement elegant performant software always demand',
#  'developer adapt skill ride wave generative ai thrive evolving software development landscape',
#  'conclusion generative ai potential revolutionize software development eliminating grunt work reinventing framework promoting generalist skill revolutionizing testing enhancing lowcodenocode development tool',
#  'however potential risk overtesting skill degradation trust deficit need addressed',
#  'although ai make software developer obsolete push profession towards highervalue task innovation',
#  'developer embrace change brought generative ai focus upskilling remain valuable evolving landscape',
#  'ian goldinprofessor globalisation development oxford martin schooland report coauthor said generative ai dualedged sword offer enormous potential accelerate solution number world greatest challenge new health cure energy innovation',
#  'also could destroy job undermine democracy widen inequality division within society country',
#  'challenge develop regulatory framework guardrail required ensure benefit widely shared sustained',
#  'generative aioffers enormous potential accelerate solution number world greatest challengesbut also could destroy job undermine democracy widen inequality',
#  'professor ian goldin',
#  'contribution tounleashing ai citi investment bank oxford martin team explores opportunity challenge generative artificial intelligence found potential opportunity',
#  'dr pantelis koutroumpisdirector oxford martin programme technological economic change report coauthor said generative ai already shown impressive potential across range application recent month',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'beyond data better computing resource model excel fed highquality human generated input',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'dr pantelis koutroumpis',
#  'report also highlight series challenge including',
#  'report concludes world ai arm race country striving establish scientific technological dominance research output patenting',
#  'article',
#  'tech giant arent much acquiring day due mostly unfavorable regulatory environment',
#  'theyre finding way spend billion dollar next big thing',
#  'amazons275 billion investment artificial intelligence startup anthropic announced week itslargest venture dealand latest example ai gold rush thats prompting biggest tech company fling open wallet',
#  'anthropic developer behind ai model claude competes gpt frommicrosoftbacked openai andgooglesgemini',
#  'along withmetaandapple theyre racing integrate generative ai vast portfolio product feature ensure dont fall behind market thatspredicted top one trillionin revenue within decade',
#  'two thousand and twenty-three investor pumped two hundred and ninety-one billion combined nearly seven hundred generative ai deal increase two hundred and sixty value prior year according pitchbook',
#  'significant chunk money strategic came tech company rather venture capitalist institution',
#  'fred havemeyer head u ai software research macquarie said fear missing one factor driving decision',
#  'definitely dont want miss part ai ecosystem havemeyer said',
#  'definitely think there fomo marketplace',
#  'hefty investment necessary ai model notoriously expensive build train requiring thousand specialized chip date largely come fromnvidia',
#  'meta developing model calledllama said spending billion nvidias graphic processing unit one many company thats helped chipmakerbolsteryearoveryear revenue two hundred and fifty',
#  'whether going building investing route finite number company afford play market',
#  'addition developing chip nvidia emerged one silicon valley top investor taking stake number emerging ai company partly way make sure technology get widely deployed',
#  'similarly microsoft google amazon sometimes offer cloud credit part investment',
#  'amazonanthropic deal announced wednesday two company said theyll work closely together variety way',
#  'anthropic using amazon web service computing need well amazon chip',
#  'anthropics model distributed amazon aws customer',
#  'earlier month anthropic launchedclaude three powerful model one say let user upload photo chart document type unstructured data analysis answer',
#  'microsoft got business generative ai investing earlier putting1 billioninto openai two thousand and nineteen',
#  'size investment since swelled thirteen billion',
#  'microsoft heavily us openais model offer open source model azure cloud',
#  'alphabet playing part builder investor',
#  'company refocused much product development generative ai newly rebranded gemini model adding feature search document map elsewhere',
#  'last year googlecommittedto invest two billion anthropic previously confirming taken ten stake startup alongside large cloud contract two company',
#  'havemeyer said tech giant arent throwing money hype cycle investment ai startup align product road map',
#  'dont think frivolous said',
#  'havemeyer said alliance big cloud provider bring muchneeded cash startup also help sign customer',
#  'cloud company saying come u work platform native access latest greatest ai model also use infrastructure havemeyer said',
#  'also part much larger ecosystem play',
#  'seeing lot alliance appearing among hyperscalers substantial scale infrastructure deep pocket added',
#  'recent earnings call tech exec reiterated focus generative ai making clear investor spend money make money whether internal development investing startup',
#  'microsoft chief financial officer amy hood said last year company adjusting workforce toward aifirst work without adding material number people workforce',
#  'said microsoft continue prioritize investing ai thing thats going shape next decade',
#  'leader google apple amazon alsosuggested investorsthat theyre willing cut cost broadly across department order redirect funding toward ai effort',
#  'startup among beneficiary',
#  'microsoft taken stake mistral figure humane addition openai',
#  'company invested inflection ai startup essentially dissolved joined microsoft month',
#  'mistral open sourcefocused company us azure cloud offer service azure client',
#  'figure startup seeking build robot walk like human raised money microsoft openai nvidia wasvalued last monthat twenty-six billion',
#  'amazon biggest bet anthropic pouring total four billion far',
#  'company also invested open source ai platform developer hugging face',
#  'google investment include essential ai developing consumer ai program backed byamdand nvidia',
#  'alphabet nvidia also investor runway ml generative ai company known videoediting visual effect tool',
#  'others nvidias portfolio include mistral perplexity cohere',
#  'meanwhile many big tech company continue spend internally developing model',
#  'microsoft invested many technique underpinning generative ai microsoft research division',
#  'amazonreportedlyhas plan train bigger datahungry model even openais gpt4',
#  'apple researcher recently published detail work mm1a family small ai modelsthat take text visual input',
#  'apple different position peer doesnt sell cloud service',
#  'still tech giant reportedly looking ai partner including potentially google u andbaiduin china',
#  'apple representative declined comment ai partner',
#  'daniel newman ceo technology analysis firm futurum group said tech company get clever come investing ai',
#  'example openais investment microsoft included profit sharing nonprofit wing well credit use microsofts cloud service',
#  'microsofts deal inflection ai amounted expensive acquihire report putting total outlay at1 billion',
#  'part transaction microsofthiredinflection ai founder mustafa suleyman lead copilot ai initiative',
#  'think starting see creativity dealmaking said newman',
#  'respect amazon agreement anthropic said acquisition would lot harder investing',
#  'thats regulator across globe cracking big tech making difficult sizable acquisition',
#  'even investment attracting scrutiny',
#  'january federal trade commission announced willconduct extensive inquiryinto field biggest player ai including amazon alphabet microsoft anthropic openai',
#  'ftc chair lina khan described probe market inquiry investment partnership formed ai developer major cloud service provider',
#  'regulator authority order company file specific report answer question writing business',
#  'know regulator becoming increasingly focused traditional path closing acquisition newman said',
#  'right game access fundamental ip',
#  'watchai hype drive valuation higher']

# %%
website14 = 'https://www.unite.ai/beyond-generative-ai-building-a-comprehensive-and-scalable-digital-infrastructure/'
class14 = 'mvp-post-soc-out right relative'
text14 = scrape_clean(website14, class14)
sentences.extend(text14)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe',
#  'adult social care supporting people live independently protect fundamental human right',
#  'generative ai offer many potential benefit opportunity adult social care',
#  'however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately',
#  'therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college',
#  'artificial intelligence offer many opportunity potential benefit adult social care',
#  'generative ai large language model llm power ai chatbots aid various task social care',
#  'however many activity social care directly touch people human right wellbeing',
#  'currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail',
#  'aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case',
#  'core focus would constitute responsible ethical use emerging technology',
#  'following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care',
#  'addition commits group engaging coproduction consultation process drawing people organisation social care',
#  'full statement endorsed twenty-three participating organisation beread',
#  'according recent global report business agree generative ai gen ai substantial impact industry',
#  'however despite fanfare adoption rate technology remained abysmally low business',
#  'three quarter surveyed company experimented gen ai lowly nine percent admitted adopted technology',
#  'based survey conducted mit technology review insight telecom company telstrathe reportcovered three hundred csuite executive vice president director across asiapacific america europe',
#  'report question participant company using plan use gen ai technology',
#  'addition gauging interest technology report also highlight barrier adoption gen ai business',
#  'readgenerative ai market projected reach one trillion two thousand and thirty-one',
#  'misconception easy run mature enterpriseready generative ai said stela solar inaugural director australia national artificial intelligence centre report',
#  'agreeing solars assessment brian prince founder ceo top ai tool say investing gen ai expensive',
#  'argues beyond software business likely need also invest training infrastructure upgrade ongoing maintenance',
#  'especially true small medium enterprise may find challenging allocate sufficient budget without guaranteed shortterm return',
#  'telstra survey showed skill training company culture major impediment adoption say prince',
#  'integrating ai existing workflow system complex',
#  'speaking experience paolo danese ceo storya say observed tangible disconnect theoretical allure gen ai practical reality faced business',
#  'divergence technology encompasses broader concern readiness infrastructure steep learning curve effective deployment ethical consideration surrounding ai use say danese',
#  'building sukhdeep sohal senior consultant glue affinity reply say business apprehension towards gen ai often traced back series strategic operational disconnect',
#  'belief crux issue lie alignment lack thereof ai initiative overarching business strategy',
#  'ai strategy perceived standalone experiment rather integral part business growth disconnect breed reluctance say sohal',
#  'additionally delivery ai foundation piecemeal rather holistically fails instil confidence technology comprehensive benefit',
#  'report highlighted evolving regulatory compliance data privacy environment leading nontechnological barrier rapid gen ai adoption business',
#  'danese agrees saying business navigating uncharted water need balance push digital transformation adhering strict privacy standard',
#  'according prince especially true sector like healthcare finance legal data sensitivity critical concern',
#  'burden compliance becomes significant deterrent say',
#  'read5 way make money generative ai',
#  'peter john alexander chief business officer meetkai highlight nontechnical factor business must take consideration',
#  'say company likely fear potential data breach ethical misuse high implementation usage cost unreliable output risk falling behind competitor',
#  'apprehension highlight need careful consideration benefit risk generative ai deployment alongside proactive measure address security compliance ethical operational challenge say alexander',
#  'according report seventy-eight percent business look gen ai competitive opportunity',
#  'many expect number function deploying gen ai double two thousand and twenty-four',
#  'term actual use sixty-five percent respondent say business actively considering new innovative way use gen ai unlock hidden opportunity data',
#  'doesnt surprise sohal',
#  'say gen ai aligned wellarticulated strategy fit best leverage predictive power data stream identified rigorous data audit',
#  'suggests analysis especially predictive analytics prime area application directly amplifies strategic decisionmaking capability',
#  'read42 percent uae company adopt ai business operation say study',
#  'alexander agrees saying ai excels rapidly analyzing vast amount data surface pattern making prediction uncovering actionable insight',
#  'say could include customer analytics identify trend segment financial analysis forecasting operation optimization',
#  'leveraging ai business make smarter datadriven decision much faster manual analysis say alexander',
#  'according report rather confined specific sector gen ai likely transform specific function across economy customer service',
#  'also point two thousand and twenty-three national bureau economic research working paper predicts gen ai customer service could raise productivity fourteen percent',
#  'generative ai prowess natural language understanding generation position linchpin customer service revolution offering personalized efficient engaging user experience say danese',
#  'alexander belief business must approach gen ai transformative business capability scattershot set project',
#  'readmeta roll new generative ai feature uae saudi',
#  'ultimately best fit gen ai depends company unique need available data strategic priority say alexander',
#  'company align ai initiative overarching business goal start focused experiment prove value scale success',
#  'ensure readiness maximize benefit sohal suggests organization seek use case depending level ai maturity',
#  'additionally recommends business also look industry precedent validate inform approach',
#  'integrative strategy promise yield tangible business value elevating gen ai technological experiment cornerstone enterprise capability say sohal',
#  'technology news clickhere',
#  'world software development emergence generative ai sparked excitement skepticism',
#  'predict ai render many software development skill obsolete others cautious potential impact',
#  '20year veteran field ceo company serving software developer keith pitt share insight potential benefit danger generative ai software development',
#  'one significant positive impact generative ai potential eliminate grunt work developer',
#  'developer often spend considerable amount time detail like syntax punctuation automated ai',
#  'instead poring manual searching code snippet developer describe desired outcome receive perfectly formatted code response',
#  'additionally large language model llm help identify typo punctuation mistake detail tedious developer',
#  'generative ai also potential reinvent software framework',
#  'framework like spring expressjs django already increased productivity abstracting mundane aspect software development',
#  'help gen ai framework enhance value creating boilerplate code automating repetitive task suggesting code optimization',
#  'ai also assist customizing framework component specific project',
#  'another significant change brought generative ai rise generalist developer',
#  'traditionally developer specialized specific language backend skill',
#  'however machine capable generating code language language proficiency may become le important',
#  'valuable skill machine replicate building user interface translating user requirement specification inventing new way support customer',
#  'shift put spotlight developer excel area',
#  'generative ai also hold great potential revolutionizing software testing',
#  'developer write code bot generate numerous test script quickly efficiently',
#  'according recent idc survey anticipated benefit generative ai software development software quality assurance security testing',
#  'disruption devops practice continuous integrationdeployment may lead testing specialist seeking new opportunity',
#  'lowcodenocode development tool already made software development accessible generative ai take next level',
#  'currently tool require individual piece together workflow whiteboard translating code',
#  'future developer able provide handdrawn sketch desired workflow ai model generate necessary code second',
#  'however essential recognize generative ai panacea',
#  'potential downside need considered',
#  'one concern risk overtesting',
#  'ai model capable generating test quickly possibility ending test necessary',
#  'overtesting slow project create bottleneck development pipeline',
#  'ai recommendation remove test could help address issue',
#  'skill degradation another potential danger associated generative ai',
#  'lazy developer may rely ai find shortcut leading bloated inefficient poorly performing code',
#  'reliance existing pattern data may limit innovative potential developer think outside box explore new solution',
#  'trust crucial come generative ai',
#  'quality data used train ai model significantly impact performance',
#  'poor quality data training shortcut inadequate prompt engineering result aigenerated code meet quality standard fails fulfill intended function',
#  'organization must trust quality generative ai fully benefit potential',
#  'despite potential benefit danger unlikely ai make software developer obsolete',
#  'historical precedent show technological advancement consistently made developer productive without diminishing demand skill',
#  'generative ai may affect market lowend basic coding skill push entire profession focus innovation highervalue task',
#  'creative problemsolving skill developer remain high demand',
#  'rather resisting change brought generative ai developer embrace',
#  'prospect eliminating tedious task software development excite everyone',
#  'certain function may disappear serve incentive developer upskill focus area machine yet capable',
#  'highquality developer translate business requirement elegant performant software always demand',
#  'developer adapt skill ride wave generative ai thrive evolving software development landscape',
#  'conclusion generative ai potential revolutionize software development eliminating grunt work reinventing framework promoting generalist skill revolutionizing testing enhancing lowcodenocode development tool',
#  'however potential risk overtesting skill degradation trust deficit need addressed',
#  'although ai make software developer obsolete push profession towards highervalue task innovation',
#  'developer embrace change brought generative ai focus upskilling remain valuable evolving landscape',
#  'ian goldinprofessor globalisation development oxford martin schooland report coauthor said generative ai dualedged sword offer enormous potential accelerate solution number world greatest challenge new health cure energy innovation',
#  'also could destroy job undermine democracy widen inequality division within society country',
#  'challenge develop regulatory framework guardrail required ensure benefit widely shared sustained',
#  'generative aioffers enormous potential accelerate solution number world greatest challengesbut also could destroy job undermine democracy widen inequality',
#  'professor ian goldin',
#  'contribution tounleashing ai citi investment bank oxford martin team explores opportunity challenge generative artificial intelligence found potential opportunity',
#  'dr pantelis koutroumpisdirector oxford martin programme technological economic change report coauthor said generative ai already shown impressive potential across range application recent month',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'beyond data better computing resource model excel fed highquality human generated input',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'dr pantelis koutroumpis',
#  'report also highlight series challenge including',
#  'report concludes world ai arm race country striving establish scientific technological dominance research output patenting',
#  'article',
#  'tech giant arent much acquiring day due mostly unfavorable regulatory environment',
#  'theyre finding way spend billion dollar next big thing',
#  'amazons275 billion investment artificial intelligence startup anthropic announced week itslargest venture dealand latest example ai gold rush thats prompting biggest tech company fling open wallet',
#  'anthropic developer behind ai model claude competes gpt frommicrosoftbacked openai andgooglesgemini',
#  'along withmetaandapple theyre racing integrate generative ai vast portfolio product feature ensure dont fall behind market thatspredicted top one trillionin revenue within decade',
#  'two thousand and twenty-three investor pumped two hundred and ninety-one billion combined nearly seven hundred generative ai deal increase two hundred and sixty value prior year according pitchbook',
#  'significant chunk money strategic came tech company rather venture capitalist institution',
#  'fred havemeyer head u ai software research macquarie said fear missing one factor driving decision',
#  'definitely dont want miss part ai ecosystem havemeyer said',
#  'definitely think there fomo marketplace',
#  'hefty investment necessary ai model notoriously expensive build train requiring thousand specialized chip date largely come fromnvidia',
#  'meta developing model calledllama said spending billion nvidias graphic processing unit one many company thats helped chipmakerbolsteryearoveryear revenue two hundred and fifty',
#  'whether going building investing route finite number company afford play market',
#  'addition developing chip nvidia emerged one silicon valley top investor taking stake number emerging ai company partly way make sure technology get widely deployed',
#  'similarly microsoft google amazon sometimes offer cloud credit part investment',
#  'amazonanthropic deal announced wednesday two company said theyll work closely together variety way',
#  'anthropic using amazon web service computing need well amazon chip',
#  'anthropics model distributed amazon aws customer',
#  'earlier month anthropic launchedclaude three powerful model one say let user upload photo chart document type unstructured data analysis answer',
#  'microsoft got business generative ai investing earlier putting1 billioninto openai two thousand and nineteen',
#  'size investment since swelled thirteen billion',
#  'microsoft heavily us openais model offer open source model azure cloud',
#  'alphabet playing part builder investor',
#  'company refocused much product development generative ai newly rebranded gemini model adding feature search document map elsewhere',
#  'last year googlecommittedto invest two billion anthropic previously confirming taken ten stake startup alongside large cloud contract two company',
#  'havemeyer said tech giant arent throwing money hype cycle investment ai startup align product road map',
#  'dont think frivolous said',
#  'havemeyer said alliance big cloud provider bring muchneeded cash startup also help sign customer',
#  'cloud company saying come u work platform native access latest greatest ai model also use infrastructure havemeyer said',
#  'also part much larger ecosystem play',
#  'seeing lot alliance appearing among hyperscalers substantial scale infrastructure deep pocket added',
#  'recent earnings call tech exec reiterated focus generative ai making clear investor spend money make money whether internal development investing startup',
#  'microsoft chief financial officer amy hood said last year company adjusting workforce toward aifirst work without adding material number people workforce',
#  'said microsoft continue prioritize investing ai thing thats going shape next decade',
#  'leader google apple amazon alsosuggested investorsthat theyre willing cut cost broadly across department order redirect funding toward ai effort',
#  'startup among beneficiary',
#  'microsoft taken stake mistral figure humane addition openai',
#  'company invested inflection ai startup essentially dissolved joined microsoft month',
#  'mistral open sourcefocused company us azure cloud offer service azure client',
#  'figure startup seeking build robot walk like human raised money microsoft openai nvidia wasvalued last monthat twenty-six billion',
#  'amazon biggest bet anthropic pouring total four billion far',
#  'company also invested open source ai platform developer hugging face',
#  'google investment include essential ai developing consumer ai program backed byamdand nvidia',
#  'alphabet nvidia also investor runway ml generative ai company known videoediting visual effect tool',
#  'others nvidias portfolio include mistral perplexity cohere',
#  'meanwhile many big tech company continue spend internally developing model',
#  'microsoft invested many technique underpinning generative ai microsoft research division',
#  'amazonreportedlyhas plan train bigger datahungry model even openais gpt4',
#  'apple researcher recently published detail work mm1a family small ai modelsthat take text visual input',
#  'apple different position peer doesnt sell cloud service',
#  'still tech giant reportedly looking ai partner including potentially google u andbaiduin china',
#  'apple representative declined comment ai partner',
#  'daniel newman ceo technology analysis firm futurum group said tech company get clever come investing ai',
#  'example openais investment microsoft included profit sharing nonprofit wing well credit use microsofts cloud service',
#  'microsofts deal inflection ai amounted expensive acquihire report putting total outlay at1 billion',
#  'part transaction microsofthiredinflection ai founder mustafa suleyman lead copilot ai initiative',
#  'think starting see creativity dealmaking said newman',
#  'respect amazon agreement anthropic said acquisition would lot harder investing',
#  'thats regulator across globe cracking big tech making difficult sizable acquisition',
#  'even investment attracting scrutiny',
#  'january federal trade commission announced willconduct extensive inquiryinto field biggest player ai including amazon alphabet microsoft anthropic openai',
#  'ftc chair lina khan described probe market inquiry investment partnership formed ai developer major cloud service provider',
#  'regulator authority order company file specific report answer question writing business',
#  'know regulator becoming increasingly focused traditional path closing acquisition newman said',
#  'right game access fundamental ip',
#  'watchai hype drive valuation higher',
#  'hardly day go generative ai genai doesnt dominate business medium headline',
#  'last twelve month become ubiquitous business strategy organization across industry increasingly investing genai solution',
#  'google trend data visualizesgenais rise center business relevance since two thousand and twenty-two peaking june two thousand and twenty-three',
#  'certainly cant ignore transformative potential genai jumping right without adequate planning mean risking resource without guaranteed roi',
#  'custom genai solution expensive costing three hundred thousand dollar annuallyaccording webfx require deep technical expertise maintain',
#  'reality organization ready invest genai',
#  'leader may feel pressure buy hype taking genai operationally realistic mean huge drain resourcesaccording mckinsey business area stand benefit gen ai include sale marketing customer relation customer operation software development research development',
#  'using gen ai business function like finance hr may yield return',
#  'meantime hype wane genai becomes polished accessible way exist move innovation forward',
#  'prioritizing operational efficiency best way guarantee measurable roi',
#  'largest benefit likely come following use case',
#  'organization strong area already relevant business goal gen ai solution may necessary',
#  'here know make move',
#  'making major investment organization take pause ass internal structure identify gap data process inefficiency silo business function',
#  'along way knowing successful genai implementation relies quality data leader ask process digitized automated better organized maximize resource streamline operation optimize efficiency scalability',
#  'ceo ask following question ready right people aiming right generating revenue',
#  'consider amazon relentless focus customer experience philosophy embedded deeply operational ethos',
#  'approach led innovation like amazon walk technology leveraging ai machine learning reimagine retail',
#  'similarly business contemplating genai investment must start deep dive operational fabric identifying inefficiency area digital transformation catalyze revolutionary customer experience',
#  'clear understanding operational process improved consider give time back teamsfreeing space continued learning preparation genai',
#  'one option embrace citizen development allowing nontechnical employee build apps simply quickly bring efficiency scalability mundane task',
#  'using lowcode nocode tool general business user build custom apps without burdening team',
#  'team pepsi relied heavily lowcodenocode build deploy digital application inventory merchandising function saving company five hundred thousand first year without professional developer staffaccording venturebeat',
#  'intuitive visual interface prebuilt template draganddrop element solve seemingly complicated business problem required coding knowledge little day minimal reeducation',
#  'embracing approach allows team understand nuance digital engineering turn focus genai without sacrificing team productivity',
#  'creating infrastructure designed grow business top priority technology leader two thousand and twenty-four',
#  'inefficiency created first wave digital transformation need corrected',
#  'key maximizing return genai investment aim big start small grow incrementally following wellplanned roadmap',
#  'focusing first streamlining existing process gradually introducing genai one use case time organization ensure genai integrated amplifies rather disrupts operational effectiveness',
#  'truly capitalize transformative potential genai business must approach integration incrementally focusing longterm improvement',
#  'journey toward genai efficiency technical upgrade strategic initiative requires holistic view business process technical culture goal',
#  'embedding genai operation already optimized agility innovation company ensure investment enhances current capability also open new avenue growth differentiation',
#  'real return genai investment lie adoption technology sake strategic integration core business',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'mohan chief evangelist digital transformation atkissflow',
#  'mohan extensive experience implementing erp banking insurance solution apac usa europe leading large team deliver outstanding client outcome',
#  'recent focus leading client digital transformation journey',
#  'specializes conducting design thinking workshop identify problem evaluate benefit various innovative idea',
#  'engineer iit mba xlri',
#  'boil ocean ai',
#  'bridging digital divide role aipowered platformcentric strategy crafting futureready enterprise',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'ai hr navigating opportunity challenge',
#  'advancement ai mixed reality technology continued training development healthcare industry']

# %%
website15 = 'https://www.epam.com/about/newsroom/in-the-news/2024/for-creating-real-value-with-generative-ai-put-people-at-the-center'
class15 = 'text'
text15 = scrape_clean(website15, class15)
sentences.extend(text15)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe',
#  'adult social care supporting people live independently protect fundamental human right',
#  'generative ai offer many potential benefit opportunity adult social care',
#  'however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately',
#  'therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college',
#  'artificial intelligence offer many opportunity potential benefit adult social care',
#  'generative ai large language model llm power ai chatbots aid various task social care',
#  'however many activity social care directly touch people human right wellbeing',
#  'currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail',
#  'aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case',
#  'core focus would constitute responsible ethical use emerging technology',
#  'following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care',
#  'addition commits group engaging coproduction consultation process drawing people organisation social care',
#  'full statement endorsed twenty-three participating organisation beread',
#  'according recent global report business agree generative ai gen ai substantial impact industry',
#  'however despite fanfare adoption rate technology remained abysmally low business',
#  'three quarter surveyed company experimented gen ai lowly nine percent admitted adopted technology',
#  'based survey conducted mit technology review insight telecom company telstrathe reportcovered three hundred csuite executive vice president director across asiapacific america europe',
#  'report question participant company using plan use gen ai technology',
#  'addition gauging interest technology report also highlight barrier adoption gen ai business',
#  'readgenerative ai market projected reach one trillion two thousand and thirty-one',
#  'misconception easy run mature enterpriseready generative ai said stela solar inaugural director australia national artificial intelligence centre report',
#  'agreeing solars assessment brian prince founder ceo top ai tool say investing gen ai expensive',
#  'argues beyond software business likely need also invest training infrastructure upgrade ongoing maintenance',
#  'especially true small medium enterprise may find challenging allocate sufficient budget without guaranteed shortterm return',
#  'telstra survey showed skill training company culture major impediment adoption say prince',
#  'integrating ai existing workflow system complex',
#  'speaking experience paolo danese ceo storya say observed tangible disconnect theoretical allure gen ai practical reality faced business',
#  'divergence technology encompasses broader concern readiness infrastructure steep learning curve effective deployment ethical consideration surrounding ai use say danese',
#  'building sukhdeep sohal senior consultant glue affinity reply say business apprehension towards gen ai often traced back series strategic operational disconnect',
#  'belief crux issue lie alignment lack thereof ai initiative overarching business strategy',
#  'ai strategy perceived standalone experiment rather integral part business growth disconnect breed reluctance say sohal',
#  'additionally delivery ai foundation piecemeal rather holistically fails instil confidence technology comprehensive benefit',
#  'report highlighted evolving regulatory compliance data privacy environment leading nontechnological barrier rapid gen ai adoption business',
#  'danese agrees saying business navigating uncharted water need balance push digital transformation adhering strict privacy standard',
#  'according prince especially true sector like healthcare finance legal data sensitivity critical concern',
#  'burden compliance becomes significant deterrent say',
#  'read5 way make money generative ai',
#  'peter john alexander chief business officer meetkai highlight nontechnical factor business must take consideration',
#  'say company likely fear potential data breach ethical misuse high implementation usage cost unreliable output risk falling behind competitor',
#  'apprehension highlight need careful consideration benefit risk generative ai deployment alongside proactive measure address security compliance ethical operational challenge say alexander',
#  'according report seventy-eight percent business look gen ai competitive opportunity',
#  'many expect number function deploying gen ai double two thousand and twenty-four',
#  'term actual use sixty-five percent respondent say business actively considering new innovative way use gen ai unlock hidden opportunity data',
#  'doesnt surprise sohal',
#  'say gen ai aligned wellarticulated strategy fit best leverage predictive power data stream identified rigorous data audit',
#  'suggests analysis especially predictive analytics prime area application directly amplifies strategic decisionmaking capability',
#  'read42 percent uae company adopt ai business operation say study',
#  'alexander agrees saying ai excels rapidly analyzing vast amount data surface pattern making prediction uncovering actionable insight',
#  'say could include customer analytics identify trend segment financial analysis forecasting operation optimization',
#  'leveraging ai business make smarter datadriven decision much faster manual analysis say alexander',
#  'according report rather confined specific sector gen ai likely transform specific function across economy customer service',
#  'also point two thousand and twenty-three national bureau economic research working paper predicts gen ai customer service could raise productivity fourteen percent',
#  'generative ai prowess natural language understanding generation position linchpin customer service revolution offering personalized efficient engaging user experience say danese',
#  'alexander belief business must approach gen ai transformative business capability scattershot set project',
#  'readmeta roll new generative ai feature uae saudi',
#  'ultimately best fit gen ai depends company unique need available data strategic priority say alexander',
#  'company align ai initiative overarching business goal start focused experiment prove value scale success',
#  'ensure readiness maximize benefit sohal suggests organization seek use case depending level ai maturity',
#  'additionally recommends business also look industry precedent validate inform approach',
#  'integrative strategy promise yield tangible business value elevating gen ai technological experiment cornerstone enterprise capability say sohal',
#  'technology news clickhere',
#  'world software development emergence generative ai sparked excitement skepticism',
#  'predict ai render many software development skill obsolete others cautious potential impact',
#  '20year veteran field ceo company serving software developer keith pitt share insight potential benefit danger generative ai software development',
#  'one significant positive impact generative ai potential eliminate grunt work developer',
#  'developer often spend considerable amount time detail like syntax punctuation automated ai',
#  'instead poring manual searching code snippet developer describe desired outcome receive perfectly formatted code response',
#  'additionally large language model llm help identify typo punctuation mistake detail tedious developer',
#  'generative ai also potential reinvent software framework',
#  'framework like spring expressjs django already increased productivity abstracting mundane aspect software development',
#  'help gen ai framework enhance value creating boilerplate code automating repetitive task suggesting code optimization',
#  'ai also assist customizing framework component specific project',
#  'another significant change brought generative ai rise generalist developer',
#  'traditionally developer specialized specific language backend skill',
#  'however machine capable generating code language language proficiency may become le important',
#  'valuable skill machine replicate building user interface translating user requirement specification inventing new way support customer',
#  'shift put spotlight developer excel area',
#  'generative ai also hold great potential revolutionizing software testing',
#  'developer write code bot generate numerous test script quickly efficiently',
#  'according recent idc survey anticipated benefit generative ai software development software quality assurance security testing',
#  'disruption devops practice continuous integrationdeployment may lead testing specialist seeking new opportunity',
#  'lowcodenocode development tool already made software development accessible generative ai take next level',
#  'currently tool require individual piece together workflow whiteboard translating code',
#  'future developer able provide handdrawn sketch desired workflow ai model generate necessary code second',
#  'however essential recognize generative ai panacea',
#  'potential downside need considered',
#  'one concern risk overtesting',
#  'ai model capable generating test quickly possibility ending test necessary',
#  'overtesting slow project create bottleneck development pipeline',
#  'ai recommendation remove test could help address issue',
#  'skill degradation another potential danger associated generative ai',
#  'lazy developer may rely ai find shortcut leading bloated inefficient poorly performing code',
#  'reliance existing pattern data may limit innovative potential developer think outside box explore new solution',
#  'trust crucial come generative ai',
#  'quality data used train ai model significantly impact performance',
#  'poor quality data training shortcut inadequate prompt engineering result aigenerated code meet quality standard fails fulfill intended function',
#  'organization must trust quality generative ai fully benefit potential',
#  'despite potential benefit danger unlikely ai make software developer obsolete',
#  'historical precedent show technological advancement consistently made developer productive without diminishing demand skill',
#  'generative ai may affect market lowend basic coding skill push entire profession focus innovation highervalue task',
#  'creative problemsolving skill developer remain high demand',
#  'rather resisting change brought generative ai developer embrace',
#  'prospect eliminating tedious task software development excite everyone',
#  'certain function may disappear serve incentive developer upskill focus area machine yet capable',
#  'highquality developer translate business requirement elegant performant software always demand',
#  'developer adapt skill ride wave generative ai thrive evolving software development landscape',
#  'conclusion generative ai potential revolutionize software development eliminating grunt work reinventing framework promoting generalist skill revolutionizing testing enhancing lowcodenocode development tool',
#  'however potential risk overtesting skill degradation trust deficit need addressed',
#  'although ai make software developer obsolete push profession towards highervalue task innovation',
#  'developer embrace change brought generative ai focus upskilling remain valuable evolving landscape',
#  'ian goldinprofessor globalisation development oxford martin schooland report coauthor said generative ai dualedged sword offer enormous potential accelerate solution number world greatest challenge new health cure energy innovation',
#  'also could destroy job undermine democracy widen inequality division within society country',
#  'challenge develop regulatory framework guardrail required ensure benefit widely shared sustained',
#  'generative aioffers enormous potential accelerate solution number world greatest challengesbut also could destroy job undermine democracy widen inequality',
#  'professor ian goldin',
#  'contribution tounleashing ai citi investment bank oxford martin team explores opportunity challenge generative artificial intelligence found potential opportunity',
#  'dr pantelis koutroumpisdirector oxford martin programme technological economic change report coauthor said generative ai already shown impressive potential across range application recent month',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'beyond data better computing resource model excel fed highquality human generated input',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'dr pantelis koutroumpis',
#  'report also highlight series challenge including',
#  'report concludes world ai arm race country striving establish scientific technological dominance research output patenting',
#  'article',
#  'tech giant arent much acquiring day due mostly unfavorable regulatory environment',
#  'theyre finding way spend billion dollar next big thing',
#  'amazons275 billion investment artificial intelligence startup anthropic announced week itslargest venture dealand latest example ai gold rush thats prompting biggest tech company fling open wallet',
#  'anthropic developer behind ai model claude competes gpt frommicrosoftbacked openai andgooglesgemini',
#  'along withmetaandapple theyre racing integrate generative ai vast portfolio product feature ensure dont fall behind market thatspredicted top one trillionin revenue within decade',
#  'two thousand and twenty-three investor pumped two hundred and ninety-one billion combined nearly seven hundred generative ai deal increase two hundred and sixty value prior year according pitchbook',
#  'significant chunk money strategic came tech company rather venture capitalist institution',
#  'fred havemeyer head u ai software research macquarie said fear missing one factor driving decision',
#  'definitely dont want miss part ai ecosystem havemeyer said',
#  'definitely think there fomo marketplace',
#  'hefty investment necessary ai model notoriously expensive build train requiring thousand specialized chip date largely come fromnvidia',
#  'meta developing model calledllama said spending billion nvidias graphic processing unit one many company thats helped chipmakerbolsteryearoveryear revenue two hundred and fifty',
#  'whether going building investing route finite number company afford play market',
#  'addition developing chip nvidia emerged one silicon valley top investor taking stake number emerging ai company partly way make sure technology get widely deployed',
#  'similarly microsoft google amazon sometimes offer cloud credit part investment',
#  'amazonanthropic deal announced wednesday two company said theyll work closely together variety way',
#  'anthropic using amazon web service computing need well amazon chip',
#  'anthropics model distributed amazon aws customer',
#  'earlier month anthropic launchedclaude three powerful model one say let user upload photo chart document type unstructured data analysis answer',
#  'microsoft got business generative ai investing earlier putting1 billioninto openai two thousand and nineteen',
#  'size investment since swelled thirteen billion',
#  'microsoft heavily us openais model offer open source model azure cloud',
#  'alphabet playing part builder investor',
#  'company refocused much product development generative ai newly rebranded gemini model adding feature search document map elsewhere',
#  'last year googlecommittedto invest two billion anthropic previously confirming taken ten stake startup alongside large cloud contract two company',
#  'havemeyer said tech giant arent throwing money hype cycle investment ai startup align product road map',
#  'dont think frivolous said',
#  'havemeyer said alliance big cloud provider bring muchneeded cash startup also help sign customer',
#  'cloud company saying come u work platform native access latest greatest ai model also use infrastructure havemeyer said',
#  'also part much larger ecosystem play',
#  'seeing lot alliance appearing among hyperscalers substantial scale infrastructure deep pocket added',
#  'recent earnings call tech exec reiterated focus generative ai making clear investor spend money make money whether internal development investing startup',
#  'microsoft chief financial officer amy hood said last year company adjusting workforce toward aifirst work without adding material number people workforce',
#  'said microsoft continue prioritize investing ai thing thats going shape next decade',
#  'leader google apple amazon alsosuggested investorsthat theyre willing cut cost broadly across department order redirect funding toward ai effort',
#  'startup among beneficiary',
#  'microsoft taken stake mistral figure humane addition openai',
#  'company invested inflection ai startup essentially dissolved joined microsoft month',
#  'mistral open sourcefocused company us azure cloud offer service azure client',
#  'figure startup seeking build robot walk like human raised money microsoft openai nvidia wasvalued last monthat twenty-six billion',
#  'amazon biggest bet anthropic pouring total four billion far',
#  'company also invested open source ai platform developer hugging face',
#  'google investment include essential ai developing consumer ai program backed byamdand nvidia',
#  'alphabet nvidia also investor runway ml generative ai company known videoediting visual effect tool',
#  'others nvidias portfolio include mistral perplexity cohere',
#  'meanwhile many big tech company continue spend internally developing model',
#  'microsoft invested many technique underpinning generative ai microsoft research division',
#  'amazonreportedlyhas plan train bigger datahungry model even openais gpt4',
#  'apple researcher recently published detail work mm1a family small ai modelsthat take text visual input',
#  'apple different position peer doesnt sell cloud service',
#  'still tech giant reportedly looking ai partner including potentially google u andbaiduin china',
#  'apple representative declined comment ai partner',
#  'daniel newman ceo technology analysis firm futurum group said tech company get clever come investing ai',
#  'example openais investment microsoft included profit sharing nonprofit wing well credit use microsofts cloud service',
#  'microsofts deal inflection ai amounted expensive acquihire report putting total outlay at1 billion',
#  'part transaction microsofthiredinflection ai founder mustafa suleyman lead copilot ai initiative',
#  'think starting see creativity dealmaking said newman',
#  'respect amazon agreement anthropic said acquisition would lot harder investing',
#  'thats regulator across globe cracking big tech making difficult sizable acquisition',
#  'even investment attracting scrutiny',
#  'january federal trade commission announced willconduct extensive inquiryinto field biggest player ai including amazon alphabet microsoft anthropic openai',
#  'ftc chair lina khan described probe market inquiry investment partnership formed ai developer major cloud service provider',
#  'regulator authority order company file specific report answer question writing business',
#  'know regulator becoming increasingly focused traditional path closing acquisition newman said',
#  'right game access fundamental ip',
#  'watchai hype drive valuation higher',
#  'hardly day go generative ai genai doesnt dominate business medium headline',
#  'last twelve month become ubiquitous business strategy organization across industry increasingly investing genai solution',
#  'google trend data visualizesgenais rise center business relevance since two thousand and twenty-two peaking june two thousand and twenty-three',
#  'certainly cant ignore transformative potential genai jumping right without adequate planning mean risking resource without guaranteed roi',
#  'custom genai solution expensive costing three hundred thousand dollar annuallyaccording webfx require deep technical expertise maintain',
#  'reality organization ready invest genai',
#  'leader may feel pressure buy hype taking genai operationally realistic mean huge drain resourcesaccording mckinsey business area stand benefit gen ai include sale marketing customer relation customer operation software development research development',
#  'using gen ai business function like finance hr may yield return',
#  'meantime hype wane genai becomes polished accessible way exist move innovation forward',
#  'prioritizing operational efficiency best way guarantee measurable roi',
#  'largest benefit likely come following use case',
#  'organization strong area already relevant business goal gen ai solution may necessary',
#  'here know make move',
#  'making major investment organization take pause ass internal structure identify gap data process inefficiency silo business function',
#  'along way knowing successful genai implementation relies quality data leader ask process digitized automated better organized maximize resource streamline operation optimize efficiency scalability',
#  'ceo ask following question ready right people aiming right generating revenue',
#  'consider amazon relentless focus customer experience philosophy embedded deeply operational ethos',
#  'approach led innovation like amazon walk technology leveraging ai machine learning reimagine retail',
#  'similarly business contemplating genai investment must start deep dive operational fabric identifying inefficiency area digital transformation catalyze revolutionary customer experience',
#  'clear understanding operational process improved consider give time back teamsfreeing space continued learning preparation genai',
#  'one option embrace citizen development allowing nontechnical employee build apps simply quickly bring efficiency scalability mundane task',
#  'using lowcode nocode tool general business user build custom apps without burdening team',
#  'team pepsi relied heavily lowcodenocode build deploy digital application inventory merchandising function saving company five hundred thousand first year without professional developer staffaccording venturebeat',
#  'intuitive visual interface prebuilt template draganddrop element solve seemingly complicated business problem required coding knowledge little day minimal reeducation',
#  'embracing approach allows team understand nuance digital engineering turn focus genai without sacrificing team productivity',
#  'creating infrastructure designed grow business top priority technology leader two thousand and twenty-four',
#  'inefficiency created first wave digital transformation need corrected',
#  'key maximizing return genai investment aim big start small grow incrementally following wellplanned roadmap',
#  'focusing first streamlining existing process gradually introducing genai one use case time organization ensure genai integrated amplifies rather disrupts operational effectiveness',
#  'truly capitalize transformative potential genai business must approach integration incrementally focusing longterm improvement',
#  'journey toward genai efficiency technical upgrade strategic initiative requires holistic view business process technical culture goal',
#  'embedding genai operation already optimized agility innovation company ensure investment enhances current capability also open new avenue growth differentiation',
#  'real return genai investment lie adoption technology sake strategic integration core business',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'mohan chief evangelist digital transformation atkissflow',
#  'mohan extensive experience implementing erp banking insurance solution apac usa europe leading large team deliver outstanding client outcome',
#  'recent focus leading client digital transformation journey',
#  'specializes conducting design thinking workshop identify problem evaluate benefit various innovative idea',
#  'engineer iit mba xlri',
#  'boil ocean ai',
#  'bridging digital divide role aipowered platformcentric strategy crafting futureready enterprise',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'ai hr navigating opportunity challenge',
#  'advancement ai mixed reality technology continued training development healthcare industry',
#  'creating real value generative ai put people center',
#  'creating real value generative ai put people center',
#  'generative ai democratizes creative process anyone create text image presentation video music instant',
#  'however without human creativity little value',
#  'role human creative process',
#  'organization cleverly combine',
#  'creativity generating new valuable idea lead innovative solution problem',
#  'thats limited artist genius according mihaly csikszentmihalyi creator term flow author book creativity',
#  'argues creativity broad accessible human trait',
#  'creativity work exactly',
#  'important factor creativity deep human involvement',
#  'pattern lead creativity include suffering struggle like vincent van gogh dream isaac newton joy filmmaker david lynch practice transcendental meditation',
#  'typing smart prompt chatgpt show little involvement question extent result generative ai really called creative',
#  'however still essential question extent creativity actually important company',
#  'creativity make distinction impact',
#  'due generative ai flood aigenerated content way',
#  'meme deepfakes book amazon music video presentation audacity mail faq personal recommendation business chatbots code content creation',
#  'direct result democratization generative ai lowerquality output',
#  'read full articlehere',
#  'open dutch',
#  'learn epam revolutionizing future business power aihttpswwwepamcomservicesartificialintelligence',
#  'voor echte waarde creëren met generatieve ai stel de men centraal',
#  'generatieve ai democratiseert creatieve processen iedereen kan nu een handomdraai teksten afbeeldingen presentaties video muziek en meer creëren',
#  'zonder menselijke creativiteit heeft het echter weinig waarde',
#  'wat de rol van de men het creatieve proces',
#  'hoe kunnen organisaties beiden slim combineren',
#  'creativiteit gaat het genereren van nieuwe en waardevolle ideeën die leiden tot innovatieve oplossingen voor problemen',
#  'dat niet beperkt tot kunstenaars en genieën volgensmihaly csikszentmihalyi de bedenker van de term flow en schrijver van het boekcreativiteit',
#  'hij stelt dat creativiteit een brede en toegankelijke menselijke eigenschap',
#  'hoe werkt creativiteit precies',
#  'een belangrijke factor voor creativiteit diepe menselijke betrokkenheid',
#  'patronen die leiden tot creativiteit zijn bijvoorbeeld lijden en strijd zoals vincent van gogh dromen isaac newton en vreugde filmmaker david lynch die transcendentale meditatie beoefent',
#  'een slimme prompt intikken chatgpt toont weinig van deze betrokkenheid de vraag hoeverre de uitkomsten van generatieve ai dus echt creatief zijn te noemen',
#  'daar zit echter nog een essentiële vraag voor hoeverre creativiteit eigenlijk belangrijk voor bedrijven',
#  'creativiteit maakt onderscheid en impact',
#  'door generatieve ai er een stortvloed aan aigegenereerde content op komst',
#  'van meme deepfakesboeken op amazonenmuziekvideopresentatie van audacity tot mail faq persoonlijke aanbevelingen zakelijke chatbots code en contentcreatie',
#  'dit een direct gevolg van de democratisering van generative ai meer output van lagere kwaliteit',
#  'lee hier het volledige artikel',
#  'ontdek hoe epam een revolutie teweegbrengt de toekomst van het bedrijfsleven met de kracht van aihttpswwwepamcomservicesartificialintelligence',
#  'featured story']

# %%
website16 = 'https://www.reinsurancene.ws/50bn-opportunity-opportunity-arises-for-insurers-worldwide-from-genai-bain-company/'
class16 = 'pf-content'
text16 = scrape_clean(website16, class16)
sentences.extend(text16)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe',
#  'adult social care supporting people live independently protect fundamental human right',
#  'generative ai offer many potential benefit opportunity adult social care',
#  'however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately',
#  'therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college',
#  'artificial intelligence offer many opportunity potential benefit adult social care',
#  'generative ai large language model llm power ai chatbots aid various task social care',
#  'however many activity social care directly touch people human right wellbeing',
#  'currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail',
#  'aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case',
#  'core focus would constitute responsible ethical use emerging technology',
#  'following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care',
#  'addition commits group engaging coproduction consultation process drawing people organisation social care',
#  'full statement endorsed twenty-three participating organisation beread',
#  'according recent global report business agree generative ai gen ai substantial impact industry',
#  'however despite fanfare adoption rate technology remained abysmally low business',
#  'three quarter surveyed company experimented gen ai lowly nine percent admitted adopted technology',
#  'based survey conducted mit technology review insight telecom company telstrathe reportcovered three hundred csuite executive vice president director across asiapacific america europe',
#  'report question participant company using plan use gen ai technology',
#  'addition gauging interest technology report also highlight barrier adoption gen ai business',
#  'readgenerative ai market projected reach one trillion two thousand and thirty-one',
#  'misconception easy run mature enterpriseready generative ai said stela solar inaugural director australia national artificial intelligence centre report',
#  'agreeing solars assessment brian prince founder ceo top ai tool say investing gen ai expensive',
#  'argues beyond software business likely need also invest training infrastructure upgrade ongoing maintenance',
#  'especially true small medium enterprise may find challenging allocate sufficient budget without guaranteed shortterm return',
#  'telstra survey showed skill training company culture major impediment adoption say prince',
#  'integrating ai existing workflow system complex',
#  'speaking experience paolo danese ceo storya say observed tangible disconnect theoretical allure gen ai practical reality faced business',
#  'divergence technology encompasses broader concern readiness infrastructure steep learning curve effective deployment ethical consideration surrounding ai use say danese',
#  'building sukhdeep sohal senior consultant glue affinity reply say business apprehension towards gen ai often traced back series strategic operational disconnect',
#  'belief crux issue lie alignment lack thereof ai initiative overarching business strategy',
#  'ai strategy perceived standalone experiment rather integral part business growth disconnect breed reluctance say sohal',
#  'additionally delivery ai foundation piecemeal rather holistically fails instil confidence technology comprehensive benefit',
#  'report highlighted evolving regulatory compliance data privacy environment leading nontechnological barrier rapid gen ai adoption business',
#  'danese agrees saying business navigating uncharted water need balance push digital transformation adhering strict privacy standard',
#  'according prince especially true sector like healthcare finance legal data sensitivity critical concern',
#  'burden compliance becomes significant deterrent say',
#  'read5 way make money generative ai',
#  'peter john alexander chief business officer meetkai highlight nontechnical factor business must take consideration',
#  'say company likely fear potential data breach ethical misuse high implementation usage cost unreliable output risk falling behind competitor',
#  'apprehension highlight need careful consideration benefit risk generative ai deployment alongside proactive measure address security compliance ethical operational challenge say alexander',
#  'according report seventy-eight percent business look gen ai competitive opportunity',
#  'many expect number function deploying gen ai double two thousand and twenty-four',
#  'term actual use sixty-five percent respondent say business actively considering new innovative way use gen ai unlock hidden opportunity data',
#  'doesnt surprise sohal',
#  'say gen ai aligned wellarticulated strategy fit best leverage predictive power data stream identified rigorous data audit',
#  'suggests analysis especially predictive analytics prime area application directly amplifies strategic decisionmaking capability',
#  'read42 percent uae company adopt ai business operation say study',
#  'alexander agrees saying ai excels rapidly analyzing vast amount data surface pattern making prediction uncovering actionable insight',
#  'say could include customer analytics identify trend segment financial analysis forecasting operation optimization',
#  'leveraging ai business make smarter datadriven decision much faster manual analysis say alexander',
#  'according report rather confined specific sector gen ai likely transform specific function across economy customer service',
#  'also point two thousand and twenty-three national bureau economic research working paper predicts gen ai customer service could raise productivity fourteen percent',
#  'generative ai prowess natural language understanding generation position linchpin customer service revolution offering personalized efficient engaging user experience say danese',
#  'alexander belief business must approach gen ai transformative business capability scattershot set project',
#  'readmeta roll new generative ai feature uae saudi',
#  'ultimately best fit gen ai depends company unique need available data strategic priority say alexander',
#  'company align ai initiative overarching business goal start focused experiment prove value scale success',
#  'ensure readiness maximize benefit sohal suggests organization seek use case depending level ai maturity',
#  'additionally recommends business also look industry precedent validate inform approach',
#  'integrative strategy promise yield tangible business value elevating gen ai technological experiment cornerstone enterprise capability say sohal',
#  'technology news clickhere',
#  'world software development emergence generative ai sparked excitement skepticism',
#  'predict ai render many software development skill obsolete others cautious potential impact',
#  '20year veteran field ceo company serving software developer keith pitt share insight potential benefit danger generative ai software development',
#  'one significant positive impact generative ai potential eliminate grunt work developer',
#  'developer often spend considerable amount time detail like syntax punctuation automated ai',
#  'instead poring manual searching code snippet developer describe desired outcome receive perfectly formatted code response',
#  'additionally large language model llm help identify typo punctuation mistake detail tedious developer',
#  'generative ai also potential reinvent software framework',
#  'framework like spring expressjs django already increased productivity abstracting mundane aspect software development',
#  'help gen ai framework enhance value creating boilerplate code automating repetitive task suggesting code optimization',
#  'ai also assist customizing framework component specific project',
#  'another significant change brought generative ai rise generalist developer',
#  'traditionally developer specialized specific language backend skill',
#  'however machine capable generating code language language proficiency may become le important',
#  'valuable skill machine replicate building user interface translating user requirement specification inventing new way support customer',
#  'shift put spotlight developer excel area',
#  'generative ai also hold great potential revolutionizing software testing',
#  'developer write code bot generate numerous test script quickly efficiently',
#  'according recent idc survey anticipated benefit generative ai software development software quality assurance security testing',
#  'disruption devops practice continuous integrationdeployment may lead testing specialist seeking new opportunity',
#  'lowcodenocode development tool already made software development accessible generative ai take next level',
#  'currently tool require individual piece together workflow whiteboard translating code',
#  'future developer able provide handdrawn sketch desired workflow ai model generate necessary code second',
#  'however essential recognize generative ai panacea',
#  'potential downside need considered',
#  'one concern risk overtesting',
#  'ai model capable generating test quickly possibility ending test necessary',
#  'overtesting slow project create bottleneck development pipeline',
#  'ai recommendation remove test could help address issue',
#  'skill degradation another potential danger associated generative ai',
#  'lazy developer may rely ai find shortcut leading bloated inefficient poorly performing code',
#  'reliance existing pattern data may limit innovative potential developer think outside box explore new solution',
#  'trust crucial come generative ai',
#  'quality data used train ai model significantly impact performance',
#  'poor quality data training shortcut inadequate prompt engineering result aigenerated code meet quality standard fails fulfill intended function',
#  'organization must trust quality generative ai fully benefit potential',
#  'despite potential benefit danger unlikely ai make software developer obsolete',
#  'historical precedent show technological advancement consistently made developer productive without diminishing demand skill',
#  'generative ai may affect market lowend basic coding skill push entire profession focus innovation highervalue task',
#  'creative problemsolving skill developer remain high demand',
#  'rather resisting change brought generative ai developer embrace',
#  'prospect eliminating tedious task software development excite everyone',
#  'certain function may disappear serve incentive developer upskill focus area machine yet capable',
#  'highquality developer translate business requirement elegant performant software always demand',
#  'developer adapt skill ride wave generative ai thrive evolving software development landscape',
#  'conclusion generative ai potential revolutionize software development eliminating grunt work reinventing framework promoting generalist skill revolutionizing testing enhancing lowcodenocode development tool',
#  'however potential risk overtesting skill degradation trust deficit need addressed',
#  'although ai make software developer obsolete push profession towards highervalue task innovation',
#  'developer embrace change brought generative ai focus upskilling remain valuable evolving landscape',
#  'ian goldinprofessor globalisation development oxford martin schooland report coauthor said generative ai dualedged sword offer enormous potential accelerate solution number world greatest challenge new health cure energy innovation',
#  'also could destroy job undermine democracy widen inequality division within society country',
#  'challenge develop regulatory framework guardrail required ensure benefit widely shared sustained',
#  'generative aioffers enormous potential accelerate solution number world greatest challengesbut also could destroy job undermine democracy widen inequality',
#  'professor ian goldin',
#  'contribution tounleashing ai citi investment bank oxford martin team explores opportunity challenge generative artificial intelligence found potential opportunity',
#  'dr pantelis koutroumpisdirector oxford martin programme technological economic change report coauthor said generative ai already shown impressive potential across range application recent month',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'beyond data better computing resource model excel fed highquality human generated input',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'dr pantelis koutroumpis',
#  'report also highlight series challenge including',
#  'report concludes world ai arm race country striving establish scientific technological dominance research output patenting',
#  'article',
#  'tech giant arent much acquiring day due mostly unfavorable regulatory environment',
#  'theyre finding way spend billion dollar next big thing',
#  'amazons275 billion investment artificial intelligence startup anthropic announced week itslargest venture dealand latest example ai gold rush thats prompting biggest tech company fling open wallet',
#  'anthropic developer behind ai model claude competes gpt frommicrosoftbacked openai andgooglesgemini',
#  'along withmetaandapple theyre racing integrate generative ai vast portfolio product feature ensure dont fall behind market thatspredicted top one trillionin revenue within decade',
#  'two thousand and twenty-three investor pumped two hundred and ninety-one billion combined nearly seven hundred generative ai deal increase two hundred and sixty value prior year according pitchbook',
#  'significant chunk money strategic came tech company rather venture capitalist institution',
#  'fred havemeyer head u ai software research macquarie said fear missing one factor driving decision',
#  'definitely dont want miss part ai ecosystem havemeyer said',
#  'definitely think there fomo marketplace',
#  'hefty investment necessary ai model notoriously expensive build train requiring thousand specialized chip date largely come fromnvidia',
#  'meta developing model calledllama said spending billion nvidias graphic processing unit one many company thats helped chipmakerbolsteryearoveryear revenue two hundred and fifty',
#  'whether going building investing route finite number company afford play market',
#  'addition developing chip nvidia emerged one silicon valley top investor taking stake number emerging ai company partly way make sure technology get widely deployed',
#  'similarly microsoft google amazon sometimes offer cloud credit part investment',
#  'amazonanthropic deal announced wednesday two company said theyll work closely together variety way',
#  'anthropic using amazon web service computing need well amazon chip',
#  'anthropics model distributed amazon aws customer',
#  'earlier month anthropic launchedclaude three powerful model one say let user upload photo chart document type unstructured data analysis answer',
#  'microsoft got business generative ai investing earlier putting1 billioninto openai two thousand and nineteen',
#  'size investment since swelled thirteen billion',
#  'microsoft heavily us openais model offer open source model azure cloud',
#  'alphabet playing part builder investor',
#  'company refocused much product development generative ai newly rebranded gemini model adding feature search document map elsewhere',
#  'last year googlecommittedto invest two billion anthropic previously confirming taken ten stake startup alongside large cloud contract two company',
#  'havemeyer said tech giant arent throwing money hype cycle investment ai startup align product road map',
#  'dont think frivolous said',
#  'havemeyer said alliance big cloud provider bring muchneeded cash startup also help sign customer',
#  'cloud company saying come u work platform native access latest greatest ai model also use infrastructure havemeyer said',
#  'also part much larger ecosystem play',
#  'seeing lot alliance appearing among hyperscalers substantial scale infrastructure deep pocket added',
#  'recent earnings call tech exec reiterated focus generative ai making clear investor spend money make money whether internal development investing startup',
#  'microsoft chief financial officer amy hood said last year company adjusting workforce toward aifirst work without adding material number people workforce',
#  'said microsoft continue prioritize investing ai thing thats going shape next decade',
#  'leader google apple amazon alsosuggested investorsthat theyre willing cut cost broadly across department order redirect funding toward ai effort',
#  'startup among beneficiary',
#  'microsoft taken stake mistral figure humane addition openai',
#  'company invested inflection ai startup essentially dissolved joined microsoft month',
#  'mistral open sourcefocused company us azure cloud offer service azure client',
#  'figure startup seeking build robot walk like human raised money microsoft openai nvidia wasvalued last monthat twenty-six billion',
#  'amazon biggest bet anthropic pouring total four billion far',
#  'company also invested open source ai platform developer hugging face',
#  'google investment include essential ai developing consumer ai program backed byamdand nvidia',
#  'alphabet nvidia also investor runway ml generative ai company known videoediting visual effect tool',
#  'others nvidias portfolio include mistral perplexity cohere',
#  'meanwhile many big tech company continue spend internally developing model',
#  'microsoft invested many technique underpinning generative ai microsoft research division',
#  'amazonreportedlyhas plan train bigger datahungry model even openais gpt4',
#  'apple researcher recently published detail work mm1a family small ai modelsthat take text visual input',
#  'apple different position peer doesnt sell cloud service',
#  'still tech giant reportedly looking ai partner including potentially google u andbaiduin china',
#  'apple representative declined comment ai partner',
#  'daniel newman ceo technology analysis firm futurum group said tech company get clever come investing ai',
#  'example openais investment microsoft included profit sharing nonprofit wing well credit use microsofts cloud service',
#  'microsofts deal inflection ai amounted expensive acquihire report putting total outlay at1 billion',
#  'part transaction microsofthiredinflection ai founder mustafa suleyman lead copilot ai initiative',
#  'think starting see creativity dealmaking said newman',
#  'respect amazon agreement anthropic said acquisition would lot harder investing',
#  'thats regulator across globe cracking big tech making difficult sizable acquisition',
#  'even investment attracting scrutiny',
#  'january federal trade commission announced willconduct extensive inquiryinto field biggest player ai including amazon alphabet microsoft anthropic openai',
#  'ftc chair lina khan described probe market inquiry investment partnership formed ai developer major cloud service provider',
#  'regulator authority order company file specific report answer question writing business',
#  'know regulator becoming increasingly focused traditional path closing acquisition newman said',
#  'right game access fundamental ip',
#  'watchai hype drive valuation higher',
#  'hardly day go generative ai genai doesnt dominate business medium headline',
#  'last twelve month become ubiquitous business strategy organization across industry increasingly investing genai solution',
#  'google trend data visualizesgenais rise center business relevance since two thousand and twenty-two peaking june two thousand and twenty-three',
#  'certainly cant ignore transformative potential genai jumping right without adequate planning mean risking resource without guaranteed roi',
#  'custom genai solution expensive costing three hundred thousand dollar annuallyaccording webfx require deep technical expertise maintain',
#  'reality organization ready invest genai',
#  'leader may feel pressure buy hype taking genai operationally realistic mean huge drain resourcesaccording mckinsey business area stand benefit gen ai include sale marketing customer relation customer operation software development research development',
#  'using gen ai business function like finance hr may yield return',
#  'meantime hype wane genai becomes polished accessible way exist move innovation forward',
#  'prioritizing operational efficiency best way guarantee measurable roi',
#  'largest benefit likely come following use case',
#  'organization strong area already relevant business goal gen ai solution may necessary',
#  'here know make move',
#  'making major investment organization take pause ass internal structure identify gap data process inefficiency silo business function',
#  'along way knowing successful genai implementation relies quality data leader ask process digitized automated better organized maximize resource streamline operation optimize efficiency scalability',
#  'ceo ask following question ready right people aiming right generating revenue',
#  'consider amazon relentless focus customer experience philosophy embedded deeply operational ethos',
#  'approach led innovation like amazon walk technology leveraging ai machine learning reimagine retail',
#  'similarly business contemplating genai investment must start deep dive operational fabric identifying inefficiency area digital transformation catalyze revolutionary customer experience',
#  'clear understanding operational process improved consider give time back teamsfreeing space continued learning preparation genai',
#  'one option embrace citizen development allowing nontechnical employee build apps simply quickly bring efficiency scalability mundane task',
#  'using lowcode nocode tool general business user build custom apps without burdening team',
#  'team pepsi relied heavily lowcodenocode build deploy digital application inventory merchandising function saving company five hundred thousand first year without professional developer staffaccording venturebeat',
#  'intuitive visual interface prebuilt template draganddrop element solve seemingly complicated business problem required coding knowledge little day minimal reeducation',
#  'embracing approach allows team understand nuance digital engineering turn focus genai without sacrificing team productivity',
#  'creating infrastructure designed grow business top priority technology leader two thousand and twenty-four',
#  'inefficiency created first wave digital transformation need corrected',
#  'key maximizing return genai investment aim big start small grow incrementally following wellplanned roadmap',
#  'focusing first streamlining existing process gradually introducing genai one use case time organization ensure genai integrated amplifies rather disrupts operational effectiveness',
#  'truly capitalize transformative potential genai business must approach integration incrementally focusing longterm improvement',
#  'journey toward genai efficiency technical upgrade strategic initiative requires holistic view business process technical culture goal',
#  'embedding genai operation already optimized agility innovation company ensure investment enhances current capability also open new avenue growth differentiation',
#  'real return genai investment lie adoption technology sake strategic integration core business',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'mohan chief evangelist digital transformation atkissflow',
#  'mohan extensive experience implementing erp banking insurance solution apac usa europe leading large team deliver outstanding client outcome',
#  'recent focus leading client digital transformation journey',
#  'specializes conducting design thinking workshop identify problem evaluate benefit various innovative idea',
#  'engineer iit mba xlri',
#  'boil ocean ai',
#  'bridging digital divide role aipowered platformcentric strategy crafting futureready enterprise',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'ai hr navigating opportunity challenge',
#  'advancement ai mixed reality technology continued training development healthcare industry',
#  'creating real value generative ai put people center',
#  'creating real value generative ai put people center',
#  'generative ai democratizes creative process anyone create text image presentation video music instant',
#  'however without human creativity little value',
#  'role human creative process',
#  'organization cleverly combine',
#  'creativity generating new valuable idea lead innovative solution problem',
#  'thats limited artist genius according mihaly csikszentmihalyi creator term flow author book creativity',
#  'argues creativity broad accessible human trait',
#  'creativity work exactly',
#  'important factor creativity deep human involvement',
#  'pattern lead creativity include suffering struggle like vincent van gogh dream isaac newton joy filmmaker david lynch practice transcendental meditation',
#  'typing smart prompt chatgpt show little involvement question extent result generative ai really called creative',
#  'however still essential question extent creativity actually important company',
#  'creativity make distinction impact',
#  'due generative ai flood aigenerated content way',
#  'meme deepfakes book amazon music video presentation audacity mail faq personal recommendation business chatbots code content creation',
#  'direct result democratization generative ai lowerquality output',
#  'read full articlehere',
#  'open dutch',
#  'learn epam revolutionizing future business power aihttpswwwepamcomservicesartificialintelligence',
#  'voor echte waarde creëren met generatieve ai stel de men centraal',
#  'generatieve ai democratiseert creatieve processen iedereen kan nu een handomdraai teksten afbeeldingen presentaties video muziek en meer creëren',
#  'zonder menselijke creativiteit heeft het echter weinig waarde',
#  'wat de rol van de men het creatieve proces',
#  'hoe kunnen organisaties beiden slim combineren',
#  'creativiteit gaat het genereren van nieuwe en waardevolle ideeën die leiden tot innovatieve oplossingen voor problemen',
#  'dat niet beperkt tot kunstenaars en genieën volgensmihaly csikszentmihalyi de bedenker van de term flow en schrijver van het boekcreativiteit',
#  'hij stelt dat creativiteit een brede en toegankelijke menselijke eigenschap',
#  'hoe werkt creativiteit precies',
#  'een belangrijke factor voor creativiteit diepe menselijke betrokkenheid',
#  'patronen die leiden tot creativiteit zijn bijvoorbeeld lijden en strijd zoals vincent van gogh dromen isaac newton en vreugde filmmaker david lynch die transcendentale meditatie beoefent',
#  'een slimme prompt intikken chatgpt toont weinig van deze betrokkenheid de vraag hoeverre de uitkomsten van generatieve ai dus echt creatief zijn te noemen',
#  'daar zit echter nog een essentiële vraag voor hoeverre creativiteit eigenlijk belangrijk voor bedrijven',
#  'creativiteit maakt onderscheid en impact',
#  'door generatieve ai er een stortvloed aan aigegenereerde content op komst',
#  'van meme deepfakesboeken op amazonenmuziekvideopresentatie van audacity tot mail faq persoonlijke aanbevelingen zakelijke chatbots code en contentcreatie',
#  'dit een direct gevolg van de democratisering van generative ai meer output van lagere kwaliteit',
#  'lee hier het volledige artikel',
#  'ontdek hoe epam een revolutie teweegbrengt de toekomst van het bedrijfsleven met de kracht van aihttpswwwepamcomservicesartificialintelligence',
#  'featured story',
#  'according global consultancy bain company insurance organisation across globe a50 billionfinancial opportunity generative ai genai harness technology way could boost revenue much twenty well cut cost fifteen',
#  'new report released firm reveals leveraging genai insurance distribution potential yield than50 billionin annual economic benefit company across sector',
#  'bhavimehta global lead ai financial service bain commented insurer benefit due generative ai come three route',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'moreover bain company noted genai permeates insurance company operation early initiative suggesting technology transform distribution four way including',
#  'meanwhile bains analysis also highlight several key risk area emerging insurer developing use genai include hallucination data provenance misinformation toxicity intellectual property ownership',
#  'sean oneill leader bains global insurance practice said nascent technology risk',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'however genai continuing develop evolve bain urge insurer take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor well ensuring delivery team crossfunctional designing operating model adaptable']

# %%
website17 = 'https://finance.yahoo.com/news/openai-makes-chatgpts-accessible-without-171737585.html?guccounter=1&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAAG5mu38jctSM9NyGRQWT0zmFdhgRGK_08M2n9GoZ3gG7IkHCE7-6tHVj5lUUdDzuVzKsj8GW1UJwaO9S4b99ompBG2BAZB4w9t83yyfhakzi9CW_TW4Oue0TDL95YO6IF0syszLJwwJnTkppnxu5JzZ6erc8_Npf4SFfhSVCRIVl'
class17 = 'caas-content-wrapper'
text17 = scrape_clean(website17, class17)
sentences.extend(text17)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe',
#  'adult social care supporting people live independently protect fundamental human right',
#  'generative ai offer many potential benefit opportunity adult social care',
#  'however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately',
#  'therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college',
#  'artificial intelligence offer many opportunity potential benefit adult social care',
#  'generative ai large language model llm power ai chatbots aid various task social care',
#  'however many activity social care directly touch people human right wellbeing',
#  'currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail',
#  'aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case',
#  'core focus would constitute responsible ethical use emerging technology',
#  'following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care',
#  'addition commits group engaging coproduction consultation process drawing people organisation social care',
#  'full statement endorsed twenty-three participating organisation beread',
#  'according recent global report business agree generative ai gen ai substantial impact industry',
#  'however despite fanfare adoption rate technology remained abysmally low business',
#  'three quarter surveyed company experimented gen ai lowly nine percent admitted adopted technology',
#  'based survey conducted mit technology review insight telecom company telstrathe reportcovered three hundred csuite executive vice president director across asiapacific america europe',
#  'report question participant company using plan use gen ai technology',
#  'addition gauging interest technology report also highlight barrier adoption gen ai business',
#  'readgenerative ai market projected reach one trillion two thousand and thirty-one',
#  'misconception easy run mature enterpriseready generative ai said stela solar inaugural director australia national artificial intelligence centre report',
#  'agreeing solars assessment brian prince founder ceo top ai tool say investing gen ai expensive',
#  'argues beyond software business likely need also invest training infrastructure upgrade ongoing maintenance',
#  'especially true small medium enterprise may find challenging allocate sufficient budget without guaranteed shortterm return',
#  'telstra survey showed skill training company culture major impediment adoption say prince',
#  'integrating ai existing workflow system complex',
#  'speaking experience paolo danese ceo storya say observed tangible disconnect theoretical allure gen ai practical reality faced business',
#  'divergence technology encompasses broader concern readiness infrastructure steep learning curve effective deployment ethical consideration surrounding ai use say danese',
#  'building sukhdeep sohal senior consultant glue affinity reply say business apprehension towards gen ai often traced back series strategic operational disconnect',
#  'belief crux issue lie alignment lack thereof ai initiative overarching business strategy',
#  'ai strategy perceived standalone experiment rather integral part business growth disconnect breed reluctance say sohal',
#  'additionally delivery ai foundation piecemeal rather holistically fails instil confidence technology comprehensive benefit',
#  'report highlighted evolving regulatory compliance data privacy environment leading nontechnological barrier rapid gen ai adoption business',
#  'danese agrees saying business navigating uncharted water need balance push digital transformation adhering strict privacy standard',
#  'according prince especially true sector like healthcare finance legal data sensitivity critical concern',
#  'burden compliance becomes significant deterrent say',
#  'read5 way make money generative ai',
#  'peter john alexander chief business officer meetkai highlight nontechnical factor business must take consideration',
#  'say company likely fear potential data breach ethical misuse high implementation usage cost unreliable output risk falling behind competitor',
#  'apprehension highlight need careful consideration benefit risk generative ai deployment alongside proactive measure address security compliance ethical operational challenge say alexander',
#  'according report seventy-eight percent business look gen ai competitive opportunity',
#  'many expect number function deploying gen ai double two thousand and twenty-four',
#  'term actual use sixty-five percent respondent say business actively considering new innovative way use gen ai unlock hidden opportunity data',
#  'doesnt surprise sohal',
#  'say gen ai aligned wellarticulated strategy fit best leverage predictive power data stream identified rigorous data audit',
#  'suggests analysis especially predictive analytics prime area application directly amplifies strategic decisionmaking capability',
#  'read42 percent uae company adopt ai business operation say study',
#  'alexander agrees saying ai excels rapidly analyzing vast amount data surface pattern making prediction uncovering actionable insight',
#  'say could include customer analytics identify trend segment financial analysis forecasting operation optimization',
#  'leveraging ai business make smarter datadriven decision much faster manual analysis say alexander',
#  'according report rather confined specific sector gen ai likely transform specific function across economy customer service',
#  'also point two thousand and twenty-three national bureau economic research working paper predicts gen ai customer service could raise productivity fourteen percent',
#  'generative ai prowess natural language understanding generation position linchpin customer service revolution offering personalized efficient engaging user experience say danese',
#  'alexander belief business must approach gen ai transformative business capability scattershot set project',
#  'readmeta roll new generative ai feature uae saudi',
#  'ultimately best fit gen ai depends company unique need available data strategic priority say alexander',
#  'company align ai initiative overarching business goal start focused experiment prove value scale success',
#  'ensure readiness maximize benefit sohal suggests organization seek use case depending level ai maturity',
#  'additionally recommends business also look industry precedent validate inform approach',
#  'integrative strategy promise yield tangible business value elevating gen ai technological experiment cornerstone enterprise capability say sohal',
#  'technology news clickhere',
#  'world software development emergence generative ai sparked excitement skepticism',
#  'predict ai render many software development skill obsolete others cautious potential impact',
#  '20year veteran field ceo company serving software developer keith pitt share insight potential benefit danger generative ai software development',
#  'one significant positive impact generative ai potential eliminate grunt work developer',
#  'developer often spend considerable amount time detail like syntax punctuation automated ai',
#  'instead poring manual searching code snippet developer describe desired outcome receive perfectly formatted code response',
#  'additionally large language model llm help identify typo punctuation mistake detail tedious developer',
#  'generative ai also potential reinvent software framework',
#  'framework like spring expressjs django already increased productivity abstracting mundane aspect software development',
#  'help gen ai framework enhance value creating boilerplate code automating repetitive task suggesting code optimization',
#  'ai also assist customizing framework component specific project',
#  'another significant change brought generative ai rise generalist developer',
#  'traditionally developer specialized specific language backend skill',
#  'however machine capable generating code language language proficiency may become le important',
#  'valuable skill machine replicate building user interface translating user requirement specification inventing new way support customer',
#  'shift put spotlight developer excel area',
#  'generative ai also hold great potential revolutionizing software testing',
#  'developer write code bot generate numerous test script quickly efficiently',
#  'according recent idc survey anticipated benefit generative ai software development software quality assurance security testing',
#  'disruption devops practice continuous integrationdeployment may lead testing specialist seeking new opportunity',
#  'lowcodenocode development tool already made software development accessible generative ai take next level',
#  'currently tool require individual piece together workflow whiteboard translating code',
#  'future developer able provide handdrawn sketch desired workflow ai model generate necessary code second',
#  'however essential recognize generative ai panacea',
#  'potential downside need considered',
#  'one concern risk overtesting',
#  'ai model capable generating test quickly possibility ending test necessary',
#  'overtesting slow project create bottleneck development pipeline',
#  'ai recommendation remove test could help address issue',
#  'skill degradation another potential danger associated generative ai',
#  'lazy developer may rely ai find shortcut leading bloated inefficient poorly performing code',
#  'reliance existing pattern data may limit innovative potential developer think outside box explore new solution',
#  'trust crucial come generative ai',
#  'quality data used train ai model significantly impact performance',
#  'poor quality data training shortcut inadequate prompt engineering result aigenerated code meet quality standard fails fulfill intended function',
#  'organization must trust quality generative ai fully benefit potential',
#  'despite potential benefit danger unlikely ai make software developer obsolete',
#  'historical precedent show technological advancement consistently made developer productive without diminishing demand skill',
#  'generative ai may affect market lowend basic coding skill push entire profession focus innovation highervalue task',
#  'creative problemsolving skill developer remain high demand',
#  'rather resisting change brought generative ai developer embrace',
#  'prospect eliminating tedious task software development excite everyone',
#  'certain function may disappear serve incentive developer upskill focus area machine yet capable',
#  'highquality developer translate business requirement elegant performant software always demand',
#  'developer adapt skill ride wave generative ai thrive evolving software development landscape',
#  'conclusion generative ai potential revolutionize software development eliminating grunt work reinventing framework promoting generalist skill revolutionizing testing enhancing lowcodenocode development tool',
#  'however potential risk overtesting skill degradation trust deficit need addressed',
#  'although ai make software developer obsolete push profession towards highervalue task innovation',
#  'developer embrace change brought generative ai focus upskilling remain valuable evolving landscape',
#  'ian goldinprofessor globalisation development oxford martin schooland report coauthor said generative ai dualedged sword offer enormous potential accelerate solution number world greatest challenge new health cure energy innovation',
#  'also could destroy job undermine democracy widen inequality division within society country',
#  'challenge develop regulatory framework guardrail required ensure benefit widely shared sustained',
#  'generative aioffers enormous potential accelerate solution number world greatest challengesbut also could destroy job undermine democracy widen inequality',
#  'professor ian goldin',
#  'contribution tounleashing ai citi investment bank oxford martin team explores opportunity challenge generative artificial intelligence found potential opportunity',
#  'dr pantelis koutroumpisdirector oxford martin programme technological economic change report coauthor said generative ai already shown impressive potential across range application recent month',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'beyond data better computing resource model excel fed highquality human generated input',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'dr pantelis koutroumpis',
#  'report also highlight series challenge including',
#  'report concludes world ai arm race country striving establish scientific technological dominance research output patenting',
#  'article',
#  'tech giant arent much acquiring day due mostly unfavorable regulatory environment',
#  'theyre finding way spend billion dollar next big thing',
#  'amazons275 billion investment artificial intelligence startup anthropic announced week itslargest venture dealand latest example ai gold rush thats prompting biggest tech company fling open wallet',
#  'anthropic developer behind ai model claude competes gpt frommicrosoftbacked openai andgooglesgemini',
#  'along withmetaandapple theyre racing integrate generative ai vast portfolio product feature ensure dont fall behind market thatspredicted top one trillionin revenue within decade',
#  'two thousand and twenty-three investor pumped two hundred and ninety-one billion combined nearly seven hundred generative ai deal increase two hundred and sixty value prior year according pitchbook',
#  'significant chunk money strategic came tech company rather venture capitalist institution',
#  'fred havemeyer head u ai software research macquarie said fear missing one factor driving decision',
#  'definitely dont want miss part ai ecosystem havemeyer said',
#  'definitely think there fomo marketplace',
#  'hefty investment necessary ai model notoriously expensive build train requiring thousand specialized chip date largely come fromnvidia',
#  'meta developing model calledllama said spending billion nvidias graphic processing unit one many company thats helped chipmakerbolsteryearoveryear revenue two hundred and fifty',
#  'whether going building investing route finite number company afford play market',
#  'addition developing chip nvidia emerged one silicon valley top investor taking stake number emerging ai company partly way make sure technology get widely deployed',
#  'similarly microsoft google amazon sometimes offer cloud credit part investment',
#  'amazonanthropic deal announced wednesday two company said theyll work closely together variety way',
#  'anthropic using amazon web service computing need well amazon chip',
#  'anthropics model distributed amazon aws customer',
#  'earlier month anthropic launchedclaude three powerful model one say let user upload photo chart document type unstructured data analysis answer',
#  'microsoft got business generative ai investing earlier putting1 billioninto openai two thousand and nineteen',
#  'size investment since swelled thirteen billion',
#  'microsoft heavily us openais model offer open source model azure cloud',
#  'alphabet playing part builder investor',
#  'company refocused much product development generative ai newly rebranded gemini model adding feature search document map elsewhere',
#  'last year googlecommittedto invest two billion anthropic previously confirming taken ten stake startup alongside large cloud contract two company',
#  'havemeyer said tech giant arent throwing money hype cycle investment ai startup align product road map',
#  'dont think frivolous said',
#  'havemeyer said alliance big cloud provider bring muchneeded cash startup also help sign customer',
#  'cloud company saying come u work platform native access latest greatest ai model also use infrastructure havemeyer said',
#  'also part much larger ecosystem play',
#  'seeing lot alliance appearing among hyperscalers substantial scale infrastructure deep pocket added',
#  'recent earnings call tech exec reiterated focus generative ai making clear investor spend money make money whether internal development investing startup',
#  'microsoft chief financial officer amy hood said last year company adjusting workforce toward aifirst work without adding material number people workforce',
#  'said microsoft continue prioritize investing ai thing thats going shape next decade',
#  'leader google apple amazon alsosuggested investorsthat theyre willing cut cost broadly across department order redirect funding toward ai effort',
#  'startup among beneficiary',
#  'microsoft taken stake mistral figure humane addition openai',
#  'company invested inflection ai startup essentially dissolved joined microsoft month',
#  'mistral open sourcefocused company us azure cloud offer service azure client',
#  'figure startup seeking build robot walk like human raised money microsoft openai nvidia wasvalued last monthat twenty-six billion',
#  'amazon biggest bet anthropic pouring total four billion far',
#  'company also invested open source ai platform developer hugging face',
#  'google investment include essential ai developing consumer ai program backed byamdand nvidia',
#  'alphabet nvidia also investor runway ml generative ai company known videoediting visual effect tool',
#  'others nvidias portfolio include mistral perplexity cohere',
#  'meanwhile many big tech company continue spend internally developing model',
#  'microsoft invested many technique underpinning generative ai microsoft research division',
#  'amazonreportedlyhas plan train bigger datahungry model even openais gpt4',
#  'apple researcher recently published detail work mm1a family small ai modelsthat take text visual input',
#  'apple different position peer doesnt sell cloud service',
#  'still tech giant reportedly looking ai partner including potentially google u andbaiduin china',
#  'apple representative declined comment ai partner',
#  'daniel newman ceo technology analysis firm futurum group said tech company get clever come investing ai',
#  'example openais investment microsoft included profit sharing nonprofit wing well credit use microsofts cloud service',
#  'microsofts deal inflection ai amounted expensive acquihire report putting total outlay at1 billion',
#  'part transaction microsofthiredinflection ai founder mustafa suleyman lead copilot ai initiative',
#  'think starting see creativity dealmaking said newman',
#  'respect amazon agreement anthropic said acquisition would lot harder investing',
#  'thats regulator across globe cracking big tech making difficult sizable acquisition',
#  'even investment attracting scrutiny',
#  'january federal trade commission announced willconduct extensive inquiryinto field biggest player ai including amazon alphabet microsoft anthropic openai',
#  'ftc chair lina khan described probe market inquiry investment partnership formed ai developer major cloud service provider',
#  'regulator authority order company file specific report answer question writing business',
#  'know regulator becoming increasingly focused traditional path closing acquisition newman said',
#  'right game access fundamental ip',
#  'watchai hype drive valuation higher',
#  'hardly day go generative ai genai doesnt dominate business medium headline',
#  'last twelve month become ubiquitous business strategy organization across industry increasingly investing genai solution',
#  'google trend data visualizesgenais rise center business relevance since two thousand and twenty-two peaking june two thousand and twenty-three',
#  'certainly cant ignore transformative potential genai jumping right without adequate planning mean risking resource without guaranteed roi',
#  'custom genai solution expensive costing three hundred thousand dollar annuallyaccording webfx require deep technical expertise maintain',
#  'reality organization ready invest genai',
#  'leader may feel pressure buy hype taking genai operationally realistic mean huge drain resourcesaccording mckinsey business area stand benefit gen ai include sale marketing customer relation customer operation software development research development',
#  'using gen ai business function like finance hr may yield return',
#  'meantime hype wane genai becomes polished accessible way exist move innovation forward',
#  'prioritizing operational efficiency best way guarantee measurable roi',
#  'largest benefit likely come following use case',
#  'organization strong area already relevant business goal gen ai solution may necessary',
#  'here know make move',
#  'making major investment organization take pause ass internal structure identify gap data process inefficiency silo business function',
#  'along way knowing successful genai implementation relies quality data leader ask process digitized automated better organized maximize resource streamline operation optimize efficiency scalability',
#  'ceo ask following question ready right people aiming right generating revenue',
#  'consider amazon relentless focus customer experience philosophy embedded deeply operational ethos',
#  'approach led innovation like amazon walk technology leveraging ai machine learning reimagine retail',
#  'similarly business contemplating genai investment must start deep dive operational fabric identifying inefficiency area digital transformation catalyze revolutionary customer experience',
#  'clear understanding operational process improved consider give time back teamsfreeing space continued learning preparation genai',
#  'one option embrace citizen development allowing nontechnical employee build apps simply quickly bring efficiency scalability mundane task',
#  'using lowcode nocode tool general business user build custom apps without burdening team',
#  'team pepsi relied heavily lowcodenocode build deploy digital application inventory merchandising function saving company five hundred thousand first year without professional developer staffaccording venturebeat',
#  'intuitive visual interface prebuilt template draganddrop element solve seemingly complicated business problem required coding knowledge little day minimal reeducation',
#  'embracing approach allows team understand nuance digital engineering turn focus genai without sacrificing team productivity',
#  'creating infrastructure designed grow business top priority technology leader two thousand and twenty-four',
#  'inefficiency created first wave digital transformation need corrected',
#  'key maximizing return genai investment aim big start small grow incrementally following wellplanned roadmap',
#  'focusing first streamlining existing process gradually introducing genai one use case time organization ensure genai integrated amplifies rather disrupts operational effectiveness',
#  'truly capitalize transformative potential genai business must approach integration incrementally focusing longterm improvement',
#  'journey toward genai efficiency technical upgrade strategic initiative requires holistic view business process technical culture goal',
#  'embedding genai operation already optimized agility innovation company ensure investment enhances current capability also open new avenue growth differentiation',
#  'real return genai investment lie adoption technology sake strategic integration core business',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'mohan chief evangelist digital transformation atkissflow',
#  'mohan extensive experience implementing erp banking insurance solution apac usa europe leading large team deliver outstanding client outcome',
#  'recent focus leading client digital transformation journey',
#  'specializes conducting design thinking workshop identify problem evaluate benefit various innovative idea',
#  'engineer iit mba xlri',
#  'boil ocean ai',
#  'bridging digital divide role aipowered platformcentric strategy crafting futureready enterprise',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'ai hr navigating opportunity challenge',
#  'advancement ai mixed reality technology continued training development healthcare industry',
#  'creating real value generative ai put people center',
#  'creating real value generative ai put people center',
#  'generative ai democratizes creative process anyone create text image presentation video music instant',
#  'however without human creativity little value',
#  'role human creative process',
#  'organization cleverly combine',
#  'creativity generating new valuable idea lead innovative solution problem',
#  'thats limited artist genius according mihaly csikszentmihalyi creator term flow author book creativity',
#  'argues creativity broad accessible human trait',
#  'creativity work exactly',
#  'important factor creativity deep human involvement',
#  'pattern lead creativity include suffering struggle like vincent van gogh dream isaac newton joy filmmaker david lynch practice transcendental meditation',
#  'typing smart prompt chatgpt show little involvement question extent result generative ai really called creative',
#  'however still essential question extent creativity actually important company',
#  'creativity make distinction impact',
#  'due generative ai flood aigenerated content way',
#  'meme deepfakes book amazon music video presentation audacity mail faq personal recommendation business chatbots code content creation',
#  'direct result democratization generative ai lowerquality output',
#  'read full articlehere',
#  'open dutch',
#  'learn epam revolutionizing future business power aihttpswwwepamcomservicesartificialintelligence',
#  'voor echte waarde creëren met generatieve ai stel de men centraal',
#  'generatieve ai democratiseert creatieve processen iedereen kan nu een handomdraai teksten afbeeldingen presentaties video muziek en meer creëren',
#  'zonder menselijke creativiteit heeft het echter weinig waarde',
#  'wat de rol van de men het creatieve proces',
#  'hoe kunnen organisaties beiden slim combineren',
#  'creativiteit gaat het genereren van nieuwe en waardevolle ideeën die leiden tot innovatieve oplossingen voor problemen',
#  'dat niet beperkt tot kunstenaars en genieën volgensmihaly csikszentmihalyi de bedenker van de term flow en schrijver van het boekcreativiteit',
#  'hij stelt dat creativiteit een brede en toegankelijke menselijke eigenschap',
#  'hoe werkt creativiteit precies',
#  'een belangrijke factor voor creativiteit diepe menselijke betrokkenheid',
#  'patronen die leiden tot creativiteit zijn bijvoorbeeld lijden en strijd zoals vincent van gogh dromen isaac newton en vreugde filmmaker david lynch die transcendentale meditatie beoefent',
#  'een slimme prompt intikken chatgpt toont weinig van deze betrokkenheid de vraag hoeverre de uitkomsten van generatieve ai dus echt creatief zijn te noemen',
#  'daar zit echter nog een essentiële vraag voor hoeverre creativiteit eigenlijk belangrijk voor bedrijven',
#  'creativiteit maakt onderscheid en impact',
#  'door generatieve ai er een stortvloed aan aigegenereerde content op komst',
#  'van meme deepfakesboeken op amazonenmuziekvideopresentatie van audacity tot mail faq persoonlijke aanbevelingen zakelijke chatbots code en contentcreatie',
#  'dit een direct gevolg van de democratisering van generative ai meer output van lagere kwaliteit',
#  'lee hier het volledige artikel',
#  'ontdek hoe epam een revolutie teweegbrengt de toekomst van het bedrijfsleven met de kracht van aihttpswwwepamcomservicesartificialintelligence',
#  'featured story',
#  'according global consultancy bain company insurance organisation across globe a50 billionfinancial opportunity generative ai genai harness technology way could boost revenue much twenty well cut cost fifteen',
#  'new report released firm reveals leveraging genai insurance distribution potential yield than50 billionin annual economic benefit company across sector',
#  'bhavimehta global lead ai financial service bain commented insurer benefit due generative ai come three route',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'moreover bain company noted genai permeates insurance company operation early initiative suggesting technology transform distribution four way including',
#  'meanwhile bains analysis also highlight several key risk area emerging insurer developing use genai include hallucination data provenance misinformation toxicity intellectual property ownership',
#  'sean oneill leader bains global insurance practice said nascent technology risk',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'however genai continuing develop evolve bain urge insurer take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor well ensuring delivery team crossfunctional designing operating model adaptable',
#  'reuters openai start allowing user access freetouse chatgpt generative ai chatbot without needing sign service beginning monday microsoftbacked startup said monday',
#  'chatgpt kickstarted genai boom late two thousand and twenty-two mimic human conversation perform task creating summary long text writing poem even generating idea theme party',
#  'san franciscobased company said gradually roll feature make ai accessible anyone curious capability',
#  'popular service set record fastestgrowing user base seen growth slow since may two thousand and twenty-three traffic peaked eighteen billion web visit according data analytics firm similarweb',
#  'openai said introduced additional content safeguard user accessing chatgpt without signing blocking prompt generation wider range category',
#  'specify category',
#  'apart free version chatgpt direct access internet openai also offer paid version individual team user enterprise',
#  'company also said may use content provided user help improve largelanguage model said user turn feature',
#  'move come month billionaire entrepreneur elon musk sued openai ceo sam altman saying abandoned startup original mission develop artificial intelligence benefit humanity profit',
#  'reporting arsheeya bajwa bengaluru anna tong san francisco krystal hu new york editing tasim zahid']

# %%
website18 = 'https://www.euractiv.com/section/artificial-intelligence/infographic/generative-ai-puts-trust-in-the-news-media-to-the-test/'
class18 = 'ea-article-body-content'
text18 = scrape_clean(website18, class18)
sentences.extend(text18)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe',
#  'adult social care supporting people live independently protect fundamental human right',
#  'generative ai offer many potential benefit opportunity adult social care',
#  'however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately',
#  'therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college',
#  'artificial intelligence offer many opportunity potential benefit adult social care',
#  'generative ai large language model llm power ai chatbots aid various task social care',
#  'however many activity social care directly touch people human right wellbeing',
#  'currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail',
#  'aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case',
#  'core focus would constitute responsible ethical use emerging technology',
#  'following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care',
#  'addition commits group engaging coproduction consultation process drawing people organisation social care',
#  'full statement endorsed twenty-three participating organisation beread',
#  'according recent global report business agree generative ai gen ai substantial impact industry',
#  'however despite fanfare adoption rate technology remained abysmally low business',
#  'three quarter surveyed company experimented gen ai lowly nine percent admitted adopted technology',
#  'based survey conducted mit technology review insight telecom company telstrathe reportcovered three hundred csuite executive vice president director across asiapacific america europe',
#  'report question participant company using plan use gen ai technology',
#  'addition gauging interest technology report also highlight barrier adoption gen ai business',
#  'readgenerative ai market projected reach one trillion two thousand and thirty-one',
#  'misconception easy run mature enterpriseready generative ai said stela solar inaugural director australia national artificial intelligence centre report',
#  'agreeing solars assessment brian prince founder ceo top ai tool say investing gen ai expensive',
#  'argues beyond software business likely need also invest training infrastructure upgrade ongoing maintenance',
#  'especially true small medium enterprise may find challenging allocate sufficient budget without guaranteed shortterm return',
#  'telstra survey showed skill training company culture major impediment adoption say prince',
#  'integrating ai existing workflow system complex',
#  'speaking experience paolo danese ceo storya say observed tangible disconnect theoretical allure gen ai practical reality faced business',
#  'divergence technology encompasses broader concern readiness infrastructure steep learning curve effective deployment ethical consideration surrounding ai use say danese',
#  'building sukhdeep sohal senior consultant glue affinity reply say business apprehension towards gen ai often traced back series strategic operational disconnect',
#  'belief crux issue lie alignment lack thereof ai initiative overarching business strategy',
#  'ai strategy perceived standalone experiment rather integral part business growth disconnect breed reluctance say sohal',
#  'additionally delivery ai foundation piecemeal rather holistically fails instil confidence technology comprehensive benefit',
#  'report highlighted evolving regulatory compliance data privacy environment leading nontechnological barrier rapid gen ai adoption business',
#  'danese agrees saying business navigating uncharted water need balance push digital transformation adhering strict privacy standard',
#  'according prince especially true sector like healthcare finance legal data sensitivity critical concern',
#  'burden compliance becomes significant deterrent say',
#  'read5 way make money generative ai',
#  'peter john alexander chief business officer meetkai highlight nontechnical factor business must take consideration',
#  'say company likely fear potential data breach ethical misuse high implementation usage cost unreliable output risk falling behind competitor',
#  'apprehension highlight need careful consideration benefit risk generative ai deployment alongside proactive measure address security compliance ethical operational challenge say alexander',
#  'according report seventy-eight percent business look gen ai competitive opportunity',
#  'many expect number function deploying gen ai double two thousand and twenty-four',
#  'term actual use sixty-five percent respondent say business actively considering new innovative way use gen ai unlock hidden opportunity data',
#  'doesnt surprise sohal',
#  'say gen ai aligned wellarticulated strategy fit best leverage predictive power data stream identified rigorous data audit',
#  'suggests analysis especially predictive analytics prime area application directly amplifies strategic decisionmaking capability',
#  'read42 percent uae company adopt ai business operation say study',
#  'alexander agrees saying ai excels rapidly analyzing vast amount data surface pattern making prediction uncovering actionable insight',
#  'say could include customer analytics identify trend segment financial analysis forecasting operation optimization',
#  'leveraging ai business make smarter datadriven decision much faster manual analysis say alexander',
#  'according report rather confined specific sector gen ai likely transform specific function across economy customer service',
#  'also point two thousand and twenty-three national bureau economic research working paper predicts gen ai customer service could raise productivity fourteen percent',
#  'generative ai prowess natural language understanding generation position linchpin customer service revolution offering personalized efficient engaging user experience say danese',
#  'alexander belief business must approach gen ai transformative business capability scattershot set project',
#  'readmeta roll new generative ai feature uae saudi',
#  'ultimately best fit gen ai depends company unique need available data strategic priority say alexander',
#  'company align ai initiative overarching business goal start focused experiment prove value scale success',
#  'ensure readiness maximize benefit sohal suggests organization seek use case depending level ai maturity',
#  'additionally recommends business also look industry precedent validate inform approach',
#  'integrative strategy promise yield tangible business value elevating gen ai technological experiment cornerstone enterprise capability say sohal',
#  'technology news clickhere',
#  'world software development emergence generative ai sparked excitement skepticism',
#  'predict ai render many software development skill obsolete others cautious potential impact',
#  '20year veteran field ceo company serving software developer keith pitt share insight potential benefit danger generative ai software development',
#  'one significant positive impact generative ai potential eliminate grunt work developer',
#  'developer often spend considerable amount time detail like syntax punctuation automated ai',
#  'instead poring manual searching code snippet developer describe desired outcome receive perfectly formatted code response',
#  'additionally large language model llm help identify typo punctuation mistake detail tedious developer',
#  'generative ai also potential reinvent software framework',
#  'framework like spring expressjs django already increased productivity abstracting mundane aspect software development',
#  'help gen ai framework enhance value creating boilerplate code automating repetitive task suggesting code optimization',
#  'ai also assist customizing framework component specific project',
#  'another significant change brought generative ai rise generalist developer',
#  'traditionally developer specialized specific language backend skill',
#  'however machine capable generating code language language proficiency may become le important',
#  'valuable skill machine replicate building user interface translating user requirement specification inventing new way support customer',
#  'shift put spotlight developer excel area',
#  'generative ai also hold great potential revolutionizing software testing',
#  'developer write code bot generate numerous test script quickly efficiently',
#  'according recent idc survey anticipated benefit generative ai software development software quality assurance security testing',
#  'disruption devops practice continuous integrationdeployment may lead testing specialist seeking new opportunity',
#  'lowcodenocode development tool already made software development accessible generative ai take next level',
#  'currently tool require individual piece together workflow whiteboard translating code',
#  'future developer able provide handdrawn sketch desired workflow ai model generate necessary code second',
#  'however essential recognize generative ai panacea',
#  'potential downside need considered',
#  'one concern risk overtesting',
#  'ai model capable generating test quickly possibility ending test necessary',
#  'overtesting slow project create bottleneck development pipeline',
#  'ai recommendation remove test could help address issue',
#  'skill degradation another potential danger associated generative ai',
#  'lazy developer may rely ai find shortcut leading bloated inefficient poorly performing code',
#  'reliance existing pattern data may limit innovative potential developer think outside box explore new solution',
#  'trust crucial come generative ai',
#  'quality data used train ai model significantly impact performance',
#  'poor quality data training shortcut inadequate prompt engineering result aigenerated code meet quality standard fails fulfill intended function',
#  'organization must trust quality generative ai fully benefit potential',
#  'despite potential benefit danger unlikely ai make software developer obsolete',
#  'historical precedent show technological advancement consistently made developer productive without diminishing demand skill',
#  'generative ai may affect market lowend basic coding skill push entire profession focus innovation highervalue task',
#  'creative problemsolving skill developer remain high demand',
#  'rather resisting change brought generative ai developer embrace',
#  'prospect eliminating tedious task software development excite everyone',
#  'certain function may disappear serve incentive developer upskill focus area machine yet capable',
#  'highquality developer translate business requirement elegant performant software always demand',
#  'developer adapt skill ride wave generative ai thrive evolving software development landscape',
#  'conclusion generative ai potential revolutionize software development eliminating grunt work reinventing framework promoting generalist skill revolutionizing testing enhancing lowcodenocode development tool',
#  'however potential risk overtesting skill degradation trust deficit need addressed',
#  'although ai make software developer obsolete push profession towards highervalue task innovation',
#  'developer embrace change brought generative ai focus upskilling remain valuable evolving landscape',
#  'ian goldinprofessor globalisation development oxford martin schooland report coauthor said generative ai dualedged sword offer enormous potential accelerate solution number world greatest challenge new health cure energy innovation',
#  'also could destroy job undermine democracy widen inequality division within society country',
#  'challenge develop regulatory framework guardrail required ensure benefit widely shared sustained',
#  'generative aioffers enormous potential accelerate solution number world greatest challengesbut also could destroy job undermine democracy widen inequality',
#  'professor ian goldin',
#  'contribution tounleashing ai citi investment bank oxford martin team explores opportunity challenge generative artificial intelligence found potential opportunity',
#  'dr pantelis koutroumpisdirector oxford martin programme technological economic change report coauthor said generative ai already shown impressive potential across range application recent month',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'beyond data better computing resource model excel fed highquality human generated input',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'dr pantelis koutroumpis',
#  'report also highlight series challenge including',
#  'report concludes world ai arm race country striving establish scientific technological dominance research output patenting',
#  'article',
#  'tech giant arent much acquiring day due mostly unfavorable regulatory environment',
#  'theyre finding way spend billion dollar next big thing',
#  'amazons275 billion investment artificial intelligence startup anthropic announced week itslargest venture dealand latest example ai gold rush thats prompting biggest tech company fling open wallet',
#  'anthropic developer behind ai model claude competes gpt frommicrosoftbacked openai andgooglesgemini',
#  'along withmetaandapple theyre racing integrate generative ai vast portfolio product feature ensure dont fall behind market thatspredicted top one trillionin revenue within decade',
#  'two thousand and twenty-three investor pumped two hundred and ninety-one billion combined nearly seven hundred generative ai deal increase two hundred and sixty value prior year according pitchbook',
#  'significant chunk money strategic came tech company rather venture capitalist institution',
#  'fred havemeyer head u ai software research macquarie said fear missing one factor driving decision',
#  'definitely dont want miss part ai ecosystem havemeyer said',
#  'definitely think there fomo marketplace',
#  'hefty investment necessary ai model notoriously expensive build train requiring thousand specialized chip date largely come fromnvidia',
#  'meta developing model calledllama said spending billion nvidias graphic processing unit one many company thats helped chipmakerbolsteryearoveryear revenue two hundred and fifty',
#  'whether going building investing route finite number company afford play market',
#  'addition developing chip nvidia emerged one silicon valley top investor taking stake number emerging ai company partly way make sure technology get widely deployed',
#  'similarly microsoft google amazon sometimes offer cloud credit part investment',
#  'amazonanthropic deal announced wednesday two company said theyll work closely together variety way',
#  'anthropic using amazon web service computing need well amazon chip',
#  'anthropics model distributed amazon aws customer',
#  'earlier month anthropic launchedclaude three powerful model one say let user upload photo chart document type unstructured data analysis answer',
#  'microsoft got business generative ai investing earlier putting1 billioninto openai two thousand and nineteen',
#  'size investment since swelled thirteen billion',
#  'microsoft heavily us openais model offer open source model azure cloud',
#  'alphabet playing part builder investor',
#  'company refocused much product development generative ai newly rebranded gemini model adding feature search document map elsewhere',
#  'last year googlecommittedto invest two billion anthropic previously confirming taken ten stake startup alongside large cloud contract two company',
#  'havemeyer said tech giant arent throwing money hype cycle investment ai startup align product road map',
#  'dont think frivolous said',
#  'havemeyer said alliance big cloud provider bring muchneeded cash startup also help sign customer',
#  'cloud company saying come u work platform native access latest greatest ai model also use infrastructure havemeyer said',
#  'also part much larger ecosystem play',
#  'seeing lot alliance appearing among hyperscalers substantial scale infrastructure deep pocket added',
#  'recent earnings call tech exec reiterated focus generative ai making clear investor spend money make money whether internal development investing startup',
#  'microsoft chief financial officer amy hood said last year company adjusting workforce toward aifirst work without adding material number people workforce',
#  'said microsoft continue prioritize investing ai thing thats going shape next decade',
#  'leader google apple amazon alsosuggested investorsthat theyre willing cut cost broadly across department order redirect funding toward ai effort',
#  'startup among beneficiary',
#  'microsoft taken stake mistral figure humane addition openai',
#  'company invested inflection ai startup essentially dissolved joined microsoft month',
#  'mistral open sourcefocused company us azure cloud offer service azure client',
#  'figure startup seeking build robot walk like human raised money microsoft openai nvidia wasvalued last monthat twenty-six billion',
#  'amazon biggest bet anthropic pouring total four billion far',
#  'company also invested open source ai platform developer hugging face',
#  'google investment include essential ai developing consumer ai program backed byamdand nvidia',
#  'alphabet nvidia also investor runway ml generative ai company known videoediting visual effect tool',
#  'others nvidias portfolio include mistral perplexity cohere',
#  'meanwhile many big tech company continue spend internally developing model',
#  'microsoft invested many technique underpinning generative ai microsoft research division',
#  'amazonreportedlyhas plan train bigger datahungry model even openais gpt4',
#  'apple researcher recently published detail work mm1a family small ai modelsthat take text visual input',
#  'apple different position peer doesnt sell cloud service',
#  'still tech giant reportedly looking ai partner including potentially google u andbaiduin china',
#  'apple representative declined comment ai partner',
#  'daniel newman ceo technology analysis firm futurum group said tech company get clever come investing ai',
#  'example openais investment microsoft included profit sharing nonprofit wing well credit use microsofts cloud service',
#  'microsofts deal inflection ai amounted expensive acquihire report putting total outlay at1 billion',
#  'part transaction microsofthiredinflection ai founder mustafa suleyman lead copilot ai initiative',
#  'think starting see creativity dealmaking said newman',
#  'respect amazon agreement anthropic said acquisition would lot harder investing',
#  'thats regulator across globe cracking big tech making difficult sizable acquisition',
#  'even investment attracting scrutiny',
#  'january federal trade commission announced willconduct extensive inquiryinto field biggest player ai including amazon alphabet microsoft anthropic openai',
#  'ftc chair lina khan described probe market inquiry investment partnership formed ai developer major cloud service provider',
#  'regulator authority order company file specific report answer question writing business',
#  'know regulator becoming increasingly focused traditional path closing acquisition newman said',
#  'right game access fundamental ip',
#  'watchai hype drive valuation higher',
#  'hardly day go generative ai genai doesnt dominate business medium headline',
#  'last twelve month become ubiquitous business strategy organization across industry increasingly investing genai solution',
#  'google trend data visualizesgenais rise center business relevance since two thousand and twenty-two peaking june two thousand and twenty-three',
#  'certainly cant ignore transformative potential genai jumping right without adequate planning mean risking resource without guaranteed roi',
#  'custom genai solution expensive costing three hundred thousand dollar annuallyaccording webfx require deep technical expertise maintain',
#  'reality organization ready invest genai',
#  'leader may feel pressure buy hype taking genai operationally realistic mean huge drain resourcesaccording mckinsey business area stand benefit gen ai include sale marketing customer relation customer operation software development research development',
#  'using gen ai business function like finance hr may yield return',
#  'meantime hype wane genai becomes polished accessible way exist move innovation forward',
#  'prioritizing operational efficiency best way guarantee measurable roi',
#  'largest benefit likely come following use case',
#  'organization strong area already relevant business goal gen ai solution may necessary',
#  'here know make move',
#  'making major investment organization take pause ass internal structure identify gap data process inefficiency silo business function',
#  'along way knowing successful genai implementation relies quality data leader ask process digitized automated better organized maximize resource streamline operation optimize efficiency scalability',
#  'ceo ask following question ready right people aiming right generating revenue',
#  'consider amazon relentless focus customer experience philosophy embedded deeply operational ethos',
#  'approach led innovation like amazon walk technology leveraging ai machine learning reimagine retail',
#  'similarly business contemplating genai investment must start deep dive operational fabric identifying inefficiency area digital transformation catalyze revolutionary customer experience',
#  'clear understanding operational process improved consider give time back teamsfreeing space continued learning preparation genai',
#  'one option embrace citizen development allowing nontechnical employee build apps simply quickly bring efficiency scalability mundane task',
#  'using lowcode nocode tool general business user build custom apps without burdening team',
#  'team pepsi relied heavily lowcodenocode build deploy digital application inventory merchandising function saving company five hundred thousand first year without professional developer staffaccording venturebeat',
#  'intuitive visual interface prebuilt template draganddrop element solve seemingly complicated business problem required coding knowledge little day minimal reeducation',
#  'embracing approach allows team understand nuance digital engineering turn focus genai without sacrificing team productivity',
#  'creating infrastructure designed grow business top priority technology leader two thousand and twenty-four',
#  'inefficiency created first wave digital transformation need corrected',
#  'key maximizing return genai investment aim big start small grow incrementally following wellplanned roadmap',
#  'focusing first streamlining existing process gradually introducing genai one use case time organization ensure genai integrated amplifies rather disrupts operational effectiveness',
#  'truly capitalize transformative potential genai business must approach integration incrementally focusing longterm improvement',
#  'journey toward genai efficiency technical upgrade strategic initiative requires holistic view business process technical culture goal',
#  'embedding genai operation already optimized agility innovation company ensure investment enhances current capability also open new avenue growth differentiation',
#  'real return genai investment lie adoption technology sake strategic integration core business',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'mohan chief evangelist digital transformation atkissflow',
#  'mohan extensive experience implementing erp banking insurance solution apac usa europe leading large team deliver outstanding client outcome',
#  'recent focus leading client digital transformation journey',
#  'specializes conducting design thinking workshop identify problem evaluate benefit various innovative idea',
#  'engineer iit mba xlri',
#  'boil ocean ai',
#  'bridging digital divide role aipowered platformcentric strategy crafting futureready enterprise',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'ai hr navigating opportunity challenge',
#  'advancement ai mixed reality technology continued training development healthcare industry',
#  'creating real value generative ai put people center',
#  'creating real value generative ai put people center',
#  'generative ai democratizes creative process anyone create text image presentation video music instant',
#  'however without human creativity little value',
#  'role human creative process',
#  'organization cleverly combine',
#  'creativity generating new valuable idea lead innovative solution problem',
#  'thats limited artist genius according mihaly csikszentmihalyi creator term flow author book creativity',
#  'argues creativity broad accessible human trait',
#  'creativity work exactly',
#  'important factor creativity deep human involvement',
#  'pattern lead creativity include suffering struggle like vincent van gogh dream isaac newton joy filmmaker david lynch practice transcendental meditation',
#  'typing smart prompt chatgpt show little involvement question extent result generative ai really called creative',
#  'however still essential question extent creativity actually important company',
#  'creativity make distinction impact',
#  'due generative ai flood aigenerated content way',
#  'meme deepfakes book amazon music video presentation audacity mail faq personal recommendation business chatbots code content creation',
#  'direct result democratization generative ai lowerquality output',
#  'read full articlehere',
#  'open dutch',
#  'learn epam revolutionizing future business power aihttpswwwepamcomservicesartificialintelligence',
#  'voor echte waarde creëren met generatieve ai stel de men centraal',
#  'generatieve ai democratiseert creatieve processen iedereen kan nu een handomdraai teksten afbeeldingen presentaties video muziek en meer creëren',
#  'zonder menselijke creativiteit heeft het echter weinig waarde',
#  'wat de rol van de men het creatieve proces',
#  'hoe kunnen organisaties beiden slim combineren',
#  'creativiteit gaat het genereren van nieuwe en waardevolle ideeën die leiden tot innovatieve oplossingen voor problemen',
#  'dat niet beperkt tot kunstenaars en genieën volgensmihaly csikszentmihalyi de bedenker van de term flow en schrijver van het boekcreativiteit',
#  'hij stelt dat creativiteit een brede en toegankelijke menselijke eigenschap',
#  'hoe werkt creativiteit precies',
#  'een belangrijke factor voor creativiteit diepe menselijke betrokkenheid',
#  'patronen die leiden tot creativiteit zijn bijvoorbeeld lijden en strijd zoals vincent van gogh dromen isaac newton en vreugde filmmaker david lynch die transcendentale meditatie beoefent',
#  'een slimme prompt intikken chatgpt toont weinig van deze betrokkenheid de vraag hoeverre de uitkomsten van generatieve ai dus echt creatief zijn te noemen',
#  'daar zit echter nog een essentiële vraag voor hoeverre creativiteit eigenlijk belangrijk voor bedrijven',
#  'creativiteit maakt onderscheid en impact',
#  'door generatieve ai er een stortvloed aan aigegenereerde content op komst',
#  'van meme deepfakesboeken op amazonenmuziekvideopresentatie van audacity tot mail faq persoonlijke aanbevelingen zakelijke chatbots code en contentcreatie',
#  'dit een direct gevolg van de democratisering van generative ai meer output van lagere kwaliteit',
#  'lee hier het volledige artikel',
#  'ontdek hoe epam een revolutie teweegbrengt de toekomst van het bedrijfsleven met de kracht van aihttpswwwepamcomservicesartificialintelligence',
#  'featured story',
#  'according global consultancy bain company insurance organisation across globe a50 billionfinancial opportunity generative ai genai harness technology way could boost revenue much twenty well cut cost fifteen',
#  'new report released firm reveals leveraging genai insurance distribution potential yield than50 billionin annual economic benefit company across sector',
#  'bhavimehta global lead ai financial service bain commented insurer benefit due generative ai come three route',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'moreover bain company noted genai permeates insurance company operation early initiative suggesting technology transform distribution four way including',
#  'meanwhile bains analysis also highlight several key risk area emerging insurer developing use genai include hallucination data provenance misinformation toxicity intellectual property ownership',
#  'sean oneill leader bains global insurance practice said nascent technology risk',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'however genai continuing develop evolve bain urge insurer take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor well ensuring delivery team crossfunctional designing operating model adaptable',
#  'reuters openai start allowing user access freetouse chatgpt generative ai chatbot without needing sign service beginning monday microsoftbacked startup said monday',
#  'chatgpt kickstarted genai boom late two thousand and twenty-two mimic human conversation perform task creating summary long text writing poem even generating idea theme party',
#  'san franciscobased company said gradually roll feature make ai accessible anyone curious capability',
#  'popular service set record fastestgrowing user base seen growth slow since may two thousand and twenty-three traffic peaked eighteen billion web visit according data analytics firm similarweb',
#  'openai said introduced additional content safeguard user accessing chatgpt without signing blocking prompt generation wider range category',
#  'specify category',
#  'apart free version chatgpt direct access internet openai also offer paid version individual team user enterprise',
#  'company also said may use content provided user help improve largelanguage model said user turn feature',
#  'move come month billionaire entrepreneur elon musk sued openai ceo sam altman saying abandoned startup original mission develop artificial intelligence benefit humanity profit',
#  'reporting arsheeya bajwa bengaluru anna tong san francisco krystal hu new york editing tasim zahid',
#  'spread fake news disinformation steadily risen past year audience increasingly getting news online false information sometimes generated ai spread faster threatening audience trust medium',
#  'series infographics euractiv take deeper dive trend playing across europe medium landscape',
#  'trend consumer trusting medium le le observed resulting turning social medium get news instead',
#  'boththis yearandlast year u trust medium hit alltime low',
#  'pattern eu laid graph',
#  'meanwhiletiktok example popular among younger generation alternative traditional news source',
#  'using data two thousand and twenty chart also show social medium play big role news source',
#  'yet according aeurobarometer surveypublished european parliament seventeen november us two thousand and twenty-two data main source news television seventy-one respondent saying one used source past seven day time research',
#  'however eleven increase using social medium platform get news compared last year survey',
#  'counteract risk artificial intelligence believe aican help debunk fake news horizon europe project ai4trust',
#  'ai4trust isdevelopinga system based machinehuman cooperation advanced solution horizon europe two hundred and two thousand, three hundred and twenty-four work programmeaimsto move closer aibased market solution ensure access meaningful information quality content trustworthy online interaction',
#  'however social medium platform also source',
#  'knowing real aigenerated help trust news',
#  'march example eu law enforcement agency europolwarnedthat chatgpt benefit business individual malicious actor exploit technology posing law enforcement challenge',
#  'criminal typically quick exploit new technology fast seen coming concrete criminal exploitation providing first practical example mere week public release chatgpt read thereport',
#  'dissemination nude image minor created ai concern law enforcement one bound become increasingly difficult address europol alsotold euractivin october',
#  'law enforcement agency added aigenerated material must detected using ai classifier tool currently authorised use classifier tool specific purpose',
#  'european union reading news online increased past year graph show two thousand and thirteen two thousand and twenty-two according tostatista',
#  'online frequency type fake news reader differ seen graph cover europe largest country',
#  'frequency seeing disinformation depend different type medium citizen exposure level disinformation general every country either',
#  'country may different percentage regarding fake news following map show scandinavian country le affected central southern europe',
#  'last year bulgarian citizen highest exposure misinformation twenty-eight april twenty-six may eleven living netherlands least exposed six',
#  'regardless frequency exposure seeing false information impact one life differently',
#  'claim thirty-five check news thoroughly encounter',
#  'however almost many people thirty-three believe impact',
#  'edited alice taylornathalie weatherald']

# %%
website19 = 'https://www.verdict.co.uk/generative-ai-unfounded-fears/'
class19 = 'cell large-8 main-content'
text19 = scrape_clean(website19, class19)
sentences.extend(text19)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe',
#  'adult social care supporting people live independently protect fundamental human right',
#  'generative ai offer many potential benefit opportunity adult social care',
#  'however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately',
#  'therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college',
#  'artificial intelligence offer many opportunity potential benefit adult social care',
#  'generative ai large language model llm power ai chatbots aid various task social care',
#  'however many activity social care directly touch people human right wellbeing',
#  'currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail',
#  'aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case',
#  'core focus would constitute responsible ethical use emerging technology',
#  'following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care',
#  'addition commits group engaging coproduction consultation process drawing people organisation social care',
#  'full statement endorsed twenty-three participating organisation beread',
#  'according recent global report business agree generative ai gen ai substantial impact industry',
#  'however despite fanfare adoption rate technology remained abysmally low business',
#  'three quarter surveyed company experimented gen ai lowly nine percent admitted adopted technology',
#  'based survey conducted mit technology review insight telecom company telstrathe reportcovered three hundred csuite executive vice president director across asiapacific america europe',
#  'report question participant company using plan use gen ai technology',
#  'addition gauging interest technology report also highlight barrier adoption gen ai business',
#  'readgenerative ai market projected reach one trillion two thousand and thirty-one',
#  'misconception easy run mature enterpriseready generative ai said stela solar inaugural director australia national artificial intelligence centre report',
#  'agreeing solars assessment brian prince founder ceo top ai tool say investing gen ai expensive',
#  'argues beyond software business likely need also invest training infrastructure upgrade ongoing maintenance',
#  'especially true small medium enterprise may find challenging allocate sufficient budget without guaranteed shortterm return',
#  'telstra survey showed skill training company culture major impediment adoption say prince',
#  'integrating ai existing workflow system complex',
#  'speaking experience paolo danese ceo storya say observed tangible disconnect theoretical allure gen ai practical reality faced business',
#  'divergence technology encompasses broader concern readiness infrastructure steep learning curve effective deployment ethical consideration surrounding ai use say danese',
#  'building sukhdeep sohal senior consultant glue affinity reply say business apprehension towards gen ai often traced back series strategic operational disconnect',
#  'belief crux issue lie alignment lack thereof ai initiative overarching business strategy',
#  'ai strategy perceived standalone experiment rather integral part business growth disconnect breed reluctance say sohal',
#  'additionally delivery ai foundation piecemeal rather holistically fails instil confidence technology comprehensive benefit',
#  'report highlighted evolving regulatory compliance data privacy environment leading nontechnological barrier rapid gen ai adoption business',
#  'danese agrees saying business navigating uncharted water need balance push digital transformation adhering strict privacy standard',
#  'according prince especially true sector like healthcare finance legal data sensitivity critical concern',
#  'burden compliance becomes significant deterrent say',
#  'read5 way make money generative ai',
#  'peter john alexander chief business officer meetkai highlight nontechnical factor business must take consideration',
#  'say company likely fear potential data breach ethical misuse high implementation usage cost unreliable output risk falling behind competitor',
#  'apprehension highlight need careful consideration benefit risk generative ai deployment alongside proactive measure address security compliance ethical operational challenge say alexander',
#  'according report seventy-eight percent business look gen ai competitive opportunity',
#  'many expect number function deploying gen ai double two thousand and twenty-four',
#  'term actual use sixty-five percent respondent say business actively considering new innovative way use gen ai unlock hidden opportunity data',
#  'doesnt surprise sohal',
#  'say gen ai aligned wellarticulated strategy fit best leverage predictive power data stream identified rigorous data audit',
#  'suggests analysis especially predictive analytics prime area application directly amplifies strategic decisionmaking capability',
#  'read42 percent uae company adopt ai business operation say study',
#  'alexander agrees saying ai excels rapidly analyzing vast amount data surface pattern making prediction uncovering actionable insight',
#  'say could include customer analytics identify trend segment financial analysis forecasting operation optimization',
#  'leveraging ai business make smarter datadriven decision much faster manual analysis say alexander',
#  'according report rather confined specific sector gen ai likely transform specific function across economy customer service',
#  'also point two thousand and twenty-three national bureau economic research working paper predicts gen ai customer service could raise productivity fourteen percent',
#  'generative ai prowess natural language understanding generation position linchpin customer service revolution offering personalized efficient engaging user experience say danese',
#  'alexander belief business must approach gen ai transformative business capability scattershot set project',
#  'readmeta roll new generative ai feature uae saudi',
#  'ultimately best fit gen ai depends company unique need available data strategic priority say alexander',
#  'company align ai initiative overarching business goal start focused experiment prove value scale success',
#  'ensure readiness maximize benefit sohal suggests organization seek use case depending level ai maturity',
#  'additionally recommends business also look industry precedent validate inform approach',
#  'integrative strategy promise yield tangible business value elevating gen ai technological experiment cornerstone enterprise capability say sohal',
#  'technology news clickhere',
#  'world software development emergence generative ai sparked excitement skepticism',
#  'predict ai render many software development skill obsolete others cautious potential impact',
#  '20year veteran field ceo company serving software developer keith pitt share insight potential benefit danger generative ai software development',
#  'one significant positive impact generative ai potential eliminate grunt work developer',
#  'developer often spend considerable amount time detail like syntax punctuation automated ai',
#  'instead poring manual searching code snippet developer describe desired outcome receive perfectly formatted code response',
#  'additionally large language model llm help identify typo punctuation mistake detail tedious developer',
#  'generative ai also potential reinvent software framework',
#  'framework like spring expressjs django already increased productivity abstracting mundane aspect software development',
#  'help gen ai framework enhance value creating boilerplate code automating repetitive task suggesting code optimization',
#  'ai also assist customizing framework component specific project',
#  'another significant change brought generative ai rise generalist developer',
#  'traditionally developer specialized specific language backend skill',
#  'however machine capable generating code language language proficiency may become le important',
#  'valuable skill machine replicate building user interface translating user requirement specification inventing new way support customer',
#  'shift put spotlight developer excel area',
#  'generative ai also hold great potential revolutionizing software testing',
#  'developer write code bot generate numerous test script quickly efficiently',
#  'according recent idc survey anticipated benefit generative ai software development software quality assurance security testing',
#  'disruption devops practice continuous integrationdeployment may lead testing specialist seeking new opportunity',
#  'lowcodenocode development tool already made software development accessible generative ai take next level',
#  'currently tool require individual piece together workflow whiteboard translating code',
#  'future developer able provide handdrawn sketch desired workflow ai model generate necessary code second',
#  'however essential recognize generative ai panacea',
#  'potential downside need considered',
#  'one concern risk overtesting',
#  'ai model capable generating test quickly possibility ending test necessary',
#  'overtesting slow project create bottleneck development pipeline',
#  'ai recommendation remove test could help address issue',
#  'skill degradation another potential danger associated generative ai',
#  'lazy developer may rely ai find shortcut leading bloated inefficient poorly performing code',
#  'reliance existing pattern data may limit innovative potential developer think outside box explore new solution',
#  'trust crucial come generative ai',
#  'quality data used train ai model significantly impact performance',
#  'poor quality data training shortcut inadequate prompt engineering result aigenerated code meet quality standard fails fulfill intended function',
#  'organization must trust quality generative ai fully benefit potential',
#  'despite potential benefit danger unlikely ai make software developer obsolete',
#  'historical precedent show technological advancement consistently made developer productive without diminishing demand skill',
#  'generative ai may affect market lowend basic coding skill push entire profession focus innovation highervalue task',
#  'creative problemsolving skill developer remain high demand',
#  'rather resisting change brought generative ai developer embrace',
#  'prospect eliminating tedious task software development excite everyone',
#  'certain function may disappear serve incentive developer upskill focus area machine yet capable',
#  'highquality developer translate business requirement elegant performant software always demand',
#  'developer adapt skill ride wave generative ai thrive evolving software development landscape',
#  'conclusion generative ai potential revolutionize software development eliminating grunt work reinventing framework promoting generalist skill revolutionizing testing enhancing lowcodenocode development tool',
#  'however potential risk overtesting skill degradation trust deficit need addressed',
#  'although ai make software developer obsolete push profession towards highervalue task innovation',
#  'developer embrace change brought generative ai focus upskilling remain valuable evolving landscape',
#  'ian goldinprofessor globalisation development oxford martin schooland report coauthor said generative ai dualedged sword offer enormous potential accelerate solution number world greatest challenge new health cure energy innovation',
#  'also could destroy job undermine democracy widen inequality division within society country',
#  'challenge develop regulatory framework guardrail required ensure benefit widely shared sustained',
#  'generative aioffers enormous potential accelerate solution number world greatest challengesbut also could destroy job undermine democracy widen inequality',
#  'professor ian goldin',
#  'contribution tounleashing ai citi investment bank oxford martin team explores opportunity challenge generative artificial intelligence found potential opportunity',
#  'dr pantelis koutroumpisdirector oxford martin programme technological economic change report coauthor said generative ai already shown impressive potential across range application recent month',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'beyond data better computing resource model excel fed highquality human generated input',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'dr pantelis koutroumpis',
#  'report also highlight series challenge including',
#  'report concludes world ai arm race country striving establish scientific technological dominance research output patenting',
#  'article',
#  'tech giant arent much acquiring day due mostly unfavorable regulatory environment',
#  'theyre finding way spend billion dollar next big thing',
#  'amazons275 billion investment artificial intelligence startup anthropic announced week itslargest venture dealand latest example ai gold rush thats prompting biggest tech company fling open wallet',
#  'anthropic developer behind ai model claude competes gpt frommicrosoftbacked openai andgooglesgemini',
#  'along withmetaandapple theyre racing integrate generative ai vast portfolio product feature ensure dont fall behind market thatspredicted top one trillionin revenue within decade',
#  'two thousand and twenty-three investor pumped two hundred and ninety-one billion combined nearly seven hundred generative ai deal increase two hundred and sixty value prior year according pitchbook',
#  'significant chunk money strategic came tech company rather venture capitalist institution',
#  'fred havemeyer head u ai software research macquarie said fear missing one factor driving decision',
#  'definitely dont want miss part ai ecosystem havemeyer said',
#  'definitely think there fomo marketplace',
#  'hefty investment necessary ai model notoriously expensive build train requiring thousand specialized chip date largely come fromnvidia',
#  'meta developing model calledllama said spending billion nvidias graphic processing unit one many company thats helped chipmakerbolsteryearoveryear revenue two hundred and fifty',
#  'whether going building investing route finite number company afford play market',
#  'addition developing chip nvidia emerged one silicon valley top investor taking stake number emerging ai company partly way make sure technology get widely deployed',
#  'similarly microsoft google amazon sometimes offer cloud credit part investment',
#  'amazonanthropic deal announced wednesday two company said theyll work closely together variety way',
#  'anthropic using amazon web service computing need well amazon chip',
#  'anthropics model distributed amazon aws customer',
#  'earlier month anthropic launchedclaude three powerful model one say let user upload photo chart document type unstructured data analysis answer',
#  'microsoft got business generative ai investing earlier putting1 billioninto openai two thousand and nineteen',
#  'size investment since swelled thirteen billion',
#  'microsoft heavily us openais model offer open source model azure cloud',
#  'alphabet playing part builder investor',
#  'company refocused much product development generative ai newly rebranded gemini model adding feature search document map elsewhere',
#  'last year googlecommittedto invest two billion anthropic previously confirming taken ten stake startup alongside large cloud contract two company',
#  'havemeyer said tech giant arent throwing money hype cycle investment ai startup align product road map',
#  'dont think frivolous said',
#  'havemeyer said alliance big cloud provider bring muchneeded cash startup also help sign customer',
#  'cloud company saying come u work platform native access latest greatest ai model also use infrastructure havemeyer said',
#  'also part much larger ecosystem play',
#  'seeing lot alliance appearing among hyperscalers substantial scale infrastructure deep pocket added',
#  'recent earnings call tech exec reiterated focus generative ai making clear investor spend money make money whether internal development investing startup',
#  'microsoft chief financial officer amy hood said last year company adjusting workforce toward aifirst work without adding material number people workforce',
#  'said microsoft continue prioritize investing ai thing thats going shape next decade',
#  'leader google apple amazon alsosuggested investorsthat theyre willing cut cost broadly across department order redirect funding toward ai effort',
#  'startup among beneficiary',
#  'microsoft taken stake mistral figure humane addition openai',
#  'company invested inflection ai startup essentially dissolved joined microsoft month',
#  'mistral open sourcefocused company us azure cloud offer service azure client',
#  'figure startup seeking build robot walk like human raised money microsoft openai nvidia wasvalued last monthat twenty-six billion',
#  'amazon biggest bet anthropic pouring total four billion far',
#  'company also invested open source ai platform developer hugging face',
#  'google investment include essential ai developing consumer ai program backed byamdand nvidia',
#  'alphabet nvidia also investor runway ml generative ai company known videoediting visual effect tool',
#  'others nvidias portfolio include mistral perplexity cohere',
#  'meanwhile many big tech company continue spend internally developing model',
#  'microsoft invested many technique underpinning generative ai microsoft research division',
#  'amazonreportedlyhas plan train bigger datahungry model even openais gpt4',
#  'apple researcher recently published detail work mm1a family small ai modelsthat take text visual input',
#  'apple different position peer doesnt sell cloud service',
#  'still tech giant reportedly looking ai partner including potentially google u andbaiduin china',
#  'apple representative declined comment ai partner',
#  'daniel newman ceo technology analysis firm futurum group said tech company get clever come investing ai',
#  'example openais investment microsoft included profit sharing nonprofit wing well credit use microsofts cloud service',
#  'microsofts deal inflection ai amounted expensive acquihire report putting total outlay at1 billion',
#  'part transaction microsofthiredinflection ai founder mustafa suleyman lead copilot ai initiative',
#  'think starting see creativity dealmaking said newman',
#  'respect amazon agreement anthropic said acquisition would lot harder investing',
#  'thats regulator across globe cracking big tech making difficult sizable acquisition',
#  'even investment attracting scrutiny',
#  'january federal trade commission announced willconduct extensive inquiryinto field biggest player ai including amazon alphabet microsoft anthropic openai',
#  'ftc chair lina khan described probe market inquiry investment partnership formed ai developer major cloud service provider',
#  'regulator authority order company file specific report answer question writing business',
#  'know regulator becoming increasingly focused traditional path closing acquisition newman said',
#  'right game access fundamental ip',
#  'watchai hype drive valuation higher',
#  'hardly day go generative ai genai doesnt dominate business medium headline',
#  'last twelve month become ubiquitous business strategy organization across industry increasingly investing genai solution',
#  'google trend data visualizesgenais rise center business relevance since two thousand and twenty-two peaking june two thousand and twenty-three',
#  'certainly cant ignore transformative potential genai jumping right without adequate planning mean risking resource without guaranteed roi',
#  'custom genai solution expensive costing three hundred thousand dollar annuallyaccording webfx require deep technical expertise maintain',
#  'reality organization ready invest genai',
#  'leader may feel pressure buy hype taking genai operationally realistic mean huge drain resourcesaccording mckinsey business area stand benefit gen ai include sale marketing customer relation customer operation software development research development',
#  'using gen ai business function like finance hr may yield return',
#  'meantime hype wane genai becomes polished accessible way exist move innovation forward',
#  'prioritizing operational efficiency best way guarantee measurable roi',
#  'largest benefit likely come following use case',
#  'organization strong area already relevant business goal gen ai solution may necessary',
#  'here know make move',
#  'making major investment organization take pause ass internal structure identify gap data process inefficiency silo business function',
#  'along way knowing successful genai implementation relies quality data leader ask process digitized automated better organized maximize resource streamline operation optimize efficiency scalability',
#  'ceo ask following question ready right people aiming right generating revenue',
#  'consider amazon relentless focus customer experience philosophy embedded deeply operational ethos',
#  'approach led innovation like amazon walk technology leveraging ai machine learning reimagine retail',
#  'similarly business contemplating genai investment must start deep dive operational fabric identifying inefficiency area digital transformation catalyze revolutionary customer experience',
#  'clear understanding operational process improved consider give time back teamsfreeing space continued learning preparation genai',
#  'one option embrace citizen development allowing nontechnical employee build apps simply quickly bring efficiency scalability mundane task',
#  'using lowcode nocode tool general business user build custom apps without burdening team',
#  'team pepsi relied heavily lowcodenocode build deploy digital application inventory merchandising function saving company five hundred thousand first year without professional developer staffaccording venturebeat',
#  'intuitive visual interface prebuilt template draganddrop element solve seemingly complicated business problem required coding knowledge little day minimal reeducation',
#  'embracing approach allows team understand nuance digital engineering turn focus genai without sacrificing team productivity',
#  'creating infrastructure designed grow business top priority technology leader two thousand and twenty-four',
#  'inefficiency created first wave digital transformation need corrected',
#  'key maximizing return genai investment aim big start small grow incrementally following wellplanned roadmap',
#  'focusing first streamlining existing process gradually introducing genai one use case time organization ensure genai integrated amplifies rather disrupts operational effectiveness',
#  'truly capitalize transformative potential genai business must approach integration incrementally focusing longterm improvement',
#  'journey toward genai efficiency technical upgrade strategic initiative requires holistic view business process technical culture goal',
#  'embedding genai operation already optimized agility innovation company ensure investment enhances current capability also open new avenue growth differentiation',
#  'real return genai investment lie adoption technology sake strategic integration core business',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'mohan chief evangelist digital transformation atkissflow',
#  'mohan extensive experience implementing erp banking insurance solution apac usa europe leading large team deliver outstanding client outcome',
#  'recent focus leading client digital transformation journey',
#  'specializes conducting design thinking workshop identify problem evaluate benefit various innovative idea',
#  'engineer iit mba xlri',
#  'boil ocean ai',
#  'bridging digital divide role aipowered platformcentric strategy crafting futureready enterprise',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'ai hr navigating opportunity challenge',
#  'advancement ai mixed reality technology continued training development healthcare industry',
#  'creating real value generative ai put people center',
#  'creating real value generative ai put people center',
#  'generative ai democratizes creative process anyone create text image presentation video music instant',
#  'however without human creativity little value',
#  'role human creative process',
#  'organization cleverly combine',
#  'creativity generating new valuable idea lead innovative solution problem',
#  'thats limited artist genius according mihaly csikszentmihalyi creator term flow author book creativity',
#  'argues creativity broad accessible human trait',
#  'creativity work exactly',
#  'important factor creativity deep human involvement',
#  'pattern lead creativity include suffering struggle like vincent van gogh dream isaac newton joy filmmaker david lynch practice transcendental meditation',
#  'typing smart prompt chatgpt show little involvement question extent result generative ai really called creative',
#  'however still essential question extent creativity actually important company',
#  'creativity make distinction impact',
#  'due generative ai flood aigenerated content way',
#  'meme deepfakes book amazon music video presentation audacity mail faq personal recommendation business chatbots code content creation',
#  'direct result democratization generative ai lowerquality output',
#  'read full articlehere',
#  'open dutch',
#  'learn epam revolutionizing future business power aihttpswwwepamcomservicesartificialintelligence',
#  'voor echte waarde creëren met generatieve ai stel de men centraal',
#  'generatieve ai democratiseert creatieve processen iedereen kan nu een handomdraai teksten afbeeldingen presentaties video muziek en meer creëren',
#  'zonder menselijke creativiteit heeft het echter weinig waarde',
#  'wat de rol van de men het creatieve proces',
#  'hoe kunnen organisaties beiden slim combineren',
#  'creativiteit gaat het genereren van nieuwe en waardevolle ideeën die leiden tot innovatieve oplossingen voor problemen',
#  'dat niet beperkt tot kunstenaars en genieën volgensmihaly csikszentmihalyi de bedenker van de term flow en schrijver van het boekcreativiteit',
#  'hij stelt dat creativiteit een brede en toegankelijke menselijke eigenschap',
#  'hoe werkt creativiteit precies',
#  'een belangrijke factor voor creativiteit diepe menselijke betrokkenheid',
#  'patronen die leiden tot creativiteit zijn bijvoorbeeld lijden en strijd zoals vincent van gogh dromen isaac newton en vreugde filmmaker david lynch die transcendentale meditatie beoefent',
#  'een slimme prompt intikken chatgpt toont weinig van deze betrokkenheid de vraag hoeverre de uitkomsten van generatieve ai dus echt creatief zijn te noemen',
#  'daar zit echter nog een essentiële vraag voor hoeverre creativiteit eigenlijk belangrijk voor bedrijven',
#  'creativiteit maakt onderscheid en impact',
#  'door generatieve ai er een stortvloed aan aigegenereerde content op komst',
#  'van meme deepfakesboeken op amazonenmuziekvideopresentatie van audacity tot mail faq persoonlijke aanbevelingen zakelijke chatbots code en contentcreatie',
#  'dit een direct gevolg van de democratisering van generative ai meer output van lagere kwaliteit',
#  'lee hier het volledige artikel',
#  'ontdek hoe epam een revolutie teweegbrengt de toekomst van het bedrijfsleven met de kracht van aihttpswwwepamcomservicesartificialintelligence',
#  'featured story',
#  'according global consultancy bain company insurance organisation across globe a50 billionfinancial opportunity generative ai genai harness technology way could boost revenue much twenty well cut cost fifteen',
#  'new report released firm reveals leveraging genai insurance distribution potential yield than50 billionin annual economic benefit company across sector',
#  'bhavimehta global lead ai financial service bain commented insurer benefit due generative ai come three route',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'moreover bain company noted genai permeates insurance company operation early initiative suggesting technology transform distribution four way including',
#  'meanwhile bains analysis also highlight several key risk area emerging insurer developing use genai include hallucination data provenance misinformation toxicity intellectual property ownership',
#  'sean oneill leader bains global insurance practice said nascent technology risk',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'however genai continuing develop evolve bain urge insurer take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor well ensuring delivery team crossfunctional designing operating model adaptable',
#  'reuters openai start allowing user access freetouse chatgpt generative ai chatbot without needing sign service beginning monday microsoftbacked startup said monday',
#  'chatgpt kickstarted genai boom late two thousand and twenty-two mimic human conversation perform task creating summary long text writing poem even generating idea theme party',
#  'san franciscobased company said gradually roll feature make ai accessible anyone curious capability',
#  'popular service set record fastestgrowing user base seen growth slow since may two thousand and twenty-three traffic peaked eighteen billion web visit according data analytics firm similarweb',
#  'openai said introduced additional content safeguard user accessing chatgpt without signing blocking prompt generation wider range category',
#  'specify category',
#  'apart free version chatgpt direct access internet openai also offer paid version individual team user enterprise',
#  'company also said may use content provided user help improve largelanguage model said user turn feature',
#  'move come month billionaire entrepreneur elon musk sued openai ceo sam altman saying abandoned startup original mission develop artificial intelligence benefit humanity profit',
#  'reporting arsheeya bajwa bengaluru anna tong san francisco krystal hu new york editing tasim zahid',
#  'spread fake news disinformation steadily risen past year audience increasingly getting news online false information sometimes generated ai spread faster threatening audience trust medium',
#  'series infographics euractiv take deeper dive trend playing across europe medium landscape',
#  'trend consumer trusting medium le le observed resulting turning social medium get news instead',
#  'boththis yearandlast year u trust medium hit alltime low',
#  'pattern eu laid graph',
#  'meanwhiletiktok example popular among younger generation alternative traditional news source',
#  'using data two thousand and twenty chart also show social medium play big role news source',
#  'yet according aeurobarometer surveypublished european parliament seventeen november us two thousand and twenty-two data main source news television seventy-one respondent saying one used source past seven day time research',
#  'however eleven increase using social medium platform get news compared last year survey',
#  'counteract risk artificial intelligence believe aican help debunk fake news horizon europe project ai4trust',
#  'ai4trust isdevelopinga system based machinehuman cooperation advanced solution horizon europe two hundred and two thousand, three hundred and twenty-four work programmeaimsto move closer aibased market solution ensure access meaningful information quality content trustworthy online interaction',
#  'however social medium platform also source',
#  'knowing real aigenerated help trust news',
#  'march example eu law enforcement agency europolwarnedthat chatgpt benefit business individual malicious actor exploit technology posing law enforcement challenge',
#  'criminal typically quick exploit new technology fast seen coming concrete criminal exploitation providing first practical example mere week public release chatgpt read thereport',
#  'dissemination nude image minor created ai concern law enforcement one bound become increasingly difficult address europol alsotold euractivin october',
#  'law enforcement agency added aigenerated material must detected using ai classifier tool currently authorised use classifier tool specific purpose',
#  'european union reading news online increased past year graph show two thousand and thirteen two thousand and twenty-two according tostatista',
#  'online frequency type fake news reader differ seen graph cover europe largest country',
#  'frequency seeing disinformation depend different type medium citizen exposure level disinformation general every country either',
#  'country may different percentage regarding fake news following map show scandinavian country le affected central southern europe',
#  'last year bulgarian citizen highest exposure misinformation twenty-eight april twenty-six may eleven living netherlands least exposed six',
#  'regardless frequency exposure seeing false information impact one life differently',
#  'claim thirty-five check news thoroughly encounter',
#  'however almost many people thirty-three believe impact',
#  'edited alice taylornathalie weatherald',
#  'significant hype fear ai particularly generative ai crowding news headline last week',
#  'generative ai least context us large language model create response',
#  'essentially selftrained ai smart collectively',
#  'use training data make educated guess',
#  'algorithmic',
#  'complicated math',
#  'make pretty good guess time',
#  'yes',
#  'however ai today isnt actual intelligence actual sapience fact lost many result fromgenerative aican impressive',
#  'gold standard business intelligence',
#  'find',
#  'need think intake information',
#  'anything human race learned need critically examine information given',
#  'fear generative ai fooled',
#  'happened already',
#  'happened',
#  'human inclined believe gullible want believe giving u information good intention',
#  'ai today intention',
#  'moral give use generate u',
#  'need apply scepticism',
#  'hard appears',
#  'anyone take television advertisement really kind ad undisputed truth',
#  'course',
#  'assumed advertiser best interest heart economic interest',
#  'verification stated claim required product service purchased',
#  'individual need apply level scepticism nearly everything read see',
#  'including article',
#  'time panic generative ai',
#  'technology impressive extremely helpful',
#  'time educate raise standard accepting see truth',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'adapt willing far benefit ai bring worth challenge']

# %%
website20 = 'https://itwire.com/business-it-news/enterprise-solutions/vonage-launches-generative-ai-for-conversational-commerce-solution.html'
class20 = 'itemFullText'
text20 = scrape_clean(website20, class20)
sentences.extend(text20)
sentences
# Out:
# ['india cusp digital hyper growth',
#  'indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever',
#  'speed agility along adequate understanding deployment relevant technology make difference',
#  'digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four',
#  'despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy',
#  'believe next year genai stay limelight also find way many initiative across company india',
#  'top five india technology prediction two thousand and twenty-four',
#  'glimpse top prediction',
#  'many prediction around tech always finer nuance around would benefit dialogue',
#  'would happy chat topic detail',
#  'please reach u inquiry guidance session know',
#  'brian hopkins vp emerging tech portfolio',
#  'julie mohr principal analyst',
#  'ted schadler vp principal analyst',
#  'generative ai genai disruptive force disruptive',
#  'know big quite sure big',
#  'colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u',
#  'kicking new research stream withted schadlerjulie mohr others explore topic',
#  'focus disruptive impact genai industry market economy',
#  'today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government',
#  'last week ted published first blog topicgenai shatter reconstruct every company industry',
#  'pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming',
#  'next step research stream diving technical',
#  'two belief',
#  'two reality impact every industry mean disruption hit every firm equally',
#  'believe impact based use knowledge create business value',
#  'example',
#  'beginning',
#  'research go deeper',
#  'seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk',
#  'brian hopkins julie mohr julie ask investigating generative ai genai change face business industry',
#  'research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure',
#  'look back twenty-five year longlasting economic value created captured',
#  'company industry country win',
#  'lose',
#  'along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question',
#  'artificial intelligence shatter reconstruct company industry country redefine role company play genainative future',
#  'see change inevitable murky future early day internet',
#  'seeking understand artificial general intelligence examine existential threat',
#  'rather assume ability govern keep ai safe grow ai grows',
#  'future look like',
#  'post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai',
#  'colleague brian hopkins posting shortly early hypothesis happen',
#  'also look upcoming post julie mohr julie ask',
#  'first productivitycentric wave genai impact company coming focus',
#  'improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry',
#  'kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model',
#  'aboutgenais impact revenue generating new revenue stream extension channel',
#  'reinventionhow company reinvent themselvesusing power genai',
#  'next twenty-five year genaiforce entire industry restructureto take advantage value generated machine',
#  'country respond toset economy citizen success',
#  'invite idea participation part research pursue question',
#  'learn impact generative ai read bloggenais worldchanging power putting knowledge work',
#  'interested view generative ai',
#  'please reach schedule time via inquiry team emailing inquiryforrestercom',
#  'eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected',
#  'effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said',
#  'said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result',
#  'analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed',
#  'figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp',
#  'author described worst case scenario',
#  'painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training',
#  'new drake song cause confusion listener question whether ai rapper behind',
#  'creating fake sexual image another person become criminal offence',
#  'ai helping meta fight misinformation election say former deputy pm nick clegg',
#  'please use chrome browser accessible video player',
#  'claimed could lead economic boost thirteen gdp around 306bn year best case',
#  'government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics',
#  'carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u',
#  'please use chrome browser accessible video player',
#  'many firm already investing potential speed many task business adopt',
#  'next five year could transform knowledge work',
#  'question le whether ai useful rather fast manner employer use',
#  'history show technological transition boon well managed end disruption left unfold without control',
#  'first getbreaking news',
#  'install sky news app free',
#  'read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel',
#  'spokesperson department science innovation technology said research hugely speculative',
#  'numerous report also predict ai spark huge creation job unlocking growth ramping productivity',
#  'ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future',
#  'continue ass impact ai different sector ensure employer play leading role building robust uk skill talent',
#  'also working innovate uk alan turing institute develop guidance core ai skill people need published later year',
#  'recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan',
#  'first base ai labour market',
#  'help maximise benefit ai employer government work together particularly skill development compliance',
#  'fastmoving area one need people proficient trained using ai also given skill adapt future development',
#  'education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy',
#  'ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience',
#  'bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find',
#  'bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector',
#  'insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'generative ai transform insurance distribution four way',
#  'early use generative ai within insurance suggests technology transform distribution four way including',
#  'managing risk',
#  'bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership',
#  'nascent technology risk saidsean oneill leader bains global insurance practice',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'critical step insurance business leader',
#  'generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable',
#  'medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected',
#  'bain company',
#  'bain company global consultancy help world ambitious change maker define future',
#  'across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry',
#  'complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome',
#  '10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment',
#  'earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company',
#  'since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry',
#  'source bain company',
#  'machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty',
#  'unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market',
#  'banking financial service',
#  'insurance',
#  'data analytics',
#  'data analytics',
#  'morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure',
#  'regard highlight significant growth revenue capture opportunity company meet energy need',
#  'specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe',
#  'adult social care supporting people live independently protect fundamental human right',
#  'generative ai offer many potential benefit opportunity adult social care',
#  'however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately',
#  'therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college',
#  'artificial intelligence offer many opportunity potential benefit adult social care',
#  'generative ai large language model llm power ai chatbots aid various task social care',
#  'however many activity social care directly touch people human right wellbeing',
#  'currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail',
#  'aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case',
#  'core focus would constitute responsible ethical use emerging technology',
#  'following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care',
#  'addition commits group engaging coproduction consultation process drawing people organisation social care',
#  'full statement endorsed twenty-three participating organisation beread',
#  'according recent global report business agree generative ai gen ai substantial impact industry',
#  'however despite fanfare adoption rate technology remained abysmally low business',
#  'three quarter surveyed company experimented gen ai lowly nine percent admitted adopted technology',
#  'based survey conducted mit technology review insight telecom company telstrathe reportcovered three hundred csuite executive vice president director across asiapacific america europe',
#  'report question participant company using plan use gen ai technology',
#  'addition gauging interest technology report also highlight barrier adoption gen ai business',
#  'readgenerative ai market projected reach one trillion two thousand and thirty-one',
#  'misconception easy run mature enterpriseready generative ai said stela solar inaugural director australia national artificial intelligence centre report',
#  'agreeing solars assessment brian prince founder ceo top ai tool say investing gen ai expensive',
#  'argues beyond software business likely need also invest training infrastructure upgrade ongoing maintenance',
#  'especially true small medium enterprise may find challenging allocate sufficient budget without guaranteed shortterm return',
#  'telstra survey showed skill training company culture major impediment adoption say prince',
#  'integrating ai existing workflow system complex',
#  'speaking experience paolo danese ceo storya say observed tangible disconnect theoretical allure gen ai practical reality faced business',
#  'divergence technology encompasses broader concern readiness infrastructure steep learning curve effective deployment ethical consideration surrounding ai use say danese',
#  'building sukhdeep sohal senior consultant glue affinity reply say business apprehension towards gen ai often traced back series strategic operational disconnect',
#  'belief crux issue lie alignment lack thereof ai initiative overarching business strategy',
#  'ai strategy perceived standalone experiment rather integral part business growth disconnect breed reluctance say sohal',
#  'additionally delivery ai foundation piecemeal rather holistically fails instil confidence technology comprehensive benefit',
#  'report highlighted evolving regulatory compliance data privacy environment leading nontechnological barrier rapid gen ai adoption business',
#  'danese agrees saying business navigating uncharted water need balance push digital transformation adhering strict privacy standard',
#  'according prince especially true sector like healthcare finance legal data sensitivity critical concern',
#  'burden compliance becomes significant deterrent say',
#  'read5 way make money generative ai',
#  'peter john alexander chief business officer meetkai highlight nontechnical factor business must take consideration',
#  'say company likely fear potential data breach ethical misuse high implementation usage cost unreliable output risk falling behind competitor',
#  'apprehension highlight need careful consideration benefit risk generative ai deployment alongside proactive measure address security compliance ethical operational challenge say alexander',
#  'according report seventy-eight percent business look gen ai competitive opportunity',
#  'many expect number function deploying gen ai double two thousand and twenty-four',
#  'term actual use sixty-five percent respondent say business actively considering new innovative way use gen ai unlock hidden opportunity data',
#  'doesnt surprise sohal',
#  'say gen ai aligned wellarticulated strategy fit best leverage predictive power data stream identified rigorous data audit',
#  'suggests analysis especially predictive analytics prime area application directly amplifies strategic decisionmaking capability',
#  'read42 percent uae company adopt ai business operation say study',
#  'alexander agrees saying ai excels rapidly analyzing vast amount data surface pattern making prediction uncovering actionable insight',
#  'say could include customer analytics identify trend segment financial analysis forecasting operation optimization',
#  'leveraging ai business make smarter datadriven decision much faster manual analysis say alexander',
#  'according report rather confined specific sector gen ai likely transform specific function across economy customer service',
#  'also point two thousand and twenty-three national bureau economic research working paper predicts gen ai customer service could raise productivity fourteen percent',
#  'generative ai prowess natural language understanding generation position linchpin customer service revolution offering personalized efficient engaging user experience say danese',
#  'alexander belief business must approach gen ai transformative business capability scattershot set project',
#  'readmeta roll new generative ai feature uae saudi',
#  'ultimately best fit gen ai depends company unique need available data strategic priority say alexander',
#  'company align ai initiative overarching business goal start focused experiment prove value scale success',
#  'ensure readiness maximize benefit sohal suggests organization seek use case depending level ai maturity',
#  'additionally recommends business also look industry precedent validate inform approach',
#  'integrative strategy promise yield tangible business value elevating gen ai technological experiment cornerstone enterprise capability say sohal',
#  'technology news clickhere',
#  'world software development emergence generative ai sparked excitement skepticism',
#  'predict ai render many software development skill obsolete others cautious potential impact',
#  '20year veteran field ceo company serving software developer keith pitt share insight potential benefit danger generative ai software development',
#  'one significant positive impact generative ai potential eliminate grunt work developer',
#  'developer often spend considerable amount time detail like syntax punctuation automated ai',
#  'instead poring manual searching code snippet developer describe desired outcome receive perfectly formatted code response',
#  'additionally large language model llm help identify typo punctuation mistake detail tedious developer',
#  'generative ai also potential reinvent software framework',
#  'framework like spring expressjs django already increased productivity abstracting mundane aspect software development',
#  'help gen ai framework enhance value creating boilerplate code automating repetitive task suggesting code optimization',
#  'ai also assist customizing framework component specific project',
#  'another significant change brought generative ai rise generalist developer',
#  'traditionally developer specialized specific language backend skill',
#  'however machine capable generating code language language proficiency may become le important',
#  'valuable skill machine replicate building user interface translating user requirement specification inventing new way support customer',
#  'shift put spotlight developer excel area',
#  'generative ai also hold great potential revolutionizing software testing',
#  'developer write code bot generate numerous test script quickly efficiently',
#  'according recent idc survey anticipated benefit generative ai software development software quality assurance security testing',
#  'disruption devops practice continuous integrationdeployment may lead testing specialist seeking new opportunity',
#  'lowcodenocode development tool already made software development accessible generative ai take next level',
#  'currently tool require individual piece together workflow whiteboard translating code',
#  'future developer able provide handdrawn sketch desired workflow ai model generate necessary code second',
#  'however essential recognize generative ai panacea',
#  'potential downside need considered',
#  'one concern risk overtesting',
#  'ai model capable generating test quickly possibility ending test necessary',
#  'overtesting slow project create bottleneck development pipeline',
#  'ai recommendation remove test could help address issue',
#  'skill degradation another potential danger associated generative ai',
#  'lazy developer may rely ai find shortcut leading bloated inefficient poorly performing code',
#  'reliance existing pattern data may limit innovative potential developer think outside box explore new solution',
#  'trust crucial come generative ai',
#  'quality data used train ai model significantly impact performance',
#  'poor quality data training shortcut inadequate prompt engineering result aigenerated code meet quality standard fails fulfill intended function',
#  'organization must trust quality generative ai fully benefit potential',
#  'despite potential benefit danger unlikely ai make software developer obsolete',
#  'historical precedent show technological advancement consistently made developer productive without diminishing demand skill',
#  'generative ai may affect market lowend basic coding skill push entire profession focus innovation highervalue task',
#  'creative problemsolving skill developer remain high demand',
#  'rather resisting change brought generative ai developer embrace',
#  'prospect eliminating tedious task software development excite everyone',
#  'certain function may disappear serve incentive developer upskill focus area machine yet capable',
#  'highquality developer translate business requirement elegant performant software always demand',
#  'developer adapt skill ride wave generative ai thrive evolving software development landscape',
#  'conclusion generative ai potential revolutionize software development eliminating grunt work reinventing framework promoting generalist skill revolutionizing testing enhancing lowcodenocode development tool',
#  'however potential risk overtesting skill degradation trust deficit need addressed',
#  'although ai make software developer obsolete push profession towards highervalue task innovation',
#  'developer embrace change brought generative ai focus upskilling remain valuable evolving landscape',
#  'ian goldinprofessor globalisation development oxford martin schooland report coauthor said generative ai dualedged sword offer enormous potential accelerate solution number world greatest challenge new health cure energy innovation',
#  'also could destroy job undermine democracy widen inequality division within society country',
#  'challenge develop regulatory framework guardrail required ensure benefit widely shared sustained',
#  'generative aioffers enormous potential accelerate solution number world greatest challengesbut also could destroy job undermine democracy widen inequality',
#  'professor ian goldin',
#  'contribution tounleashing ai citi investment bank oxford martin team explores opportunity challenge generative artificial intelligence found potential opportunity',
#  'dr pantelis koutroumpisdirector oxford martin programme technological economic change report coauthor said generative ai already shown impressive potential across range application recent month',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'beyond data better computing resource model excel fed highquality human generated input',
#  'adoption technology appears correlate sizeable productivity boost limitation also evident user',
#  'dr pantelis koutroumpis',
#  'report also highlight series challenge including',
#  'report concludes world ai arm race country striving establish scientific technological dominance research output patenting',
#  'article',
#  'tech giant arent much acquiring day due mostly unfavorable regulatory environment',
#  'theyre finding way spend billion dollar next big thing',
#  'amazons275 billion investment artificial intelligence startup anthropic announced week itslargest venture dealand latest example ai gold rush thats prompting biggest tech company fling open wallet',
#  'anthropic developer behind ai model claude competes gpt frommicrosoftbacked openai andgooglesgemini',
#  'along withmetaandapple theyre racing integrate generative ai vast portfolio product feature ensure dont fall behind market thatspredicted top one trillionin revenue within decade',
#  'two thousand and twenty-three investor pumped two hundred and ninety-one billion combined nearly seven hundred generative ai deal increase two hundred and sixty value prior year according pitchbook',
#  'significant chunk money strategic came tech company rather venture capitalist institution',
#  'fred havemeyer head u ai software research macquarie said fear missing one factor driving decision',
#  'definitely dont want miss part ai ecosystem havemeyer said',
#  'definitely think there fomo marketplace',
#  'hefty investment necessary ai model notoriously expensive build train requiring thousand specialized chip date largely come fromnvidia',
#  'meta developing model calledllama said spending billion nvidias graphic processing unit one many company thats helped chipmakerbolsteryearoveryear revenue two hundred and fifty',
#  'whether going building investing route finite number company afford play market',
#  'addition developing chip nvidia emerged one silicon valley top investor taking stake number emerging ai company partly way make sure technology get widely deployed',
#  'similarly microsoft google amazon sometimes offer cloud credit part investment',
#  'amazonanthropic deal announced wednesday two company said theyll work closely together variety way',
#  'anthropic using amazon web service computing need well amazon chip',
#  'anthropics model distributed amazon aws customer',
#  'earlier month anthropic launchedclaude three powerful model one say let user upload photo chart document type unstructured data analysis answer',
#  'microsoft got business generative ai investing earlier putting1 billioninto openai two thousand and nineteen',
#  'size investment since swelled thirteen billion',
#  'microsoft heavily us openais model offer open source model azure cloud',
#  'alphabet playing part builder investor',
#  'company refocused much product development generative ai newly rebranded gemini model adding feature search document map elsewhere',
#  'last year googlecommittedto invest two billion anthropic previously confirming taken ten stake startup alongside large cloud contract two company',
#  'havemeyer said tech giant arent throwing money hype cycle investment ai startup align product road map',
#  'dont think frivolous said',
#  'havemeyer said alliance big cloud provider bring muchneeded cash startup also help sign customer',
#  'cloud company saying come u work platform native access latest greatest ai model also use infrastructure havemeyer said',
#  'also part much larger ecosystem play',
#  'seeing lot alliance appearing among hyperscalers substantial scale infrastructure deep pocket added',
#  'recent earnings call tech exec reiterated focus generative ai making clear investor spend money make money whether internal development investing startup',
#  'microsoft chief financial officer amy hood said last year company adjusting workforce toward aifirst work without adding material number people workforce',
#  'said microsoft continue prioritize investing ai thing thats going shape next decade',
#  'leader google apple amazon alsosuggested investorsthat theyre willing cut cost broadly across department order redirect funding toward ai effort',
#  'startup among beneficiary',
#  'microsoft taken stake mistral figure humane addition openai',
#  'company invested inflection ai startup essentially dissolved joined microsoft month',
#  'mistral open sourcefocused company us azure cloud offer service azure client',
#  'figure startup seeking build robot walk like human raised money microsoft openai nvidia wasvalued last monthat twenty-six billion',
#  'amazon biggest bet anthropic pouring total four billion far',
#  'company also invested open source ai platform developer hugging face',
#  'google investment include essential ai developing consumer ai program backed byamdand nvidia',
#  'alphabet nvidia also investor runway ml generative ai company known videoediting visual effect tool',
#  'others nvidias portfolio include mistral perplexity cohere',
#  'meanwhile many big tech company continue spend internally developing model',
#  'microsoft invested many technique underpinning generative ai microsoft research division',
#  'amazonreportedlyhas plan train bigger datahungry model even openais gpt4',
#  'apple researcher recently published detail work mm1a family small ai modelsthat take text visual input',
#  'apple different position peer doesnt sell cloud service',
#  'still tech giant reportedly looking ai partner including potentially google u andbaiduin china',
#  'apple representative declined comment ai partner',
#  'daniel newman ceo technology analysis firm futurum group said tech company get clever come investing ai',
#  'example openais investment microsoft included profit sharing nonprofit wing well credit use microsofts cloud service',
#  'microsofts deal inflection ai amounted expensive acquihire report putting total outlay at1 billion',
#  'part transaction microsofthiredinflection ai founder mustafa suleyman lead copilot ai initiative',
#  'think starting see creativity dealmaking said newman',
#  'respect amazon agreement anthropic said acquisition would lot harder investing',
#  'thats regulator across globe cracking big tech making difficult sizable acquisition',
#  'even investment attracting scrutiny',
#  'january federal trade commission announced willconduct extensive inquiryinto field biggest player ai including amazon alphabet microsoft anthropic openai',
#  'ftc chair lina khan described probe market inquiry investment partnership formed ai developer major cloud service provider',
#  'regulator authority order company file specific report answer question writing business',
#  'know regulator becoming increasingly focused traditional path closing acquisition newman said',
#  'right game access fundamental ip',
#  'watchai hype drive valuation higher',
#  'hardly day go generative ai genai doesnt dominate business medium headline',
#  'last twelve month become ubiquitous business strategy organization across industry increasingly investing genai solution',
#  'google trend data visualizesgenais rise center business relevance since two thousand and twenty-two peaking june two thousand and twenty-three',
#  'certainly cant ignore transformative potential genai jumping right without adequate planning mean risking resource without guaranteed roi',
#  'custom genai solution expensive costing three hundred thousand dollar annuallyaccording webfx require deep technical expertise maintain',
#  'reality organization ready invest genai',
#  'leader may feel pressure buy hype taking genai operationally realistic mean huge drain resourcesaccording mckinsey business area stand benefit gen ai include sale marketing customer relation customer operation software development research development',
#  'using gen ai business function like finance hr may yield return',
#  'meantime hype wane genai becomes polished accessible way exist move innovation forward',
#  'prioritizing operational efficiency best way guarantee measurable roi',
#  'largest benefit likely come following use case',
#  'organization strong area already relevant business goal gen ai solution may necessary',
#  'here know make move',
#  'making major investment organization take pause ass internal structure identify gap data process inefficiency silo business function',
#  'along way knowing successful genai implementation relies quality data leader ask process digitized automated better organized maximize resource streamline operation optimize efficiency scalability',
#  'ceo ask following question ready right people aiming right generating revenue',
#  'consider amazon relentless focus customer experience philosophy embedded deeply operational ethos',
#  'approach led innovation like amazon walk technology leveraging ai machine learning reimagine retail',
#  'similarly business contemplating genai investment must start deep dive operational fabric identifying inefficiency area digital transformation catalyze revolutionary customer experience',
#  'clear understanding operational process improved consider give time back teamsfreeing space continued learning preparation genai',
#  'one option embrace citizen development allowing nontechnical employee build apps simply quickly bring efficiency scalability mundane task',
#  'using lowcode nocode tool general business user build custom apps without burdening team',
#  'team pepsi relied heavily lowcodenocode build deploy digital application inventory merchandising function saving company five hundred thousand first year without professional developer staffaccording venturebeat',
#  'intuitive visual interface prebuilt template draganddrop element solve seemingly complicated business problem required coding knowledge little day minimal reeducation',
#  'embracing approach allows team understand nuance digital engineering turn focus genai without sacrificing team productivity',
#  'creating infrastructure designed grow business top priority technology leader two thousand and twenty-four',
#  'inefficiency created first wave digital transformation need corrected',
#  'key maximizing return genai investment aim big start small grow incrementally following wellplanned roadmap',
#  'focusing first streamlining existing process gradually introducing genai one use case time organization ensure genai integrated amplifies rather disrupts operational effectiveness',
#  'truly capitalize transformative potential genai business must approach integration incrementally focusing longterm improvement',
#  'journey toward genai efficiency technical upgrade strategic initiative requires holistic view business process technical culture goal',
#  'embedding genai operation already optimized agility innovation company ensure investment enhances current capability also open new avenue growth differentiation',
#  'real return genai investment lie adoption technology sake strategic integration core business',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'mohan chief evangelist digital transformation atkissflow',
#  'mohan extensive experience implementing erp banking insurance solution apac usa europe leading large team deliver outstanding client outcome',
#  'recent focus leading client digital transformation journey',
#  'specializes conducting design thinking workshop identify problem evaluate benefit various innovative idea',
#  'engineer iit mba xlri',
#  'boil ocean ai',
#  'bridging digital divide role aipowered platformcentric strategy crafting futureready enterprise',
#  'three way ai overcomes custom delay',
#  'fusion robotics ai arvr two thousand and twenty-four revolution manufacturing',
#  'ai hr navigating opportunity challenge',
#  'advancement ai mixed reality technology continued training development healthcare industry',
#  'creating real value generative ai put people center',
#  'creating real value generative ai put people center',
#  'generative ai democratizes creative process anyone create text image presentation video music instant',
#  'however without human creativity little value',
#  'role human creative process',
#  'organization cleverly combine',
#  'creativity generating new valuable idea lead innovative solution problem',
#  'thats limited artist genius according mihaly csikszentmihalyi creator term flow author book creativity',
#  'argues creativity broad accessible human trait',
#  'creativity work exactly',
#  'important factor creativity deep human involvement',
#  'pattern lead creativity include suffering struggle like vincent van gogh dream isaac newton joy filmmaker david lynch practice transcendental meditation',
#  'typing smart prompt chatgpt show little involvement question extent result generative ai really called creative',
#  'however still essential question extent creativity actually important company',
#  'creativity make distinction impact',
#  'due generative ai flood aigenerated content way',
#  'meme deepfakes book amazon music video presentation audacity mail faq personal recommendation business chatbots code content creation',
#  'direct result democratization generative ai lowerquality output',
#  'read full articlehere',
#  'open dutch',
#  'learn epam revolutionizing future business power aihttpswwwepamcomservicesartificialintelligence',
#  'voor echte waarde creëren met generatieve ai stel de men centraal',
#  'generatieve ai democratiseert creatieve processen iedereen kan nu een handomdraai teksten afbeeldingen presentaties video muziek en meer creëren',
#  'zonder menselijke creativiteit heeft het echter weinig waarde',
#  'wat de rol van de men het creatieve proces',
#  'hoe kunnen organisaties beiden slim combineren',
#  'creativiteit gaat het genereren van nieuwe en waardevolle ideeën die leiden tot innovatieve oplossingen voor problemen',
#  'dat niet beperkt tot kunstenaars en genieën volgensmihaly csikszentmihalyi de bedenker van de term flow en schrijver van het boekcreativiteit',
#  'hij stelt dat creativiteit een brede en toegankelijke menselijke eigenschap',
#  'hoe werkt creativiteit precies',
#  'een belangrijke factor voor creativiteit diepe menselijke betrokkenheid',
#  'patronen die leiden tot creativiteit zijn bijvoorbeeld lijden en strijd zoals vincent van gogh dromen isaac newton en vreugde filmmaker david lynch die transcendentale meditatie beoefent',
#  'een slimme prompt intikken chatgpt toont weinig van deze betrokkenheid de vraag hoeverre de uitkomsten van generatieve ai dus echt creatief zijn te noemen',
#  'daar zit echter nog een essentiële vraag voor hoeverre creativiteit eigenlijk belangrijk voor bedrijven',
#  'creativiteit maakt onderscheid en impact',
#  'door generatieve ai er een stortvloed aan aigegenereerde content op komst',
#  'van meme deepfakesboeken op amazonenmuziekvideopresentatie van audacity tot mail faq persoonlijke aanbevelingen zakelijke chatbots code en contentcreatie',
#  'dit een direct gevolg van de democratisering van generative ai meer output van lagere kwaliteit',
#  'lee hier het volledige artikel',
#  'ontdek hoe epam een revolutie teweegbrengt de toekomst van het bedrijfsleven met de kracht van aihttpswwwepamcomservicesartificialintelligence',
#  'featured story',
#  'according global consultancy bain company insurance organisation across globe a50 billionfinancial opportunity generative ai genai harness technology way could boost revenue much twenty well cut cost fifteen',
#  'new report released firm reveals leveraging genai insurance distribution potential yield than50 billionin annual economic benefit company across sector',
#  'bhavimehta global lead ai financial service bain commented insurer benefit due generative ai come three route',
#  'includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise',
#  'bain remain committed helping client within insurance across industry identify realize ai full business potential',
#  'moreover bain company noted genai permeates insurance company operation early initiative suggesting technology transform distribution four way including',
#  'meanwhile bains analysis also highlight several key risk area emerging insurer developing use genai include hallucination data provenance misinformation toxicity intellectual property ownership',
#  'sean oneill leader bains global insurance practice said nascent technology risk',
#  'manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation',
#  'however genai continuing develop evolve bain urge insurer take several critical step adapt fastdeveloping technology',
#  'include aligning across business unit ai support business strategy determining build internally buy vendor well ensuring delivery team crossfunctional designing operating model adaptable',
#  'reuters openai start allowing user access freetouse chatgpt generative ai chatbot without needing sign service beginning monday microsoftbacked startup said monday',
#  'chatgpt kickstarted genai boom late two thousand and twenty-two mimic human conversation perform task creating summary long text writing poem even generating idea theme party',
#  'san franciscobased company said gradually roll feature make ai accessible anyone curious capability',
#  'popular service set record fastestgrowing user base seen growth slow since may two thousand and twenty-three traffic peaked eighteen billion web visit according data analytics firm similarweb',
#  'openai said introduced additional content safeguard user accessing chatgpt without signing blocking prompt generation wider range category',
#  'specify category',
#  'apart free version chatgpt direct access internet openai also offer paid version individual team user enterprise',
#  'company also said may use content provided user help improve largelanguage model said user turn feature',
#  'move come month billionaire entrepreneur elon musk sued openai ceo sam altman saying abandoned startup original mission develop artificial intelligence benefit humanity profit',
#  'reporting arsheeya bajwa bengaluru anna tong san francisco krystal hu new york editing tasim zahid',
#  'spread fake news disinformation steadily risen past year audience increasingly getting news online false information sometimes generated ai spread faster threatening audience trust medium',
#  'series infographics euractiv take deeper dive trend playing across europe medium landscape',
#  'trend consumer trusting medium le le observed resulting turning social medium get news instead',
#  'boththis yearandlast year u trust medium hit alltime low',
#  'pattern eu laid graph',
#  'meanwhiletiktok example popular among younger generation alternative traditional news source',
#  'using data two thousand and twenty chart also show social medium play big role news source',
#  'yet according aeurobarometer surveypublished european parliament seventeen november us two thousand and twenty-two data main source news television seventy-one respondent saying one used source past seven day time research',
#  'however eleven increase using social medium platform get news compared last year survey',
#  'counteract risk artificial intelligence believe aican help debunk fake news horizon europe project ai4trust',
#  'ai4trust isdevelopinga system based machinehuman cooperation advanced solution horizon europe two hundred and two thousand, three hundred and twenty-four work programmeaimsto move closer aibased market solution ensure access meaningful information quality content trustworthy online interaction',
#  'however social medium platform also source',
#  'knowing real aigenerated help trust news',
#  'march example eu law enforcement agency europolwarnedthat chatgpt benefit business individual malicious actor exploit technology posing law enforcement challenge',
#  'criminal typically quick exploit new technology fast seen coming concrete criminal exploitation providing first practical example mere week public release chatgpt read thereport',
#  'dissemination nude image minor created ai concern law enforcement one bound become increasingly difficult address europol alsotold euractivin october',
#  'law enforcement agency added aigenerated material must detected using ai classifier tool currently authorised use classifier tool specific purpose',
#  'european union reading news online increased past year graph show two thousand and thirteen two thousand and twenty-two according tostatista',
#  'online frequency type fake news reader differ seen graph cover europe largest country',
#  'frequency seeing disinformation depend different type medium citizen exposure level disinformation general every country either',
#  'country may different percentage regarding fake news following map show scandinavian country le affected central southern europe',
#  'last year bulgarian citizen highest exposure misinformation twenty-eight april twenty-six may eleven living netherlands least exposed six',
#  'regardless frequency exposure seeing false information impact one life differently',
#  'claim thirty-five check news thoroughly encounter',
#  'however almost many people thirty-three believe impact',
#  'edited alice taylornathalie weatherald',
#  'significant hype fear ai particularly generative ai crowding news headline last week',
#  'generative ai least context us large language model create response',
#  'essentially selftrained ai smart collectively',
#  'use training data make educated guess',
#  'algorithmic',
#  'complicated math',
#  'make pretty good guess time',
#  'yes',
#  'however ai today isnt actual intelligence actual sapience fact lost many result fromgenerative aican impressive',
#  'gold standard business intelligence',
#  'find',
#  'need think intake information',
#  'anything human race learned need critically examine information given',
#  'fear generative ai fooled',
#  'happened already',
#  'happened',
#  'human inclined believe gullible want believe giving u information good intention',
#  'ai today intention',
#  'moral give use generate u',
#  'need apply scepticism',
#  'hard appears',
#  'anyone take television advertisement really kind ad undisputed truth',
#  'course',
#  'assumed advertiser best interest heart economic interest',
#  'verification stated claim required product service purchased',
#  'individual need apply level scepticism nearly everything read see',
#  'including article',
#  'time panic generative ai',
#  'technology impressive extremely helpful',
#  'time educate raise standard accepting see truth',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'adapt willing far benefit ai bring worth challenge',
#  'leveraging advanced generative ai capability seamlessly integrated itsconversational commercesolution vonage arming business tool create realtime personalised connection customer across platform delivering meaningful customer data streamlining operation automation notesvonage',
#  'generative aipowered update vonage conversational commerce solution addition marketing template content generator live chat assistance intuitive knowledge base inquiry making impact across customer touchpoints today enterprise including agent marketing customer support team',
#  'vonage say core new generative aipowered capability aipowered assistance live chat interaction helping agent tailor response provide better customer service realtime improving accelerating live chat response customer well rephrasing functionality ensure precise communication allowing agent refine tone response power ai helping business enhance agent productivity overall communication effectiveness',
#  'also included new offering content generator designed crafting whatsappbased marketing template empower brand speed simplify production diverse marketing content significantly reduce workload marketing team',
#  'significantly reducing time resource craft diverse marketing message marketing team better equipped run multiple campaign still ensuring message resonates individual customer',
#  'intuitive template business unlocking kind connection drive real lead ultimate profitability',
#  'aipowered answer offering knowledge base also help reduce human dependency allow knowledge base ai bot interpret user query parse knowledge base document answer user query directly',
#  'utilising document uploaded knowledge base respond query streamline customer support knowledge base eliminates need canned impersonal response delivering personalised experience customer vonage note',
#  'seeing significant increase demand integrated ai capability easily expanded across platform business recognise efficiency customization possibility generative ai offer saidsavinay berry evp product engineering vonage',
#  'integrating stateoftheart generative ai capability conversational commerce solution empowering user generate creative content automate task improve overall user experience',
#  'advancement generative ai harnessed significantly enhance conversational commerce solution empowering ecommerce marketer online retailer seamlessly connect potential customer delivering personalised experience saidkrishna baidya sr director information communication technology frost sullivan',
#  'infusing generative ai knowledge base brand respond query streamline customer support ensuring efficient reliable selfservice option conversation',
#  'adding aipowered assistance live chat interaction boost agent productivity communication effectiveness',
#  'according vonage referral marketing continues powerful strategy business reach target customer drive sale vonage conversational commerce user initiate whatsapp referral campaign right dashboard giving ability acquire new customer without additional marketing overhead cost',
#  'whatsapp vonage weve able better identify market top twenty-five percent active subscriber saidkamila skötsch global crm team leadholidaypirates international travel company vonage conversational commerce customer',
#  'subscriber using whatsapp faster act deal people using channel generating traffic partner clickthroughrates high forty percent message receiving ninety-seven percent open rate',
#  'vonage also launched conversational commerce apis enable third party application connect jumperai dashboard deliver conversational marketing commerce capability via integration leading customer engagement platform moengage salesforce marketing cloud',
#  'developer apis empower marketer product owner extend platform lower level 1way notification richer 2way conversation leveraging vonage conversational commerce capability share product catalog complete transactionturning notification sale concludes vonagegenerative aipowered enhancement vonage conversational commerce powered jumperai solution currently beta generally available second quarter two thousand and twenty-four']

# %%
for i in sentences:
  print(f'{i}\n')
# Out:
# india cusp digital hyper growth
#
# indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever
#
# speed agility along adequate understanding deployment relevant technology make difference
#
# digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four
#
# despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy
#
# believe next year genai stay limelight also find way many initiative across company india
#
# top five india technology prediction two thousand and twenty-four
#
# glimpse top prediction
#
# many prediction around tech always finer nuance around would benefit dialogue
#
# would happy chat topic detail
#
# please reach u inquiry guidance session know
#
# brian hopkins vp emerging tech portfolio
#
# julie mohr principal analyst
#
# ted schadler vp principal analyst
#
# generative ai genai disruptive force disruptive
#
# know big quite sure big
#
# colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u
#
# kicking new research stream withted schadlerjulie mohr others explore topic
#
# focus disruptive impact genai industry market economy
#
# today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government
#
# last week ted published first blog topicgenai shatter reconstruct every company industry
#
# pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming
#
# next step research stream diving technical
#
# two belief
#
# two reality impact every industry mean disruption hit every firm equally
#
# believe impact based use knowledge create business value
#
# example
#
# beginning
#
# research go deeper
#
# seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk
#
# brian hopkins julie mohr julie ask investigating generative ai genai change face business industry
#
# research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure
#
# look back twenty-five year longlasting economic value created captured
#
# company industry country win
#
# lose
#
# along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question
#
# artificial intelligence shatter reconstruct company industry country redefine role company play genainative future
#
# see change inevitable murky future early day internet
#
# seeking understand artificial general intelligence examine existential threat
#
# rather assume ability govern keep ai safe grow ai grows
#
# future look like
#
# post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai
#
# colleague brian hopkins posting shortly early hypothesis happen
#
# also look upcoming post julie mohr julie ask
#
# first productivitycentric wave genai impact company coming focus
#
# improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry
#
# kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model
#
# aboutgenais impact revenue generating new revenue stream extension channel
#
# reinventionhow company reinvent themselvesusing power genai
#
# next twenty-five year genaiforce entire industry restructureto take advantage value generated machine
#
# country respond toset economy citizen success
#
# invite idea participation part research pursue question
#
# learn impact generative ai read bloggenais worldchanging power putting knowledge work
#
# interested view generative ai
#
# please reach schedule time via inquiry team emailing inquiryforrestercom
#
# eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected
#
# effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said
#
# said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result
#
# analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed
#
# figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp
#
# author described worst case scenario
#
# painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training
#
# new drake song cause confusion listener question whether ai rapper behind
#
# creating fake sexual image another person become criminal offence
#
# ai helping meta fight misinformation election say former deputy pm nick clegg
#
# please use chrome browser accessible video player
#
# claimed could lead economic boost thirteen gdp around 306bn year best case
#
# government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics
#
# carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u
#
# please use chrome browser accessible video player
#
# many firm already investing potential speed many task business adopt
#
# next five year could transform knowledge work
#
# question le whether ai useful rather fast manner employer use
#
# history show technological transition boon well managed end disruption left unfold without control
#
# first getbreaking news
#
# install sky news app free
#
# read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel
#
# spokesperson department science innovation technology said research hugely speculative
#
# numerous report also predict ai spark huge creation job unlocking growth ramping productivity
#
# ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future
#
# continue ass impact ai different sector ensure employer play leading role building robust uk skill talent
#
# also working innovate uk alan turing institute develop guidance core ai skill people need published later year
#
# recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan
#
# first base ai labour market
#
# help maximise benefit ai employer government work together particularly skill development compliance
#
# fastmoving area one need people proficient trained using ai also given skill adapt future development
#
# education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy
#
# ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience
#
# bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find
#
# bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector
#
# insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain
#
# includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise
#
# bain remain committed helping client within insurance across industry identify realize ai full business potential
#
# generative ai transform insurance distribution four way
#
# early use generative ai within insurance suggests technology transform distribution four way including
#
# managing risk
#
# bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership
#
# nascent technology risk saidsean oneill leader bains global insurance practice
#
# manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation
#
# critical step insurance business leader
#
# generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology
#
# include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable
#
# medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected
#
# bain company
#
# bain company global consultancy help world ambitious change maker define future
#
# across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry
#
# complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome
#
# 10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment
#
# earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company
#
# since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry
#
# source bain company
#
# machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty
#
# unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market
#
# banking financial service
#
# insurance
#
# data analytics
#
# data analytics
#
# morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure
#
# regard highlight significant growth revenue capture opportunity company meet energy need
#
# specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe
#
# adult social care supporting people live independently protect fundamental human right
#
# generative ai offer many potential benefit opportunity adult social care
#
# however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately
#
# therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college
#
# artificial intelligence offer many opportunity potential benefit adult social care
#
# generative ai large language model llm power ai chatbots aid various task social care
#
# however many activity social care directly touch people human right wellbeing
#
# currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail
#
# aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case
#
# core focus would constitute responsible ethical use emerging technology
#
# following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care
#
# addition commits group engaging coproduction consultation process drawing people organisation social care
#
# full statement endorsed twenty-three participating organisation beread
#
# according recent global report business agree generative ai gen ai substantial impact industry
#
# however despite fanfare adoption rate technology remained abysmally low business
#
# three quarter surveyed company experimented gen ai lowly nine percent admitted adopted technology
#
# based survey conducted mit technology review insight telecom company telstrathe reportcovered three hundred csuite executive vice president director across asiapacific america europe
#
# report question participant company using plan use gen ai technology
#
# addition gauging interest technology report also highlight barrier adoption gen ai business
#
# readgenerative ai market projected reach one trillion two thousand and thirty-one
#
# misconception easy run mature enterpriseready generative ai said stela solar inaugural director australia national artificial intelligence centre report
#
# agreeing solars assessment brian prince founder ceo top ai tool say investing gen ai expensive
#
# argues beyond software business likely need also invest training infrastructure upgrade ongoing maintenance
#
# especially true small medium enterprise may find challenging allocate sufficient budget without guaranteed shortterm return
#
# telstra survey showed skill training company culture major impediment adoption say prince
#
# integrating ai existing workflow system complex
#
# speaking experience paolo danese ceo storya say observed tangible disconnect theoretical allure gen ai practical reality faced business
#
# divergence technology encompasses broader concern readiness infrastructure steep learning curve effective deployment ethical consideration surrounding ai use say danese
#
# building sukhdeep sohal senior consultant glue affinity reply say business apprehension towards gen ai often traced back series strategic operational disconnect
#
# belief crux issue lie alignment lack thereof ai initiative overarching business strategy
#
# ai strategy perceived standalone experiment rather integral part business growth disconnect breed reluctance say sohal
#
# additionally delivery ai foundation piecemeal rather holistically fails instil confidence technology comprehensive benefit
#
# report highlighted evolving regulatory compliance data privacy environment leading nontechnological barrier rapid gen ai adoption business
#
# danese agrees saying business navigating uncharted water need balance push digital transformation adhering strict privacy standard
#
# according prince especially true sector like healthcare finance legal data sensitivity critical concern
#
# burden compliance becomes significant deterrent say
#
# read5 way make money generative ai
#
# peter john alexander chief business officer meetkai highlight nontechnical factor business must take consideration
#
# say company likely fear potential data breach ethical misuse high implementation usage cost unreliable output risk falling behind competitor
#
# apprehension highlight need careful consideration benefit risk generative ai deployment alongside proactive measure address security compliance ethical operational challenge say alexander
#
# according report seventy-eight percent business look gen ai competitive opportunity
#
# many expect number function deploying gen ai double two thousand and twenty-four
#
# term actual use sixty-five percent respondent say business actively considering new innovative way use gen ai unlock hidden opportunity data
#
# doesnt surprise sohal
#
# say gen ai aligned wellarticulated strategy fit best leverage predictive power data stream identified rigorous data audit
#
# suggests analysis especially predictive analytics prime area application directly amplifies strategic decisionmaking capability
#
# read42 percent uae company adopt ai business operation say study
#
# alexander agrees saying ai excels rapidly analyzing vast amount data surface pattern making prediction uncovering actionable insight
#
# say could include customer analytics identify trend segment financial analysis forecasting operation optimization
#
# leveraging ai business make smarter datadriven decision much faster manual analysis say alexander
#
# according report rather confined specific sector gen ai likely transform specific function across economy customer service
#
# also point two thousand and twenty-three national bureau economic research working paper predicts gen ai customer service could raise productivity fourteen percent
#
# generative ai prowess natural language understanding generation position linchpin customer service revolution offering personalized efficient engaging user experience say danese
#
# alexander belief business must approach gen ai transformative business capability scattershot set project
#
# readmeta roll new generative ai feature uae saudi
#
# ultimately best fit gen ai depends company unique need available data strategic priority say alexander
#
# company align ai initiative overarching business goal start focused experiment prove value scale success
#
# ensure readiness maximize benefit sohal suggests organization seek use case depending level ai maturity
#
# additionally recommends business also look industry precedent validate inform approach
#
# integrative strategy promise yield tangible business value elevating gen ai technological experiment cornerstone enterprise capability say sohal
#
# technology news clickhere
#
# world software development emergence generative ai sparked excitement skepticism
#
# predict ai render many software development skill obsolete others cautious potential impact
#
# 20year veteran field ceo company serving software developer keith pitt share insight potential benefit danger generative ai software development
#
# one significant positive impact generative ai potential eliminate grunt work developer
#
# developer often spend considerable amount time detail like syntax punctuation automated ai
#
# instead poring manual searching code snippet developer describe desired outcome receive perfectly formatted code response
#
# additionally large language model llm help identify typo punctuation mistake detail tedious developer
#
# generative ai also potential reinvent software framework
#
# framework like spring expressjs django already increased productivity abstracting mundane aspect software development
#
# help gen ai framework enhance value creating boilerplate code automating repetitive task suggesting code optimization
#
# ai also assist customizing framework component specific project
#
# another significant change brought generative ai rise generalist developer
#
# traditionally developer specialized specific language backend skill
#
# however machine capable generating code language language proficiency may become le important
#
# valuable skill machine replicate building user interface translating user requirement specification inventing new way support customer
#
# shift put spotlight developer excel area
#
# generative ai also hold great potential revolutionizing software testing
#
# developer write code bot generate numerous test script quickly efficiently
#
# according recent idc survey anticipated benefit generative ai software development software quality assurance security testing
#
# disruption devops practice continuous integrationdeployment may lead testing specialist seeking new opportunity
#
# lowcodenocode development tool already made software development accessible generative ai take next level
#
# currently tool require individual piece together workflow whiteboard translating code
#
# future developer able provide handdrawn sketch desired workflow ai model generate necessary code second
#
# however essential recognize generative ai panacea
#
# potential downside need considered
#
# one concern risk overtesting
#
# ai model capable generating test quickly possibility ending test necessary
#
# overtesting slow project create bottleneck development pipeline
#
# ai recommendation remove test could help address issue
#
# skill degradation another potential danger associated generative ai
#
# lazy developer may rely ai find shortcut leading bloated inefficient poorly performing code
#
# reliance existing pattern data may limit innovative potential developer think outside box explore new solution
#
# trust crucial come generative ai
#
# quality data used train ai model significantly impact performance
#
# poor quality data training shortcut inadequate prompt engineering result aigenerated code meet quality standard fails fulfill intended function
#
# organization must trust quality generative ai fully benefit potential
#
# despite potential benefit danger unlikely ai make software developer obsolete
#
# historical precedent show technological advancement consistently made developer productive without diminishing demand skill
#
# generative ai may affect market lowend basic coding skill push entire profession focus innovation highervalue task
#
# creative problemsolving skill developer remain high demand
#
# rather resisting change brought generative ai developer embrace
#
# prospect eliminating tedious task software development excite everyone
#
# certain function may disappear serve incentive developer upskill focus area machine yet capable
#
# highquality developer translate business requirement elegant performant software always demand
#
# developer adapt skill ride wave generative ai thrive evolving software development landscape
#
# conclusion generative ai potential revolutionize software development eliminating grunt work reinventing framework promoting generalist skill revolutionizing testing enhancing lowcodenocode development tool
#
# however potential risk overtesting skill degradation trust deficit need addressed
#
# although ai make software developer obsolete push profession towards highervalue task innovation
#
# developer embrace change brought generative ai focus upskilling remain valuable evolving landscape
#
# ian goldinprofessor globalisation development oxford martin schooland report coauthor said generative ai dualedged sword offer enormous potential accelerate solution number world greatest challenge new health cure energy innovation
#
# also could destroy job undermine democracy widen inequality division within society country
#
# challenge develop regulatory framework guardrail required ensure benefit widely shared sustained
#
# generative aioffers enormous potential accelerate solution number world greatest challengesbut also could destroy job undermine democracy widen inequality
#
# professor ian goldin
#
# contribution tounleashing ai citi investment bank oxford martin team explores opportunity challenge generative artificial intelligence found potential opportunity
#
# dr pantelis koutroumpisdirector oxford martin programme technological economic change report coauthor said generative ai already shown impressive potential across range application recent month
#
# adoption technology appears correlate sizeable productivity boost limitation also evident user
#
# beyond data better computing resource model excel fed highquality human generated input
#
# adoption technology appears correlate sizeable productivity boost limitation also evident user
#
# dr pantelis koutroumpis
#
# report also highlight series challenge including
#
# report concludes world ai arm race country striving establish scientific technological dominance research output patenting
#
# article
#
# tech giant arent much acquiring day due mostly unfavorable regulatory environment
#
# theyre finding way spend billion dollar next big thing
#
# amazons275 billion investment artificial intelligence startup anthropic announced week itslargest venture dealand latest example ai gold rush thats prompting biggest tech company fling open wallet
#
# anthropic developer behind ai model claude competes gpt frommicrosoftbacked openai andgooglesgemini
#
# along withmetaandapple theyre racing integrate generative ai vast portfolio product feature ensure dont fall behind market thatspredicted top one trillionin revenue within decade
#
# two thousand and twenty-three investor pumped two hundred and ninety-one billion combined nearly seven hundred generative ai deal increase two hundred and sixty value prior year according pitchbook
#
# significant chunk money strategic came tech company rather venture capitalist institution
#
# fred havemeyer head u ai software research macquarie said fear missing one factor driving decision
#
# definitely dont want miss part ai ecosystem havemeyer said
#
# definitely think there fomo marketplace
#
# hefty investment necessary ai model notoriously expensive build train requiring thousand specialized chip date largely come fromnvidia
#
# meta developing model calledllama said spending billion nvidias graphic processing unit one many company thats helped chipmakerbolsteryearoveryear revenue two hundred and fifty
#
# whether going building investing route finite number company afford play market
#
# addition developing chip nvidia emerged one silicon valley top investor taking stake number emerging ai company partly way make sure technology get widely deployed
#
# similarly microsoft google amazon sometimes offer cloud credit part investment
#
# amazonanthropic deal announced wednesday two company said theyll work closely together variety way
#
# anthropic using amazon web service computing need well amazon chip
#
# anthropics model distributed amazon aws customer
#
# earlier month anthropic launchedclaude three powerful model one say let user upload photo chart document type unstructured data analysis answer
#
# microsoft got business generative ai investing earlier putting1 billioninto openai two thousand and nineteen
#
# size investment since swelled thirteen billion
#
# microsoft heavily us openais model offer open source model azure cloud
#
# alphabet playing part builder investor
#
# company refocused much product development generative ai newly rebranded gemini model adding feature search document map elsewhere
#
# last year googlecommittedto invest two billion anthropic previously confirming taken ten stake startup alongside large cloud contract two company
#
# havemeyer said tech giant arent throwing money hype cycle investment ai startup align product road map
#
# dont think frivolous said
#
# havemeyer said alliance big cloud provider bring muchneeded cash startup also help sign customer
#
# cloud company saying come u work platform native access latest greatest ai model also use infrastructure havemeyer said
#
# also part much larger ecosystem play
#
# seeing lot alliance appearing among hyperscalers substantial scale infrastructure deep pocket added
#
# recent earnings call tech exec reiterated focus generative ai making clear investor spend money make money whether internal development investing startup
#
# microsoft chief financial officer amy hood said last year company adjusting workforce toward aifirst work without adding material number people workforce
#
# said microsoft continue prioritize investing ai thing thats going shape next decade
#
# leader google apple amazon alsosuggested investorsthat theyre willing cut cost broadly across department order redirect funding toward ai effort
#
# startup among beneficiary
#
# microsoft taken stake mistral figure humane addition openai
#
# company invested inflection ai startup essentially dissolved joined microsoft month
#
# mistral open sourcefocused company us azure cloud offer service azure client
#
# figure startup seeking build robot walk like human raised money microsoft openai nvidia wasvalued last monthat twenty-six billion
#
# amazon biggest bet anthropic pouring total four billion far
#
# company also invested open source ai platform developer hugging face
#
# google investment include essential ai developing consumer ai program backed byamdand nvidia
#
# alphabet nvidia also investor runway ml generative ai company known videoediting visual effect tool
#
# others nvidias portfolio include mistral perplexity cohere
#
# meanwhile many big tech company continue spend internally developing model
#
# microsoft invested many technique underpinning generative ai microsoft research division
#
# amazonreportedlyhas plan train bigger datahungry model even openais gpt4
#
# apple researcher recently published detail work mm1a family small ai modelsthat take text visual input
#
# apple different position peer doesnt sell cloud service
#
# still tech giant reportedly looking ai partner including potentially google u andbaiduin china
#
# apple representative declined comment ai partner
#
# daniel newman ceo technology analysis firm futurum group said tech company get clever come investing ai
#
# example openais investment microsoft included profit sharing nonprofit wing well credit use microsofts cloud service
#
# microsofts deal inflection ai amounted expensive acquihire report putting total outlay at1 billion
#
# part transaction microsofthiredinflection ai founder mustafa suleyman lead copilot ai initiative
#
# think starting see creativity dealmaking said newman
#
# respect amazon agreement anthropic said acquisition would lot harder investing
#
# thats regulator across globe cracking big tech making difficult sizable acquisition
#
# even investment attracting scrutiny
#
# january federal trade commission announced willconduct extensive inquiryinto field biggest player ai including amazon alphabet microsoft anthropic openai
#
# ftc chair lina khan described probe market inquiry investment partnership formed ai developer major cloud service provider
#
# regulator authority order company file specific report answer question writing business
#
# know regulator becoming increasingly focused traditional path closing acquisition newman said
#
# right game access fundamental ip
#
# watchai hype drive valuation higher
#
# hardly day go generative ai genai doesnt dominate business medium headline
#
# last twelve month become ubiquitous business strategy organization across industry increasingly investing genai solution
#
# google trend data visualizesgenais rise center business relevance since two thousand and twenty-two peaking june two thousand and twenty-three
#
# certainly cant ignore transformative potential genai jumping right without adequate planning mean risking resource without guaranteed roi
#
# custom genai solution expensive costing three hundred thousand dollar annuallyaccording webfx require deep technical expertise maintain
#
# reality organization ready invest genai
#
# leader may feel pressure buy hype taking genai operationally realistic mean huge drain resourcesaccording mckinsey business area stand benefit gen ai include sale marketing customer relation customer operation software development research development
#
# using gen ai business function like finance hr may yield return
#
# meantime hype wane genai becomes polished accessible way exist move innovation forward
#
# prioritizing operational efficiency best way guarantee measurable roi
#
# largest benefit likely come following use case
#
# organization strong area already relevant business goal gen ai solution may necessary
#
# here know make move
#
# making major investment organization take pause ass internal structure identify gap data process inefficiency silo business function
#
# along way knowing successful genai implementation relies quality data leader ask process digitized automated better organized maximize resource streamline operation optimize efficiency scalability
#
# ceo ask following question ready right people aiming right generating revenue
#
# consider amazon relentless focus customer experience philosophy embedded deeply operational ethos
#
# approach led innovation like amazon walk technology leveraging ai machine learning reimagine retail
#
# similarly business contemplating genai investment must start deep dive operational fabric identifying inefficiency area digital transformation catalyze revolutionary customer experience
#
# clear understanding operational process improved consider give time back teamsfreeing space continued learning preparation genai
#
# one option embrace citizen development allowing nontechnical employee build apps simply quickly bring efficiency scalability mundane task
#
# using lowcode nocode tool general business user build custom apps without burdening team
#
# team pepsi relied heavily lowcodenocode build deploy digital application inventory merchandising function saving company five hundred thousand first year without professional developer staffaccording venturebeat
#
# intuitive visual interface prebuilt template draganddrop element solve seemingly complicated business problem required coding knowledge little day minimal reeducation
#
# embracing approach allows team understand nuance digital engineering turn focus genai without sacrificing team productivity
#
# creating infrastructure designed grow business top priority technology leader two thousand and twenty-four
#
# inefficiency created first wave digital transformation need corrected
#
# key maximizing return genai investment aim big start small grow incrementally following wellplanned roadmap
#
# focusing first streamlining existing process gradually introducing genai one use case time organization ensure genai integrated amplifies rather disrupts operational effectiveness
#
# truly capitalize transformative potential genai business must approach integration incrementally focusing longterm improvement
#
# journey toward genai efficiency technical upgrade strategic initiative requires holistic view business process technical culture goal
#
# embedding genai operation already optimized agility innovation company ensure investment enhances current capability also open new avenue growth differentiation
#
# real return genai investment lie adoption technology sake strategic integration core business
#
# three way ai overcomes custom delay
#
# fusion robotics ai arvr two thousand and twenty-four revolution manufacturing
#
# mohan chief evangelist digital transformation atkissflow
#
# mohan extensive experience implementing erp banking insurance solution apac usa europe leading large team deliver outstanding client outcome
#
# recent focus leading client digital transformation journey
#
# specializes conducting design thinking workshop identify problem evaluate benefit various innovative idea
#
# engineer iit mba xlri
#
# boil ocean ai
#
# bridging digital divide role aipowered platformcentric strategy crafting futureready enterprise
#
# three way ai overcomes custom delay
#
# fusion robotics ai arvr two thousand and twenty-four revolution manufacturing
#
# ai hr navigating opportunity challenge
#
# advancement ai mixed reality technology continued training development healthcare industry
#
# creating real value generative ai put people center
#
# creating real value generative ai put people center
#
# generative ai democratizes creative process anyone create text image presentation video music instant
#
# however without human creativity little value
#
# role human creative process
#
# organization cleverly combine
#
# creativity generating new valuable idea lead innovative solution problem
#
# thats limited artist genius according mihaly csikszentmihalyi creator term flow author book creativity
#
# argues creativity broad accessible human trait
#
# creativity work exactly
#
# important factor creativity deep human involvement
#
# pattern lead creativity include suffering struggle like vincent van gogh dream isaac newton joy filmmaker david lynch practice transcendental meditation
#
# typing smart prompt chatgpt show little involvement question extent result generative ai really called creative
#
# however still essential question extent creativity actually important company
#
# creativity make distinction impact
#
# due generative ai flood aigenerated content way
#
# meme deepfakes book amazon music video presentation audacity mail faq personal recommendation business chatbots code content creation
#
# direct result democratization generative ai lowerquality output
#
# read full articlehere
#
# open dutch
#
# learn epam revolutionizing future business power aihttpswwwepamcomservicesartificialintelligence
#
# voor echte waarde creëren met generatieve ai stel de men centraal
#
# generatieve ai democratiseert creatieve processen iedereen kan nu een handomdraai teksten afbeeldingen presentaties video muziek en meer creëren
#
# zonder menselijke creativiteit heeft het echter weinig waarde
#
# wat de rol van de men het creatieve proces
#
# hoe kunnen organisaties beiden slim combineren
#
# creativiteit gaat het genereren van nieuwe en waardevolle ideeën die leiden tot innovatieve oplossingen voor problemen
#
# dat niet beperkt tot kunstenaars en genieën volgensmihaly csikszentmihalyi de bedenker van de term flow en schrijver van het boekcreativiteit
#
# hij stelt dat creativiteit een brede en toegankelijke menselijke eigenschap
#
# hoe werkt creativiteit precies
#
# een belangrijke factor voor creativiteit diepe menselijke betrokkenheid
#
# patronen die leiden tot creativiteit zijn bijvoorbeeld lijden en strijd zoals vincent van gogh dromen isaac newton en vreugde filmmaker david lynch die transcendentale meditatie beoefent
#
# een slimme prompt intikken chatgpt toont weinig van deze betrokkenheid de vraag hoeverre de uitkomsten van generatieve ai dus echt creatief zijn te noemen
#
# daar zit echter nog een essentiële vraag voor hoeverre creativiteit eigenlijk belangrijk voor bedrijven
#
# creativiteit maakt onderscheid en impact
#
# door generatieve ai er een stortvloed aan aigegenereerde content op komst
#
# van meme deepfakesboeken op amazonenmuziekvideopresentatie van audacity tot mail faq persoonlijke aanbevelingen zakelijke chatbots code en contentcreatie
#
# dit een direct gevolg van de democratisering van generative ai meer output van lagere kwaliteit
#
# lee hier het volledige artikel
#
# ontdek hoe epam een revolutie teweegbrengt de toekomst van het bedrijfsleven met de kracht van aihttpswwwepamcomservicesartificialintelligence
#
# featured story
#
# according global consultancy bain company insurance organisation across globe a50 billionfinancial opportunity generative ai genai harness technology way could boost revenue much twenty well cut cost fifteen
#
# new report released firm reveals leveraging genai insurance distribution potential yield than50 billionin annual economic benefit company across sector
#
# bhavimehta global lead ai financial service bain commented insurer benefit due generative ai come three route
#
# includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise
#
# bain remain committed helping client within insurance across industry identify realize ai full business potential
#
# moreover bain company noted genai permeates insurance company operation early initiative suggesting technology transform distribution four way including
#
# meanwhile bains analysis also highlight several key risk area emerging insurer developing use genai include hallucination data provenance misinformation toxicity intellectual property ownership
#
# sean oneill leader bains global insurance practice said nascent technology risk
#
# manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation
#
# however genai continuing develop evolve bain urge insurer take several critical step adapt fastdeveloping technology
#
# include aligning across business unit ai support business strategy determining build internally buy vendor well ensuring delivery team crossfunctional designing operating model adaptable
#
# reuters openai start allowing user access freetouse chatgpt generative ai chatbot without needing sign service beginning monday microsoftbacked startup said monday
#
# chatgpt kickstarted genai boom late two thousand and twenty-two mimic human conversation perform task creating summary long text writing poem even generating idea theme party
#
# san franciscobased company said gradually roll feature make ai accessible anyone curious capability
#
# popular service set record fastestgrowing user base seen growth slow since may two thousand and twenty-three traffic peaked eighteen billion web visit according data analytics firm similarweb
#
# openai said introduced additional content safeguard user accessing chatgpt without signing blocking prompt generation wider range category
#
# specify category
#
# apart free version chatgpt direct access internet openai also offer paid version individual team user enterprise
#
# company also said may use content provided user help improve largelanguage model said user turn feature
#
# move come month billionaire entrepreneur elon musk sued openai ceo sam altman saying abandoned startup original mission develop artificial intelligence benefit humanity profit
#
# reporting arsheeya bajwa bengaluru anna tong san francisco krystal hu new york editing tasim zahid
#
# spread fake news disinformation steadily risen past year audience increasingly getting news online false information sometimes generated ai spread faster threatening audience trust medium
#
# series infographics euractiv take deeper dive trend playing across europe medium landscape
#
# trend consumer trusting medium le le observed resulting turning social medium get news instead
#
# boththis yearandlast year u trust medium hit alltime low
#
# pattern eu laid graph
#
# meanwhiletiktok example popular among younger generation alternative traditional news source
#
# using data two thousand and twenty chart also show social medium play big role news source
#
# yet according aeurobarometer surveypublished european parliament seventeen november us two thousand and twenty-two data main source news television seventy-one respondent saying one used source past seven day time research
#
# however eleven increase using social medium platform get news compared last year survey
#
# counteract risk artificial intelligence believe aican help debunk fake news horizon europe project ai4trust
#
# ai4trust isdevelopinga system based machinehuman cooperation advanced solution horizon europe two hundred and two thousand, three hundred and twenty-four work programmeaimsto move closer aibased market solution ensure access meaningful information quality content trustworthy online interaction
#
# however social medium platform also source
#
# knowing real aigenerated help trust news
#
# march example eu law enforcement agency europolwarnedthat chatgpt benefit business individual malicious actor exploit technology posing law enforcement challenge
#
# criminal typically quick exploit new technology fast seen coming concrete criminal exploitation providing first practical example mere week public release chatgpt read thereport
#
# dissemination nude image minor created ai concern law enforcement one bound become increasingly difficult address europol alsotold euractivin october
#
# law enforcement agency added aigenerated material must detected using ai classifier tool currently authorised use classifier tool specific purpose
#
# european union reading news online increased past year graph show two thousand and thirteen two thousand and twenty-two according tostatista
#
# online frequency type fake news reader differ seen graph cover europe largest country
#
# frequency seeing disinformation depend different type medium citizen exposure level disinformation general every country either
#
# country may different percentage regarding fake news following map show scandinavian country le affected central southern europe
#
# last year bulgarian citizen highest exposure misinformation twenty-eight april twenty-six may eleven living netherlands least exposed six
#
# regardless frequency exposure seeing false information impact one life differently
#
# claim thirty-five check news thoroughly encounter
#
# however almost many people thirty-three believe impact
#
# edited alice taylornathalie weatherald
#
# significant hype fear ai particularly generative ai crowding news headline last week
#
# generative ai least context us large language model create response
#
# essentially selftrained ai smart collectively
#
# use training data make educated guess
#
# algorithmic
#
# complicated math
#
# make pretty good guess time
#
# yes
#
# however ai today isnt actual intelligence actual sapience fact lost many result fromgenerative aican impressive
#
# gold standard business intelligence
#
# find
#
# need think intake information
#
# anything human race learned need critically examine information given
#
# fear generative ai fooled
#
# happened already
#
# happened
#
# human inclined believe gullible want believe giving u information good intention
#
# ai today intention
#
# moral give use generate u
#
# need apply scepticism
#
# hard appears
#
# anyone take television advertisement really kind ad undisputed truth
#
# course
#
# assumed advertiser best interest heart economic interest
#
# verification stated claim required product service purchased
#
# individual need apply level scepticism nearly everything read see
#
# including article
#
# time panic generative ai
#
# technology impressive extremely helpful
#
# time educate raise standard accepting see truth
#
# access comprehensive company profile market powered globaldata
#
# save hour research
#
# gain competitive edge
#
# download email arrive shortly
#
# confident unique quality company profile
#
# however want make beneficial decision business offer free sample download submitting form
#
# adapt willing far benefit ai bring worth challenge
#
# leveraging advanced generative ai capability seamlessly integrated itsconversational commercesolution vonage arming business tool create realtime personalised connection customer across platform delivering meaningful customer data streamlining operation automation notesvonage
#
# generative aipowered update vonage conversational commerce solution addition marketing template content generator live chat assistance intuitive knowledge base inquiry making impact across customer touchpoints today enterprise including agent marketing customer support team
#
# vonage say core new generative aipowered capability aipowered assistance live chat interaction helping agent tailor response provide better customer service realtime improving accelerating live chat response customer well rephrasing functionality ensure precise communication allowing agent refine tone response power ai helping business enhance agent productivity overall communication effectiveness
#
# also included new offering content generator designed crafting whatsappbased marketing template empower brand speed simplify production diverse marketing content significantly reduce workload marketing team
#
# significantly reducing time resource craft diverse marketing message marketing team better equipped run multiple campaign still ensuring message resonates individual customer
#
# intuitive template business unlocking kind connection drive real lead ultimate profitability
#
# aipowered answer offering knowledge base also help reduce human dependency allow knowledge base ai bot interpret user query parse knowledge base document answer user query directly
#
# utilising document uploaded knowledge base respond query streamline customer support knowledge base eliminates need canned impersonal response delivering personalised experience customer vonage note
#
# seeing significant increase demand integrated ai capability easily expanded across platform business recognise efficiency customization possibility generative ai offer saidsavinay berry evp product engineering vonage
#
# integrating stateoftheart generative ai capability conversational commerce solution empowering user generate creative content automate task improve overall user experience
#
# advancement generative ai harnessed significantly enhance conversational commerce solution empowering ecommerce marketer online retailer seamlessly connect potential customer delivering personalised experience saidkrishna baidya sr director information communication technology frost sullivan
#
# infusing generative ai knowledge base brand respond query streamline customer support ensuring efficient reliable selfservice option conversation
#
# adding aipowered assistance live chat interaction boost agent productivity communication effectiveness
#
# according vonage referral marketing continues powerful strategy business reach target customer drive sale vonage conversational commerce user initiate whatsapp referral campaign right dashboard giving ability acquire new customer without additional marketing overhead cost
#
# whatsapp vonage weve able better identify market top twenty-five percent active subscriber saidkamila skötsch global crm team leadholidaypirates international travel company vonage conversational commerce customer
#
# subscriber using whatsapp faster act deal people using channel generating traffic partner clickthroughrates high forty percent message receiving ninety-seven percent open rate
#
# vonage also launched conversational commerce apis enable third party application connect jumperai dashboard deliver conversational marketing commerce capability via integration leading customer engagement platform moengage salesforce marketing cloud
#
# developer apis empower marketer product owner extend platform lower level 1way notification richer 2way conversation leveraging vonage conversational commerce capability share product catalog complete transactionturning notification sale concludes vonagegenerative aipowered enhancement vonage conversational commerce powered jumperai solution currently beta generally available second quarter two thousand and twenty-four

# %%
# Use Vader library to get the polarity of the sentence
def getPolarity(text):
    polarity = SentimentIntensityAnalyzer().polarity_scores(text)
    if polarity['compound'] > 0:
      sentiment = 'postive'
    elif polarity['compound'] < 0:
      sentiment = 'negative'
    else:
      sentiment = 'neutral'
    return sentiment,polarity

# %%
for sentence in sentences:
  sentiment, polarity = getPolarity(sentence)
  print('\n', sentence)
  print(f"{sentiment}, {polarity}")
# Out:
#  india cusp digital hyper growth
# postive, {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.3818}
#
#  indian business realized differentiated service experience key moving ahead competition staying relevant turning emerging technology build differentiated service experience ever
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  speed agility along adequate understanding deployment relevant technology make difference
# postive, {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.2263}
#
#  digital technology generative ai genai gained lot interest traction india continue throughout two thousand and twenty-four
# postive, {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.6808}
#
#  despite challenge two thousand and twenty-four see many successful use case genai implementation require firm ai strategy line data cloud strategy
# postive, {'neg': 0.051, 'neu': 0.791, 'pos': 0.158, 'compound': 0.5541}
#
#  believe next year genai stay limelight also find way many initiative across company india
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  top five india technology prediction two thousand and twenty-four
# postive, {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.2023}
#
#  glimpse top prediction
# postive, {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.2023}
#
#  many prediction around tech always finer nuance around would benefit dialogue
# postive, {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.4588}
#
#  would happy chat topic detail
# postive, {'neg': 0.0, 'neu': 0.519, 'pos': 0.481, 'compound': 0.5719}
#
#  please reach u inquiry guidance session know
# postive, {'neg': 0.0, 'neu': 0.541, 'pos': 0.459, 'compound': 0.34}
#
#  brian hopkins vp emerging tech portfolio
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  julie mohr principal analyst
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  ted schadler vp principal analyst
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  generative ai genai disruptive force disruptive
# negative, {'neg': 0.535, 'neu': 0.465, 'pos': 0.0, 'compound': -0.5574}
#
#  know big quite sure big
# postive, {'neg': 0.0, 'neu': 0.607, 'pos': 0.393, 'compound': 0.3804}
#
#  colleague explored aspect via recent researchthe generative ai advantageandforresters two thousand and twenty-three generative ai job impact forecast u
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  kicking new research stream withted schadlerjulie mohr others explore topic
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  focus disruptive impact genai industry market economy
# negative, {'neg': 0.277, 'neu': 0.723, 'pos': 0.0, 'compound': -0.3182}
#
#  today company every industry pursuing value genai pursuit kick cycle ultimately change industry tech priority market labor force government
# postive, {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.34}
#
#  last week ted published first blog topicgenai shatter reconstruct every company industry
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  pose big question business level fundamental economic force unleashed extend far beyond current productivityboosting wave coming
# postive, {'neg': 0.0, 'neu': 0.898, 'pos': 0.102, 'compound': 0.1779}
#
#  next step research stream diving technical
# postive, {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.0772}
#
#  two belief
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  two reality impact every industry mean disruption hit every firm equally
# negative, {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.3612}
#
#  believe impact based use knowledge create business value
# postive, {'neg': 0.0, 'neu': 0.571, 'pos': 0.429, 'compound': 0.5423}
#
#  example
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  beginning
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  research go deeper
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  seeing knowledge cycle develop seeing change happening interested potential please emailinquiryforrestercom set time talk
# postive, {'neg': 0.0, 'neu': 0.706, 'pos': 0.294, 'compound': 0.6124}
#
#  brian hopkins julie mohr julie ask investigating generative ai genai change face business industry
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  research long view ofwhatwhy andhowgenai break rebuild business work consumer live knowledge reality pattern shift company industry economy forced new shape structure
# negative, {'neg': 0.125, 'neu': 0.875, 'pos': 0.0, 'compound': -0.4588}
#
#  look back twenty-five year longlasting economic value created captured
# postive, {'neg': 0.0, 'neu': 0.614, 'pos': 0.386, 'compound': 0.5267}
#
#  company industry country win
# postive, {'neg': 0.0, 'neu': 0.441, 'pos': 0.559, 'compound': 0.5859}
#
#  lose
# negative, {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.4019}
#
#  along rapidly expanding commitment genai research guidance help forresters commercial government technology client go eradefining question
# postive, {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.6486}
#
#  artificial intelligence shatter reconstruct company industry country redefine role company play genainative future
# postive, {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.6705}
#
#  see change inevitable murky future early day internet
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  seeking understand artificial general intelligence examine existential threat
# negative, {'neg': 0.272, 'neu': 0.48, 'pos': 0.248, 'compound': -0.0772}
#
#  rather assume ability govern keep ai safe grow ai grows
# postive, {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.6369}
#
#  future look like
# postive, {'neg': 0.0, 'neu': 0.444, 'pos': 0.556, 'compound': 0.3612}
#
#  post frame research happen company institution capture put knowledge data content captured tacit work using software automation power ai
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  colleague brian hopkins posting shortly early hypothesis happen
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  also look upcoming post julie mohr julie ask
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  first productivitycentric wave genai impact company coming focus
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  improving task productivity roughly thirty three hundred next year genaipowered application reshape every knowledgefueled task job reconstruct knowledge practice resource every company every industry
# postive, {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.4215}
#
#  kpmg example announced fifty productivity gain knowledge task gave seven thousand employee microsoft copilot set productivity application built openais large language model
# postive, {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.5267}
#
#  aboutgenais impact revenue generating new revenue stream extension channel
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  reinventionhow company reinvent themselvesusing power genai
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  next twenty-five year genaiforce entire industry restructureto take advantage value generated machine
# postive, {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'compound': 0.5267}
#
#  country respond toset economy citizen success
# postive, {'neg': 0.0, 'neu': 0.575, 'pos': 0.425, 'compound': 0.5719}
#
#  invite idea participation part research pursue question
# postive, {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.1531}
#
#  learn impact generative ai read bloggenais worldchanging power putting knowledge work
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  interested view generative ai
# postive, {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.4019}
#
#  please reach schedule time via inquiry team emailing inquiryforrestercom
# postive, {'neg': 0.0, 'neu': 0.673, 'pos': 0.327, 'compound': 0.34}
#
#  eight million uk job risk rise artificial intelligence ai according report warning lowskilled would worst affected
# negative, {'neg': 0.42, 'neu': 0.453, 'pos': 0.128, 'compound': -0.7269}
#
#  effect generativeaiare already widely felt eleven task done worker currently exposed institute public policy research ippr said
# negative, {'neg': 0.075, 'neu': 0.925, 'pos': 0.0, 'compound': -0.0772}
#
#  said back office entry level parttime job highest risk disrupted socalled first wave woman young people likely affected result
# negative, {'neg': 0.179, 'neu': 0.821, 'pos': 0.0, 'compound': -0.4019}
#
#  analysis showed employer integrate ai technology work process fifty-nine task would hit without government intervention leaving lowskilled exposed
# negative, {'neg': 0.071, 'neu': 0.929, 'pos': 0.0, 'compound': -0.0772}
#
#  figure equated seventy-nine million role report said adding shift would provide benefit gross domestic product gdp
# negative, {'neg': 0.154, 'neu': 0.697, 'pos': 0.149, 'compound': -0.0258}
#
#  author described worst case scenario
# negative, {'neg': 0.506, 'neu': 0.494, 'pos': 0.0, 'compound': -0.6249}
#
#  painted positive picture economy people transition effectively managed industrial strategy placed emphasis protecting key human function regulation aimed unlock investment particularly training
# postive, {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.7579}
#
#  new drake song cause confusion listener question whether ai rapper behind
# negative, {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compound': -0.296}
#
#  creating fake sexual image another person become criminal offence
# negative, {'neg': 0.547, 'neu': 0.314, 'pos': 0.138, 'compound': -0.7579}
#
#  ai helping meta fight misinformation election say former deputy pm nick clegg
# negative, {'neg': 0.304, 'neu': 0.559, 'pos': 0.137, 'compound': -0.4019}
#
#  please use chrome browser accessible video player
# postive, {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'compound': 0.3182}
#
#  claimed could lead economic boost thirteen gdp around 306bn year best case
# postive, {'neg': 0.0, 'neu': 0.592, 'pos': 0.408, 'compound': 0.7845}
#
#  government yet bring forward legislation specifically aimed rise ai last month announce plan spend 90m new ai research hub look way using ai responsibly across area healthcare chemistry mathematics
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  carsten jung senior economist ippr said already existing generative ai could lead big labour market disruption could hugely boost economic growth either way set game changer million u
# postive, {'neg': 0.077, 'neu': 0.742, 'pos': 0.181, 'compound': 0.5198}
#
#  please use chrome browser accessible video player
# postive, {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'compound': 0.3182}
#
#  many firm already investing potential speed many task business adopt
# postive, {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'compound': 0.1779}
#
#  next five year could transform knowledge work
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  question le whether ai useful rather fast manner employer use
# postive, {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.4404}
#
#  history show technological transition boon well managed end disruption left unfold without control
# negative, {'neg': 0.16, 'neu': 0.705, 'pos': 0.135, 'compound': -0.1027}
#
#  first getbreaking news
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  install sky news app free
# postive, {'neg': 0.0, 'neu': 0.548, 'pos': 0.452, 'compound': 0.5106}
#
#  read moreimf issue warning affect ai global workforcei lost job due ai toolthe number firm using ai worker feel
# negative, {'neg': 0.214, 'neu': 0.727, 'pos': 0.059, 'compound': -0.5267}
#
#  spokesperson department science innovation technology said research hugely speculative
# postive, {'neg': 0.0, 'neu': 0.62, 'pos': 0.38, 'compound': 0.5095}
#
#  numerous report also predict ai spark huge creation job unlocking growth ramping productivity
# postive, {'neg': 0.0, 'neu': 0.503, 'pos': 0.497, 'compound': 0.7845}
#
#  ai already contributes 37bn economy every year already invested 290m since two thousand and eighteen skill talent initiative job future
# postive, {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.4215}
#
#  continue ass impact ai different sector ensure employer play leading role building robust uk skill talent
# postive, {'neg': 0.142, 'neu': 0.445, 'pos': 0.413, 'compound': 0.6908}
#
#  also working innovate uk alan turing institute develop guidance core ai skill people need published later year
# postive, {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.4939}
#
#  recruitment employment confederation deputy chief executive kate shoesmith said finding employer using ai well scheduling sourcing candidate background check personal development plan
# postive, {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.2732}
#
#  first base ai labour market
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  help maximise benefit ai employer government work together particularly skill development compliance
# postive, {'neg': 0.0, 'neu': 0.637, 'pos': 0.363, 'compound': 0.6908}
#
#  fastmoving area one need people proficient trained using ai also given skill adapt future development
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  education system need built around core employer need flexibility fund appropriate shortcourse training would come flexible apprenticeship levy
# postive, {'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'compound': 0.5106}
#
#  ai technology offer insurance business largescale financial potential productivity gain optimizing sale channel digital advice delivering enhanced personalized customer experience
# postive, {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.7506}
#
#  bostonapril one 2024prnewswire insurance business worldwide a50 billion dollarfinancial opportunity generative ai harness technology way could boost revenue much twenty cut cost fifteen research bain company released today find
# postive, {'neg': 0.062, 'neu': 0.774, 'pos': 0.164, 'compound': 0.5267}
#
#  bains reportits real generative ai take hold insurance distribution concludes leveraging generative ai insurance distribution potential yield than50 billionin annual economic benefit company sector
# postive, {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.4588}
#
#  insurer benefit due generative ai come three route saidbhavi mehta global lead ai financial service bain
# postive, {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.4588}
#
#  includes raising productivity lifting sale effective agent digital advice better risk identification targeting help customer agent enterprise
# postive, {'neg': 0.088, 'neu': 0.546, 'pos': 0.366, 'compound': 0.765}
#
#  bain remain committed helping client within insurance across industry identify realize ai full business potential
# postive, {'neg': 0.0, 'neu': 0.751, 'pos': 0.249, 'compound': 0.5106}
#
#  generative ai transform insurance distribution four way
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  early use generative ai within insurance suggests technology transform distribution four way including
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  managing risk
# negative, {'neg': 0.677, 'neu': 0.323, 'pos': 0.0, 'compound': -0.2732}
#
#  bains analysis also pinpoint key risk area emerging insurer developing use generative ai including hallucination data provenance misinformation toxicity intellectual property ownership
# negative, {'neg': 0.165, 'neu': 0.712, 'pos': 0.124, 'compound': -0.0258}
#
#  nascent technology risk saidsean oneill leader bains global insurance practice
# negative, {'neg': 0.189, 'neu': 0.811, 'pos': 0.0, 'compound': -0.2732}
#
#  manage risk insurer adopt responsible ai strategy includes shortterm priority well longterm vision enabling company build valuable ai capability redefine business operation
# postive, {'neg': 0.072, 'neu': 0.546, 'pos': 0.382, 'compound': 0.7964}
#
#  critical step insurance business leader
# negative, {'neg': 0.365, 'neu': 0.635, 'pos': 0.0, 'compound': -0.3182}
#
#  generative ai continues evolve bain urge insurance company take several critical step adapt fastdeveloping technology
# negative, {'neg': 0.141, 'neu': 0.859, 'pos': 0.0, 'compound': -0.3182}
#
#  include aligning across business unit ai support business strategy determining build internally buy vendor ensuring delivery team crossfunctional designing operating model adaptable
# postive, {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'compound': 0.5859}
#
#  medium contactsto arrange interview question please contactkatie warenew york emailemail protectedgary duncanlondon emailemail protectedann leesingapore emailemail protected
# postive, {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.6369}
#
#  bain company
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  bain company global consultancy help world ambitious change maker define future
# postive, {'neg': 0.0, 'neu': 0.608, 'pos': 0.392, 'compound': 0.7003}
#
#  across sixty-five city forty country work alongside client one team shared ambition achieve extraordinary result outperform competition redefine industry
# postive, {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.34}
#
#  complement tailored integrated expertise vibrant ecosystem digital innovator deliver better faster enduring outcome
# postive, {'neg': 0.0, 'neu': 0.636, 'pos': 0.364, 'compound': 0.743}
#
#  10year commitment invest than1 billionin pro bono service brings talent expertise insight organization tackling today urgent challenge education racial equity social justice economic development environment
# postive, {'neg': 0.0, 'neu': 0.627, 'pos': 0.373, 'compound': 0.872}
#
#  earned platinum rating ecovadis leading platform environmental social ethical performance rating global supply chain putting u top one company
# postive, {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.6249}
#
#  since founding one thousand, nine hundred and seventy-three measured success success client proudly maintain highest level client advocacy industry
# postive, {'neg': 0.0, 'neu': 0.593, 'pos': 0.407, 'compound': 0.9001}
#
#  source bain company
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  machinery equipment maker worldwide immediate largescale opportunity transform productivity gain three thousand and fifty
# postive, {'neg': 0.0, 'neu': 0.659, 'pos': 0.341, 'compound': 0.7351}
#
#  unsettling mix macroeconomic condition uncertainty led yet another year slowdown asia pacific private equity pe market
# negative, {'neg': 0.138, 'neu': 0.862, 'pos': 0.0, 'compound': -0.34}
#
#  banking financial service
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  insurance
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  data analytics
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  data analytics
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  morgan stanley stephen byrd identified important mismatch rapid growth generative ai energy need moderate growth grid infrastructure
# postive, {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.7964}
#
#  regard highlight significant growth revenue capture opportunity company meet energy need
# postive, {'neg': 0.0, 'neu': 0.339, 'pos': 0.661, 'compound': 0.8658}
#
#  specifically identified thirteen stock overweight ow recommendation would benefit dynamic including iberdrola ibe
# postive, {'neg': 0.138, 'neu': 0.552, 'pos': 0.309, 'compound': 0.4767}
#
#  adult social care supporting people live independently protect fundamental human right
# postive, {'neg': 0.0, 'neu': 0.479, 'pos': 0.521, 'compound': 0.8271}
#
#  generative ai offer many potential benefit opportunity adult social care
# postive, {'neg': 0.0, 'neu': 0.438, 'pos': 0.562, 'compound': 0.8402}
#
#  however rapid development wide availability generative ai ai chatbots concern come use case adult social care setting fundamental value defining quality care look like stake technology used inappropriately
# postive, {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.8834}
#
#  therefore need address gap knowledge guidance around generative ai quickly involving group people affected working social care provision saiddr caroline greenearly career research fellow institute ethic ai university oxford research fellow reuben college
# postive, {'neg': 0.045, 'neu': 0.866, 'pos': 0.089, 'compound': 0.3818}
#
#  artificial intelligence offer many opportunity potential benefit adult social care
# postive, {'neg': 0.0, 'neu': 0.331, 'pos': 0.669, 'compound': 0.9022}
#
#  generative ai large language model llm power ai chatbots aid various task social care
# postive, {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.4939}
#
#  however many activity social care directly touch people human right wellbeing
# postive, {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.4939}
#
#  currently guideline people using social care service care provider including family carers tech developer organisation integrating ai chatbots service responsible use generative ai social care entail
# postive, {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.8979}
#
#  aim event articulate collective understanding generative ai role social care setting discus challenge benefit viable use case
# postive, {'neg': 0.0, 'neu': 0.651, 'pos': 0.349, 'compound': 0.7579}
#
#  core focus would constitute responsible ethical use emerging technology
# postive, {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.6808}
#
#  following event statement published outline need robust rapid work coproduce practical guideline appropriate usage deployment generative ai social care
# postive, {'neg': 0.0, 'neu': 0.752, 'pos': 0.248, 'compound': 0.6808}
#
#  addition commits group engaging coproduction consultation process drawing people organisation social care
# postive, {'neg': 0.0, 'neu': 0.573, 'pos': 0.427, 'compound': 0.6908}
#
#  full statement endorsed twenty-three participating organisation beread
# postive, {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.25}
#
#  according recent global report business agree generative ai gen ai substantial impact industry
# postive, {'neg': 0.0, 'neu': 0.719, 'pos': 0.281, 'compound': 0.5106}
#
#  however despite fanfare adoption rate technology remained abysmally low business
# negative, {'neg': 0.189, 'neu': 0.811, 'pos': 0.0, 'compound': -0.2732}
#
#  three quarter surveyed company experimented gen ai lowly nine percent admitted adopted technology
# negative, {'neg': 0.139, 'neu': 0.764, 'pos': 0.097, 'compound': -0.1531}
#
#  based survey conducted mit technology review insight telecom company telstrathe reportcovered three hundred csuite executive vice president director across asiapacific america europe
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  report question participant company using plan use gen ai technology
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  addition gauging interest technology report also highlight barrier adoption gen ai business
# postive, {'neg': 0.094, 'neu': 0.566, 'pos': 0.34, 'compound': 0.5994}
#
#  readgenerative ai market projected reach one trillion two thousand and thirty-one
# postive, {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'compound': 0.0258}
#
#  misconception easy run mature enterpriseready generative ai said stela solar inaugural director australia national artificial intelligence centre report
# postive, {'neg': 0.0, 'neu': 0.63, 'pos': 0.37, 'compound': 0.8316}
#
#  agreeing solars assessment brian prince founder ceo top ai tool say investing gen ai expensive
# postive, {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.4939}
#
#  argues beyond software business likely need also invest training infrastructure upgrade ongoing maintenance
# negative, {'neg': 0.178, 'neu': 0.822, 'pos': 0.0, 'compound': -0.3818}
#
#  especially true small medium enterprise may find challenging allocate sufficient budget without guaranteed shortterm return
# postive, {'neg': 0.0, 'neu': 0.735, 'pos': 0.265, 'compound': 0.5709}
#
#  telstra survey showed skill training company culture major impediment adoption say prince
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  integrating ai existing workflow system complex
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  speaking experience paolo danese ceo storya say observed tangible disconnect theoretical allure gen ai practical reality faced business
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  divergence technology encompasses broader concern readiness infrastructure steep learning curve effective deployment ethical consideration surrounding ai use say danese
# postive, {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.8126}
#
#  building sukhdeep sohal senior consultant glue affinity reply say business apprehension towards gen ai often traced back series strategic operational disconnect
# negative, {'neg': 0.134, 'neu': 0.866, 'pos': 0.0, 'compound': -0.4767}
#
#  belief crux issue lie alignment lack thereof ai initiative overarching business strategy
# negative, {'neg': 0.173, 'neu': 0.827, 'pos': 0.0, 'compound': -0.3182}
#
#  ai strategy perceived standalone experiment rather integral part business growth disconnect breed reluctance say sohal
# postive, {'neg': 0.133, 'neu': 0.722, 'pos': 0.144, 'compound': 0.0516}
#
#  additionally delivery ai foundation piecemeal rather holistically fails instil confidence technology comprehensive benefit
# postive, {'neg': 0.139, 'neu': 0.448, 'pos': 0.413, 'compound': 0.6705}
#
#  report highlighted evolving regulatory compliance data privacy environment leading nontechnological barrier rapid gen ai adoption business
# negative, {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'compound': -0.128}
#
#  danese agrees saying business navigating uncharted water need balance push digital transformation adhering strict privacy standard
# postive, {'neg': 0.0, 'neu': 0.893, 'pos': 0.107, 'compound': 0.2023}
#
#  according prince especially true sector like healthcare finance legal data sensitivity critical concern
# postive, {'neg': 0.123, 'neu': 0.482, 'pos': 0.394, 'compound': 0.6195}
#
#  burden compliance becomes significant deterrent say
# negative, {'neg': 0.333, 'neu': 0.46, 'pos': 0.207, 'compound': -0.2732}
#
#  read5 way make money generative ai
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  peter john alexander chief business officer meetkai highlight nontechnical factor business must take consideration
# postive, {'neg': 0.0, 'neu': 0.844, 'pos': 0.156, 'compound': 0.34}
#
#  say company likely fear potential data breach ethical misuse high implementation usage cost unreliable output risk falling behind competitor
# negative, {'neg': 0.274, 'neu': 0.595, 'pos': 0.131, 'compound': -0.3818}
#
#  apprehension highlight need careful consideration benefit risk generative ai deployment alongside proactive measure address security compliance ethical operational challenge say alexander
# postive, {'neg': 0.153, 'neu': 0.353, 'pos': 0.494, 'compound': 0.8625}
#
#  according report seventy-eight percent business look gen ai competitive opportunity
# postive, {'neg': 0.0, 'neu': 0.64, 'pos': 0.36, 'compound': 0.5423}
#
#  many expect number function deploying gen ai double two thousand and twenty-four
# postive, {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.0772}
#
#  term actual use sixty-five percent respondent say business actively considering new innovative way use gen ai unlock hidden opportunity data
# postive, {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.7906}
#
#  doesnt surprise sohal
# negative, {'neg': 0.476, 'neu': 0.524, 'pos': 0.0, 'compound': -0.2057}
#
#  say gen ai aligned wellarticulated strategy fit best leverage predictive power data stream identified rigorous data audit
# postive, {'neg': 0.092, 'neu': 0.614, 'pos': 0.294, 'compound': 0.6808}
#
#  suggests analysis especially predictive analytics prime area application directly amplifies strategic decisionmaking capability
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  read42 percent uae company adopt ai business operation say study
# postive, {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'compound': 0.1779}
#
#  alexander agrees saying ai excels rapidly analyzing vast amount data surface pattern making prediction uncovering actionable insight
# postive, {'neg': 0.0, 'neu': 0.739, 'pos': 0.261, 'compound': 0.6486}
#
#  say could include customer analytics identify trend segment financial analysis forecasting operation optimization
# postive, {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.3818}
#
#  leveraging ai business make smarter datadriven decision much faster manual analysis say alexander
# postive, {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.4588}
#
#  according report rather confined specific sector gen ai likely transform specific function across economy customer service
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  also point two thousand and twenty-three national bureau economic research working paper predicts gen ai customer service could raise productivity fourteen percent
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  generative ai prowess natural language understanding generation position linchpin customer service revolution offering personalized efficient engaging user experience say danese
# postive, {'neg': 0.0, 'neu': 0.688, 'pos': 0.312, 'compound': 0.7717}
#
#  alexander belief business must approach gen ai transformative business capability scattershot set project
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  readmeta roll new generative ai feature uae saudi
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  ultimately best fit gen ai depends company unique need available data strategic priority say alexander
# postive, {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.7717}
#
#  company align ai initiative overarching business goal start focused experiment prove value scale success
# postive, {'neg': 0.0, 'neu': 0.558, 'pos': 0.442, 'compound': 0.8271}
#
#  ensure readiness maximize benefit sohal suggests organization seek use case depending level ai maturity
# postive, {'neg': 0.0, 'neu': 0.591, 'pos': 0.409, 'compound': 0.765}
#
#  additionally recommends business also look industry precedent validate inform approach
# postive, {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.5267}
#
#  integrative strategy promise yield tangible business value elevating gen ai technological experiment cornerstone enterprise capability say sohal
# postive, {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'compound': 0.5719}
#
#  technology news clickhere
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  world software development emergence generative ai sparked excitement skepticism
# postive, {'neg': 0.164, 'neu': 0.574, 'pos': 0.262, 'compound': 0.296}
#
#  predict ai render many software development skill obsolete others cautious potential impact
# negative, {'neg': 0.265, 'neu': 0.735, 'pos': 0.0, 'compound': -0.3818}
#
#  20year veteran field ceo company serving software developer keith pitt share insight potential benefit danger generative ai software development
# postive, {'neg': 0.138, 'neu': 0.65, 'pos': 0.211, 'compound': 0.2023}
#
#  one significant positive impact generative ai potential eliminate grunt work developer
# postive, {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.6597}
#
#  developer often spend considerable amount time detail like syntax punctuation automated ai
# postive, {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'compound': 0.3612}
#
#  instead poring manual searching code snippet developer describe desired outcome receive perfectly formatted code response
# postive, {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.743}
#
#  additionally large language model llm help identify typo punctuation mistake detail tedious developer
# postive, {'neg': 0.149, 'neu': 0.683, 'pos': 0.168, 'compound': 0.0772}
#
#  generative ai also potential reinvent software framework
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  framework like spring expressjs django already increased productivity abstracting mundane aspect software development
# postive, {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.5574}
#
#  help gen ai framework enhance value creating boilerplate code automating repetitive task suggesting code optimization
# postive, {'neg': 0.091, 'neu': 0.457, 'pos': 0.452, 'compound': 0.7845}
#
#  ai also assist customizing framework component specific project
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  another significant change brought generative ai rise generalist developer
# postive, {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.2023}
#
#  traditionally developer specialized specific language backend skill
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  however machine capable generating code language language proficiency may become le important
# postive, {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'compound': 0.5267}
#
#  valuable skill machine replicate building user interface translating user requirement specification inventing new way support customer
# postive, {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.7003}
#
#  shift put spotlight developer excel area
# postive, {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.4588}
#
#  generative ai also hold great potential revolutionizing software testing
# postive, {'neg': 0.0, 'neu': 0.661, 'pos': 0.339, 'compound': 0.6249}
#
#  developer write code bot generate numerous test script quickly efficiently
# postive, {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.4019}
#
#  according recent idc survey anticipated benefit generative ai software development software quality assurance security testing
# postive, {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.7783}
#
#  disruption devops practice continuous integrationdeployment may lead testing specialist seeking new opportunity
# postive, {'neg': 0.163, 'neu': 0.654, 'pos': 0.183, 'compound': 0.0772}
#
#  lowcodenocode development tool already made software development accessible generative ai take next level
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  currently tool require individual piece together workflow whiteboard translating code
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  future developer able provide handdrawn sketch desired workflow ai model generate necessary code second
# postive, {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.2732}
#
#  however essential recognize generative ai panacea
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  potential downside need considered
# negative, {'neg': 0.4, 'neu': 0.6, 'pos': 0.0, 'compound': -0.25}
#
#  one concern risk overtesting
# negative, {'neg': 0.412, 'neu': 0.588, 'pos': 0.0, 'compound': -0.2732}
#
#  ai model capable generating test quickly possibility ending test necessary
# postive, {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.3818}
#
#  overtesting slow project create bottleneck development pipeline
# postive, {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.2732}
#
#  ai recommendation remove test could help address issue
# postive, {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.4019}
#
#  skill degradation another potential danger associated generative ai
# negative, {'neg': 0.531, 'neu': 0.469, 'pos': 0.0, 'compound': -0.7783}
#
#  lazy developer may rely ai find shortcut leading bloated inefficient poorly performing code
# negative, {'neg': 0.172, 'neu': 0.828, 'pos': 0.0, 'compound': -0.3612}
#
#  reliance existing pattern data may limit innovative potential developer think outside box explore new solution
# postive, {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.6369}
#
#  trust crucial come generative ai
# postive, {'neg': 0.0, 'neu': 0.548, 'pos': 0.452, 'compound': 0.5106}
#
#  quality data used train ai model significantly impact performance
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  poor quality data training shortcut inadequate prompt engineering result aigenerated code meet quality standard fails fulfill intended function
# negative, {'neg': 0.337, 'neu': 0.549, 'pos': 0.114, 'compound': -0.6908}
#
#  organization must trust quality generative ai fully benefit potential
# postive, {'neg': 0.0, 'neu': 0.515, 'pos': 0.485, 'compound': 0.7645}
#
#  despite potential benefit danger unlikely ai make software developer obsolete
# negative, {'neg': 0.324, 'neu': 0.484, 'pos': 0.192, 'compound': -0.2273}
#
#  historical precedent show technological advancement consistently made developer productive without diminishing demand skill
# postive, {'neg': 0.0, 'neu': 0.898, 'pos': 0.102, 'compound': 0.0951}
#
#  generative ai may affect market lowend basic coding skill push entire profession focus innovation highervalue task
# postive, {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'compound': 0.3818}
#
#  creative problemsolving skill developer remain high demand
# postive, {'neg': 0.16, 'neu': 0.532, 'pos': 0.309, 'compound': 0.34}
#
#  rather resisting change brought generative ai developer embrace
# postive, {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.3182}
#
#  prospect eliminating tedious task software development excite everyone
# postive, {'neg': 0.0, 'neu': 0.531, 'pos': 0.469, 'compound': 0.6486}
#
#  certain function may disappear serve incentive developer upskill focus area machine yet capable
# postive, {'neg': 0.105, 'neu': 0.497, 'pos': 0.398, 'compound': 0.6486}
#
#  highquality developer translate business requirement elegant performant software always demand
# postive, {'neg': 0.119, 'neu': 0.635, 'pos': 0.246, 'compound': 0.3818}
#
#  developer adapt skill ride wave generative ai thrive evolving software development landscape
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  conclusion generative ai potential revolutionize software development eliminating grunt work reinventing framework promoting generalist skill revolutionizing testing enhancing lowcodenocode development tool
# postive, {'neg': 0.0, 'neu': 0.889, 'pos': 0.111, 'compound': 0.3612}
#
#  however potential risk overtesting skill degradation trust deficit need addressed
# negative, {'neg': 0.469, 'neu': 0.343, 'pos': 0.189, 'compound': -0.5994}
#
#  although ai make software developer obsolete push profession towards highervalue task innovation
# postive, {'neg': 0.149, 'neu': 0.676, 'pos': 0.176, 'compound': 0.1027}
#
#  developer embrace change brought generative ai focus upskilling remain valuable evolving landscape
# postive, {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.6597}
#
#  ian goldinprofessor globalisation development oxford martin schooland report coauthor said generative ai dualedged sword offer enormous potential accelerate solution number world greatest challenge new health cure energy innovation
# postive, {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.8957}
#
#  also could destroy job undermine democracy widen inequality division within society country
# negative, {'neg': 0.363, 'neu': 0.637, 'pos': 0.0, 'compound': -0.6908}
#
#  challenge develop regulatory framework guardrail required ensure benefit widely shared sustained
# postive, {'neg': 0.0, 'neu': 0.429, 'pos': 0.571, 'compound': 0.8074}
#
#  generative aioffers enormous potential accelerate solution number world greatest challengesbut also could destroy job undermine democracy widen inequality
# postive, {'neg': 0.215, 'neu': 0.491, 'pos': 0.294, 'compound': 0.2732}
#
#  professor ian goldin
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  contribution tounleashing ai citi investment bank oxford martin team explores opportunity challenge generative artificial intelligence found potential opportunity
# postive, {'neg': 0.0, 'neu': 0.583, 'pos': 0.417, 'compound': 0.8402}
#
#  dr pantelis koutroumpisdirector oxford martin programme technological economic change report coauthor said generative ai already shown impressive potential across range application recent month
# postive, {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.5106}
#
#  adoption technology appears correlate sizeable productivity boost limitation also evident user
# postive, {'neg': 0.158, 'neu': 0.647, 'pos': 0.194, 'compound': 0.128}
#
#  beyond data better computing resource model excel fed highquality human generated input
# postive, {'neg': 0.0, 'neu': 0.629, 'pos': 0.371, 'compound': 0.7096}
#
#  adoption technology appears correlate sizeable productivity boost limitation also evident user
# postive, {'neg': 0.158, 'neu': 0.647, 'pos': 0.194, 'compound': 0.128}
#
#  dr pantelis koutroumpis
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  report also highlight series challenge including
# postive, {'neg': 0.0, 'neu': 0.519, 'pos': 0.481, 'compound': 0.4019}
#
#  report concludes world ai arm race country striving establish scientific technological dominance research output patenting
# postive, {'neg': 0.0, 'neu': 0.886, 'pos': 0.114, 'compound': 0.2023}
#
#  article
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  tech giant arent much acquiring day due mostly unfavorable regulatory environment
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  theyre finding way spend billion dollar next big thing
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  amazons275 billion investment artificial intelligence startup anthropic announced week itslargest venture dealand latest example ai gold rush thats prompting biggest tech company fling open wallet
# postive, {'neg': 0.0, 'neu': 0.886, 'pos': 0.114, 'compound': 0.4767}
#
#  anthropic developer behind ai model claude competes gpt frommicrosoftbacked openai andgooglesgemini
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  along withmetaandapple theyre racing integrate generative ai vast portfolio product feature ensure dont fall behind market thatspredicted top one trillionin revenue within decade
# postive, {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.5267}
#
#  two thousand and twenty-three investor pumped two hundred and ninety-one billion combined nearly seven hundred generative ai deal increase two hundred and sixty value prior year according pitchbook
# postive, {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.5719}
#
#  significant chunk money strategic came tech company rather venture capitalist institution
# postive, {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.2023}
#
#  fred havemeyer head u ai software research macquarie said fear missing one factor driving decision
# negative, {'neg': 0.31, 'neu': 0.69, 'pos': 0.0, 'compound': -0.6597}
#
#  definitely dont want miss part ai ecosystem havemeyer said
# postive, {'neg': 0.108, 'neu': 0.528, 'pos': 0.365, 'compound': 0.4445}
#
#  definitely think there fomo marketplace
# postive, {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'compound': 0.4019}
#
#  hefty investment necessary ai model notoriously expensive build train requiring thousand specialized chip date largely come fromnvidia
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  meta developing model calledllama said spending billion nvidias graphic processing unit one many company thats helped chipmakerbolsteryearoveryear revenue two hundred and fifty
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  whether going building investing route finite number company afford play market
# postive, {'neg': 0.0, 'neu': 0.709, 'pos': 0.291, 'compound': 0.4019}
#
#  addition developing chip nvidia emerged one silicon valley top investor taking stake number emerging ai company partly way make sure technology get widely deployed
# postive, {'neg': 0.0, 'neu': 0.803, 'pos': 0.197, 'compound': 0.483}
#
#  similarly microsoft google amazon sometimes offer cloud credit part investment
# postive, {'neg': 0.0, 'neu': 0.65, 'pos': 0.35, 'compound': 0.5106}
#
#  amazonanthropic deal announced wednesday two company said theyll work closely together variety way
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  anthropic using amazon web service computing need well amazon chip
# postive, {'neg': 0.0, 'neu': 0.56, 'pos': 0.44, 'compound': 0.5423}
#
#  anthropics model distributed amazon aws customer
# postive, {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'compound': 0.1779}
#
#  earlier month anthropic launchedclaude three powerful model one say let user upload photo chart document type unstructured data analysis answer
# postive, {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.4215}
#
#  microsoft got business generative ai investing earlier putting1 billioninto openai two thousand and nineteen
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  size investment since swelled thirteen billion
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  microsoft heavily us openais model offer open source model azure cloud
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  alphabet playing part builder investor
# postive, {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.2023}
#
#  company refocused much product development generative ai newly rebranded gemini model adding feature search document map elsewhere
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  last year googlecommittedto invest two billion anthropic previously confirming taken ten stake startup alongside large cloud contract two company
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  havemeyer said tech giant arent throwing money hype cycle investment ai startup align product road map
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  dont think frivolous said
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  havemeyer said alliance big cloud provider bring muchneeded cash startup also help sign customer
# postive, {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.4019}
#
#  cloud company saying come u work platform native access latest greatest ai model also use infrastructure havemeyer said
# postive, {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'compound': 0.6369}
#
#  also part much larger ecosystem play
# postive, {'neg': 0.0, 'neu': 0.676, 'pos': 0.324, 'compound': 0.34}
#
#  seeing lot alliance appearing among hyperscalers substantial scale infrastructure deep pocket added
# postive, {'neg': 0.0, 'neu': 0.859, 'pos': 0.141, 'compound': 0.2023}
#
#  recent earnings call tech exec reiterated focus generative ai making clear investor spend money make money whether internal development investing startup
# postive, {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.3818}
#
#  microsoft chief financial officer amy hood said last year company adjusting workforce toward aifirst work without adding material number people workforce
# negative, {'neg': 0.058, 'neu': 0.942, 'pos': 0.0, 'compound': -0.0572}
#
#  said microsoft continue prioritize investing ai thing thats going shape next decade
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  leader google apple amazon alsosuggested investorsthat theyre willing cut cost broadly across department order redirect funding toward ai effort
# negative, {'neg': 0.101, 'neu': 0.817, 'pos': 0.082, 'compound': -0.1027}
#
#  startup among beneficiary
# postive, {'neg': 0.0, 'neu': 0.392, 'pos': 0.608, 'compound': 0.4767}
#
#  microsoft taken stake mistral figure humane addition openai
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  company invested inflection ai startup essentially dissolved joined microsoft month
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  mistral open sourcefocused company us azure cloud offer service azure client
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  figure startup seeking build robot walk like human raised money microsoft openai nvidia wasvalued last monthat twenty-six billion
# postive, {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.3612}
#
#  amazon biggest bet anthropic pouring total four billion far
# postive, {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.1779}
#
#  company also invested open source ai platform developer hugging face
# postive, {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.4215}
#
#  google investment include essential ai developing consumer ai program backed byamdand nvidia
# postive, {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.0258}
#
# ...
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  chatgpt kickstarted genai boom late two thousand and twenty-two mimic human conversation perform task creating summary long text writing poem even generating idea theme party
# postive, {'neg': 0.0, 'neu': 0.824, 'pos': 0.176, 'compound': 0.5994}
#
#  san franciscobased company said gradually roll feature make ai accessible anyone curious capability
# postive, {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3182}
#
#  popular service set record fastestgrowing user base seen growth slow since may two thousand and twenty-three traffic peaked eighteen billion web visit according data analytics firm similarweb
# postive, {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.6597}
#
#  openai said introduced additional content safeguard user accessing chatgpt without signing blocking prompt generation wider range category
# postive, {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.5837}
#
#  specify category
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  apart free version chatgpt direct access internet openai also offer paid version individual team user enterprise
# postive, {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5106}
#
#  company also said may use content provided user help improve largelanguage model said user turn feature
# postive, {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.6808}
#
#  move come month billionaire entrepreneur elon musk sued openai ceo sam altman saying abandoned startup original mission develop artificial intelligence benefit humanity profit
# postive, {'neg': 0.093, 'neu': 0.557, 'pos': 0.35, 'compound': 0.8074}
#
#  reporting arsheeya bajwa bengaluru anna tong san francisco krystal hu new york editing tasim zahid
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  spread fake news disinformation steadily risen past year audience increasingly getting news online false information sometimes generated ai spread faster threatening audience trust medium
# negative, {'neg': 0.211, 'neu': 0.682, 'pos': 0.107, 'compound': -0.4939}
#
#  series infographics euractiv take deeper dive trend playing across europe medium landscape
# postive, {'neg': 0.0, 'neu': 0.859, 'pos': 0.141, 'compound': 0.2023}
#
#  trend consumer trusting medium le le observed resulting turning social medium get news instead
# postive, {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.4019}
#
#  boththis yearandlast year u trust medium hit alltime low
# postive, {'neg': 0.184, 'neu': 0.526, 'pos': 0.289, 'compound': 0.296}
#
#  pattern eu laid graph
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  meanwhiletiktok example popular among younger generation alternative traditional news source
# postive, {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.4215}
#
#  using data two thousand and twenty chart also show social medium play big role news source
# postive, {'neg': 0.0, 'neu': 0.862, 'pos': 0.138, 'compound': 0.34}
#
#  yet according aeurobarometer surveypublished european parliament seventeen november us two thousand and twenty-two data main source news television seventy-one respondent saying one used source past seven day time research
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  however eleven increase using social medium platform get news compared last year survey
# postive, {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3182}
#
#  counteract risk artificial intelligence believe aican help debunk fake news horizon europe project ai4trust
# postive, {'neg': 0.248, 'neu': 0.476, 'pos': 0.276, 'compound': 0.1531}
#
#  ai4trust isdevelopinga system based machinehuman cooperation advanced solution horizon europe two hundred and two thousand, three hundred and twenty-four work programmeaimsto move closer aibased market solution ensure access meaningful information quality content trustworthy online interaction
# postive, {'neg': 0.0, 'neu': 0.658, 'pos': 0.342, 'compound': 0.9201}
#
#  however social medium platform also source
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  knowing real aigenerated help trust news
# postive, {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound': 0.7184}
#
#  march example eu law enforcement agency europolwarnedthat chatgpt benefit business individual malicious actor exploit technology posing law enforcement challenge
# postive, {'neg': 0.065, 'neu': 0.737, 'pos': 0.198, 'compound': 0.4404}
#
#  criminal typically quick exploit new technology fast seen coming concrete criminal exploitation providing first practical example mere week public release chatgpt read thereport
# negative, {'neg': 0.291, 'neu': 0.709, 'pos': 0.0, 'compound': -0.802}
#
#  dissemination nude image minor created ai concern law enforcement one bound become increasingly difficult address europol alsotold euractivin october
# negative, {'neg': 0.116, 'neu': 0.791, 'pos': 0.093, 'compound': -0.128}
#
#  law enforcement agency added aigenerated material must detected using ai classifier tool currently authorised use classifier tool specific purpose
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  european union reading news online increased past year graph show two thousand and thirteen two thousand and twenty-two according tostatista
# postive, {'neg': 0.0, 'neu': 0.9, 'pos': 0.1, 'compound': 0.2732}
#
#  online frequency type fake news reader differ seen graph cover europe largest country
# negative, {'neg': 0.205, 'neu': 0.795, 'pos': 0.0, 'compound': -0.4767}
#
#  frequency seeing disinformation depend different type medium citizen exposure level disinformation general every country either
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  country may different percentage regarding fake news following map show scandinavian country le affected central southern europe
# negative, {'neg': 0.239, 'neu': 0.761, 'pos': 0.0, 'compound': -0.5719}
#
#  last year bulgarian citizen highest exposure misinformation twenty-eight april twenty-six may eleven living netherlands least exposed six
# negative, {'neg': 0.124, 'neu': 0.81, 'pos': 0.066, 'compound': -0.2681}
#
#  regardless frequency exposure seeing false information impact one life differently
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  claim thirty-five check news thoroughly encounter
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  however almost many people thirty-three believe impact
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  edited alice taylornathalie weatherald
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  significant hype fear ai particularly generative ai crowding news headline last week
# negative, {'neg': 0.213, 'neu': 0.667, 'pos': 0.12, 'compound': -0.34}
#
#  generative ai least context us large language model create response
# postive, {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.2732}
#
#  essentially selftrained ai smart collectively
# postive, {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'compound': 0.4019}
#
#  use training data make educated guess
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  algorithmic
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  complicated math
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  make pretty good guess time
# postive, {'neg': 0.0, 'neu': 0.33, 'pos': 0.67, 'compound': 0.7269}
#
#  yes
# postive, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4019}
#
#  however ai today isnt actual intelligence actual sapience fact lost many result fromgenerative aican impressive
# negative, {'neg': 0.241, 'neu': 0.595, 'pos': 0.164, 'compound': -0.1416}
#
#  gold standard business intelligence
# postive, {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.4767}
#
#  find
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  need think intake information
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  anything human race learned need critically examine information given
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  fear generative ai fooled
# negative, {'neg': 0.744, 'neu': 0.256, 'pos': 0.0, 'compound': -0.7003}
#
#  happened already
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  happened
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  human inclined believe gullible want believe giving u information good intention
# postive, {'neg': 0.166, 'neu': 0.397, 'pos': 0.437, 'compound': 0.4767}
#
#  ai today intention
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  moral give use generate u
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  need apply scepticism
# negative, {'neg': 0.474, 'neu': 0.526, 'pos': 0.0, 'compound': -0.2023}
#
#  hard appears
# negative, {'neg': 0.583, 'neu': 0.417, 'pos': 0.0, 'compound': -0.1027}
#
#  anyone take television advertisement really kind ad undisputed truth
# postive, {'neg': 0.0, 'neu': 0.539, 'pos': 0.461, 'compound': 0.7178}
#
#  course
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  assumed advertiser best interest heart economic interest
# postive, {'neg': 0.0, 'neu': 0.282, 'pos': 0.718, 'compound': 0.8807}
#
#  verification stated claim required product service purchased
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  individual need apply level scepticism nearly everything read see
# negative, {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'compound': -0.2023}
#
#  including article
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  time panic generative ai
# negative, {'neg': 0.524, 'neu': 0.476, 'pos': 0.0, 'compound': -0.5106}
#
#  technology impressive extremely helpful
# postive, {'neg': 0.0, 'neu': 0.238, 'pos': 0.762, 'compound': 0.7501}
#
#  time educate raise standard accepting see truth
# postive, {'neg': 0.0, 'neu': 0.505, 'pos': 0.495, 'compound': 0.5994}
#
#  access comprehensive company profile market powered globaldata
# postive, {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.25}
#
#  save hour research
# postive, {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.4939}
#
#  gain competitive edge
# postive, {'neg': 0.0, 'neu': 0.164, 'pos': 0.836, 'compound': 0.6249}
#
#  download email arrive shortly
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  confident unique quality company profile
# postive, {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.4939}
#
#  however want make beneficial decision business offer free sample download submitting form
# postive, {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.7579}
#
#  adapt willing far benefit ai bring worth challenge
# postive, {'neg': 0.0, 'neu': 0.446, 'pos': 0.554, 'compound': 0.6369}
#
#  leveraging advanced generative ai capability seamlessly integrated itsconversational commercesolution vonage arming business tool create realtime personalised connection customer across platform delivering meaningful customer data streamlining operation automation notesvonage
# postive, {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.6597}
#
#  generative aipowered update vonage conversational commerce solution addition marketing template content generator live chat assistance intuitive knowledge base inquiry making impact across customer touchpoints today enterprise including agent marketing customer support team
# postive, {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.6124}
#
#  vonage say core new generative aipowered capability aipowered assistance live chat interaction helping agent tailor response provide better customer service realtime improving accelerating live chat response customer well rephrasing functionality ensure precise communication allowing agent refine tone response power ai helping business enhance agent productivity overall communication effectiveness
# postive, {'neg': 0.0, 'neu': 0.739, 'pos': 0.261, 'compound': 0.9153}
#
#  also included new offering content generator designed crafting whatsappbased marketing template empower brand speed simplify production diverse marketing content significantly reduce workload marketing team
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  significantly reducing time resource craft diverse marketing message marketing team better equipped run multiple campaign still ensuring message resonates individual customer
# postive, {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'compound': 0.6124}
#
#  intuitive template business unlocking kind connection drive real lead ultimate profitability
# postive, {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'compound': 0.6705}
#
#  aipowered answer offering knowledge base also help reduce human dependency allow knowledge base ai bot interpret user query parse knowledge base document answer user query directly
# postive, {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.5574}
#
#  utilising document uploaded knowledge base respond query streamline customer support knowledge base eliminates need canned impersonal response delivering personalised experience customer vonage note
# postive, {'neg': 0.088, 'neu': 0.808, 'pos': 0.104, 'compound': 0.1027}
#
#  seeing significant increase demand integrated ai capability easily expanded across platform business recognise efficiency customization possibility generative ai offer saidsavinay berry evp product engineering vonage
# postive, {'neg': 0.049, 'neu': 0.656, 'pos': 0.295, 'compound': 0.7579}
#
#  integrating stateoftheart generative ai capability conversational commerce solution empowering user generate creative content automate task improve overall user experience
# postive, {'neg': 0.0, 'neu': 0.664, 'pos': 0.336, 'compound': 0.7964}
#
#  advancement generative ai harnessed significantly enhance conversational commerce solution empowering ecommerce marketer online retailer seamlessly connect potential customer delivering personalised experience saidkrishna baidya sr director information communication technology frost sullivan
# postive, {'neg': 0.0, 'neu': 0.927, 'pos': 0.073, 'compound': 0.3182}
#
#  infusing generative ai knowledge base brand respond query streamline customer support ensuring efficient reliable selfservice option conversation
# postive, {'neg': 0.0, 'neu': 0.648, 'pos': 0.352, 'compound': 0.765}
#
#  adding aipowered assistance live chat interaction boost agent productivity communication effectiveness
# postive, {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019}
#
#  according vonage referral marketing continues powerful strategy business reach target customer drive sale vonage conversational commerce user initiate whatsapp referral campaign right dashboard giving ability acquire new customer without additional marketing overhead cost
# postive, {'neg': 0.0, 'neu': 0.771, 'pos': 0.229, 'compound': 0.765}
#
#  whatsapp vonage weve able better identify market top twenty-five percent active subscriber saidkamila skötsch global crm team leadholidaypirates international travel company vonage conversational commerce customer
# postive, {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.7506}
#
#  subscriber using whatsapp faster act deal people using channel generating traffic partner clickthroughrates high forty percent message receiving ninety-seven percent open rate
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  vonage also launched conversational commerce apis enable third party application connect jumperai dashboard deliver conversational marketing commerce capability via integration leading customer engagement platform moengage salesforce marketing cloud
# postive, {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.7351}
#
#  developer apis empower marketer product owner extend platform lower level 1way notification richer 2way conversation leveraging vonage conversational commerce capability share product catalog complete transactionturning notification sale concludes vonagegenerative aipowered enhancement vonage conversational commerce powered jumperai solution currently beta generally available second quarter two thousand and twenty-four
# postive, {'neg': 0.041, 'neu': 0.781, 'pos': 0.178, 'compound': 0.7506}

# %%
data = [] #List to store dictioneries
for sentence in sentences:
  sentiment, polarity = getPolarity(sentence)
  new_item = {'sentence' : sentence, 'sentiment' : sentiment, 'category' : 'GenAI'}
  data.append(new_item)

df = pd.DataFrame(data)

df.to_csv('GenAI (No numbers) - Vader ver.csv', index=False)
