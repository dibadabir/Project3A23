# %%
# Downloading libraries for web-scraping
# !pip install requests
# !pip install beautifulsoup4==4.9.3
# !pip install bs4
# !pip install html5lib
# !pip install num2words
# !pip install vaderSentiment

# Importing libraries for web-scraping and tokenization purposes
from bs4 import BeautifulSoup as bs
import requests
import nltk
import pandas as pd
import re
from textblob import TextBlob
from num2words import num2words
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# The list of common words such as "a", "an", etc.
nltk.download('stopwords')
# Download a collection of popular resources from the NLTK library
nltk.download('popular', quiet=True)
# Sentence tokenization (Splitting a text into individual senteces)
nltk.download('punkt')
# English vocabulary database
nltk.download('wordnet')
# Used for training language models or evaluating nlp algothms
nltk.download('brown')
# Used for performing sentiment analysis on text
nltk.download('vader_lexicon')

from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize

lemmatizer = WordNetLemmatizer()
analyzer = SentimentIntensityAnalyzer()
stemmer = SnowballStemmer("english")
stop_words = stopwords.words("english")
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Collecting beautifulsoup4==4.9.3
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.8/115.8 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4==4.9.3) (2.5)
# Installing collected packages: beautifulsoup4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.3
#     Uninstalling beautifulsoup4-4.12.3:
#       Successfully uninstalled beautifulsoup4-4.12.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yfinance 0.2.37 requires beautifulsoup4>=4.11.1, but you have beautifulsoup4 4.9.3 which is incompatible.
# Successfully installed beautifulsoup4-4.9.3
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib) (0.5.1)
# Collecting num2words
#   Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 3.1 MB/s eta 0:00:00
# Collecting docopt>=0.6.2 (from num2words)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=58a79148abf700a3d7f60f0dc25859dba8dcaf5e0d5769ca49f484dcbdc2a565
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: docopt, num2words
# Successfully installed docopt-0.6.2 num2words-0.5.13
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2024.2.2)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
sentences = []

def scrape_clean (url, div_class):
  # Load the website
  website = requests.get(url).text
  soup = bs(website,'html.parser')

  # Find the div section that is the parent of all paragraphs
  div = soup.find_all('div', attrs={'class':div_class})

  # Get the text from paragraphs
  extracted_text = []
  for div in div:
      paragraphs = div.find_all('p')
      for paragraph in paragraphs:
          extracted_text.append(paragraph.get_text(strip=True))  # Remove leading/trailing whitespace

  # Splitting the text into sentences, remove the stopwords and punctuations, and save the cleaned version in a list
  sentences = []
  for text in extracted_text:
    sentence = sent_tokenize(text)
    for item in sentence:
      # Convert to lowercase
      text_lowercase = item.lower()
      # Remove punctuation
      text_without_punctuation = re.sub(r"[^\w\s]", "", text_lowercase)
      # Remove stopwords and stem words
      tokens = word_tokenize(text_without_punctuation)
      new_tokens = []
      for word in tokens:
        if word.isnumeric():
          word = num2words(word)
          new_tokens.append(lemmatizer.lemmatize(word))
          continue
        elif word not in stop_words:
          new_tokens.append(lemmatizer.lemmatize(word))
          continue
      # Join tokens back into a string
      cleaned_text = " ".join(new_tokens)
      sentences.append(cleaned_text)

  return sentences

# %%
website1 = 'https://www.theguardian.com/fashion/2024/feb/08/ai-london-fashion-week'
class1 = 'dcr-ch7w1w'
text1 = scrape_clean(website1, class1)
sentences.extend(text1)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright']

# %%
website2 = 'https://www.bbc.co.uk/news/business-68347250'
class2 = 'ssrcss-1ki8hfp-StyledZone e1mcntqj3'
text2 = scrape_clean(website2, class2)
sentences.extend(text2)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better']

# %%
website3 = 'https://ytech.news/en/the-integral-role-of-ai-in-the-future-of-fashion/'
class3 = 'post-content-inner'
text3 = scrape_clean(website3, class3)
sentences.extend(text3)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application']

# %%
website4 = 'https://www.aljazeera.com/economy/2024/2/23/the-latest-industry-upset-with-the-use-of-ai-fashion'
class4 = 'wysiwyg wysiwyg--all-content css-ibbk12'
text4 = scrape_clean(website4, class4)
sentences.extend(text4)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product']

# %%
website5 = 'https://www.just-style.com/news/signal-upskilling-in-ai-could-be-the-next-big-requirement-in-fashion/?cf-view'
class5 = 'cell large-8 main-content'
text5 = scrape_clean(website5, class5)
sentences.extend(text5)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report']

# %%
website6 = 'https://www.forbes.com/sites/forbescommunicationscouncil/2023/11/30/the-future-of-marketing-in-the-fashion-and-lifestyle-industries-ai-personalization-and-data-driven-insights/?sh=2eeb47975f0e'
class6 = 'body-container'
text6 = scrape_clean(website6, class6)
sentences.extend(text6)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify']

# %%
website7 = 'https://fashionunited.uk/news/business/gen-ai-game-changer-for-sustainable-fashion/2024010373369'
class7 = 'css-1s0my6s e15wwp330'
text7 = scrape_clean(website7, class7)
sentences.extend(text7)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability']

# %%
website8 = 'https://www.standard.co.uk/news/tech/ai-fashion-models-virtual-tryon-diffusion-models-b1120382.html'
class8 = 'sc-ghHZHN kNjFqH'
text8 = scrape_clean(website8, class8)
sentences.extend(text8)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability']

# %%
website9 = 'https://jingdaily.com/posts/web3-ai-and-the-fashion-revolution-insights-from-the-2023-new-codes-digital-fashion-summit'
class9 = 'c-cvYqge'
text9 = scrape_clean(website9, class9)
sentences.extend(text9)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability',
#  'digital fashion look like today',
#  'question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one',
#  'taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution',
#  'digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research',
#  'fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one',
#  'response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment',
#  'speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem',
#  'hype cooled two thousand and twenty-two critic quick slate web3 nonfungible token nfts metaverse dead marco marchesi chief technology officer fabricant belief industry still show sign life',
#  'technology take lot cycle new idea take adopted',
#  'reality completely figured yet going take lot cycle find steady ground say',
#  'educating audience technicality digital fashion bolster credibility',
#  'there assumption around craft digital fashion dont realize technically challenging practice digital artist stephy fung say',
#  'dani loftus founder digital fashion house draup also argues clunky earlystage technology prevented widespread adoption',
#  'lot people exposed digital fashion first time ever last year loftus say',
#  'youre making digital dress arm fall people going see confirmation bias',
#  'doesnt perform well people turn away',
#  'evolution gaming platform social hub business goldmine potentially biggest seismic shift brand reach audience today',
#  'gen z gen alpha come age unleash spending power brand longer rely outdated marketing tactic magazine campaign celebrity partnership attract eyeball',
#  'key consumer demographic residing gaming destination like fornite roblox early adopter reaping benefit translating identity robust presence space',
#  'gaming space sartorial space play philippa morgan chief content officer savant say',
#  'brand planting seed space reach audience',
#  'attract younger consumer youre going advertise parking lot youre going go kid play',
#  'today brand need willing fully engage new ecosystem shy away experimenting image play',
#  'year saw unprecedented boom generative ai technology potential still yet fully realized fashion',
#  'remains fundamental issue industry approach machine learning',
#  'brand dont get bandwagon product like ai theyll left dust marchesi say discussing brand reticence towards generative system',
#  'fashion slowly surely actively reshaped ai',
#  'september fashion week alone saw coperni collina strada ganni deploy burgeoning tech runway',
#  'question whether ai replace creative role like designer pattern cutter image maker remains hot topic',
#  'fung belief tech cant wont replace human touch',
#  'use ai might take role art director creative director ai cant replicate whats inside brain',
#  'curation come u say',
#  'beyond creative scope machine learning also assisting brand making much productive decision across supply chain efficiency environmental standpoint',
#  'sasha mcfarlane executive director future proof fashion highlight trend cycle moving record speed traditional manufacturing roadmaps cant keep rapid turnover consumer demand',
#  'generative ai disrupting process predicting trend customer behavior month advance helping supplier scale waste',
#  'size global augmented reality virtual reality market estimated thirty-eight billion two thousand and twenty-two projected hit around three hundred and seventy-two billion two thousand and thirty-two according toprecedence research',
#  'trailblazer zero10 fffaceme paving way augmented realitypowered experience retail',
#  'effort havent gone unnoticed',
#  'year brand including tiffany co tommy hilfiger coach jd sport tapped ar capture consumer eyeball',
#  'beyond novelness moin robertsislam technology development manager fashion innovation agency explains ar emerged premium tool collecting data driving consumer loyalty',
#  'speaking one initiative latest ar activation robertsislam note consumer expressed brand loyalty immersive experience',
#  'ninety percent audience said would pay product understood better valued',
#  'digital fashion landscape remains fertile ground emerging technology like ar ai web3 already process overturning industry',
#  'brand still turning blind eye potential run risk selfsabotage',
#  'even understanding basic soon indispensable tool loftus argues',
#  'learning use something like discord server absolutely monumental',
#  'valuable asset say',
#  'there use entering increasingly digitized world without authenticity',
#  'marchesi highlight longterm wellintentioned goal behind every digital activation',
#  'create revenue youre trying create revenue say',
#  'there use trying jump bandwagon reason reason solely making profit']

# %%
website10 = 'https://www.context.news/ai/digital-designs-to-avatar-models-how-is-ai-transforming-fashion'
class10 = 'ArticleText_text__9RYj1'
text10 = scrape_clean(website10, class10)
sentences.extend(text10)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability',
#  'digital fashion look like today',
#  'question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one',
#  'taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution',
#  'digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research',
#  'fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one',
#  'response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment',
#  'speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem',
#  'hype cooled two thousand and twenty-two critic quick slate web3 nonfungible token nfts metaverse dead marco marchesi chief technology officer fabricant belief industry still show sign life',
#  'technology take lot cycle new idea take adopted',
#  'reality completely figured yet going take lot cycle find steady ground say',
#  'educating audience technicality digital fashion bolster credibility',
#  'there assumption around craft digital fashion dont realize technically challenging practice digital artist stephy fung say',
#  'dani loftus founder digital fashion house draup also argues clunky earlystage technology prevented widespread adoption',
#  'lot people exposed digital fashion first time ever last year loftus say',
#  'youre making digital dress arm fall people going see confirmation bias',
#  'doesnt perform well people turn away',
#  'evolution gaming platform social hub business goldmine potentially biggest seismic shift brand reach audience today',
#  'gen z gen alpha come age unleash spending power brand longer rely outdated marketing tactic magazine campaign celebrity partnership attract eyeball',
#  'key consumer demographic residing gaming destination like fornite roblox early adopter reaping benefit translating identity robust presence space',
#  'gaming space sartorial space play philippa morgan chief content officer savant say',
#  'brand planting seed space reach audience',
#  'attract younger consumer youre going advertise parking lot youre going go kid play',
#  'today brand need willing fully engage new ecosystem shy away experimenting image play',
#  'year saw unprecedented boom generative ai technology potential still yet fully realized fashion',
#  'remains fundamental issue industry approach machine learning',
#  'brand dont get bandwagon product like ai theyll left dust marchesi say discussing brand reticence towards generative system',
#  'fashion slowly surely actively reshaped ai',
#  'september fashion week alone saw coperni collina strada ganni deploy burgeoning tech runway',
#  'question whether ai replace creative role like designer pattern cutter image maker remains hot topic',
#  'fung belief tech cant wont replace human touch',
#  'use ai might take role art director creative director ai cant replicate whats inside brain',
#  'curation come u say',
#  'beyond creative scope machine learning also assisting brand making much productive decision across supply chain efficiency environmental standpoint',
#  'sasha mcfarlane executive director future proof fashion highlight trend cycle moving record speed traditional manufacturing roadmaps cant keep rapid turnover consumer demand',
#  'generative ai disrupting process predicting trend customer behavior month advance helping supplier scale waste',
#  'size global augmented reality virtual reality market estimated thirty-eight billion two thousand and twenty-two projected hit around three hundred and seventy-two billion two thousand and thirty-two according toprecedence research',
#  'trailblazer zero10 fffaceme paving way augmented realitypowered experience retail',
#  'effort havent gone unnoticed',
#  'year brand including tiffany co tommy hilfiger coach jd sport tapped ar capture consumer eyeball',
#  'beyond novelness moin robertsislam technology development manager fashion innovation agency explains ar emerged premium tool collecting data driving consumer loyalty',
#  'speaking one initiative latest ar activation robertsislam note consumer expressed brand loyalty immersive experience',
#  'ninety percent audience said would pay product understood better valued',
#  'digital fashion landscape remains fertile ground emerging technology like ar ai web3 already process overturning industry',
#  'brand still turning blind eye potential run risk selfsabotage',
#  'even understanding basic soon indispensable tool loftus argues',
#  'learning use something like discord server absolutely monumental',
#  'valuable asset say',
#  'there use entering increasingly digitized world without authenticity',
#  'marchesi highlight longterm wellintentioned goal behind every digital activation',
#  'create revenue youre trying create revenue say',
#  'there use trying jump bandwagon reason reason solely making profit',
#  'two hundred fashion designer showcase digital collection designed help ai tool modelled avatar theworlds first ai fashion weekin new york thursday',
#  'twoday event hosted ai creative agency maison meta give three winner deal produce design condition physically manufactured',
#  'predictive tool slash material waste virtual fitting room ai increasingly used manufacturing retail fashion sector',
#  'ai reshaping industry people feel',
#  'sixty designer participating ai fashion week used texttoimage generator midjourney produce image based written prompt help design collection',
#  'explain texture length emotion specific better result said alena stepanova whose collection ai fashion week inspired colour landscape nature native kazakhstan',
#  'digital design allows see one item look different body shape told context',
#  'datadriven ai also used inform design predicting trend fashion giving insight consumer preferred colour style',
#  'american designer tommy hilfiger partnered hardware service company ibm fashion institute technology use ai todesign clothes based dataabout consumer trend',
#  'retail side ai used detect fake optimise pricing clothing resale site help shopper try clothes virtually even choose buy tool uniqlo store recommends product aftermeasuring shopper reaction clothing',
#  'consultancy mckinsey found company excel personalisation generate40 profitthan',
#  'aigenerated model also increasingly used editorial shoot vogue singapore online edition vogue brazil choosing useavatars coversof spring edition year',
#  'ai could add to275 billionto apparel fashion luxury sector operating profit according mckinsey report published march',
#  'ai model agency lalaland said using ai model is90 fasterthan photoshoots requires sample helping brand reduce waste well save time',
#  'ai help company predict inventory needed thus minimising overstocking also reduce return rate helping consumer find bettersuited product according holger harreis senior partner mckinsey',
#  'designer even hope move fashion industry online entirely cutting physical sample',
#  'digital fashion house fabricant creates sell fashion collection nonfungible token nfts kind digital asset often linked image piece artwork usually bought cryptocurrencies',
#  'say using digital sample instead physical garment design development phase clothing canreduce brand carbon footprint thirty',
#  'boom ai tool like chatgpt automate certain area work data entry customer service sparked fear thatrobots could poach job',
#  'use avatar place human model raising similar concern fashion industry makeup artist hair stylist photographer behindthescenes creatives could lose use ai model',
#  'new york city model manager greg chan said hard tell much work missed opportunity may completely bypass agency go straight ai',
#  'model losing job computer fact software able slightly change people skin colour slide switch said chan worry ai manipulate ethnicity reinforce unrealistic beauty standard',
#  'apparel company levi strauss announced march would partner ai model agency create personal inclusive shopping experience prompting online backlash critic said company hire real model promote diversity',
#  'company responded partnership would address business efficiency conflated diversity inclusion strategy',
#  'calvin wong head laboratory artificial intelligence design hong kong said ai used assistant rather something creates design maintain agency designer ensure creation manufacturable',
#  'lab hasdesigned ai toolthat allows designer upload draft sketch material colour palette generate design tweaked',
#  'need treasure originality inspiration fashion designer wong said',
#  'reporting beatrice tridimas editing zoe tabary']

# %%
website11 = 'https://www.glossy.co/fashion/how-generative-ai-will-impact-fashion/'
class11 = 'article-content'
text11 = scrape_clean(website11, class11)
sentences.extend(text11)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability',
#  'digital fashion look like today',
#  'question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one',
#  'taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution',
#  'digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research',
#  'fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one',
#  'response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment',
#  'speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem',
#  'hype cooled two thousand and twenty-two critic quick slate web3 nonfungible token nfts metaverse dead marco marchesi chief technology officer fabricant belief industry still show sign life',
#  'technology take lot cycle new idea take adopted',
#  'reality completely figured yet going take lot cycle find steady ground say',
#  'educating audience technicality digital fashion bolster credibility',
#  'there assumption around craft digital fashion dont realize technically challenging practice digital artist stephy fung say',
#  'dani loftus founder digital fashion house draup also argues clunky earlystage technology prevented widespread adoption',
#  'lot people exposed digital fashion first time ever last year loftus say',
#  'youre making digital dress arm fall people going see confirmation bias',
#  'doesnt perform well people turn away',
#  'evolution gaming platform social hub business goldmine potentially biggest seismic shift brand reach audience today',
#  'gen z gen alpha come age unleash spending power brand longer rely outdated marketing tactic magazine campaign celebrity partnership attract eyeball',
#  'key consumer demographic residing gaming destination like fornite roblox early adopter reaping benefit translating identity robust presence space',
#  'gaming space sartorial space play philippa morgan chief content officer savant say',
#  'brand planting seed space reach audience',
#  'attract younger consumer youre going advertise parking lot youre going go kid play',
#  'today brand need willing fully engage new ecosystem shy away experimenting image play',
#  'year saw unprecedented boom generative ai technology potential still yet fully realized fashion',
#  'remains fundamental issue industry approach machine learning',
#  'brand dont get bandwagon product like ai theyll left dust marchesi say discussing brand reticence towards generative system',
#  'fashion slowly surely actively reshaped ai',
#  'september fashion week alone saw coperni collina strada ganni deploy burgeoning tech runway',
#  'question whether ai replace creative role like designer pattern cutter image maker remains hot topic',
#  'fung belief tech cant wont replace human touch',
#  'use ai might take role art director creative director ai cant replicate whats inside brain',
#  'curation come u say',
#  'beyond creative scope machine learning also assisting brand making much productive decision across supply chain efficiency environmental standpoint',
#  'sasha mcfarlane executive director future proof fashion highlight trend cycle moving record speed traditional manufacturing roadmaps cant keep rapid turnover consumer demand',
#  'generative ai disrupting process predicting trend customer behavior month advance helping supplier scale waste',
#  'size global augmented reality virtual reality market estimated thirty-eight billion two thousand and twenty-two projected hit around three hundred and seventy-two billion two thousand and thirty-two according toprecedence research',
#  'trailblazer zero10 fffaceme paving way augmented realitypowered experience retail',
#  'effort havent gone unnoticed',
#  'year brand including tiffany co tommy hilfiger coach jd sport tapped ar capture consumer eyeball',
#  'beyond novelness moin robertsislam technology development manager fashion innovation agency explains ar emerged premium tool collecting data driving consumer loyalty',
#  'speaking one initiative latest ar activation robertsislam note consumer expressed brand loyalty immersive experience',
#  'ninety percent audience said would pay product understood better valued',
#  'digital fashion landscape remains fertile ground emerging technology like ar ai web3 already process overturning industry',
#  'brand still turning blind eye potential run risk selfsabotage',
#  'even understanding basic soon indispensable tool loftus argues',
#  'learning use something like discord server absolutely monumental',
#  'valuable asset say',
#  'there use entering increasingly digitized world without authenticity',
#  'marchesi highlight longterm wellintentioned goal behind every digital activation',
#  'create revenue youre trying create revenue say',
#  'there use trying jump bandwagon reason reason solely making profit',
#  'two hundred fashion designer showcase digital collection designed help ai tool modelled avatar theworlds first ai fashion weekin new york thursday',
#  'twoday event hosted ai creative agency maison meta give three winner deal produce design condition physically manufactured',
#  'predictive tool slash material waste virtual fitting room ai increasingly used manufacturing retail fashion sector',
#  'ai reshaping industry people feel',
#  'sixty designer participating ai fashion week used texttoimage generator midjourney produce image based written prompt help design collection',
#  'explain texture length emotion specific better result said alena stepanova whose collection ai fashion week inspired colour landscape nature native kazakhstan',
#  'digital design allows see one item look different body shape told context',
#  'datadriven ai also used inform design predicting trend fashion giving insight consumer preferred colour style',
#  'american designer tommy hilfiger partnered hardware service company ibm fashion institute technology use ai todesign clothes based dataabout consumer trend',
#  'retail side ai used detect fake optimise pricing clothing resale site help shopper try clothes virtually even choose buy tool uniqlo store recommends product aftermeasuring shopper reaction clothing',
#  'consultancy mckinsey found company excel personalisation generate40 profitthan',
#  'aigenerated model also increasingly used editorial shoot vogue singapore online edition vogue brazil choosing useavatars coversof spring edition year',
#  'ai could add to275 billionto apparel fashion luxury sector operating profit according mckinsey report published march',
#  'ai model agency lalaland said using ai model is90 fasterthan photoshoots requires sample helping brand reduce waste well save time',
#  'ai help company predict inventory needed thus minimising overstocking also reduce return rate helping consumer find bettersuited product according holger harreis senior partner mckinsey',
#  'designer even hope move fashion industry online entirely cutting physical sample',
#  'digital fashion house fabricant creates sell fashion collection nonfungible token nfts kind digital asset often linked image piece artwork usually bought cryptocurrencies',
#  'say using digital sample instead physical garment design development phase clothing canreduce brand carbon footprint thirty',
#  'boom ai tool like chatgpt automate certain area work data entry customer service sparked fear thatrobots could poach job',
#  'use avatar place human model raising similar concern fashion industry makeup artist hair stylist photographer behindthescenes creatives could lose use ai model',
#  'new york city model manager greg chan said hard tell much work missed opportunity may completely bypass agency go straight ai',
#  'model losing job computer fact software able slightly change people skin colour slide switch said chan worry ai manipulate ethnicity reinforce unrealistic beauty standard',
#  'apparel company levi strauss announced march would partner ai model agency create personal inclusive shopping experience prompting online backlash critic said company hire real model promote diversity',
#  'company responded partnership would address business efficiency conflated diversity inclusion strategy',
#  'calvin wong head laboratory artificial intelligence design hong kong said ai used assistant rather something creates design maintain agency designer ensure creation manufacturable',
#  'lab hasdesigned ai toolthat allows designer upload draft sketch material colour palette generate design tweaked',
#  'need treasure originality inspiration fashion designer wong said',
#  'reporting beatrice tridimas editing zoe tabary',
#  'get top trend brand industry news fashion beauty wellness straight inbox daily',
#  'sign glossy daily newsletterhere',
#  'generative aiproduced picture imaginary nike collaborationsneakershave circled social medium week',
#  'thats one example ai used fashion us already valuable vast spanning marketing engineering immersive experience',
#  'ai stirred buzz last month thanks new increasingly userfriendly ai tool',
#  'last week march twenty image editor adobe firefly graphic design platform canva rolled new ai technologysupportingtexttovideo andbrand design respectively',
#  'specific launch prove ai usefulness forvisual content creation',
#  'thats start',
#  'industry expert predict ai tool allow quicker seamless workflow allowing worker across field including marketing operation engineering focus creative problemsolving task',
#  'one fastest moving potentially impactful trend see tech landscape today said roger robert partner consultancy mckinsey coauthor december two thousand and twenty-two generative ai herereport',
#  'hyperpersonalization',
#  'nextlevel personalization product experience consumer ecommerce site targeted ad instore experience among use case set benefit retailer',
#  'date personalization largely done microsegmentation grouping customer according interest age group location',
#  'youre going see lot automation want deliver hyperpersonalizationsaid brian long ceo personalized mobile messaging platform attentive',
#  'monday company announced attentive ai tool allowing brand create complete multichannel campaign using ai insight effective content fourteen trillion attentive data point',
#  'far major retail brand using tool beta reporting one hundred and forty-eight revenue increase',
#  'lot brand going generative imagemaking platform generate marketing image leverage product product catalog paired background foreground imagery based text prompt enter',
#  'theyre personalizing image setting lighting element said long',
#  'ai us database image paired text prompt select fitting setting element',
#  'case result productionready image send',
#  'case help figure theyre looking final shoot long said tool allows brand customize marketing imagery different geographical region almost cost',
#  'attentive ai develops copy campaign wellour biggest challenge always getting marketing copy completed timely manner said jason edward director ecommerce streetwear brand hat club',
#  'main surprise close final attentive ai allows u get copy step finalize',
#  'able significantly cut content creation time turn allow u build better campaign better segment customer',
#  'visual merchandising collection creation',
#  'ai could also solve problem visual merchandising',
#  'brand open store location need visual merchandising express brand identity globally also tailored context store',
#  'head visual merchandiser rarely lay every store brand fleet due cost time constraint',
#  'able train learning program based instinct intuition best virtual visual merchandiser using ai could bring voice style capability shop door season said robert',
#  'robert also noted creative application ai business',
#  'brand able use generative ai technology synthesize note sketch idea collection',
#  'ai combined operational financial perspective well merchandising marketing create collection price margin sustainable brand good customer',
#  'apart levi strauss co using ai show wider range diversemodelson website channelswere also using ai enhance differentiate loyalty program offering personalized benefit member helping u achieve meaningful growth enrollment revenue app registrationssaid dr amy gershkoff bolles global head digital emerging technology strategy levi strauss cofor example personalized benefit include localized discount based popular product area',
#  'since expanding loyalty program europe last year brand reached five million member worldwide',
#  'ai help u provide personalized product recommendation website mobile app based consumer data specific market said gershkoff bolles',
#  'also leveraging consumer mobility data customize store unique need interest local consumer open new store greatest demand',
#  'finally said ai powering levi promotion analyzing stock category product likely benefit sale',
#  'noted example including midseason endofseason sale well black friday sale u europe',
#  'web3 brand',
#  'web3 brand already implementing ai creative process',
#  'charli cohen founder 2yearold web3 brand rtlss said studio used generative ai speed coding development work allowing ai create code optimized workflow',
#  'also using create usergenerated content',
#  'progressively integrating ai year said cohenour next drop use ai gamify minting postmint experience',
#  'ugc toolkit currently building also include backend process like validating asset managing ip protection theyll automated enhanced ai',
#  'ai used analyzean nfts blockchain transaction history ensure nft original duplicate',
#  'itcan also analyze content nft art ensure original violate copyright law',
#  'one physical fashion brand active web3tommy hilfiger experimenting ai engage customer incocreation',
#  'specifically metaverse fashion week',
#  'giving consumer opportunity design item brand signature preppy style using generative ai',
#  'fashion show',
#  'even fashion show already undergone somewhat atransformation set undergo change due ai',
#  'matthew drinkwater head emerging technology company fashion innovation agency experimenting ai us catwalk since leading aifocused course london college fashion pandemic',
#  'student able showcase final work two thousand and twenty drinkwater worked fia using archival show footage skeletal data moving model create virtual runway show',
#  'project reimagined year include photorealistic model ai released march twenty-one via linkedin',
#  'earlier catwalk huge amount manual labor work involved said drinkwater',
#  'thats say wasnt case time specific skill set required deliver tool creating kind experience much manageable',
#  'thats especially availability ai tool like text prompttovideo ai platform runway ai launched week',
#  'video component going take next level engagement',
#  'image obviously cool video people stop look take time said long',
#  'runway project year fia used ai prompt tool midjourney stable diffusionthey took image luxury brand inspired trained ai model understand look applied look one particular male model create photorealistic video',
#  'drinkwater agreed robert human element even necessary within fashion experimentation creativity ai',
#  'however said new photorealistic opportunity help facilitate mass adoption digital fashion',
#  'note ai faster implement metaverse',
#  'metaverse combination many thing come together right way create really great experience',
#  'thats case ai said robert explaining current software add feature make better',
#  'doesnt require everyone show headset create entirely new platform',
#  'thats shorter hype cycle everyone talking ai people using cforelevant impact',
#  'company aiming cut cost due recessionrelated concern ai use could leveraged cut labor cost',
#  'bottomline impact suggests something need top mind ctos cfo',
#  'many case replace repetitive part human work allowing staff carry project quickly replacement',
#  'drinkwater added combination thing put together like use machine learning artificial intelligence immersive experience start deliver nextgeneration immersive experience',
#  'image courtesy christiane lemieux']

# %%
website12 = 'https://www.just-style.com/news/new-study-suggests-ai-will-revolutionise-fashion-design/'
class12 = 'cell large-8 main-content'
text12 = scrape_clean(website12, class12)
sentences.extend(text12)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability',
#  'digital fashion look like today',
#  'question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one',
#  'taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution',
#  'digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research',
#  'fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one',
#  'response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment',
#  'speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem',
#  'hype cooled two thousand and twenty-two critic quick slate web3 nonfungible token nfts metaverse dead marco marchesi chief technology officer fabricant belief industry still show sign life',
#  'technology take lot cycle new idea take adopted',
#  'reality completely figured yet going take lot cycle find steady ground say',
#  'educating audience technicality digital fashion bolster credibility',
#  'there assumption around craft digital fashion dont realize technically challenging practice digital artist stephy fung say',
#  'dani loftus founder digital fashion house draup also argues clunky earlystage technology prevented widespread adoption',
#  'lot people exposed digital fashion first time ever last year loftus say',
#  'youre making digital dress arm fall people going see confirmation bias',
#  'doesnt perform well people turn away',
#  'evolution gaming platform social hub business goldmine potentially biggest seismic shift brand reach audience today',
#  'gen z gen alpha come age unleash spending power brand longer rely outdated marketing tactic magazine campaign celebrity partnership attract eyeball',
#  'key consumer demographic residing gaming destination like fornite roblox early adopter reaping benefit translating identity robust presence space',
#  'gaming space sartorial space play philippa morgan chief content officer savant say',
#  'brand planting seed space reach audience',
#  'attract younger consumer youre going advertise parking lot youre going go kid play',
#  'today brand need willing fully engage new ecosystem shy away experimenting image play',
#  'year saw unprecedented boom generative ai technology potential still yet fully realized fashion',
#  'remains fundamental issue industry approach machine learning',
#  'brand dont get bandwagon product like ai theyll left dust marchesi say discussing brand reticence towards generative system',
#  'fashion slowly surely actively reshaped ai',
#  'september fashion week alone saw coperni collina strada ganni deploy burgeoning tech runway',
#  'question whether ai replace creative role like designer pattern cutter image maker remains hot topic',
#  'fung belief tech cant wont replace human touch',
#  'use ai might take role art director creative director ai cant replicate whats inside brain',
#  'curation come u say',
#  'beyond creative scope machine learning also assisting brand making much productive decision across supply chain efficiency environmental standpoint',
#  'sasha mcfarlane executive director future proof fashion highlight trend cycle moving record speed traditional manufacturing roadmaps cant keep rapid turnover consumer demand',
#  'generative ai disrupting process predicting trend customer behavior month advance helping supplier scale waste',
#  'size global augmented reality virtual reality market estimated thirty-eight billion two thousand and twenty-two projected hit around three hundred and seventy-two billion two thousand and thirty-two according toprecedence research',
#  'trailblazer zero10 fffaceme paving way augmented realitypowered experience retail',
#  'effort havent gone unnoticed',
#  'year brand including tiffany co tommy hilfiger coach jd sport tapped ar capture consumer eyeball',
#  'beyond novelness moin robertsislam technology development manager fashion innovation agency explains ar emerged premium tool collecting data driving consumer loyalty',
#  'speaking one initiative latest ar activation robertsislam note consumer expressed brand loyalty immersive experience',
#  'ninety percent audience said would pay product understood better valued',
#  'digital fashion landscape remains fertile ground emerging technology like ar ai web3 already process overturning industry',
#  'brand still turning blind eye potential run risk selfsabotage',
#  'even understanding basic soon indispensable tool loftus argues',
#  'learning use something like discord server absolutely monumental',
#  'valuable asset say',
#  'there use entering increasingly digitized world without authenticity',
#  'marchesi highlight longterm wellintentioned goal behind every digital activation',
#  'create revenue youre trying create revenue say',
#  'there use trying jump bandwagon reason reason solely making profit',
#  'two hundred fashion designer showcase digital collection designed help ai tool modelled avatar theworlds first ai fashion weekin new york thursday',
#  'twoday event hosted ai creative agency maison meta give three winner deal produce design condition physically manufactured',
#  'predictive tool slash material waste virtual fitting room ai increasingly used manufacturing retail fashion sector',
#  'ai reshaping industry people feel',
#  'sixty designer participating ai fashion week used texttoimage generator midjourney produce image based written prompt help design collection',
#  'explain texture length emotion specific better result said alena stepanova whose collection ai fashion week inspired colour landscape nature native kazakhstan',
#  'digital design allows see one item look different body shape told context',
#  'datadriven ai also used inform design predicting trend fashion giving insight consumer preferred colour style',
#  'american designer tommy hilfiger partnered hardware service company ibm fashion institute technology use ai todesign clothes based dataabout consumer trend',
#  'retail side ai used detect fake optimise pricing clothing resale site help shopper try clothes virtually even choose buy tool uniqlo store recommends product aftermeasuring shopper reaction clothing',
#  'consultancy mckinsey found company excel personalisation generate40 profitthan',
#  'aigenerated model also increasingly used editorial shoot vogue singapore online edition vogue brazil choosing useavatars coversof spring edition year',
#  'ai could add to275 billionto apparel fashion luxury sector operating profit according mckinsey report published march',
#  'ai model agency lalaland said using ai model is90 fasterthan photoshoots requires sample helping brand reduce waste well save time',
#  'ai help company predict inventory needed thus minimising overstocking also reduce return rate helping consumer find bettersuited product according holger harreis senior partner mckinsey',
#  'designer even hope move fashion industry online entirely cutting physical sample',
#  'digital fashion house fabricant creates sell fashion collection nonfungible token nfts kind digital asset often linked image piece artwork usually bought cryptocurrencies',
#  'say using digital sample instead physical garment design development phase clothing canreduce brand carbon footprint thirty',
#  'boom ai tool like chatgpt automate certain area work data entry customer service sparked fear thatrobots could poach job',
#  'use avatar place human model raising similar concern fashion industry makeup artist hair stylist photographer behindthescenes creatives could lose use ai model',
#  'new york city model manager greg chan said hard tell much work missed opportunity may completely bypass agency go straight ai',
#  'model losing job computer fact software able slightly change people skin colour slide switch said chan worry ai manipulate ethnicity reinforce unrealistic beauty standard',
#  'apparel company levi strauss announced march would partner ai model agency create personal inclusive shopping experience prompting online backlash critic said company hire real model promote diversity',
#  'company responded partnership would address business efficiency conflated diversity inclusion strategy',
#  'calvin wong head laboratory artificial intelligence design hong kong said ai used assistant rather something creates design maintain agency designer ensure creation manufacturable',
#  'lab hasdesigned ai toolthat allows designer upload draft sketch material colour palette generate design tweaked',
#  'need treasure originality inspiration fashion designer wong said',
#  'reporting beatrice tridimas editing zoe tabary',
#  'get top trend brand industry news fashion beauty wellness straight inbox daily',
#  'sign glossy daily newsletterhere',
#  'generative aiproduced picture imaginary nike collaborationsneakershave circled social medium week',
#  'thats one example ai used fashion us already valuable vast spanning marketing engineering immersive experience',
#  'ai stirred buzz last month thanks new increasingly userfriendly ai tool',
#  'last week march twenty image editor adobe firefly graphic design platform canva rolled new ai technologysupportingtexttovideo andbrand design respectively',
#  'specific launch prove ai usefulness forvisual content creation',
#  'thats start',
#  'industry expert predict ai tool allow quicker seamless workflow allowing worker across field including marketing operation engineering focus creative problemsolving task',
#  'one fastest moving potentially impactful trend see tech landscape today said roger robert partner consultancy mckinsey coauthor december two thousand and twenty-two generative ai herereport',
#  'hyperpersonalization',
#  'nextlevel personalization product experience consumer ecommerce site targeted ad instore experience among use case set benefit retailer',
#  'date personalization largely done microsegmentation grouping customer according interest age group location',
#  'youre going see lot automation want deliver hyperpersonalizationsaid brian long ceo personalized mobile messaging platform attentive',
#  'monday company announced attentive ai tool allowing brand create complete multichannel campaign using ai insight effective content fourteen trillion attentive data point',
#  'far major retail brand using tool beta reporting one hundred and forty-eight revenue increase',
#  'lot brand going generative imagemaking platform generate marketing image leverage product product catalog paired background foreground imagery based text prompt enter',
#  'theyre personalizing image setting lighting element said long',
#  'ai us database image paired text prompt select fitting setting element',
#  'case result productionready image send',
#  'case help figure theyre looking final shoot long said tool allows brand customize marketing imagery different geographical region almost cost',
#  'attentive ai develops copy campaign wellour biggest challenge always getting marketing copy completed timely manner said jason edward director ecommerce streetwear brand hat club',
#  'main surprise close final attentive ai allows u get copy step finalize',
#  'able significantly cut content creation time turn allow u build better campaign better segment customer',
#  'visual merchandising collection creation',
#  'ai could also solve problem visual merchandising',
#  'brand open store location need visual merchandising express brand identity globally also tailored context store',
#  'head visual merchandiser rarely lay every store brand fleet due cost time constraint',
#  'able train learning program based instinct intuition best virtual visual merchandiser using ai could bring voice style capability shop door season said robert',
#  'robert also noted creative application ai business',
#  'brand able use generative ai technology synthesize note sketch idea collection',
#  'ai combined operational financial perspective well merchandising marketing create collection price margin sustainable brand good customer',
#  'apart levi strauss co using ai show wider range diversemodelson website channelswere also using ai enhance differentiate loyalty program offering personalized benefit member helping u achieve meaningful growth enrollment revenue app registrationssaid dr amy gershkoff bolles global head digital emerging technology strategy levi strauss cofor example personalized benefit include localized discount based popular product area',
#  'since expanding loyalty program europe last year brand reached five million member worldwide',
#  'ai help u provide personalized product recommendation website mobile app based consumer data specific market said gershkoff bolles',
#  'also leveraging consumer mobility data customize store unique need interest local consumer open new store greatest demand',
#  'finally said ai powering levi promotion analyzing stock category product likely benefit sale',
#  'noted example including midseason endofseason sale well black friday sale u europe',
#  'web3 brand',
#  'web3 brand already implementing ai creative process',
#  'charli cohen founder 2yearold web3 brand rtlss said studio used generative ai speed coding development work allowing ai create code optimized workflow',
#  'also using create usergenerated content',
#  'progressively integrating ai year said cohenour next drop use ai gamify minting postmint experience',
#  'ugc toolkit currently building also include backend process like validating asset managing ip protection theyll automated enhanced ai',
#  'ai used analyzean nfts blockchain transaction history ensure nft original duplicate',
#  'itcan also analyze content nft art ensure original violate copyright law',
#  'one physical fashion brand active web3tommy hilfiger experimenting ai engage customer incocreation',
#  'specifically metaverse fashion week',
#  'giving consumer opportunity design item brand signature preppy style using generative ai',
#  'fashion show',
#  'even fashion show already undergone somewhat atransformation set undergo change due ai',
#  'matthew drinkwater head emerging technology company fashion innovation agency experimenting ai us catwalk since leading aifocused course london college fashion pandemic',
#  'student able showcase final work two thousand and twenty drinkwater worked fia using archival show footage skeletal data moving model create virtual runway show',
#  'project reimagined year include photorealistic model ai released march twenty-one via linkedin',
#  'earlier catwalk huge amount manual labor work involved said drinkwater',
#  'thats say wasnt case time specific skill set required deliver tool creating kind experience much manageable',
#  'thats especially availability ai tool like text prompttovideo ai platform runway ai launched week',
#  'video component going take next level engagement',
#  'image obviously cool video people stop look take time said long',
#  'runway project year fia used ai prompt tool midjourney stable diffusionthey took image luxury brand inspired trained ai model understand look applied look one particular male model create photorealistic video',
#  'drinkwater agreed robert human element even necessary within fashion experimentation creativity ai',
#  'however said new photorealistic opportunity help facilitate mass adoption digital fashion',
#  'note ai faster implement metaverse',
#  'metaverse combination many thing come together right way create really great experience',
#  'thats case ai said robert explaining current software add feature make better',
#  'doesnt require everyone show headset create entirely new platform',
#  'thats shorter hype cycle everyone talking ai people using cforelevant impact',
#  'company aiming cut cost due recessionrelated concern ai use could leveraged cut labor cost',
#  'bottomline impact suggests something need top mind ctos cfo',
#  'many case replace repetitive part human work allowing staff carry project quickly replacement',
#  'drinkwater added combination thing put together like use machine learning artificial intelligence immersive experience start deliver nextgeneration immersive experience',
#  'image courtesy christiane lemieux',
#  'study titledhow complex system get engaged fashion design creation using artificial intelligence published journalthinking skill creativityaimed investigate practical applicability ai model implement creative fashion design work human designer',
#  'thank',
#  'gold standard business intelligence',
#  'find',
#  'download email arrive shortlywhile wait take look free recommend buyer guide',
#  'research note use ai fashion industry grown significantly recent year',
#  'example already used personalise fashion recommendation customer optimise supply chain management automate process improve sustainability reduce waste',
#  'however creative process fashion design continue human driven little research use ai fashion design designer often included research',
#  'assistant professor lead author study yoon kyung lee keen find could effective collaboration human ai purpose creative design explained time ai deeply ingrained life study started instead considering human better ai',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'study started generating new textile design using deep convolution generative adversarial network dcgans cyclegans',
#  'output model compared similar design produced design student',
#  'comparison revealed design produced similar biggest difference uniqueness originality seen human design came person experience',
#  'however use ai repetitive task could improve efficiency designer free time focus highdifficult creative work',
#  'research also suggests aigenerated design could used learning tool people lack expertise fashion want explore creativity ai could assist creating design',
#  'following study finding professor lee proposing humanai collaborative network integrates gans human creativity produce design',
#  'professor lee also defined studied various element complex system involved humanai collaborated design established humanai model designer collaborates ai create novel design idea',
#  'model allows designer share creative process idea others system interconnect evolve improve design',
#  'professor lee belief fashion industry leverage foresee change fashion industry offer recommendation cocreation service',
#  'setting xobjectives variable limit part designer job humanai collaborative design environment suggests work go beyond visual aspect instead cover variety discipline',
#  'concludes future everybody able creator designer help ai model',
#  'far professional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'download email arrive shortly',
#  'wait take look free recommend buyer guide',
#  'give business edge leading industry insight']

# %%
website13 = 'https://www.forbes.com/sites/cognitiveworld/2019/07/16/the-fashion-industry-is-getting-more-intelligent-with-ai/?sh=496600243c74'
class13 = 'article-body fs-article fs-responsive-text current-article'
text13 = scrape_clean(website13, class13)
sentences.extend(text13)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability',
#  'digital fashion look like today',
#  'question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one',
#  'taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution',
#  'digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research',
#  'fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one',
#  'response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment',
#  'speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem',
#  'hype cooled two thousand and twenty-two critic quick slate web3 nonfungible token nfts metaverse dead marco marchesi chief technology officer fabricant belief industry still show sign life',
#  'technology take lot cycle new idea take adopted',
#  'reality completely figured yet going take lot cycle find steady ground say',
#  'educating audience technicality digital fashion bolster credibility',
#  'there assumption around craft digital fashion dont realize technically challenging practice digital artist stephy fung say',
#  'dani loftus founder digital fashion house draup also argues clunky earlystage technology prevented widespread adoption',
#  'lot people exposed digital fashion first time ever last year loftus say',
#  'youre making digital dress arm fall people going see confirmation bias',
#  'doesnt perform well people turn away',
#  'evolution gaming platform social hub business goldmine potentially biggest seismic shift brand reach audience today',
#  'gen z gen alpha come age unleash spending power brand longer rely outdated marketing tactic magazine campaign celebrity partnership attract eyeball',
#  'key consumer demographic residing gaming destination like fornite roblox early adopter reaping benefit translating identity robust presence space',
#  'gaming space sartorial space play philippa morgan chief content officer savant say',
#  'brand planting seed space reach audience',
#  'attract younger consumer youre going advertise parking lot youre going go kid play',
#  'today brand need willing fully engage new ecosystem shy away experimenting image play',
#  'year saw unprecedented boom generative ai technology potential still yet fully realized fashion',
#  'remains fundamental issue industry approach machine learning',
#  'brand dont get bandwagon product like ai theyll left dust marchesi say discussing brand reticence towards generative system',
#  'fashion slowly surely actively reshaped ai',
#  'september fashion week alone saw coperni collina strada ganni deploy burgeoning tech runway',
#  'question whether ai replace creative role like designer pattern cutter image maker remains hot topic',
#  'fung belief tech cant wont replace human touch',
#  'use ai might take role art director creative director ai cant replicate whats inside brain',
#  'curation come u say',
#  'beyond creative scope machine learning also assisting brand making much productive decision across supply chain efficiency environmental standpoint',
#  'sasha mcfarlane executive director future proof fashion highlight trend cycle moving record speed traditional manufacturing roadmaps cant keep rapid turnover consumer demand',
#  'generative ai disrupting process predicting trend customer behavior month advance helping supplier scale waste',
#  'size global augmented reality virtual reality market estimated thirty-eight billion two thousand and twenty-two projected hit around three hundred and seventy-two billion two thousand and thirty-two according toprecedence research',
#  'trailblazer zero10 fffaceme paving way augmented realitypowered experience retail',
#  'effort havent gone unnoticed',
#  'year brand including tiffany co tommy hilfiger coach jd sport tapped ar capture consumer eyeball',
#  'beyond novelness moin robertsislam technology development manager fashion innovation agency explains ar emerged premium tool collecting data driving consumer loyalty',
#  'speaking one initiative latest ar activation robertsislam note consumer expressed brand loyalty immersive experience',
#  'ninety percent audience said would pay product understood better valued',
#  'digital fashion landscape remains fertile ground emerging technology like ar ai web3 already process overturning industry',
#  'brand still turning blind eye potential run risk selfsabotage',
#  'even understanding basic soon indispensable tool loftus argues',
#  'learning use something like discord server absolutely monumental',
#  'valuable asset say',
#  'there use entering increasingly digitized world without authenticity',
#  'marchesi highlight longterm wellintentioned goal behind every digital activation',
#  'create revenue youre trying create revenue say',
#  'there use trying jump bandwagon reason reason solely making profit',
#  'two hundred fashion designer showcase digital collection designed help ai tool modelled avatar theworlds first ai fashion weekin new york thursday',
#  'twoday event hosted ai creative agency maison meta give three winner deal produce design condition physically manufactured',
#  'predictive tool slash material waste virtual fitting room ai increasingly used manufacturing retail fashion sector',
#  'ai reshaping industry people feel',
#  'sixty designer participating ai fashion week used texttoimage generator midjourney produce image based written prompt help design collection',
#  'explain texture length emotion specific better result said alena stepanova whose collection ai fashion week inspired colour landscape nature native kazakhstan',
#  'digital design allows see one item look different body shape told context',
#  'datadriven ai also used inform design predicting trend fashion giving insight consumer preferred colour style',
#  'american designer tommy hilfiger partnered hardware service company ibm fashion institute technology use ai todesign clothes based dataabout consumer trend',
#  'retail side ai used detect fake optimise pricing clothing resale site help shopper try clothes virtually even choose buy tool uniqlo store recommends product aftermeasuring shopper reaction clothing',
#  'consultancy mckinsey found company excel personalisation generate40 profitthan',
#  'aigenerated model also increasingly used editorial shoot vogue singapore online edition vogue brazil choosing useavatars coversof spring edition year',
#  'ai could add to275 billionto apparel fashion luxury sector operating profit according mckinsey report published march',
#  'ai model agency lalaland said using ai model is90 fasterthan photoshoots requires sample helping brand reduce waste well save time',
#  'ai help company predict inventory needed thus minimising overstocking also reduce return rate helping consumer find bettersuited product according holger harreis senior partner mckinsey',
#  'designer even hope move fashion industry online entirely cutting physical sample',
#  'digital fashion house fabricant creates sell fashion collection nonfungible token nfts kind digital asset often linked image piece artwork usually bought cryptocurrencies',
#  'say using digital sample instead physical garment design development phase clothing canreduce brand carbon footprint thirty',
#  'boom ai tool like chatgpt automate certain area work data entry customer service sparked fear thatrobots could poach job',
#  'use avatar place human model raising similar concern fashion industry makeup artist hair stylist photographer behindthescenes creatives could lose use ai model',
#  'new york city model manager greg chan said hard tell much work missed opportunity may completely bypass agency go straight ai',
#  'model losing job computer fact software able slightly change people skin colour slide switch said chan worry ai manipulate ethnicity reinforce unrealistic beauty standard',
#  'apparel company levi strauss announced march would partner ai model agency create personal inclusive shopping experience prompting online backlash critic said company hire real model promote diversity',
#  'company responded partnership would address business efficiency conflated diversity inclusion strategy',
#  'calvin wong head laboratory artificial intelligence design hong kong said ai used assistant rather something creates design maintain agency designer ensure creation manufacturable',
#  'lab hasdesigned ai toolthat allows designer upload draft sketch material colour palette generate design tweaked',
#  'need treasure originality inspiration fashion designer wong said',
#  'reporting beatrice tridimas editing zoe tabary',
#  'get top trend brand industry news fashion beauty wellness straight inbox daily',
#  'sign glossy daily newsletterhere',
#  'generative aiproduced picture imaginary nike collaborationsneakershave circled social medium week',
#  'thats one example ai used fashion us already valuable vast spanning marketing engineering immersive experience',
#  'ai stirred buzz last month thanks new increasingly userfriendly ai tool',
#  'last week march twenty image editor adobe firefly graphic design platform canva rolled new ai technologysupportingtexttovideo andbrand design respectively',
#  'specific launch prove ai usefulness forvisual content creation',
#  'thats start',
#  'industry expert predict ai tool allow quicker seamless workflow allowing worker across field including marketing operation engineering focus creative problemsolving task',
#  'one fastest moving potentially impactful trend see tech landscape today said roger robert partner consultancy mckinsey coauthor december two thousand and twenty-two generative ai herereport',
#  'hyperpersonalization',
#  'nextlevel personalization product experience consumer ecommerce site targeted ad instore experience among use case set benefit retailer',
#  'date personalization largely done microsegmentation grouping customer according interest age group location',
#  'youre going see lot automation want deliver hyperpersonalizationsaid brian long ceo personalized mobile messaging platform attentive',
#  'monday company announced attentive ai tool allowing brand create complete multichannel campaign using ai insight effective content fourteen trillion attentive data point',
#  'far major retail brand using tool beta reporting one hundred and forty-eight revenue increase',
#  'lot brand going generative imagemaking platform generate marketing image leverage product product catalog paired background foreground imagery based text prompt enter',
#  'theyre personalizing image setting lighting element said long',
#  'ai us database image paired text prompt select fitting setting element',
#  'case result productionready image send',
#  'case help figure theyre looking final shoot long said tool allows brand customize marketing imagery different geographical region almost cost',
#  'attentive ai develops copy campaign wellour biggest challenge always getting marketing copy completed timely manner said jason edward director ecommerce streetwear brand hat club',
#  'main surprise close final attentive ai allows u get copy step finalize',
#  'able significantly cut content creation time turn allow u build better campaign better segment customer',
#  'visual merchandising collection creation',
#  'ai could also solve problem visual merchandising',
#  'brand open store location need visual merchandising express brand identity globally also tailored context store',
#  'head visual merchandiser rarely lay every store brand fleet due cost time constraint',
#  'able train learning program based instinct intuition best virtual visual merchandiser using ai could bring voice style capability shop door season said robert',
#  'robert also noted creative application ai business',
#  'brand able use generative ai technology synthesize note sketch idea collection',
#  'ai combined operational financial perspective well merchandising marketing create collection price margin sustainable brand good customer',
#  'apart levi strauss co using ai show wider range diversemodelson website channelswere also using ai enhance differentiate loyalty program offering personalized benefit member helping u achieve meaningful growth enrollment revenue app registrationssaid dr amy gershkoff bolles global head digital emerging technology strategy levi strauss cofor example personalized benefit include localized discount based popular product area',
#  'since expanding loyalty program europe last year brand reached five million member worldwide',
#  'ai help u provide personalized product recommendation website mobile app based consumer data specific market said gershkoff bolles',
#  'also leveraging consumer mobility data customize store unique need interest local consumer open new store greatest demand',
#  'finally said ai powering levi promotion analyzing stock category product likely benefit sale',
#  'noted example including midseason endofseason sale well black friday sale u europe',
#  'web3 brand',
#  'web3 brand already implementing ai creative process',
#  'charli cohen founder 2yearold web3 brand rtlss said studio used generative ai speed coding development work allowing ai create code optimized workflow',
#  'also using create usergenerated content',
#  'progressively integrating ai year said cohenour next drop use ai gamify minting postmint experience',
#  'ugc toolkit currently building also include backend process like validating asset managing ip protection theyll automated enhanced ai',
#  'ai used analyzean nfts blockchain transaction history ensure nft original duplicate',
#  'itcan also analyze content nft art ensure original violate copyright law',
#  'one physical fashion brand active web3tommy hilfiger experimenting ai engage customer incocreation',
#  'specifically metaverse fashion week',
#  'giving consumer opportunity design item brand signature preppy style using generative ai',
#  'fashion show',
#  'even fashion show already undergone somewhat atransformation set undergo change due ai',
#  'matthew drinkwater head emerging technology company fashion innovation agency experimenting ai us catwalk since leading aifocused course london college fashion pandemic',
#  'student able showcase final work two thousand and twenty drinkwater worked fia using archival show footage skeletal data moving model create virtual runway show',
#  'project reimagined year include photorealistic model ai released march twenty-one via linkedin',
#  'earlier catwalk huge amount manual labor work involved said drinkwater',
#  'thats say wasnt case time specific skill set required deliver tool creating kind experience much manageable',
#  'thats especially availability ai tool like text prompttovideo ai platform runway ai launched week',
#  'video component going take next level engagement',
#  'image obviously cool video people stop look take time said long',
#  'runway project year fia used ai prompt tool midjourney stable diffusionthey took image luxury brand inspired trained ai model understand look applied look one particular male model create photorealistic video',
#  'drinkwater agreed robert human element even necessary within fashion experimentation creativity ai',
#  'however said new photorealistic opportunity help facilitate mass adoption digital fashion',
#  'note ai faster implement metaverse',
#  'metaverse combination many thing come together right way create really great experience',
#  'thats case ai said robert explaining current software add feature make better',
#  'doesnt require everyone show headset create entirely new platform',
#  'thats shorter hype cycle everyone talking ai people using cforelevant impact',
#  'company aiming cut cost due recessionrelated concern ai use could leveraged cut labor cost',
#  'bottomline impact suggests something need top mind ctos cfo',
#  'many case replace repetitive part human work allowing staff carry project quickly replacement',
#  'drinkwater added combination thing put together like use machine learning artificial intelligence immersive experience start deliver nextgeneration immersive experience',
#  'image courtesy christiane lemieux',
#  'study titledhow complex system get engaged fashion design creation using artificial intelligence published journalthinking skill creativityaimed investigate practical applicability ai model implement creative fashion design work human designer',
#  'thank',
#  'gold standard business intelligence',
#  'find',
#  'download email arrive shortlywhile wait take look free recommend buyer guide',
#  'research note use ai fashion industry grown significantly recent year',
#  'example already used personalise fashion recommendation customer optimise supply chain management automate process improve sustainability reduce waste',
#  'however creative process fashion design continue human driven little research use ai fashion design designer often included research',
#  'assistant professor lead author study yoon kyung lee keen find could effective collaboration human ai purpose creative design explained time ai deeply ingrained life study started instead considering human better ai',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'study started generating new textile design using deep convolution generative adversarial network dcgans cyclegans',
#  'output model compared similar design produced design student',
#  'comparison revealed design produced similar biggest difference uniqueness originality seen human design came person experience',
#  'however use ai repetitive task could improve efficiency designer free time focus highdifficult creative work',
#  'research also suggests aigenerated design could used learning tool people lack expertise fashion want explore creativity ai could assist creating design',
#  'following study finding professor lee proposing humanai collaborative network integrates gans human creativity produce design',
#  'professor lee also defined studied various element complex system involved humanai collaborated design established humanai model designer collaborates ai create novel design idea',
#  'model allows designer share creative process idea others system interconnect evolve improve design',
#  'professor lee belief fashion industry leverage foresee change fashion industry offer recommendation cocreation service',
#  'setting xobjectives variable limit part designer job humanai collaborative design environment suggests work go beyond visual aspect instead cover variety discipline',
#  'concludes future everybody able creator designer help ai model',
#  'far professional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'download email arrive shortly',
#  'wait take look free recommend buyer guide',
#  'give business edge leading industry insight',
#  'ai fashion industry',
#  'long human started wear clothes wed desire express individuality one way achieve fashionthe fashion industry one biggest world estimated three trillion dollar two thousand and eighteen representing two percent global gdp',
#  'much brickandmortar traditional retail well online ecommerce dedicated sale clothing fashion item',
#  'much amazon acquired shoe retailer zappos one billion two thousand and ten major retailer walmart target amazon others entered fashion retail business brand brand partnership',
#  'despite established nature fashion industry ai fundamentally transforming industry way fashion company manufacture product way marketed sold',
#  'ai technology transforming fashion industry every element value chain designing manufacturing logistics marketing sale',
#  'ai helping promote sell fashion good',
#  'fashion industry much creating demand brand awareness manufacturing fashion product',
#  'clothing apparel brand constantly looking new way get good front buyer create awareness demand market',
#  'increasinglyfashion brand using ai machine learningto maximize user shopping experience improve efficiency sale system intelligent automation enhance sale process using predictive analytics guided sale process',
#  'fashion brand also starting leverage conversational assistant chatbots voice assistant device amazon alexa apple siri google home microsoft cortana',
#  'using conversational interface fashion brand gather data asking customer question understanding customer desire trend diving deeper purchase pattern suggesting related addon item',
#  'example customer need new shoe dress instead interacting website mobile app simply conversation intelligent conversational agent',
#  'back forth dialog customer find optimal fashion product accessory item',
#  'interaction provides greater satisfaction customer much valuable information fashion brand',
#  'addition conversational system ai making way ecommerce mobile apps',
#  'customer able take picture clothing like style want imitate smart image recognition system match photo real life item available sale',
#  'additionally aienabled shopping apps allow customer take screenshots clothes see online identify shoppable apparel accessory photo find outfit shop similar style',
#  'aienhanced fashion design manufacturing',
#  'documentary minimalism share beup fifty-two season clothing',
#  'given constant change fashion design retailer need consistently keep current trend predict consumer preference next season',
#  'traditionally retailer base estimate current year sale data prior year',
#  'always accurate sale influenced many factor hard predict changing trend',
#  'aibased approach demand projection however reduce forecasting error much fifty percent',
#  'clothes designed ai technology also play role textile manufacturing',
#  'fashion manufacturer innovating use ai help improve efficiency manufacturing process augment human textile employee',
#  'ai system used spot defect fabric ensure color finished textile match originally designed color',
#  'ai technology computer vision technology allowing quality assurance process streamlined',
#  'whereas used ecommerce giant amazon walmart used machine learning algorithm figure sale trend small retailer also leveraging machine learning understand dynamic fashion market may provide better chance succeedintelligent aienabled system also help provide greater intelligence fashion brandsby identifying pattern predictive analytics provide insight fashion trend purchase pattern inventoryrelated guidance',
#  'one company forefront innovation ai applied fashion stitch fix online personal styling service',
#  'company using machine learning algorithm provide better customer experience customer make supply chain efficient',
#  'machine learning technology also applied expediting logistics making supply chain efficient',
#  'ai used manage optimize supply chain well reduce shipping cost transit time',
#  'machine learning algorithm used make accurate prediction inventory demand therefore reduce wastage eliminate last minute purchase meet unexpected spike demand',
#  'computer vision enabled machine learning also used help spot fashion fake counterfeit product',
#  'previously spotting fake required trained eye specialized custom enforcement officer',
#  'ai system keep consistent watchful eye counterfeit product look increasingly similar real one',
#  'area ai technology applied custom border enforcement help spot validity highend product frequently counterfeited purse sunglass',
#  'seeing ai technology add value every part fashion industry design process manufacturing process sale marketing finished good',
#  'future fashion intelligent sure']

# %%
website14 = 'https://fashionunited.uk/news/fashion/ai-in-fashion-interview-with-vp-of-inspire-and-engage-at-zalando/2019080944674'
class14 = 'css-1s0my6s e15wwp330'
text14 = scrape_clean(website14, class14)
sentences.extend(text14)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability',
#  'digital fashion look like today',
#  'question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one',
#  'taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution',
#  'digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research',
#  'fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one',
#  'response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment',
#  'speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem',
#  'hype cooled two thousand and twenty-two critic quick slate web3 nonfungible token nfts metaverse dead marco marchesi chief technology officer fabricant belief industry still show sign life',
#  'technology take lot cycle new idea take adopted',
#  'reality completely figured yet going take lot cycle find steady ground say',
#  'educating audience technicality digital fashion bolster credibility',
#  'there assumption around craft digital fashion dont realize technically challenging practice digital artist stephy fung say',
#  'dani loftus founder digital fashion house draup also argues clunky earlystage technology prevented widespread adoption',
#  'lot people exposed digital fashion first time ever last year loftus say',
#  'youre making digital dress arm fall people going see confirmation bias',
#  'doesnt perform well people turn away',
#  'evolution gaming platform social hub business goldmine potentially biggest seismic shift brand reach audience today',
#  'gen z gen alpha come age unleash spending power brand longer rely outdated marketing tactic magazine campaign celebrity partnership attract eyeball',
#  'key consumer demographic residing gaming destination like fornite roblox early adopter reaping benefit translating identity robust presence space',
#  'gaming space sartorial space play philippa morgan chief content officer savant say',
#  'brand planting seed space reach audience',
#  'attract younger consumer youre going advertise parking lot youre going go kid play',
#  'today brand need willing fully engage new ecosystem shy away experimenting image play',
#  'year saw unprecedented boom generative ai technology potential still yet fully realized fashion',
#  'remains fundamental issue industry approach machine learning',
#  'brand dont get bandwagon product like ai theyll left dust marchesi say discussing brand reticence towards generative system',
#  'fashion slowly surely actively reshaped ai',
#  'september fashion week alone saw coperni collina strada ganni deploy burgeoning tech runway',
#  'question whether ai replace creative role like designer pattern cutter image maker remains hot topic',
#  'fung belief tech cant wont replace human touch',
#  'use ai might take role art director creative director ai cant replicate whats inside brain',
#  'curation come u say',
#  'beyond creative scope machine learning also assisting brand making much productive decision across supply chain efficiency environmental standpoint',
#  'sasha mcfarlane executive director future proof fashion highlight trend cycle moving record speed traditional manufacturing roadmaps cant keep rapid turnover consumer demand',
#  'generative ai disrupting process predicting trend customer behavior month advance helping supplier scale waste',
#  'size global augmented reality virtual reality market estimated thirty-eight billion two thousand and twenty-two projected hit around three hundred and seventy-two billion two thousand and thirty-two according toprecedence research',
#  'trailblazer zero10 fffaceme paving way augmented realitypowered experience retail',
#  'effort havent gone unnoticed',
#  'year brand including tiffany co tommy hilfiger coach jd sport tapped ar capture consumer eyeball',
#  'beyond novelness moin robertsislam technology development manager fashion innovation agency explains ar emerged premium tool collecting data driving consumer loyalty',
#  'speaking one initiative latest ar activation robertsislam note consumer expressed brand loyalty immersive experience',
#  'ninety percent audience said would pay product understood better valued',
#  'digital fashion landscape remains fertile ground emerging technology like ar ai web3 already process overturning industry',
#  'brand still turning blind eye potential run risk selfsabotage',
#  'even understanding basic soon indispensable tool loftus argues',
#  'learning use something like discord server absolutely monumental',
#  'valuable asset say',
#  'there use entering increasingly digitized world without authenticity',
#  'marchesi highlight longterm wellintentioned goal behind every digital activation',
#  'create revenue youre trying create revenue say',
#  'there use trying jump bandwagon reason reason solely making profit',
#  'two hundred fashion designer showcase digital collection designed help ai tool modelled avatar theworlds first ai fashion weekin new york thursday',
#  'twoday event hosted ai creative agency maison meta give three winner deal produce design condition physically manufactured',
#  'predictive tool slash material waste virtual fitting room ai increasingly used manufacturing retail fashion sector',
#  'ai reshaping industry people feel',
#  'sixty designer participating ai fashion week used texttoimage generator midjourney produce image based written prompt help design collection',
#  'explain texture length emotion specific better result said alena stepanova whose collection ai fashion week inspired colour landscape nature native kazakhstan',
#  'digital design allows see one item look different body shape told context',
#  'datadriven ai also used inform design predicting trend fashion giving insight consumer preferred colour style',
#  'american designer tommy hilfiger partnered hardware service company ibm fashion institute technology use ai todesign clothes based dataabout consumer trend',
#  'retail side ai used detect fake optimise pricing clothing resale site help shopper try clothes virtually even choose buy tool uniqlo store recommends product aftermeasuring shopper reaction clothing',
#  'consultancy mckinsey found company excel personalisation generate40 profitthan',
#  'aigenerated model also increasingly used editorial shoot vogue singapore online edition vogue brazil choosing useavatars coversof spring edition year',
#  'ai could add to275 billionto apparel fashion luxury sector operating profit according mckinsey report published march',
#  'ai model agency lalaland said using ai model is90 fasterthan photoshoots requires sample helping brand reduce waste well save time',
#  'ai help company predict inventory needed thus minimising overstocking also reduce return rate helping consumer find bettersuited product according holger harreis senior partner mckinsey',
#  'designer even hope move fashion industry online entirely cutting physical sample',
#  'digital fashion house fabricant creates sell fashion collection nonfungible token nfts kind digital asset often linked image piece artwork usually bought cryptocurrencies',
#  'say using digital sample instead physical garment design development phase clothing canreduce brand carbon footprint thirty',
#  'boom ai tool like chatgpt automate certain area work data entry customer service sparked fear thatrobots could poach job',
#  'use avatar place human model raising similar concern fashion industry makeup artist hair stylist photographer behindthescenes creatives could lose use ai model',
#  'new york city model manager greg chan said hard tell much work missed opportunity may completely bypass agency go straight ai',
#  'model losing job computer fact software able slightly change people skin colour slide switch said chan worry ai manipulate ethnicity reinforce unrealistic beauty standard',
#  'apparel company levi strauss announced march would partner ai model agency create personal inclusive shopping experience prompting online backlash critic said company hire real model promote diversity',
#  'company responded partnership would address business efficiency conflated diversity inclusion strategy',
#  'calvin wong head laboratory artificial intelligence design hong kong said ai used assistant rather something creates design maintain agency designer ensure creation manufacturable',
#  'lab hasdesigned ai toolthat allows designer upload draft sketch material colour palette generate design tweaked',
#  'need treasure originality inspiration fashion designer wong said',
#  'reporting beatrice tridimas editing zoe tabary',
#  'get top trend brand industry news fashion beauty wellness straight inbox daily',
#  'sign glossy daily newsletterhere',
#  'generative aiproduced picture imaginary nike collaborationsneakershave circled social medium week',
#  'thats one example ai used fashion us already valuable vast spanning marketing engineering immersive experience',
#  'ai stirred buzz last month thanks new increasingly userfriendly ai tool',
#  'last week march twenty image editor adobe firefly graphic design platform canva rolled new ai technologysupportingtexttovideo andbrand design respectively',
#  'specific launch prove ai usefulness forvisual content creation',
#  'thats start',
#  'industry expert predict ai tool allow quicker seamless workflow allowing worker across field including marketing operation engineering focus creative problemsolving task',
#  'one fastest moving potentially impactful trend see tech landscape today said roger robert partner consultancy mckinsey coauthor december two thousand and twenty-two generative ai herereport',
#  'hyperpersonalization',
#  'nextlevel personalization product experience consumer ecommerce site targeted ad instore experience among use case set benefit retailer',
#  'date personalization largely done microsegmentation grouping customer according interest age group location',
#  'youre going see lot automation want deliver hyperpersonalizationsaid brian long ceo personalized mobile messaging platform attentive',
#  'monday company announced attentive ai tool allowing brand create complete multichannel campaign using ai insight effective content fourteen trillion attentive data point',
#  'far major retail brand using tool beta reporting one hundred and forty-eight revenue increase',
#  'lot brand going generative imagemaking platform generate marketing image leverage product product catalog paired background foreground imagery based text prompt enter',
#  'theyre personalizing image setting lighting element said long',
#  'ai us database image paired text prompt select fitting setting element',
#  'case result productionready image send',
#  'case help figure theyre looking final shoot long said tool allows brand customize marketing imagery different geographical region almost cost',
#  'attentive ai develops copy campaign wellour biggest challenge always getting marketing copy completed timely manner said jason edward director ecommerce streetwear brand hat club',
#  'main surprise close final attentive ai allows u get copy step finalize',
#  'able significantly cut content creation time turn allow u build better campaign better segment customer',
#  'visual merchandising collection creation',
#  'ai could also solve problem visual merchandising',
#  'brand open store location need visual merchandising express brand identity globally also tailored context store',
#  'head visual merchandiser rarely lay every store brand fleet due cost time constraint',
#  'able train learning program based instinct intuition best virtual visual merchandiser using ai could bring voice style capability shop door season said robert',
#  'robert also noted creative application ai business',
#  'brand able use generative ai technology synthesize note sketch idea collection',
#  'ai combined operational financial perspective well merchandising marketing create collection price margin sustainable brand good customer',
#  'apart levi strauss co using ai show wider range diversemodelson website channelswere also using ai enhance differentiate loyalty program offering personalized benefit member helping u achieve meaningful growth enrollment revenue app registrationssaid dr amy gershkoff bolles global head digital emerging technology strategy levi strauss cofor example personalized benefit include localized discount based popular product area',
#  'since expanding loyalty program europe last year brand reached five million member worldwide',
#  'ai help u provide personalized product recommendation website mobile app based consumer data specific market said gershkoff bolles',
#  'also leveraging consumer mobility data customize store unique need interest local consumer open new store greatest demand',
#  'finally said ai powering levi promotion analyzing stock category product likely benefit sale',
#  'noted example including midseason endofseason sale well black friday sale u europe',
#  'web3 brand',
#  'web3 brand already implementing ai creative process',
#  'charli cohen founder 2yearold web3 brand rtlss said studio used generative ai speed coding development work allowing ai create code optimized workflow',
#  'also using create usergenerated content',
#  'progressively integrating ai year said cohenour next drop use ai gamify minting postmint experience',
#  'ugc toolkit currently building also include backend process like validating asset managing ip protection theyll automated enhanced ai',
#  'ai used analyzean nfts blockchain transaction history ensure nft original duplicate',
#  'itcan also analyze content nft art ensure original violate copyright law',
#  'one physical fashion brand active web3tommy hilfiger experimenting ai engage customer incocreation',
#  'specifically metaverse fashion week',
#  'giving consumer opportunity design item brand signature preppy style using generative ai',
#  'fashion show',
#  'even fashion show already undergone somewhat atransformation set undergo change due ai',
#  'matthew drinkwater head emerging technology company fashion innovation agency experimenting ai us catwalk since leading aifocused course london college fashion pandemic',
#  'student able showcase final work two thousand and twenty drinkwater worked fia using archival show footage skeletal data moving model create virtual runway show',
#  'project reimagined year include photorealistic model ai released march twenty-one via linkedin',
#  'earlier catwalk huge amount manual labor work involved said drinkwater',
#  'thats say wasnt case time specific skill set required deliver tool creating kind experience much manageable',
#  'thats especially availability ai tool like text prompttovideo ai platform runway ai launched week',
#  'video component going take next level engagement',
#  'image obviously cool video people stop look take time said long',
#  'runway project year fia used ai prompt tool midjourney stable diffusionthey took image luxury brand inspired trained ai model understand look applied look one particular male model create photorealistic video',
#  'drinkwater agreed robert human element even necessary within fashion experimentation creativity ai',
#  'however said new photorealistic opportunity help facilitate mass adoption digital fashion',
#  'note ai faster implement metaverse',
#  'metaverse combination many thing come together right way create really great experience',
#  'thats case ai said robert explaining current software add feature make better',
#  'doesnt require everyone show headset create entirely new platform',
#  'thats shorter hype cycle everyone talking ai people using cforelevant impact',
#  'company aiming cut cost due recessionrelated concern ai use could leveraged cut labor cost',
#  'bottomline impact suggests something need top mind ctos cfo',
#  'many case replace repetitive part human work allowing staff carry project quickly replacement',
#  'drinkwater added combination thing put together like use machine learning artificial intelligence immersive experience start deliver nextgeneration immersive experience',
#  'image courtesy christiane lemieux',
#  'study titledhow complex system get engaged fashion design creation using artificial intelligence published journalthinking skill creativityaimed investigate practical applicability ai model implement creative fashion design work human designer',
#  'thank',
#  'gold standard business intelligence',
#  'find',
#  'download email arrive shortlywhile wait take look free recommend buyer guide',
#  'research note use ai fashion industry grown significantly recent year',
#  'example already used personalise fashion recommendation customer optimise supply chain management automate process improve sustainability reduce waste',
#  'however creative process fashion design continue human driven little research use ai fashion design designer often included research',
#  'assistant professor lead author study yoon kyung lee keen find could effective collaboration human ai purpose creative design explained time ai deeply ingrained life study started instead considering human better ai',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'study started generating new textile design using deep convolution generative adversarial network dcgans cyclegans',
#  'output model compared similar design produced design student',
#  'comparison revealed design produced similar biggest difference uniqueness originality seen human design came person experience',
#  'however use ai repetitive task could improve efficiency designer free time focus highdifficult creative work',
#  'research also suggests aigenerated design could used learning tool people lack expertise fashion want explore creativity ai could assist creating design',
#  'following study finding professor lee proposing humanai collaborative network integrates gans human creativity produce design',
#  'professor lee also defined studied various element complex system involved humanai collaborated design established humanai model designer collaborates ai create novel design idea',
#  'model allows designer share creative process idea others system interconnect evolve improve design',
#  'professor lee belief fashion industry leverage foresee change fashion industry offer recommendation cocreation service',
#  'setting xobjectives variable limit part designer job humanai collaborative design environment suggests work go beyond visual aspect instead cover variety discipline',
#  'concludes future everybody able creator designer help ai model',
#  'far professional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'download email arrive shortly',
#  'wait take look free recommend buyer guide',
#  'give business edge leading industry insight',
#  'ai fashion industry',
#  'long human started wear clothes wed desire express individuality one way achieve fashionthe fashion industry one biggest world estimated three trillion dollar two thousand and eighteen representing two percent global gdp',
#  'much brickandmortar traditional retail well online ecommerce dedicated sale clothing fashion item',
#  'much amazon acquired shoe retailer zappos one billion two thousand and ten major retailer walmart target amazon others entered fashion retail business brand brand partnership',
#  'despite established nature fashion industry ai fundamentally transforming industry way fashion company manufacture product way marketed sold',
#  'ai technology transforming fashion industry every element value chain designing manufacturing logistics marketing sale',
#  'ai helping promote sell fashion good',
#  'fashion industry much creating demand brand awareness manufacturing fashion product',
#  'clothing apparel brand constantly looking new way get good front buyer create awareness demand market',
#  'increasinglyfashion brand using ai machine learningto maximize user shopping experience improve efficiency sale system intelligent automation enhance sale process using predictive analytics guided sale process',
#  'fashion brand also starting leverage conversational assistant chatbots voice assistant device amazon alexa apple siri google home microsoft cortana',
#  'using conversational interface fashion brand gather data asking customer question understanding customer desire trend diving deeper purchase pattern suggesting related addon item',
#  'example customer need new shoe dress instead interacting website mobile app simply conversation intelligent conversational agent',
#  'back forth dialog customer find optimal fashion product accessory item',
#  'interaction provides greater satisfaction customer much valuable information fashion brand',
#  'addition conversational system ai making way ecommerce mobile apps',
#  'customer able take picture clothing like style want imitate smart image recognition system match photo real life item available sale',
#  'additionally aienabled shopping apps allow customer take screenshots clothes see online identify shoppable apparel accessory photo find outfit shop similar style',
#  'aienhanced fashion design manufacturing',
#  'documentary minimalism share beup fifty-two season clothing',
#  'given constant change fashion design retailer need consistently keep current trend predict consumer preference next season',
#  'traditionally retailer base estimate current year sale data prior year',
#  'always accurate sale influenced many factor hard predict changing trend',
#  'aibased approach demand projection however reduce forecasting error much fifty percent',
#  'clothes designed ai technology also play role textile manufacturing',
#  'fashion manufacturer innovating use ai help improve efficiency manufacturing process augment human textile employee',
#  'ai system used spot defect fabric ensure color finished textile match originally designed color',
#  'ai technology computer vision technology allowing quality assurance process streamlined',
#  'whereas used ecommerce giant amazon walmart used machine learning algorithm figure sale trend small retailer also leveraging machine learning understand dynamic fashion market may provide better chance succeedintelligent aienabled system also help provide greater intelligence fashion brandsby identifying pattern predictive analytics provide insight fashion trend purchase pattern inventoryrelated guidance',
#  'one company forefront innovation ai applied fashion stitch fix online personal styling service',
#  'company using machine learning algorithm provide better customer experience customer make supply chain efficient',
#  'machine learning technology also applied expediting logistics making supply chain efficient',
#  'ai used manage optimize supply chain well reduce shipping cost transit time',
#  'machine learning algorithm used make accurate prediction inventory demand therefore reduce wastage eliminate last minute purchase meet unexpected spike demand',
#  'computer vision enabled machine learning also used help spot fashion fake counterfeit product',
#  'previously spotting fake required trained eye specialized custom enforcement officer',
#  'ai system keep consistent watchful eye counterfeit product look increasingly similar real one',
#  'area ai technology applied custom border enforcement help spot validity highend product frequently counterfeited purse sunglass',
#  'seeing ai technology add value every part fashion industry design process manufacturing process sale marketing finished good',
#  'future fashion intelligent sure',
#  'role artificial intelligence ai fashion industry wider commerce sector growing rapidly',
#  'according january study capgemini research institute technology capgemini predicts could save retailer much three hundred billion dollar two hundred and thirty-five billion pound used quarter twenty-eight percent retailer two thousand and eighteen significant jump seventeen percent two thousand and seventeen four percent two thousand and sixteen',
#  'technology well truly used throughout fashion industry supply chain sourcing design manufacturing retailnikehmandriver islandare example fashion company recently invested invested ai',
#  'another fashion giant investing technology german etail giant zalando',
#  'october company launched algorithm fashion companion afc algorithm us machine learning suggest outfit customer',
#  'james healey vice president inspire engage zalando lead multifunctional team engineer product manager designer retail expert develop new way shopper discover fashion',
#  'fashionunited spoke healey success afc since launch zalando website october future plan developing technology potential ai hold within fashion industry',
#  'zalando done great job providing wide collection item weve realised based customer feedback lot shopper two thing mind one keen explore look inspiration proving zalando place purchasing fashion place inspired',
#  'always try make sure product range broad enough shopper often feel overwhelmed four hundred thousand item sell',
#  'seeing increase engagement shopper coming back frequently theyre looking snackable content theyre hard time finding amount content',
#  'notice customer interact theyre looking individual product drive inspiration theyre thinking product context entire outfit',
#  'want know style trend occasion might want buy',
#  'dont start mindset want new pair high heel want new dress think want something wear festival weekend wedding without real understanding exact article clothing looking',
#  'outfit really great way filling gap',
#  'creating outfit manually created great sense style something hard u scale',
#  'thats created afc',
#  'zalon curated styling service eight hundred stylist manually select outfit use create machine learning step dynamically create curated outfit scale million customer',
#  'main benefit customer go use zalon experience work real stylist many want something easy seamlessly swipe quickly explore outfit',
#  'thats trying',
#  'great really see shopper engaged',
#  'see outfit recommendation driving forty percent larger basket size twice high conversion rate compared single item',
#  'insight decided invest scalable outfit solution know afc',
#  'started long term vision mind whereby shopping experience wouldnt much navigating product navigating outfit result really confirming u going right direction meaning continuing make lot investment area',
#  'outfit manually created zalon stylist tagged actually know contextually part outfit know exactly article used shoe bag',
#  'also add dimensional fact style article trend supporting type occasion used',
#  'attribute allow u able say well know shoe match dress recommendation style synergy added enrichment based two million plus outfit',
#  'yes',
#  'look gender male demographic high engagement',
#  'delve deeper see customer varying degree style confidence weve found three main customer type actively seeking certain item really prone seeking style advice',
#  'others searching inspiration side might looking particular dress pair shoe idea people might wearing festival summer want understand new trend',
#  'last group sort outlier customer already high level style confidence',
#  'customer really doesnt want recommended outfit accurate otherwise credibility hurt considerate recommend outfit customer',
#  'really unique customer arent particularly looking fashion advice may push ai style finder feature lower page making le likely find wont show based well reacted past',
#  'think always need stylist',
#  'ai opportunity u scale customer unique need enjoy experience working stylist really find something feel help style confidence',
#  'think personal touch stylist offer wont go away',
#  'absolutely',
#  'consider beauty core part fashion part overall outfit',
#  'difficult part training set used zalon dont actually beauty product hard create level sophisticated recommendation outfit',
#  'working beauty team zalon team try figure create data point help u train algorithm',
#  'photo courtesy zalando']

# %%
website15 = 'https://metro.co.uk/2020/03/04/will-wearing-clothes-designed-artificial-intelligence-12342122/'
class15 = 'article-body'
text15 = scrape_clean(website15, class15)
sentences.extend(text15)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability',
#  'digital fashion look like today',
#  'question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one',
#  'taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution',
#  'digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research',
#  'fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one',
#  'response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment',
#  'speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem',
#  'hype cooled two thousand and twenty-two critic quick slate web3 nonfungible token nfts metaverse dead marco marchesi chief technology officer fabricant belief industry still show sign life',
#  'technology take lot cycle new idea take adopted',
#  'reality completely figured yet going take lot cycle find steady ground say',
#  'educating audience technicality digital fashion bolster credibility',
#  'there assumption around craft digital fashion dont realize technically challenging practice digital artist stephy fung say',
#  'dani loftus founder digital fashion house draup also argues clunky earlystage technology prevented widespread adoption',
#  'lot people exposed digital fashion first time ever last year loftus say',
#  'youre making digital dress arm fall people going see confirmation bias',
#  'doesnt perform well people turn away',
#  'evolution gaming platform social hub business goldmine potentially biggest seismic shift brand reach audience today',
#  'gen z gen alpha come age unleash spending power brand longer rely outdated marketing tactic magazine campaign celebrity partnership attract eyeball',
#  'key consumer demographic residing gaming destination like fornite roblox early adopter reaping benefit translating identity robust presence space',
#  'gaming space sartorial space play philippa morgan chief content officer savant say',
#  'brand planting seed space reach audience',
#  'attract younger consumer youre going advertise parking lot youre going go kid play',
#  'today brand need willing fully engage new ecosystem shy away experimenting image play',
#  'year saw unprecedented boom generative ai technology potential still yet fully realized fashion',
#  'remains fundamental issue industry approach machine learning',
#  'brand dont get bandwagon product like ai theyll left dust marchesi say discussing brand reticence towards generative system',
#  'fashion slowly surely actively reshaped ai',
#  'september fashion week alone saw coperni collina strada ganni deploy burgeoning tech runway',
#  'question whether ai replace creative role like designer pattern cutter image maker remains hot topic',
#  'fung belief tech cant wont replace human touch',
#  'use ai might take role art director creative director ai cant replicate whats inside brain',
#  'curation come u say',
#  'beyond creative scope machine learning also assisting brand making much productive decision across supply chain efficiency environmental standpoint',
#  'sasha mcfarlane executive director future proof fashion highlight trend cycle moving record speed traditional manufacturing roadmaps cant keep rapid turnover consumer demand',
#  'generative ai disrupting process predicting trend customer behavior month advance helping supplier scale waste',
#  'size global augmented reality virtual reality market estimated thirty-eight billion two thousand and twenty-two projected hit around three hundred and seventy-two billion two thousand and thirty-two according toprecedence research',
#  'trailblazer zero10 fffaceme paving way augmented realitypowered experience retail',
#  'effort havent gone unnoticed',
#  'year brand including tiffany co tommy hilfiger coach jd sport tapped ar capture consumer eyeball',
#  'beyond novelness moin robertsislam technology development manager fashion innovation agency explains ar emerged premium tool collecting data driving consumer loyalty',
#  'speaking one initiative latest ar activation robertsislam note consumer expressed brand loyalty immersive experience',
#  'ninety percent audience said would pay product understood better valued',
#  'digital fashion landscape remains fertile ground emerging technology like ar ai web3 already process overturning industry',
#  'brand still turning blind eye potential run risk selfsabotage',
#  'even understanding basic soon indispensable tool loftus argues',
#  'learning use something like discord server absolutely monumental',
#  'valuable asset say',
#  'there use entering increasingly digitized world without authenticity',
#  'marchesi highlight longterm wellintentioned goal behind every digital activation',
#  'create revenue youre trying create revenue say',
#  'there use trying jump bandwagon reason reason solely making profit',
#  'two hundred fashion designer showcase digital collection designed help ai tool modelled avatar theworlds first ai fashion weekin new york thursday',
#  'twoday event hosted ai creative agency maison meta give three winner deal produce design condition physically manufactured',
#  'predictive tool slash material waste virtual fitting room ai increasingly used manufacturing retail fashion sector',
#  'ai reshaping industry people feel',
#  'sixty designer participating ai fashion week used texttoimage generator midjourney produce image based written prompt help design collection',
#  'explain texture length emotion specific better result said alena stepanova whose collection ai fashion week inspired colour landscape nature native kazakhstan',
#  'digital design allows see one item look different body shape told context',
#  'datadriven ai also used inform design predicting trend fashion giving insight consumer preferred colour style',
#  'american designer tommy hilfiger partnered hardware service company ibm fashion institute technology use ai todesign clothes based dataabout consumer trend',
#  'retail side ai used detect fake optimise pricing clothing resale site help shopper try clothes virtually even choose buy tool uniqlo store recommends product aftermeasuring shopper reaction clothing',
#  'consultancy mckinsey found company excel personalisation generate40 profitthan',
#  'aigenerated model also increasingly used editorial shoot vogue singapore online edition vogue brazil choosing useavatars coversof spring edition year',
#  'ai could add to275 billionto apparel fashion luxury sector operating profit according mckinsey report published march',
#  'ai model agency lalaland said using ai model is90 fasterthan photoshoots requires sample helping brand reduce waste well save time',
#  'ai help company predict inventory needed thus minimising overstocking also reduce return rate helping consumer find bettersuited product according holger harreis senior partner mckinsey',
#  'designer even hope move fashion industry online entirely cutting physical sample',
#  'digital fashion house fabricant creates sell fashion collection nonfungible token nfts kind digital asset often linked image piece artwork usually bought cryptocurrencies',
#  'say using digital sample instead physical garment design development phase clothing canreduce brand carbon footprint thirty',
#  'boom ai tool like chatgpt automate certain area work data entry customer service sparked fear thatrobots could poach job',
#  'use avatar place human model raising similar concern fashion industry makeup artist hair stylist photographer behindthescenes creatives could lose use ai model',
#  'new york city model manager greg chan said hard tell much work missed opportunity may completely bypass agency go straight ai',
#  'model losing job computer fact software able slightly change people skin colour slide switch said chan worry ai manipulate ethnicity reinforce unrealistic beauty standard',
#  'apparel company levi strauss announced march would partner ai model agency create personal inclusive shopping experience prompting online backlash critic said company hire real model promote diversity',
#  'company responded partnership would address business efficiency conflated diversity inclusion strategy',
#  'calvin wong head laboratory artificial intelligence design hong kong said ai used assistant rather something creates design maintain agency designer ensure creation manufacturable',
#  'lab hasdesigned ai toolthat allows designer upload draft sketch material colour palette generate design tweaked',
#  'need treasure originality inspiration fashion designer wong said',
#  'reporting beatrice tridimas editing zoe tabary',
#  'get top trend brand industry news fashion beauty wellness straight inbox daily',
#  'sign glossy daily newsletterhere',
#  'generative aiproduced picture imaginary nike collaborationsneakershave circled social medium week',
#  'thats one example ai used fashion us already valuable vast spanning marketing engineering immersive experience',
#  'ai stirred buzz last month thanks new increasingly userfriendly ai tool',
#  'last week march twenty image editor adobe firefly graphic design platform canva rolled new ai technologysupportingtexttovideo andbrand design respectively',
#  'specific launch prove ai usefulness forvisual content creation',
#  'thats start',
#  'industry expert predict ai tool allow quicker seamless workflow allowing worker across field including marketing operation engineering focus creative problemsolving task',
#  'one fastest moving potentially impactful trend see tech landscape today said roger robert partner consultancy mckinsey coauthor december two thousand and twenty-two generative ai herereport',
#  'hyperpersonalization',
#  'nextlevel personalization product experience consumer ecommerce site targeted ad instore experience among use case set benefit retailer',
#  'date personalization largely done microsegmentation grouping customer according interest age group location',
#  'youre going see lot automation want deliver hyperpersonalizationsaid brian long ceo personalized mobile messaging platform attentive',
#  'monday company announced attentive ai tool allowing brand create complete multichannel campaign using ai insight effective content fourteen trillion attentive data point',
#  'far major retail brand using tool beta reporting one hundred and forty-eight revenue increase',
#  'lot brand going generative imagemaking platform generate marketing image leverage product product catalog paired background foreground imagery based text prompt enter',
#  'theyre personalizing image setting lighting element said long',
#  'ai us database image paired text prompt select fitting setting element',
#  'case result productionready image send',
#  'case help figure theyre looking final shoot long said tool allows brand customize marketing imagery different geographical region almost cost',
#  'attentive ai develops copy campaign wellour biggest challenge always getting marketing copy completed timely manner said jason edward director ecommerce streetwear brand hat club',
#  'main surprise close final attentive ai allows u get copy step finalize',
#  'able significantly cut content creation time turn allow u build better campaign better segment customer',
#  'visual merchandising collection creation',
#  'ai could also solve problem visual merchandising',
#  'brand open store location need visual merchandising express brand identity globally also tailored context store',
#  'head visual merchandiser rarely lay every store brand fleet due cost time constraint',
#  'able train learning program based instinct intuition best virtual visual merchandiser using ai could bring voice style capability shop door season said robert',
#  'robert also noted creative application ai business',
#  'brand able use generative ai technology synthesize note sketch idea collection',
#  'ai combined operational financial perspective well merchandising marketing create collection price margin sustainable brand good customer',
#  'apart levi strauss co using ai show wider range diversemodelson website channelswere also using ai enhance differentiate loyalty program offering personalized benefit member helping u achieve meaningful growth enrollment revenue app registrationssaid dr amy gershkoff bolles global head digital emerging technology strategy levi strauss cofor example personalized benefit include localized discount based popular product area',
#  'since expanding loyalty program europe last year brand reached five million member worldwide',
#  'ai help u provide personalized product recommendation website mobile app based consumer data specific market said gershkoff bolles',
#  'also leveraging consumer mobility data customize store unique need interest local consumer open new store greatest demand',
#  'finally said ai powering levi promotion analyzing stock category product likely benefit sale',
#  'noted example including midseason endofseason sale well black friday sale u europe',
#  'web3 brand',
#  'web3 brand already implementing ai creative process',
#  'charli cohen founder 2yearold web3 brand rtlss said studio used generative ai speed coding development work allowing ai create code optimized workflow',
#  'also using create usergenerated content',
#  'progressively integrating ai year said cohenour next drop use ai gamify minting postmint experience',
#  'ugc toolkit currently building also include backend process like validating asset managing ip protection theyll automated enhanced ai',
#  'ai used analyzean nfts blockchain transaction history ensure nft original duplicate',
#  'itcan also analyze content nft art ensure original violate copyright law',
#  'one physical fashion brand active web3tommy hilfiger experimenting ai engage customer incocreation',
#  'specifically metaverse fashion week',
#  'giving consumer opportunity design item brand signature preppy style using generative ai',
#  'fashion show',
#  'even fashion show already undergone somewhat atransformation set undergo change due ai',
#  'matthew drinkwater head emerging technology company fashion innovation agency experimenting ai us catwalk since leading aifocused course london college fashion pandemic',
#  'student able showcase final work two thousand and twenty drinkwater worked fia using archival show footage skeletal data moving model create virtual runway show',
#  'project reimagined year include photorealistic model ai released march twenty-one via linkedin',
#  'earlier catwalk huge amount manual labor work involved said drinkwater',
#  'thats say wasnt case time specific skill set required deliver tool creating kind experience much manageable',
#  'thats especially availability ai tool like text prompttovideo ai platform runway ai launched week',
#  'video component going take next level engagement',
#  'image obviously cool video people stop look take time said long',
#  'runway project year fia used ai prompt tool midjourney stable diffusionthey took image luxury brand inspired trained ai model understand look applied look one particular male model create photorealistic video',
#  'drinkwater agreed robert human element even necessary within fashion experimentation creativity ai',
#  'however said new photorealistic opportunity help facilitate mass adoption digital fashion',
#  'note ai faster implement metaverse',
#  'metaverse combination many thing come together right way create really great experience',
#  'thats case ai said robert explaining current software add feature make better',
#  'doesnt require everyone show headset create entirely new platform',
#  'thats shorter hype cycle everyone talking ai people using cforelevant impact',
#  'company aiming cut cost due recessionrelated concern ai use could leveraged cut labor cost',
#  'bottomline impact suggests something need top mind ctos cfo',
#  'many case replace repetitive part human work allowing staff carry project quickly replacement',
#  'drinkwater added combination thing put together like use machine learning artificial intelligence immersive experience start deliver nextgeneration immersive experience',
#  'image courtesy christiane lemieux',
#  'study titledhow complex system get engaged fashion design creation using artificial intelligence published journalthinking skill creativityaimed investigate practical applicability ai model implement creative fashion design work human designer',
#  'thank',
#  'gold standard business intelligence',
#  'find',
#  'download email arrive shortlywhile wait take look free recommend buyer guide',
#  'research note use ai fashion industry grown significantly recent year',
#  'example already used personalise fashion recommendation customer optimise supply chain management automate process improve sustainability reduce waste',
#  'however creative process fashion design continue human driven little research use ai fashion design designer often included research',
#  'assistant professor lead author study yoon kyung lee keen find could effective collaboration human ai purpose creative design explained time ai deeply ingrained life study started instead considering human better ai',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'study started generating new textile design using deep convolution generative adversarial network dcgans cyclegans',
#  'output model compared similar design produced design student',
#  'comparison revealed design produced similar biggest difference uniqueness originality seen human design came person experience',
#  'however use ai repetitive task could improve efficiency designer free time focus highdifficult creative work',
#  'research also suggests aigenerated design could used learning tool people lack expertise fashion want explore creativity ai could assist creating design',
#  'following study finding professor lee proposing humanai collaborative network integrates gans human creativity produce design',
#  'professor lee also defined studied various element complex system involved humanai collaborated design established humanai model designer collaborates ai create novel design idea',
#  'model allows designer share creative process idea others system interconnect evolve improve design',
#  'professor lee belief fashion industry leverage foresee change fashion industry offer recommendation cocreation service',
#  'setting xobjectives variable limit part designer job humanai collaborative design environment suggests work go beyond visual aspect instead cover variety discipline',
#  'concludes future everybody able creator designer help ai model',
#  'far professional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'download email arrive shortly',
#  'wait take look free recommend buyer guide',
#  'give business edge leading industry insight',
#  'ai fashion industry',
#  'long human started wear clothes wed desire express individuality one way achieve fashionthe fashion industry one biggest world estimated three trillion dollar two thousand and eighteen representing two percent global gdp',
#  'much brickandmortar traditional retail well online ecommerce dedicated sale clothing fashion item',
#  'much amazon acquired shoe retailer zappos one billion two thousand and ten major retailer walmart target amazon others entered fashion retail business brand brand partnership',
#  'despite established nature fashion industry ai fundamentally transforming industry way fashion company manufacture product way marketed sold',
#  'ai technology transforming fashion industry every element value chain designing manufacturing logistics marketing sale',
#  'ai helping promote sell fashion good',
#  'fashion industry much creating demand brand awareness manufacturing fashion product',
#  'clothing apparel brand constantly looking new way get good front buyer create awareness demand market',
#  'increasinglyfashion brand using ai machine learningto maximize user shopping experience improve efficiency sale system intelligent automation enhance sale process using predictive analytics guided sale process',
#  'fashion brand also starting leverage conversational assistant chatbots voice assistant device amazon alexa apple siri google home microsoft cortana',
#  'using conversational interface fashion brand gather data asking customer question understanding customer desire trend diving deeper purchase pattern suggesting related addon item',
#  'example customer need new shoe dress instead interacting website mobile app simply conversation intelligent conversational agent',
#  'back forth dialog customer find optimal fashion product accessory item',
#  'interaction provides greater satisfaction customer much valuable information fashion brand',
#  'addition conversational system ai making way ecommerce mobile apps',
#  'customer able take picture clothing like style want imitate smart image recognition system match photo real life item available sale',
#  'additionally aienabled shopping apps allow customer take screenshots clothes see online identify shoppable apparel accessory photo find outfit shop similar style',
#  'aienhanced fashion design manufacturing',
#  'documentary minimalism share beup fifty-two season clothing',
#  'given constant change fashion design retailer need consistently keep current trend predict consumer preference next season',
#  'traditionally retailer base estimate current year sale data prior year',
#  'always accurate sale influenced many factor hard predict changing trend',
#  'aibased approach demand projection however reduce forecasting error much fifty percent',
#  'clothes designed ai technology also play role textile manufacturing',
#  'fashion manufacturer innovating use ai help improve efficiency manufacturing process augment human textile employee',
#  'ai system used spot defect fabric ensure color finished textile match originally designed color',
#  'ai technology computer vision technology allowing quality assurance process streamlined',
#  'whereas used ecommerce giant amazon walmart used machine learning algorithm figure sale trend small retailer also leveraging machine learning understand dynamic fashion market may provide better chance succeedintelligent aienabled system also help provide greater intelligence fashion brandsby identifying pattern predictive analytics provide insight fashion trend purchase pattern inventoryrelated guidance',
#  'one company forefront innovation ai applied fashion stitch fix online personal styling service',
#  'company using machine learning algorithm provide better customer experience customer make supply chain efficient',
#  'machine learning technology also applied expediting logistics making supply chain efficient',
#  'ai used manage optimize supply chain well reduce shipping cost transit time',
#  'machine learning algorithm used make accurate prediction inventory demand therefore reduce wastage eliminate last minute purchase meet unexpected spike demand',
#  'computer vision enabled machine learning also used help spot fashion fake counterfeit product',
#  'previously spotting fake required trained eye specialized custom enforcement officer',
#  'ai system keep consistent watchful eye counterfeit product look increasingly similar real one',
#  'area ai technology applied custom border enforcement help spot validity highend product frequently counterfeited purse sunglass',
#  'seeing ai technology add value every part fashion industry design process manufacturing process sale marketing finished good',
#  'future fashion intelligent sure',
#  'role artificial intelligence ai fashion industry wider commerce sector growing rapidly',
#  'according january study capgemini research institute technology capgemini predicts could save retailer much three hundred billion dollar two hundred and thirty-five billion pound used quarter twenty-eight percent retailer two thousand and eighteen significant jump seventeen percent two thousand and seventeen four percent two thousand and sixteen',
#  'technology well truly used throughout fashion industry supply chain sourcing design manufacturing retailnikehmandriver islandare example fashion company recently invested invested ai',
#  'another fashion giant investing technology german etail giant zalando',
#  'october company launched algorithm fashion companion afc algorithm us machine learning suggest outfit customer',
#  'james healey vice president inspire engage zalando lead multifunctional team engineer product manager designer retail expert develop new way shopper discover fashion',
#  'fashionunited spoke healey success afc since launch zalando website october future plan developing technology potential ai hold within fashion industry',
#  'zalando done great job providing wide collection item weve realised based customer feedback lot shopper two thing mind one keen explore look inspiration proving zalando place purchasing fashion place inspired',
#  'always try make sure product range broad enough shopper often feel overwhelmed four hundred thousand item sell',
#  'seeing increase engagement shopper coming back frequently theyre looking snackable content theyre hard time finding amount content',
#  'notice customer interact theyre looking individual product drive inspiration theyre thinking product context entire outfit',
#  'want know style trend occasion might want buy',
#  'dont start mindset want new pair high heel want new dress think want something wear festival weekend wedding without real understanding exact article clothing looking',
#  'outfit really great way filling gap',
#  'creating outfit manually created great sense style something hard u scale',
#  'thats created afc',
#  'zalon curated styling service eight hundred stylist manually select outfit use create machine learning step dynamically create curated outfit scale million customer',
#  'main benefit customer go use zalon experience work real stylist many want something easy seamlessly swipe quickly explore outfit',
#  'thats trying',
#  'great really see shopper engaged',
#  'see outfit recommendation driving forty percent larger basket size twice high conversion rate compared single item',
#  'insight decided invest scalable outfit solution know afc',
#  'started long term vision mind whereby shopping experience wouldnt much navigating product navigating outfit result really confirming u going right direction meaning continuing make lot investment area',
#  'outfit manually created zalon stylist tagged actually know contextually part outfit know exactly article used shoe bag',
#  'also add dimensional fact style article trend supporting type occasion used',
#  'attribute allow u able say well know shoe match dress recommendation style synergy added enrichment based two million plus outfit',
#  'yes',
#  'look gender male demographic high engagement',
#  'delve deeper see customer varying degree style confidence weve found three main customer type actively seeking certain item really prone seeking style advice',
#  'others searching inspiration side might looking particular dress pair shoe idea people might wearing festival summer want understand new trend',
#  'last group sort outlier customer already high level style confidence',
#  'customer really doesnt want recommended outfit accurate otherwise credibility hurt considerate recommend outfit customer',
#  'really unique customer arent particularly looking fashion advice may push ai style finder feature lower page making le likely find wont show based well reacted past',
#  'think always need stylist',
#  'ai opportunity u scale customer unique need enjoy experience working stylist really find something feel help style confidence',
#  'think personal touch stylist offer wont go away',
#  'absolutely',
#  'consider beauty core part fashion part overall outfit',
#  'difficult part training set used zalon dont actually beauty product hard create level sophisticated recommendation outfit',
#  'working beauty team zalon team try figure create data point help u train algorithm',
#  'photo courtesy zalando',
#  'january previously pixel made realworld splash catwalk paris fashion week',
#  'model futuristiclooking clothes designed collaboration fashion house acne studio artist programmer robbie barrat designed artificial intelligence ai',
#  'design collection idea jacket look like pair trouser say jonny johansson creative director acne studio',
#  'computer doesnt know jacket',
#  'try learn image gave creates idea',
#  'freeing could design jacket thats like parallel universe',
#  'barrat well known world ai generative art',
#  'two year ago code devised used create artwork sold christie three hundred and thirty-seven thousand first kind',
#  'since barrats method form machine learning called generative adversarial network gan used range creative pursuit fromhelping write albumstoautomating cgi',
#  'high fashion design small part total fashion industry trade spanning supply chain style suggestion large scale manufacturing',
#  'ai subset neural networkpowered machine learning set transform wear consume clothes process might even help improve planet',
#  'though acne studio futuristic clothes first example ai catwalk startup playing gangenerated clothes far longer',
#  'machine learningis kind artificial intelligence us vast quantity data predict learn certain outcome without preprogrammed',
#  'aneural networkis series algorithm work bit like human brain',
#  'theyre used machine learning spot pattern comparing template new data',
#  'agenerative adverserial networkgan kind machine learning system one neural network train another',
#  'typically consists generator network creates random version image example second discriminator network judge accurate generated image according criterion',
#  'student mit experimented help ibm produce artificial intelligence idea whattommy hilfiger look like realised application could far larger',
#  'last yeartwo graduate course launched aipoweredbrand called covenai producing unconventional unique design powered gantechniques barrat used design acne studio catwalk show',
#  'another fashionstartup used google generative ai churn outtshirts made doodle data',
#  'larger scaleindian fashion business myntraused inhouse aipowered software ratatouille suggest new clothing design cutting design process six month one',
#  'throw question around relationship designer neural network say matthew drinkwater head london college fashion innovation agency',
#  'computer designing use collaborative tool',
#  'unsettling think clothes may designed something human far aspect fashion industry affected algorithm',
#  'amazon echo look announced three year ago ability algorithmically decide outfit wear many observer envisioned new era computerchosen style choice',
#  'wasnt inconceivable imagine world aipowered recommendation advice like look suggested piece aidesigned clothing range like acne studio new offering',
#  'amazon drone would carry delivery human involved process postman carrying door',
#  'even model showcased aigenerated clothes threatened becoming obsoletevirtual influencers like miquelaattract million follower ten million pound',
#  'reality uptake fashion industry large much slower',
#  'there huge universe ai category created moment fashion industry last one adapt say hasna kourda ceo founder save wardrobe',
#  'industry skeptical digital world whole ai kourda tell metrocouk',
#  'taken decade website ecommerce even landing page',
#  'however pace takeup ai machine learningpowered tech begun increase',
#  'crawl web fashion photography much like google information say kostas koukoravas ceo founder intellistyle',
#  'focus specifically fashion imagery looking image put together human stylist social medium catalogue retailer website use imagery analyze understand style mean',
#  'concept style whats considered fashion arent human anymore',
#  'instagram like twitter hashtags googledistributed display advertising influential people buy magazine editor fashion designer',
#  'tastehas always arbitrary often decided royalty cadre magazine editor difference would make decided designed machine instead',
#  'ai understanding customer styling preference quite often outperforms human stylist koukoravas tell metrocouk',
#  'london fashion week last year pitted ai choice human stylist asked audience select one like best',
#  'seventy audience preferred combination ai provided',
#  'youre preparing getting next clothing recommendation machine might want think',
#  'likely interaction might machine person assisted ai',
#  'human recommending something customer much better result say koukoravas',
#  'ai still doesnt empathy communication ability human',
#  'better picked clothes could help fast fashion industry sustainable',
#  'study mark spencer found thatadults uk regularly wear forty-four percent clothing',
#  'theory better chosen clothes suggestion wear might reduce thirty-six billion unworn clothes left nation wardrobe',
#  'looking perspective ai help make right decision say koukoravas',
#  'opposed going buying something mindless coming back home thinking hey havent got anything match',
#  'christopher wylie whistleblower turned hm data scientist told fashion conference last year producing le get',
#  'industry retailer regularlydestroy million pound worth unused stockor send mostly fossil fuelbuilt clothes landfill huge problem solve',
#  'walk store high street across country typically theyll identical product say matthew drinkwater head london college fashion innovation agency',
#  'doesnt make sense consumer one location let say west end london would buying thing perhaps south coast cornwall',
#  'product like intellistyle save wardrobe aipowered suggestive technology based clothes already aim help reduce crisis',
#  'people aware wasteful consumer behavior say save wardrobe ceo hasna kourda',
#  'theyre taking stand looking tool help make better decision',
#  'though fashion industry may slower others take ai expert predictingenormous growth coming year',
#  'really allows people focus creative aspect fashion opposed mundane repetitive work say intellistyles koukoravas',
#  'human always need creative ai support',
#  'warning large job redundancy loomed large many industry like koukoravas kourda optimistic potential change',
#  'maybe one day everybodys tool',
#  'dont know going wanted try see work say johnasson',
#  'tip way technology transforming industry',
#  'leave comment youd like u look next',
#  'privacy policy']

# %%
website16 = 'https://fashionunited.uk/news/fashion/fashion-in-the-age-of-ai-from-design-to-customer-experience/2023031768533'
class16 = 'css-1s0my6s e15wwp330'
text16 = scrape_clean(website16, class16)
sentences.extend(text16)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability',
#  'digital fashion look like today',
#  'question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one',
#  'taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution',
#  'digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research',
#  'fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one',
#  'response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment',
#  'speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem',
#  'hype cooled two thousand and twenty-two critic quick slate web3 nonfungible token nfts metaverse dead marco marchesi chief technology officer fabricant belief industry still show sign life',
#  'technology take lot cycle new idea take adopted',
#  'reality completely figured yet going take lot cycle find steady ground say',
#  'educating audience technicality digital fashion bolster credibility',
#  'there assumption around craft digital fashion dont realize technically challenging practice digital artist stephy fung say',
#  'dani loftus founder digital fashion house draup also argues clunky earlystage technology prevented widespread adoption',
#  'lot people exposed digital fashion first time ever last year loftus say',
#  'youre making digital dress arm fall people going see confirmation bias',
#  'doesnt perform well people turn away',
#  'evolution gaming platform social hub business goldmine potentially biggest seismic shift brand reach audience today',
#  'gen z gen alpha come age unleash spending power brand longer rely outdated marketing tactic magazine campaign celebrity partnership attract eyeball',
#  'key consumer demographic residing gaming destination like fornite roblox early adopter reaping benefit translating identity robust presence space',
#  'gaming space sartorial space play philippa morgan chief content officer savant say',
#  'brand planting seed space reach audience',
#  'attract younger consumer youre going advertise parking lot youre going go kid play',
#  'today brand need willing fully engage new ecosystem shy away experimenting image play',
#  'year saw unprecedented boom generative ai technology potential still yet fully realized fashion',
#  'remains fundamental issue industry approach machine learning',
#  'brand dont get bandwagon product like ai theyll left dust marchesi say discussing brand reticence towards generative system',
#  'fashion slowly surely actively reshaped ai',
#  'september fashion week alone saw coperni collina strada ganni deploy burgeoning tech runway',
#  'question whether ai replace creative role like designer pattern cutter image maker remains hot topic',
#  'fung belief tech cant wont replace human touch',
#  'use ai might take role art director creative director ai cant replicate whats inside brain',
#  'curation come u say',
#  'beyond creative scope machine learning also assisting brand making much productive decision across supply chain efficiency environmental standpoint',
#  'sasha mcfarlane executive director future proof fashion highlight trend cycle moving record speed traditional manufacturing roadmaps cant keep rapid turnover consumer demand',
#  'generative ai disrupting process predicting trend customer behavior month advance helping supplier scale waste',
#  'size global augmented reality virtual reality market estimated thirty-eight billion two thousand and twenty-two projected hit around three hundred and seventy-two billion two thousand and thirty-two according toprecedence research',
#  'trailblazer zero10 fffaceme paving way augmented realitypowered experience retail',
#  'effort havent gone unnoticed',
#  'year brand including tiffany co tommy hilfiger coach jd sport tapped ar capture consumer eyeball',
#  'beyond novelness moin robertsislam technology development manager fashion innovation agency explains ar emerged premium tool collecting data driving consumer loyalty',
#  'speaking one initiative latest ar activation robertsislam note consumer expressed brand loyalty immersive experience',
#  'ninety percent audience said would pay product understood better valued',
#  'digital fashion landscape remains fertile ground emerging technology like ar ai web3 already process overturning industry',
#  'brand still turning blind eye potential run risk selfsabotage',
#  'even understanding basic soon indispensable tool loftus argues',
#  'learning use something like discord server absolutely monumental',
#  'valuable asset say',
#  'there use entering increasingly digitized world without authenticity',
#  'marchesi highlight longterm wellintentioned goal behind every digital activation',
#  'create revenue youre trying create revenue say',
#  'there use trying jump bandwagon reason reason solely making profit',
#  'two hundred fashion designer showcase digital collection designed help ai tool modelled avatar theworlds first ai fashion weekin new york thursday',
#  'twoday event hosted ai creative agency maison meta give three winner deal produce design condition physically manufactured',
#  'predictive tool slash material waste virtual fitting room ai increasingly used manufacturing retail fashion sector',
#  'ai reshaping industry people feel',
#  'sixty designer participating ai fashion week used texttoimage generator midjourney produce image based written prompt help design collection',
#  'explain texture length emotion specific better result said alena stepanova whose collection ai fashion week inspired colour landscape nature native kazakhstan',
#  'digital design allows see one item look different body shape told context',
#  'datadriven ai also used inform design predicting trend fashion giving insight consumer preferred colour style',
#  'american designer tommy hilfiger partnered hardware service company ibm fashion institute technology use ai todesign clothes based dataabout consumer trend',
#  'retail side ai used detect fake optimise pricing clothing resale site help shopper try clothes virtually even choose buy tool uniqlo store recommends product aftermeasuring shopper reaction clothing',
#  'consultancy mckinsey found company excel personalisation generate40 profitthan',
#  'aigenerated model also increasingly used editorial shoot vogue singapore online edition vogue brazil choosing useavatars coversof spring edition year',
#  'ai could add to275 billionto apparel fashion luxury sector operating profit according mckinsey report published march',
#  'ai model agency lalaland said using ai model is90 fasterthan photoshoots requires sample helping brand reduce waste well save time',
#  'ai help company predict inventory needed thus minimising overstocking also reduce return rate helping consumer find bettersuited product according holger harreis senior partner mckinsey',
#  'designer even hope move fashion industry online entirely cutting physical sample',
#  'digital fashion house fabricant creates sell fashion collection nonfungible token nfts kind digital asset often linked image piece artwork usually bought cryptocurrencies',
#  'say using digital sample instead physical garment design development phase clothing canreduce brand carbon footprint thirty',
#  'boom ai tool like chatgpt automate certain area work data entry customer service sparked fear thatrobots could poach job',
#  'use avatar place human model raising similar concern fashion industry makeup artist hair stylist photographer behindthescenes creatives could lose use ai model',
#  'new york city model manager greg chan said hard tell much work missed opportunity may completely bypass agency go straight ai',
#  'model losing job computer fact software able slightly change people skin colour slide switch said chan worry ai manipulate ethnicity reinforce unrealistic beauty standard',
#  'apparel company levi strauss announced march would partner ai model agency create personal inclusive shopping experience prompting online backlash critic said company hire real model promote diversity',
#  'company responded partnership would address business efficiency conflated diversity inclusion strategy',
#  'calvin wong head laboratory artificial intelligence design hong kong said ai used assistant rather something creates design maintain agency designer ensure creation manufacturable',
#  'lab hasdesigned ai toolthat allows designer upload draft sketch material colour palette generate design tweaked',
#  'need treasure originality inspiration fashion designer wong said',
#  'reporting beatrice tridimas editing zoe tabary',
#  'get top trend brand industry news fashion beauty wellness straight inbox daily',
#  'sign glossy daily newsletterhere',
#  'generative aiproduced picture imaginary nike collaborationsneakershave circled social medium week',
#  'thats one example ai used fashion us already valuable vast spanning marketing engineering immersive experience',
#  'ai stirred buzz last month thanks new increasingly userfriendly ai tool',
#  'last week march twenty image editor adobe firefly graphic design platform canva rolled new ai technologysupportingtexttovideo andbrand design respectively',
#  'specific launch prove ai usefulness forvisual content creation',
#  'thats start',
#  'industry expert predict ai tool allow quicker seamless workflow allowing worker across field including marketing operation engineering focus creative problemsolving task',
#  'one fastest moving potentially impactful trend see tech landscape today said roger robert partner consultancy mckinsey coauthor december two thousand and twenty-two generative ai herereport',
#  'hyperpersonalization',
#  'nextlevel personalization product experience consumer ecommerce site targeted ad instore experience among use case set benefit retailer',
#  'date personalization largely done microsegmentation grouping customer according interest age group location',
#  'youre going see lot automation want deliver hyperpersonalizationsaid brian long ceo personalized mobile messaging platform attentive',
#  'monday company announced attentive ai tool allowing brand create complete multichannel campaign using ai insight effective content fourteen trillion attentive data point',
#  'far major retail brand using tool beta reporting one hundred and forty-eight revenue increase',
#  'lot brand going generative imagemaking platform generate marketing image leverage product product catalog paired background foreground imagery based text prompt enter',
#  'theyre personalizing image setting lighting element said long',
#  'ai us database image paired text prompt select fitting setting element',
#  'case result productionready image send',
#  'case help figure theyre looking final shoot long said tool allows brand customize marketing imagery different geographical region almost cost',
#  'attentive ai develops copy campaign wellour biggest challenge always getting marketing copy completed timely manner said jason edward director ecommerce streetwear brand hat club',
#  'main surprise close final attentive ai allows u get copy step finalize',
#  'able significantly cut content creation time turn allow u build better campaign better segment customer',
#  'visual merchandising collection creation',
#  'ai could also solve problem visual merchandising',
#  'brand open store location need visual merchandising express brand identity globally also tailored context store',
#  'head visual merchandiser rarely lay every store brand fleet due cost time constraint',
#  'able train learning program based instinct intuition best virtual visual merchandiser using ai could bring voice style capability shop door season said robert',
#  'robert also noted creative application ai business',
#  'brand able use generative ai technology synthesize note sketch idea collection',
#  'ai combined operational financial perspective well merchandising marketing create collection price margin sustainable brand good customer',
#  'apart levi strauss co using ai show wider range diversemodelson website channelswere also using ai enhance differentiate loyalty program offering personalized benefit member helping u achieve meaningful growth enrollment revenue app registrationssaid dr amy gershkoff bolles global head digital emerging technology strategy levi strauss cofor example personalized benefit include localized discount based popular product area',
#  'since expanding loyalty program europe last year brand reached five million member worldwide',
#  'ai help u provide personalized product recommendation website mobile app based consumer data specific market said gershkoff bolles',
#  'also leveraging consumer mobility data customize store unique need interest local consumer open new store greatest demand',
#  'finally said ai powering levi promotion analyzing stock category product likely benefit sale',
#  'noted example including midseason endofseason sale well black friday sale u europe',
#  'web3 brand',
#  'web3 brand already implementing ai creative process',
#  'charli cohen founder 2yearold web3 brand rtlss said studio used generative ai speed coding development work allowing ai create code optimized workflow',
#  'also using create usergenerated content',
#  'progressively integrating ai year said cohenour next drop use ai gamify minting postmint experience',
#  'ugc toolkit currently building also include backend process like validating asset managing ip protection theyll automated enhanced ai',
#  'ai used analyzean nfts blockchain transaction history ensure nft original duplicate',
#  'itcan also analyze content nft art ensure original violate copyright law',
#  'one physical fashion brand active web3tommy hilfiger experimenting ai engage customer incocreation',
#  'specifically metaverse fashion week',
#  'giving consumer opportunity design item brand signature preppy style using generative ai',
#  'fashion show',
#  'even fashion show already undergone somewhat atransformation set undergo change due ai',
#  'matthew drinkwater head emerging technology company fashion innovation agency experimenting ai us catwalk since leading aifocused course london college fashion pandemic',
#  'student able showcase final work two thousand and twenty drinkwater worked fia using archival show footage skeletal data moving model create virtual runway show',
#  'project reimagined year include photorealistic model ai released march twenty-one via linkedin',
#  'earlier catwalk huge amount manual labor work involved said drinkwater',
#  'thats say wasnt case time specific skill set required deliver tool creating kind experience much manageable',
#  'thats especially availability ai tool like text prompttovideo ai platform runway ai launched week',
#  'video component going take next level engagement',
#  'image obviously cool video people stop look take time said long',
#  'runway project year fia used ai prompt tool midjourney stable diffusionthey took image luxury brand inspired trained ai model understand look applied look one particular male model create photorealistic video',
#  'drinkwater agreed robert human element even necessary within fashion experimentation creativity ai',
#  'however said new photorealistic opportunity help facilitate mass adoption digital fashion',
#  'note ai faster implement metaverse',
#  'metaverse combination many thing come together right way create really great experience',
#  'thats case ai said robert explaining current software add feature make better',
#  'doesnt require everyone show headset create entirely new platform',
#  'thats shorter hype cycle everyone talking ai people using cforelevant impact',
#  'company aiming cut cost due recessionrelated concern ai use could leveraged cut labor cost',
#  'bottomline impact suggests something need top mind ctos cfo',
#  'many case replace repetitive part human work allowing staff carry project quickly replacement',
#  'drinkwater added combination thing put together like use machine learning artificial intelligence immersive experience start deliver nextgeneration immersive experience',
#  'image courtesy christiane lemieux',
#  'study titledhow complex system get engaged fashion design creation using artificial intelligence published journalthinking skill creativityaimed investigate practical applicability ai model implement creative fashion design work human designer',
#  'thank',
#  'gold standard business intelligence',
#  'find',
#  'download email arrive shortlywhile wait take look free recommend buyer guide',
#  'research note use ai fashion industry grown significantly recent year',
#  'example already used personalise fashion recommendation customer optimise supply chain management automate process improve sustainability reduce waste',
#  'however creative process fashion design continue human driven little research use ai fashion design designer often included research',
#  'assistant professor lead author study yoon kyung lee keen find could effective collaboration human ai purpose creative design explained time ai deeply ingrained life study started instead considering human better ai',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'study started generating new textile design using deep convolution generative adversarial network dcgans cyclegans',
#  'output model compared similar design produced design student',
#  'comparison revealed design produced similar biggest difference uniqueness originality seen human design came person experience',
#  'however use ai repetitive task could improve efficiency designer free time focus highdifficult creative work',
#  'research also suggests aigenerated design could used learning tool people lack expertise fashion want explore creativity ai could assist creating design',
#  'following study finding professor lee proposing humanai collaborative network integrates gans human creativity produce design',
#  'professor lee also defined studied various element complex system involved humanai collaborated design established humanai model designer collaborates ai create novel design idea',
#  'model allows designer share creative process idea others system interconnect evolve improve design',
#  'professor lee belief fashion industry leverage foresee change fashion industry offer recommendation cocreation service',
#  'setting xobjectives variable limit part designer job humanai collaborative design environment suggests work go beyond visual aspect instead cover variety discipline',
#  'concludes future everybody able creator designer help ai model',
#  'far professional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'download email arrive shortly',
#  'wait take look free recommend buyer guide',
#  'give business edge leading industry insight',
#  'ai fashion industry',
#  'long human started wear clothes wed desire express individuality one way achieve fashionthe fashion industry one biggest world estimated three trillion dollar two thousand and eighteen representing two percent global gdp',
#  'much brickandmortar traditional retail well online ecommerce dedicated sale clothing fashion item',
#  'much amazon acquired shoe retailer zappos one billion two thousand and ten major retailer walmart target amazon others entered fashion retail business brand brand partnership',
#  'despite established nature fashion industry ai fundamentally transforming industry way fashion company manufacture product way marketed sold',
#  'ai technology transforming fashion industry every element value chain designing manufacturing logistics marketing sale',
#  'ai helping promote sell fashion good',
#  'fashion industry much creating demand brand awareness manufacturing fashion product',
#  'clothing apparel brand constantly looking new way get good front buyer create awareness demand market',
#  'increasinglyfashion brand using ai machine learningto maximize user shopping experience improve efficiency sale system intelligent automation enhance sale process using predictive analytics guided sale process',
# ...
#  'notice customer interact theyre looking individual product drive inspiration theyre thinking product context entire outfit',
#  'want know style trend occasion might want buy',
#  'dont start mindset want new pair high heel want new dress think want something wear festival weekend wedding without real understanding exact article clothing looking',
#  'outfit really great way filling gap',
#  'creating outfit manually created great sense style something hard u scale',
#  'thats created afc',
#  'zalon curated styling service eight hundred stylist manually select outfit use create machine learning step dynamically create curated outfit scale million customer',
#  'main benefit customer go use zalon experience work real stylist many want something easy seamlessly swipe quickly explore outfit',
#  'thats trying',
#  'great really see shopper engaged',
#  'see outfit recommendation driving forty percent larger basket size twice high conversion rate compared single item',
#  'insight decided invest scalable outfit solution know afc',
#  'started long term vision mind whereby shopping experience wouldnt much navigating product navigating outfit result really confirming u going right direction meaning continuing make lot investment area',
#  'outfit manually created zalon stylist tagged actually know contextually part outfit know exactly article used shoe bag',
#  'also add dimensional fact style article trend supporting type occasion used',
#  'attribute allow u able say well know shoe match dress recommendation style synergy added enrichment based two million plus outfit',
#  'yes',
#  'look gender male demographic high engagement',
#  'delve deeper see customer varying degree style confidence weve found three main customer type actively seeking certain item really prone seeking style advice',
#  'others searching inspiration side might looking particular dress pair shoe idea people might wearing festival summer want understand new trend',
#  'last group sort outlier customer already high level style confidence',
#  'customer really doesnt want recommended outfit accurate otherwise credibility hurt considerate recommend outfit customer',
#  'really unique customer arent particularly looking fashion advice may push ai style finder feature lower page making le likely find wont show based well reacted past',
#  'think always need stylist',
#  'ai opportunity u scale customer unique need enjoy experience working stylist really find something feel help style confidence',
#  'think personal touch stylist offer wont go away',
#  'absolutely',
#  'consider beauty core part fashion part overall outfit',
#  'difficult part training set used zalon dont actually beauty product hard create level sophisticated recommendation outfit',
#  'working beauty team zalon team try figure create data point help u train algorithm',
#  'photo courtesy zalando',
#  'january previously pixel made realworld splash catwalk paris fashion week',
#  'model futuristiclooking clothes designed collaboration fashion house acne studio artist programmer robbie barrat designed artificial intelligence ai',
#  'design collection idea jacket look like pair trouser say jonny johansson creative director acne studio',
#  'computer doesnt know jacket',
#  'try learn image gave creates idea',
#  'freeing could design jacket thats like parallel universe',
#  'barrat well known world ai generative art',
#  'two year ago code devised used create artwork sold christie three hundred and thirty-seven thousand first kind',
#  'since barrats method form machine learning called generative adversarial network gan used range creative pursuit fromhelping write albumstoautomating cgi',
#  'high fashion design small part total fashion industry trade spanning supply chain style suggestion large scale manufacturing',
#  'ai subset neural networkpowered machine learning set transform wear consume clothes process might even help improve planet',
#  'though acne studio futuristic clothes first example ai catwalk startup playing gangenerated clothes far longer',
#  'machine learningis kind artificial intelligence us vast quantity data predict learn certain outcome without preprogrammed',
#  'aneural networkis series algorithm work bit like human brain',
#  'theyre used machine learning spot pattern comparing template new data',
#  'agenerative adverserial networkgan kind machine learning system one neural network train another',
#  'typically consists generator network creates random version image example second discriminator network judge accurate generated image according criterion',
#  'student mit experimented help ibm produce artificial intelligence idea whattommy hilfiger look like realised application could far larger',
#  'last yeartwo graduate course launched aipoweredbrand called covenai producing unconventional unique design powered gantechniques barrat used design acne studio catwalk show',
#  'another fashionstartup used google generative ai churn outtshirts made doodle data',
#  'larger scaleindian fashion business myntraused inhouse aipowered software ratatouille suggest new clothing design cutting design process six month one',
#  'throw question around relationship designer neural network say matthew drinkwater head london college fashion innovation agency',
#  'computer designing use collaborative tool',
#  'unsettling think clothes may designed something human far aspect fashion industry affected algorithm',
#  'amazon echo look announced three year ago ability algorithmically decide outfit wear many observer envisioned new era computerchosen style choice',
#  'wasnt inconceivable imagine world aipowered recommendation advice like look suggested piece aidesigned clothing range like acne studio new offering',
#  'amazon drone would carry delivery human involved process postman carrying door',
#  'even model showcased aigenerated clothes threatened becoming obsoletevirtual influencers like miquelaattract million follower ten million pound',
#  'reality uptake fashion industry large much slower',
#  'there huge universe ai category created moment fashion industry last one adapt say hasna kourda ceo founder save wardrobe',
#  'industry skeptical digital world whole ai kourda tell metrocouk',
#  'taken decade website ecommerce even landing page',
#  'however pace takeup ai machine learningpowered tech begun increase',
#  'crawl web fashion photography much like google information say kostas koukoravas ceo founder intellistyle',
#  'focus specifically fashion imagery looking image put together human stylist social medium catalogue retailer website use imagery analyze understand style mean',
#  'concept style whats considered fashion arent human anymore',
#  'instagram like twitter hashtags googledistributed display advertising influential people buy magazine editor fashion designer',
#  'tastehas always arbitrary often decided royalty cadre magazine editor difference would make decided designed machine instead',
#  'ai understanding customer styling preference quite often outperforms human stylist koukoravas tell metrocouk',
#  'london fashion week last year pitted ai choice human stylist asked audience select one like best',
#  'seventy audience preferred combination ai provided',
#  'youre preparing getting next clothing recommendation machine might want think',
#  'likely interaction might machine person assisted ai',
#  'human recommending something customer much better result say koukoravas',
#  'ai still doesnt empathy communication ability human',
#  'better picked clothes could help fast fashion industry sustainable',
#  'study mark spencer found thatadults uk regularly wear forty-four percent clothing',
#  'theory better chosen clothes suggestion wear might reduce thirty-six billion unworn clothes left nation wardrobe',
#  'looking perspective ai help make right decision say koukoravas',
#  'opposed going buying something mindless coming back home thinking hey havent got anything match',
#  'christopher wylie whistleblower turned hm data scientist told fashion conference last year producing le get',
#  'industry retailer regularlydestroy million pound worth unused stockor send mostly fossil fuelbuilt clothes landfill huge problem solve',
#  'walk store high street across country typically theyll identical product say matthew drinkwater head london college fashion innovation agency',
#  'doesnt make sense consumer one location let say west end london would buying thing perhaps south coast cornwall',
#  'product like intellistyle save wardrobe aipowered suggestive technology based clothes already aim help reduce crisis',
#  'people aware wasteful consumer behavior say save wardrobe ceo hasna kourda',
#  'theyre taking stand looking tool help make better decision',
#  'though fashion industry may slower others take ai expert predictingenormous growth coming year',
#  'really allows people focus creative aspect fashion opposed mundane repetitive work say intellistyles koukoravas',
#  'human always need creative ai support',
#  'warning large job redundancy loomed large many industry like koukoravas kourda optimistic potential change',
#  'maybe one day everybodys tool',
#  'dont know going wanted try see work say johnasson',
#  'tip way technology transforming industry',
#  'leave comment youd like u look next',
#  'privacy policy',
#  'world everevolving metaverse web3 technology artificial intelligence ai currently one talked one enigmatic form tech making round',
#  'sparking debate could considered art design innovation certainly ushered new albeit ambiguous formula creation digital age',
#  'ai combination computer science data alongside machine learning develop algorithm create system prediction analysis based inputted data',
#  'machine utilised within technology mimic human mind learn improve time order adapt process',
#  'come art design ai applied way possible create constant stream content',
#  'yet actual process producing ai imagery involves plenty trial error',
#  'entering platform creator asked provide prompt generic specific desire',
#  'machine begin learn understand asked produced image become closer closer desired output',
#  'slightest adaptation prompt transform imagery explored detailed finished product',
#  'like music art fashion design creative field become subject ai tech sector rapidly evolving line accelerating interest',
#  'expert field also currently exploring whether ai creative without human intervention look understand depth communication people machine',
#  'topic ai particularly gained traction late last year technology like chatgpt lensa ai midjourney began making round sparking debate around use ai creation',
#  'argue technology could perceived form copying potentially present range ethical issue including encouraging mass production others see new form creative outlet providing designer artist accessible tool evolve creation',
#  'similar discussion recently brought light nft space artist mason rothschild taken court hermès luxury brand accusing stealing design create digital asset made one million dollar sale',
#  'ultimately jury ruled favour french luxury brand determining rothschild indeed profited name',
#  'ruling eye expert set precedent similar case technology fashion could handled future drawing parallel ongoing ai discourse',
#  'technology evolves could advancement actually benefit industry moving forward',
#  'creatives ai opened door looking fresh way enter industry array online tool free paid allow almost anyone access technology',
#  'product heavily adopted public new breed artist designer redefining mean creator modern day',
#  'field skjellerup ai artist behind instagram account ai_clothingdaily exactly title profile say creating daily ai clothing',
#  'design realistic comment page filled people asking order piece',
#  'look range ai iteration nike shoe complete heavy embellishment intricate embroidery full runway outfit donned similarly artificial model',
#  'noted skjellerups first venture fashion world',
#  'creator also operates research platform marketplace luckynumber8 collect often sell vintage archival garment',
#  'closely link ai work draw inspiration past designer runway collection well material would like experiment',
#  'speaking fashionunited said process working ai way collaborative approach give input wait generative image respond accordingly',
#  'even initial idea outcome could totally different depending ai responds',
#  'really enjoy sense mystery surrounding tool',
#  'skjellerups eye ai important tool design belief technology doesnt take away artist instead enhances creative potential',
#  'added ability rapidly generate large group image make initial concept stage highly productive push idea beyond could become otherwise',
#  'would like see ai design tool democratisation design process',
#  'see role designer consumer blur one',
#  'fashion much top industry blurring role could lead exciting possibility',
#  'criticism format presently unavoidable individual within outside sector say constitutes design',
#  'also something skjellerup acutely aware however perception remains resilient',
#  'asked view possibility misconception surrounding topic said heard people within industry refer assisted creativity tool become accessible see become norm',
#  'feel like people either havent tried ai creative tool ready pas judgement scared possibility job loss within sector',
#  'think valid concern must remember job loss come people position power making decision tool',
#  'hesitancy surrounding ai place design become increasingly analysed recent study expert look investigate practical applicability ai creative design process',
#  'concept yoon kyung lee professor pusan national university korea explored study thinking skill creativity',
#  'carry research lee started generating textile design using ai software compared model work design student',
#  'result found design similar however distinct uniqueness originality seen humanmade design often derived person experience',
#  'lee note use ai repetitive task could improve efficiency process provide good learning tool lack expertise industry',
#  'professor proposed humanai collaborative work therefore effective instance particularly work link variety discipline beyond visual aspect gone begin developing process model applied',
#  'speaking report lee said future everybody able creator designer help ai model',
#  'far progressional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'lee deduced isnt clothing design ai serf purpose',
#  'retailer increasingly implementing technology ecommerce online marketing strategy taking advantage ability enhance customer experience possibly ensure sustainable production process',
#  'particularly popular among ongoing ecommerce evolution often applied retailer website provide accurate product recommendation data collection make search discovery efficient',
#  'surge company putting use technology order provide retailer solution look expand consumer experience',
#  'one perfect corp tech firm offer aipowered tryon experience ecommerce allowing consumer try product comfort home',
#  'feature enables fast analysis offer shopper customised product recommendation efficiently matching product consumer need heightening confidence purchase',
#  'speaking fashionunited alice chang ceo founder perfect corp noted benefit product stating fashion brand provide customer personalised shopping experience boost customer satisfaction decreasing product return',
#  'solution also enable sustainable business operation allowing brand reach esg goal decreasing excess waste emission generated product sampling return process',
#  'chang perspective implementing technology also crucial staying relevant today shopper increasingly leaning personalised digital advancement make purchasing decision',
#  'chang added advancement ai recent year greatly accelerated allowing brand transform consumer journey improving sale engagement customer loyalty',
#  'consumer shopping habit shifting happening across multiple channel retail space',
#  'look future ai grow play larger role across industry empowering consumer shop personalised interactive way']

# %%
website17 = 'https://www.nbcnews.com/business/business-news/ai-models-levis-controversy-backlash-rcna77280'
class17 = 'article-body__content'
text17 = scrape_clean(website17, class17)
sentences.extend(text17)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability',
#  'digital fashion look like today',
#  'question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one',
#  'taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution',
#  'digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research',
#  'fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one',
#  'response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment',
#  'speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem',
#  'hype cooled two thousand and twenty-two critic quick slate web3 nonfungible token nfts metaverse dead marco marchesi chief technology officer fabricant belief industry still show sign life',
#  'technology take lot cycle new idea take adopted',
#  'reality completely figured yet going take lot cycle find steady ground say',
#  'educating audience technicality digital fashion bolster credibility',
#  'there assumption around craft digital fashion dont realize technically challenging practice digital artist stephy fung say',
#  'dani loftus founder digital fashion house draup also argues clunky earlystage technology prevented widespread adoption',
#  'lot people exposed digital fashion first time ever last year loftus say',
#  'youre making digital dress arm fall people going see confirmation bias',
#  'doesnt perform well people turn away',
#  'evolution gaming platform social hub business goldmine potentially biggest seismic shift brand reach audience today',
#  'gen z gen alpha come age unleash spending power brand longer rely outdated marketing tactic magazine campaign celebrity partnership attract eyeball',
#  'key consumer demographic residing gaming destination like fornite roblox early adopter reaping benefit translating identity robust presence space',
#  'gaming space sartorial space play philippa morgan chief content officer savant say',
#  'brand planting seed space reach audience',
#  'attract younger consumer youre going advertise parking lot youre going go kid play',
#  'today brand need willing fully engage new ecosystem shy away experimenting image play',
#  'year saw unprecedented boom generative ai technology potential still yet fully realized fashion',
#  'remains fundamental issue industry approach machine learning',
#  'brand dont get bandwagon product like ai theyll left dust marchesi say discussing brand reticence towards generative system',
#  'fashion slowly surely actively reshaped ai',
#  'september fashion week alone saw coperni collina strada ganni deploy burgeoning tech runway',
#  'question whether ai replace creative role like designer pattern cutter image maker remains hot topic',
#  'fung belief tech cant wont replace human touch',
#  'use ai might take role art director creative director ai cant replicate whats inside brain',
#  'curation come u say',
#  'beyond creative scope machine learning also assisting brand making much productive decision across supply chain efficiency environmental standpoint',
#  'sasha mcfarlane executive director future proof fashion highlight trend cycle moving record speed traditional manufacturing roadmaps cant keep rapid turnover consumer demand',
#  'generative ai disrupting process predicting trend customer behavior month advance helping supplier scale waste',
#  'size global augmented reality virtual reality market estimated thirty-eight billion two thousand and twenty-two projected hit around three hundred and seventy-two billion two thousand and thirty-two according toprecedence research',
#  'trailblazer zero10 fffaceme paving way augmented realitypowered experience retail',
#  'effort havent gone unnoticed',
#  'year brand including tiffany co tommy hilfiger coach jd sport tapped ar capture consumer eyeball',
#  'beyond novelness moin robertsislam technology development manager fashion innovation agency explains ar emerged premium tool collecting data driving consumer loyalty',
#  'speaking one initiative latest ar activation robertsislam note consumer expressed brand loyalty immersive experience',
#  'ninety percent audience said would pay product understood better valued',
#  'digital fashion landscape remains fertile ground emerging technology like ar ai web3 already process overturning industry',
#  'brand still turning blind eye potential run risk selfsabotage',
#  'even understanding basic soon indispensable tool loftus argues',
#  'learning use something like discord server absolutely monumental',
#  'valuable asset say',
#  'there use entering increasingly digitized world without authenticity',
#  'marchesi highlight longterm wellintentioned goal behind every digital activation',
#  'create revenue youre trying create revenue say',
#  'there use trying jump bandwagon reason reason solely making profit',
#  'two hundred fashion designer showcase digital collection designed help ai tool modelled avatar theworlds first ai fashion weekin new york thursday',
#  'twoday event hosted ai creative agency maison meta give three winner deal produce design condition physically manufactured',
#  'predictive tool slash material waste virtual fitting room ai increasingly used manufacturing retail fashion sector',
#  'ai reshaping industry people feel',
#  'sixty designer participating ai fashion week used texttoimage generator midjourney produce image based written prompt help design collection',
#  'explain texture length emotion specific better result said alena stepanova whose collection ai fashion week inspired colour landscape nature native kazakhstan',
#  'digital design allows see one item look different body shape told context',
#  'datadriven ai also used inform design predicting trend fashion giving insight consumer preferred colour style',
#  'american designer tommy hilfiger partnered hardware service company ibm fashion institute technology use ai todesign clothes based dataabout consumer trend',
#  'retail side ai used detect fake optimise pricing clothing resale site help shopper try clothes virtually even choose buy tool uniqlo store recommends product aftermeasuring shopper reaction clothing',
#  'consultancy mckinsey found company excel personalisation generate40 profitthan',
#  'aigenerated model also increasingly used editorial shoot vogue singapore online edition vogue brazil choosing useavatars coversof spring edition year',
#  'ai could add to275 billionto apparel fashion luxury sector operating profit according mckinsey report published march',
#  'ai model agency lalaland said using ai model is90 fasterthan photoshoots requires sample helping brand reduce waste well save time',
#  'ai help company predict inventory needed thus minimising overstocking also reduce return rate helping consumer find bettersuited product according holger harreis senior partner mckinsey',
#  'designer even hope move fashion industry online entirely cutting physical sample',
#  'digital fashion house fabricant creates sell fashion collection nonfungible token nfts kind digital asset often linked image piece artwork usually bought cryptocurrencies',
#  'say using digital sample instead physical garment design development phase clothing canreduce brand carbon footprint thirty',
#  'boom ai tool like chatgpt automate certain area work data entry customer service sparked fear thatrobots could poach job',
#  'use avatar place human model raising similar concern fashion industry makeup artist hair stylist photographer behindthescenes creatives could lose use ai model',
#  'new york city model manager greg chan said hard tell much work missed opportunity may completely bypass agency go straight ai',
#  'model losing job computer fact software able slightly change people skin colour slide switch said chan worry ai manipulate ethnicity reinforce unrealistic beauty standard',
#  'apparel company levi strauss announced march would partner ai model agency create personal inclusive shopping experience prompting online backlash critic said company hire real model promote diversity',
#  'company responded partnership would address business efficiency conflated diversity inclusion strategy',
#  'calvin wong head laboratory artificial intelligence design hong kong said ai used assistant rather something creates design maintain agency designer ensure creation manufacturable',
#  'lab hasdesigned ai toolthat allows designer upload draft sketch material colour palette generate design tweaked',
#  'need treasure originality inspiration fashion designer wong said',
#  'reporting beatrice tridimas editing zoe tabary',
#  'get top trend brand industry news fashion beauty wellness straight inbox daily',
#  'sign glossy daily newsletterhere',
#  'generative aiproduced picture imaginary nike collaborationsneakershave circled social medium week',
#  'thats one example ai used fashion us already valuable vast spanning marketing engineering immersive experience',
#  'ai stirred buzz last month thanks new increasingly userfriendly ai tool',
#  'last week march twenty image editor adobe firefly graphic design platform canva rolled new ai technologysupportingtexttovideo andbrand design respectively',
#  'specific launch prove ai usefulness forvisual content creation',
#  'thats start',
#  'industry expert predict ai tool allow quicker seamless workflow allowing worker across field including marketing operation engineering focus creative problemsolving task',
#  'one fastest moving potentially impactful trend see tech landscape today said roger robert partner consultancy mckinsey coauthor december two thousand and twenty-two generative ai herereport',
#  'hyperpersonalization',
#  'nextlevel personalization product experience consumer ecommerce site targeted ad instore experience among use case set benefit retailer',
#  'date personalization largely done microsegmentation grouping customer according interest age group location',
#  'youre going see lot automation want deliver hyperpersonalizationsaid brian long ceo personalized mobile messaging platform attentive',
#  'monday company announced attentive ai tool allowing brand create complete multichannel campaign using ai insight effective content fourteen trillion attentive data point',
#  'far major retail brand using tool beta reporting one hundred and forty-eight revenue increase',
#  'lot brand going generative imagemaking platform generate marketing image leverage product product catalog paired background foreground imagery based text prompt enter',
#  'theyre personalizing image setting lighting element said long',
#  'ai us database image paired text prompt select fitting setting element',
#  'case result productionready image send',
#  'case help figure theyre looking final shoot long said tool allows brand customize marketing imagery different geographical region almost cost',
#  'attentive ai develops copy campaign wellour biggest challenge always getting marketing copy completed timely manner said jason edward director ecommerce streetwear brand hat club',
#  'main surprise close final attentive ai allows u get copy step finalize',
#  'able significantly cut content creation time turn allow u build better campaign better segment customer',
#  'visual merchandising collection creation',
#  'ai could also solve problem visual merchandising',
#  'brand open store location need visual merchandising express brand identity globally also tailored context store',
#  'head visual merchandiser rarely lay every store brand fleet due cost time constraint',
#  'able train learning program based instinct intuition best virtual visual merchandiser using ai could bring voice style capability shop door season said robert',
#  'robert also noted creative application ai business',
#  'brand able use generative ai technology synthesize note sketch idea collection',
#  'ai combined operational financial perspective well merchandising marketing create collection price margin sustainable brand good customer',
#  'apart levi strauss co using ai show wider range diversemodelson website channelswere also using ai enhance differentiate loyalty program offering personalized benefit member helping u achieve meaningful growth enrollment revenue app registrationssaid dr amy gershkoff bolles global head digital emerging technology strategy levi strauss cofor example personalized benefit include localized discount based popular product area',
#  'since expanding loyalty program europe last year brand reached five million member worldwide',
#  'ai help u provide personalized product recommendation website mobile app based consumer data specific market said gershkoff bolles',
#  'also leveraging consumer mobility data customize store unique need interest local consumer open new store greatest demand',
#  'finally said ai powering levi promotion analyzing stock category product likely benefit sale',
#  'noted example including midseason endofseason sale well black friday sale u europe',
#  'web3 brand',
#  'web3 brand already implementing ai creative process',
#  'charli cohen founder 2yearold web3 brand rtlss said studio used generative ai speed coding development work allowing ai create code optimized workflow',
#  'also using create usergenerated content',
#  'progressively integrating ai year said cohenour next drop use ai gamify minting postmint experience',
#  'ugc toolkit currently building also include backend process like validating asset managing ip protection theyll automated enhanced ai',
#  'ai used analyzean nfts blockchain transaction history ensure nft original duplicate',
#  'itcan also analyze content nft art ensure original violate copyright law',
#  'one physical fashion brand active web3tommy hilfiger experimenting ai engage customer incocreation',
#  'specifically metaverse fashion week',
#  'giving consumer opportunity design item brand signature preppy style using generative ai',
#  'fashion show',
#  'even fashion show already undergone somewhat atransformation set undergo change due ai',
#  'matthew drinkwater head emerging technology company fashion innovation agency experimenting ai us catwalk since leading aifocused course london college fashion pandemic',
#  'student able showcase final work two thousand and twenty drinkwater worked fia using archival show footage skeletal data moving model create virtual runway show',
#  'project reimagined year include photorealistic model ai released march twenty-one via linkedin',
#  'earlier catwalk huge amount manual labor work involved said drinkwater',
#  'thats say wasnt case time specific skill set required deliver tool creating kind experience much manageable',
#  'thats especially availability ai tool like text prompttovideo ai platform runway ai launched week',
#  'video component going take next level engagement',
#  'image obviously cool video people stop look take time said long',
#  'runway project year fia used ai prompt tool midjourney stable diffusionthey took image luxury brand inspired trained ai model understand look applied look one particular male model create photorealistic video',
#  'drinkwater agreed robert human element even necessary within fashion experimentation creativity ai',
#  'however said new photorealistic opportunity help facilitate mass adoption digital fashion',
#  'note ai faster implement metaverse',
#  'metaverse combination many thing come together right way create really great experience',
#  'thats case ai said robert explaining current software add feature make better',
#  'doesnt require everyone show headset create entirely new platform',
#  'thats shorter hype cycle everyone talking ai people using cforelevant impact',
#  'company aiming cut cost due recessionrelated concern ai use could leveraged cut labor cost',
#  'bottomline impact suggests something need top mind ctos cfo',
#  'many case replace repetitive part human work allowing staff carry project quickly replacement',
#  'drinkwater added combination thing put together like use machine learning artificial intelligence immersive experience start deliver nextgeneration immersive experience',
#  'image courtesy christiane lemieux',
#  'study titledhow complex system get engaged fashion design creation using artificial intelligence published journalthinking skill creativityaimed investigate practical applicability ai model implement creative fashion design work human designer',
#  'thank',
#  'gold standard business intelligence',
#  'find',
#  'download email arrive shortlywhile wait take look free recommend buyer guide',
#  'research note use ai fashion industry grown significantly recent year',
#  'example already used personalise fashion recommendation customer optimise supply chain management automate process improve sustainability reduce waste',
#  'however creative process fashion design continue human driven little research use ai fashion design designer often included research',
#  'assistant professor lead author study yoon kyung lee keen find could effective collaboration human ai purpose creative design explained time ai deeply ingrained life study started instead considering human better ai',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'study started generating new textile design using deep convolution generative adversarial network dcgans cyclegans',
#  'output model compared similar design produced design student',
#  'comparison revealed design produced similar biggest difference uniqueness originality seen human design came person experience',
#  'however use ai repetitive task could improve efficiency designer free time focus highdifficult creative work',
#  'research also suggests aigenerated design could used learning tool people lack expertise fashion want explore creativity ai could assist creating design',
#  'following study finding professor lee proposing humanai collaborative network integrates gans human creativity produce design',
#  'professor lee also defined studied various element complex system involved humanai collaborated design established humanai model designer collaborates ai create novel design idea',
#  'model allows designer share creative process idea others system interconnect evolve improve design',
#  'professor lee belief fashion industry leverage foresee change fashion industry offer recommendation cocreation service',
#  'setting xobjectives variable limit part designer job humanai collaborative design environment suggests work go beyond visual aspect instead cover variety discipline',
#  'concludes future everybody able creator designer help ai model',
#  'far professional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'download email arrive shortly',
#  'wait take look free recommend buyer guide',
#  'give business edge leading industry insight',
#  'ai fashion industry',
#  'long human started wear clothes wed desire express individuality one way achieve fashionthe fashion industry one biggest world estimated three trillion dollar two thousand and eighteen representing two percent global gdp',
#  'much brickandmortar traditional retail well online ecommerce dedicated sale clothing fashion item',
#  'much amazon acquired shoe retailer zappos one billion two thousand and ten major retailer walmart target amazon others entered fashion retail business brand brand partnership',
#  'despite established nature fashion industry ai fundamentally transforming industry way fashion company manufacture product way marketed sold',
#  'ai technology transforming fashion industry every element value chain designing manufacturing logistics marketing sale',
#  'ai helping promote sell fashion good',
#  'fashion industry much creating demand brand awareness manufacturing fashion product',
#  'clothing apparel brand constantly looking new way get good front buyer create awareness demand market',
#  'increasinglyfashion brand using ai machine learningto maximize user shopping experience improve efficiency sale system intelligent automation enhance sale process using predictive analytics guided sale process',
# ...
#  'though acne studio futuristic clothes first example ai catwalk startup playing gangenerated clothes far longer',
#  'machine learningis kind artificial intelligence us vast quantity data predict learn certain outcome without preprogrammed',
#  'aneural networkis series algorithm work bit like human brain',
#  'theyre used machine learning spot pattern comparing template new data',
#  'agenerative adverserial networkgan kind machine learning system one neural network train another',
#  'typically consists generator network creates random version image example second discriminator network judge accurate generated image according criterion',
#  'student mit experimented help ibm produce artificial intelligence idea whattommy hilfiger look like realised application could far larger',
#  'last yeartwo graduate course launched aipoweredbrand called covenai producing unconventional unique design powered gantechniques barrat used design acne studio catwalk show',
#  'another fashionstartup used google generative ai churn outtshirts made doodle data',
#  'larger scaleindian fashion business myntraused inhouse aipowered software ratatouille suggest new clothing design cutting design process six month one',
#  'throw question around relationship designer neural network say matthew drinkwater head london college fashion innovation agency',
#  'computer designing use collaborative tool',
#  'unsettling think clothes may designed something human far aspect fashion industry affected algorithm',
#  'amazon echo look announced three year ago ability algorithmically decide outfit wear many observer envisioned new era computerchosen style choice',
#  'wasnt inconceivable imagine world aipowered recommendation advice like look suggested piece aidesigned clothing range like acne studio new offering',
#  'amazon drone would carry delivery human involved process postman carrying door',
#  'even model showcased aigenerated clothes threatened becoming obsoletevirtual influencers like miquelaattract million follower ten million pound',
#  'reality uptake fashion industry large much slower',
#  'there huge universe ai category created moment fashion industry last one adapt say hasna kourda ceo founder save wardrobe',
#  'industry skeptical digital world whole ai kourda tell metrocouk',
#  'taken decade website ecommerce even landing page',
#  'however pace takeup ai machine learningpowered tech begun increase',
#  'crawl web fashion photography much like google information say kostas koukoravas ceo founder intellistyle',
#  'focus specifically fashion imagery looking image put together human stylist social medium catalogue retailer website use imagery analyze understand style mean',
#  'concept style whats considered fashion arent human anymore',
#  'instagram like twitter hashtags googledistributed display advertising influential people buy magazine editor fashion designer',
#  'tastehas always arbitrary often decided royalty cadre magazine editor difference would make decided designed machine instead',
#  'ai understanding customer styling preference quite often outperforms human stylist koukoravas tell metrocouk',
#  'london fashion week last year pitted ai choice human stylist asked audience select one like best',
#  'seventy audience preferred combination ai provided',
#  'youre preparing getting next clothing recommendation machine might want think',
#  'likely interaction might machine person assisted ai',
#  'human recommending something customer much better result say koukoravas',
#  'ai still doesnt empathy communication ability human',
#  'better picked clothes could help fast fashion industry sustainable',
#  'study mark spencer found thatadults uk regularly wear forty-four percent clothing',
#  'theory better chosen clothes suggestion wear might reduce thirty-six billion unworn clothes left nation wardrobe',
#  'looking perspective ai help make right decision say koukoravas',
#  'opposed going buying something mindless coming back home thinking hey havent got anything match',
#  'christopher wylie whistleblower turned hm data scientist told fashion conference last year producing le get',
#  'industry retailer regularlydestroy million pound worth unused stockor send mostly fossil fuelbuilt clothes landfill huge problem solve',
#  'walk store high street across country typically theyll identical product say matthew drinkwater head london college fashion innovation agency',
#  'doesnt make sense consumer one location let say west end london would buying thing perhaps south coast cornwall',
#  'product like intellistyle save wardrobe aipowered suggestive technology based clothes already aim help reduce crisis',
#  'people aware wasteful consumer behavior say save wardrobe ceo hasna kourda',
#  'theyre taking stand looking tool help make better decision',
#  'though fashion industry may slower others take ai expert predictingenormous growth coming year',
#  'really allows people focus creative aspect fashion opposed mundane repetitive work say intellistyles koukoravas',
#  'human always need creative ai support',
#  'warning large job redundancy loomed large many industry like koukoravas kourda optimistic potential change',
#  'maybe one day everybodys tool',
#  'dont know going wanted try see work say johnasson',
#  'tip way technology transforming industry',
#  'leave comment youd like u look next',
#  'privacy policy',
#  'world everevolving metaverse web3 technology artificial intelligence ai currently one talked one enigmatic form tech making round',
#  'sparking debate could considered art design innovation certainly ushered new albeit ambiguous formula creation digital age',
#  'ai combination computer science data alongside machine learning develop algorithm create system prediction analysis based inputted data',
#  'machine utilised within technology mimic human mind learn improve time order adapt process',
#  'come art design ai applied way possible create constant stream content',
#  'yet actual process producing ai imagery involves plenty trial error',
#  'entering platform creator asked provide prompt generic specific desire',
#  'machine begin learn understand asked produced image become closer closer desired output',
#  'slightest adaptation prompt transform imagery explored detailed finished product',
#  'like music art fashion design creative field become subject ai tech sector rapidly evolving line accelerating interest',
#  'expert field also currently exploring whether ai creative without human intervention look understand depth communication people machine',
#  'topic ai particularly gained traction late last year technology like chatgpt lensa ai midjourney began making round sparking debate around use ai creation',
#  'argue technology could perceived form copying potentially present range ethical issue including encouraging mass production others see new form creative outlet providing designer artist accessible tool evolve creation',
#  'similar discussion recently brought light nft space artist mason rothschild taken court hermès luxury brand accusing stealing design create digital asset made one million dollar sale',
#  'ultimately jury ruled favour french luxury brand determining rothschild indeed profited name',
#  'ruling eye expert set precedent similar case technology fashion could handled future drawing parallel ongoing ai discourse',
#  'technology evolves could advancement actually benefit industry moving forward',
#  'creatives ai opened door looking fresh way enter industry array online tool free paid allow almost anyone access technology',
#  'product heavily adopted public new breed artist designer redefining mean creator modern day',
#  'field skjellerup ai artist behind instagram account ai_clothingdaily exactly title profile say creating daily ai clothing',
#  'design realistic comment page filled people asking order piece',
#  'look range ai iteration nike shoe complete heavy embellishment intricate embroidery full runway outfit donned similarly artificial model',
#  'noted skjellerups first venture fashion world',
#  'creator also operates research platform marketplace luckynumber8 collect often sell vintage archival garment',
#  'closely link ai work draw inspiration past designer runway collection well material would like experiment',
#  'speaking fashionunited said process working ai way collaborative approach give input wait generative image respond accordingly',
#  'even initial idea outcome could totally different depending ai responds',
#  'really enjoy sense mystery surrounding tool',
#  'skjellerups eye ai important tool design belief technology doesnt take away artist instead enhances creative potential',
#  'added ability rapidly generate large group image make initial concept stage highly productive push idea beyond could become otherwise',
#  'would like see ai design tool democratisation design process',
#  'see role designer consumer blur one',
#  'fashion much top industry blurring role could lead exciting possibility',
#  'criticism format presently unavoidable individual within outside sector say constitutes design',
#  'also something skjellerup acutely aware however perception remains resilient',
#  'asked view possibility misconception surrounding topic said heard people within industry refer assisted creativity tool become accessible see become norm',
#  'feel like people either havent tried ai creative tool ready pas judgement scared possibility job loss within sector',
#  'think valid concern must remember job loss come people position power making decision tool',
#  'hesitancy surrounding ai place design become increasingly analysed recent study expert look investigate practical applicability ai creative design process',
#  'concept yoon kyung lee professor pusan national university korea explored study thinking skill creativity',
#  'carry research lee started generating textile design using ai software compared model work design student',
#  'result found design similar however distinct uniqueness originality seen humanmade design often derived person experience',
#  'lee note use ai repetitive task could improve efficiency process provide good learning tool lack expertise industry',
#  'professor proposed humanai collaborative work therefore effective instance particularly work link variety discipline beyond visual aspect gone begin developing process model applied',
#  'speaking report lee said future everybody able creator designer help ai model',
#  'far progressional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'lee deduced isnt clothing design ai serf purpose',
#  'retailer increasingly implementing technology ecommerce online marketing strategy taking advantage ability enhance customer experience possibly ensure sustainable production process',
#  'particularly popular among ongoing ecommerce evolution often applied retailer website provide accurate product recommendation data collection make search discovery efficient',
#  'surge company putting use technology order provide retailer solution look expand consumer experience',
#  'one perfect corp tech firm offer aipowered tryon experience ecommerce allowing consumer try product comfort home',
#  'feature enables fast analysis offer shopper customised product recommendation efficiently matching product consumer need heightening confidence purchase',
#  'speaking fashionunited alice chang ceo founder perfect corp noted benefit product stating fashion brand provide customer personalised shopping experience boost customer satisfaction decreasing product return',
#  'solution also enable sustainable business operation allowing brand reach esg goal decreasing excess waste emission generated product sampling return process',
#  'chang perspective implementing technology also crucial staying relevant today shopper increasingly leaning personalised digital advancement make purchasing decision',
#  'chang added advancement ai recent year greatly accelerated allowing brand transform consumer journey improving sale engagement customer loyalty',
#  'consumer shopping habit shifting happening across multiple channel retail space',
#  'look future ai grow play larger role across industry empowering consumer shop personalised interactive way',
#  'plan levi test virtual clothing model generated artificial intelligence drew swift backlash industry late last month',
#  'furor mainly focused diversity concern retailer proposal also stirred anxiety simmering industry year',
#  'critic levi strauss co partnership ai design firm lalalandai aimed show online shopper different type people wearing levi garment accused retailer looking inexpensively address issue representation potentially pushing professional model job process',
#  'hire model book agency stylist makeup feed set cost money said shawn grain carter professor fashion business management fashion institute technology new york',
#  'let make mistake levi save money',
#  'levi spokesperson referred statement companydenied intention save costswith project',
#  'retailer said ai model planned introduce would supplement replace photoshoots live model',
#  'lalaland didnt respond request comment',
#  'worry technology displacing human labor nothing new theyre far distinct fashion workforce',
#  'ai used fashion year worker watching expansion space growing alarm',
#  'yanii gough model founder yanii model work one hundred model said many still dying get back consistency industry reemerges pandemicrelated disruption',
#  'rise ai modeling firm client simply send email agency say hey exactly im looking someone find person said referring company book model everything photoshoots fitting',
#  'precedent concern like goughs',
#  'shudu created two thousand and seventeen thought world first digital supermodel booked gig within past year highend brand asbmwandlouis vuitton',
#  'shudu designed black woman alsodrew criticismtoward diigitals ai modeling agency created founder cameronjames wilson white',
#  'today option continue expand brand advertiser looking use ai help market sell clothes',
#  'addition lalaland there also deep agency new ai startup allows user create virtual photoshoot either synthetic model ai version real person',
#  'gough said also worry model image used without permission via ai concern sara ziff founder nonprofit advocacy group called model alliance said hearing well',
#  'fit model may replaced ai body scan said adding model try clothes designer manufacturer check sizing silhouette already calling organization growing number',
#  'ziff said complained company hiring conduct body scan form basis product development without knowledge receiving compensation',
#  'theyre able design clothes virtually using scan model body rather actually book model person said ziff declined provide example citing model alliance policy maintaining anonymous hotline industry worker flag complaint',
#  'fashion brand defended ai effort addons benefit shopper ai design studio agency working space similarly describe effort supplemental',
#  'lalalands founder example said created company sustainably increase representation fashion',
#  'agent management company book model type job ziff described dont legally tell body scan could used project without compensation said',
#  'ziff advocating proposed fashion worker act new york said would force agency fully disclose scope work pay',
#  'current law leaf gray area around model right organize union ziff added resulting limited labor protection',
#  'model considered independent contractor many face heightened risk sued retaliated agency',
#  'representative professional creative field like thewriters guild america power propose standard best practice ai use industry',
#  'meanwhile ai model become realistic already impossible many consumer distinguish image human',
#  'ashley france influencer criticized levi partnership lalaland said hope regulator step',
#  'way put psa somethings ad somethings dietary supplement thankfully something photoshopped feel like type regulation france said',
#  'sara ruberg associate producer nbc news']

# %%
website18 = 'https://www.standard.co.uk/business/ai-uk-fashion-retail-robots-b1086114.html'
class18 = 'sc-ghHZHN kNjFqH'
text18 = scrape_clean(website18, class18)
sentences.extend(text18)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability',
#  'digital fashion look like today',
#  'question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one',
#  'taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution',
#  'digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research',
#  'fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one',
#  'response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment',
#  'speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem',
#  'hype cooled two thousand and twenty-two critic quick slate web3 nonfungible token nfts metaverse dead marco marchesi chief technology officer fabricant belief industry still show sign life',
#  'technology take lot cycle new idea take adopted',
#  'reality completely figured yet going take lot cycle find steady ground say',
#  'educating audience technicality digital fashion bolster credibility',
#  'there assumption around craft digital fashion dont realize technically challenging practice digital artist stephy fung say',
#  'dani loftus founder digital fashion house draup also argues clunky earlystage technology prevented widespread adoption',
#  'lot people exposed digital fashion first time ever last year loftus say',
#  'youre making digital dress arm fall people going see confirmation bias',
#  'doesnt perform well people turn away',
#  'evolution gaming platform social hub business goldmine potentially biggest seismic shift brand reach audience today',
#  'gen z gen alpha come age unleash spending power brand longer rely outdated marketing tactic magazine campaign celebrity partnership attract eyeball',
#  'key consumer demographic residing gaming destination like fornite roblox early adopter reaping benefit translating identity robust presence space',
#  'gaming space sartorial space play philippa morgan chief content officer savant say',
#  'brand planting seed space reach audience',
#  'attract younger consumer youre going advertise parking lot youre going go kid play',
#  'today brand need willing fully engage new ecosystem shy away experimenting image play',
#  'year saw unprecedented boom generative ai technology potential still yet fully realized fashion',
#  'remains fundamental issue industry approach machine learning',
#  'brand dont get bandwagon product like ai theyll left dust marchesi say discussing brand reticence towards generative system',
#  'fashion slowly surely actively reshaped ai',
#  'september fashion week alone saw coperni collina strada ganni deploy burgeoning tech runway',
#  'question whether ai replace creative role like designer pattern cutter image maker remains hot topic',
#  'fung belief tech cant wont replace human touch',
#  'use ai might take role art director creative director ai cant replicate whats inside brain',
#  'curation come u say',
#  'beyond creative scope machine learning also assisting brand making much productive decision across supply chain efficiency environmental standpoint',
#  'sasha mcfarlane executive director future proof fashion highlight trend cycle moving record speed traditional manufacturing roadmaps cant keep rapid turnover consumer demand',
#  'generative ai disrupting process predicting trend customer behavior month advance helping supplier scale waste',
#  'size global augmented reality virtual reality market estimated thirty-eight billion two thousand and twenty-two projected hit around three hundred and seventy-two billion two thousand and thirty-two according toprecedence research',
#  'trailblazer zero10 fffaceme paving way augmented realitypowered experience retail',
#  'effort havent gone unnoticed',
#  'year brand including tiffany co tommy hilfiger coach jd sport tapped ar capture consumer eyeball',
#  'beyond novelness moin robertsislam technology development manager fashion innovation agency explains ar emerged premium tool collecting data driving consumer loyalty',
#  'speaking one initiative latest ar activation robertsislam note consumer expressed brand loyalty immersive experience',
#  'ninety percent audience said would pay product understood better valued',
#  'digital fashion landscape remains fertile ground emerging technology like ar ai web3 already process overturning industry',
#  'brand still turning blind eye potential run risk selfsabotage',
#  'even understanding basic soon indispensable tool loftus argues',
#  'learning use something like discord server absolutely monumental',
#  'valuable asset say',
#  'there use entering increasingly digitized world without authenticity',
#  'marchesi highlight longterm wellintentioned goal behind every digital activation',
#  'create revenue youre trying create revenue say',
#  'there use trying jump bandwagon reason reason solely making profit',
#  'two hundred fashion designer showcase digital collection designed help ai tool modelled avatar theworlds first ai fashion weekin new york thursday',
#  'twoday event hosted ai creative agency maison meta give three winner deal produce design condition physically manufactured',
#  'predictive tool slash material waste virtual fitting room ai increasingly used manufacturing retail fashion sector',
#  'ai reshaping industry people feel',
#  'sixty designer participating ai fashion week used texttoimage generator midjourney produce image based written prompt help design collection',
#  'explain texture length emotion specific better result said alena stepanova whose collection ai fashion week inspired colour landscape nature native kazakhstan',
#  'digital design allows see one item look different body shape told context',
#  'datadriven ai also used inform design predicting trend fashion giving insight consumer preferred colour style',
#  'american designer tommy hilfiger partnered hardware service company ibm fashion institute technology use ai todesign clothes based dataabout consumer trend',
#  'retail side ai used detect fake optimise pricing clothing resale site help shopper try clothes virtually even choose buy tool uniqlo store recommends product aftermeasuring shopper reaction clothing',
#  'consultancy mckinsey found company excel personalisation generate40 profitthan',
#  'aigenerated model also increasingly used editorial shoot vogue singapore online edition vogue brazil choosing useavatars coversof spring edition year',
#  'ai could add to275 billionto apparel fashion luxury sector operating profit according mckinsey report published march',
#  'ai model agency lalaland said using ai model is90 fasterthan photoshoots requires sample helping brand reduce waste well save time',
#  'ai help company predict inventory needed thus minimising overstocking also reduce return rate helping consumer find bettersuited product according holger harreis senior partner mckinsey',
#  'designer even hope move fashion industry online entirely cutting physical sample',
#  'digital fashion house fabricant creates sell fashion collection nonfungible token nfts kind digital asset often linked image piece artwork usually bought cryptocurrencies',
#  'say using digital sample instead physical garment design development phase clothing canreduce brand carbon footprint thirty',
#  'boom ai tool like chatgpt automate certain area work data entry customer service sparked fear thatrobots could poach job',
#  'use avatar place human model raising similar concern fashion industry makeup artist hair stylist photographer behindthescenes creatives could lose use ai model',
#  'new york city model manager greg chan said hard tell much work missed opportunity may completely bypass agency go straight ai',
#  'model losing job computer fact software able slightly change people skin colour slide switch said chan worry ai manipulate ethnicity reinforce unrealistic beauty standard',
#  'apparel company levi strauss announced march would partner ai model agency create personal inclusive shopping experience prompting online backlash critic said company hire real model promote diversity',
#  'company responded partnership would address business efficiency conflated diversity inclusion strategy',
#  'calvin wong head laboratory artificial intelligence design hong kong said ai used assistant rather something creates design maintain agency designer ensure creation manufacturable',
#  'lab hasdesigned ai toolthat allows designer upload draft sketch material colour palette generate design tweaked',
#  'need treasure originality inspiration fashion designer wong said',
#  'reporting beatrice tridimas editing zoe tabary',
#  'get top trend brand industry news fashion beauty wellness straight inbox daily',
#  'sign glossy daily newsletterhere',
#  'generative aiproduced picture imaginary nike collaborationsneakershave circled social medium week',
#  'thats one example ai used fashion us already valuable vast spanning marketing engineering immersive experience',
#  'ai stirred buzz last month thanks new increasingly userfriendly ai tool',
#  'last week march twenty image editor adobe firefly graphic design platform canva rolled new ai technologysupportingtexttovideo andbrand design respectively',
#  'specific launch prove ai usefulness forvisual content creation',
#  'thats start',
#  'industry expert predict ai tool allow quicker seamless workflow allowing worker across field including marketing operation engineering focus creative problemsolving task',
#  'one fastest moving potentially impactful trend see tech landscape today said roger robert partner consultancy mckinsey coauthor december two thousand and twenty-two generative ai herereport',
#  'hyperpersonalization',
#  'nextlevel personalization product experience consumer ecommerce site targeted ad instore experience among use case set benefit retailer',
#  'date personalization largely done microsegmentation grouping customer according interest age group location',
#  'youre going see lot automation want deliver hyperpersonalizationsaid brian long ceo personalized mobile messaging platform attentive',
#  'monday company announced attentive ai tool allowing brand create complete multichannel campaign using ai insight effective content fourteen trillion attentive data point',
#  'far major retail brand using tool beta reporting one hundred and forty-eight revenue increase',
#  'lot brand going generative imagemaking platform generate marketing image leverage product product catalog paired background foreground imagery based text prompt enter',
#  'theyre personalizing image setting lighting element said long',
#  'ai us database image paired text prompt select fitting setting element',
#  'case result productionready image send',
#  'case help figure theyre looking final shoot long said tool allows brand customize marketing imagery different geographical region almost cost',
#  'attentive ai develops copy campaign wellour biggest challenge always getting marketing copy completed timely manner said jason edward director ecommerce streetwear brand hat club',
#  'main surprise close final attentive ai allows u get copy step finalize',
#  'able significantly cut content creation time turn allow u build better campaign better segment customer',
#  'visual merchandising collection creation',
#  'ai could also solve problem visual merchandising',
#  'brand open store location need visual merchandising express brand identity globally also tailored context store',
#  'head visual merchandiser rarely lay every store brand fleet due cost time constraint',
#  'able train learning program based instinct intuition best virtual visual merchandiser using ai could bring voice style capability shop door season said robert',
#  'robert also noted creative application ai business',
#  'brand able use generative ai technology synthesize note sketch idea collection',
#  'ai combined operational financial perspective well merchandising marketing create collection price margin sustainable brand good customer',
#  'apart levi strauss co using ai show wider range diversemodelson website channelswere also using ai enhance differentiate loyalty program offering personalized benefit member helping u achieve meaningful growth enrollment revenue app registrationssaid dr amy gershkoff bolles global head digital emerging technology strategy levi strauss cofor example personalized benefit include localized discount based popular product area',
#  'since expanding loyalty program europe last year brand reached five million member worldwide',
#  'ai help u provide personalized product recommendation website mobile app based consumer data specific market said gershkoff bolles',
#  'also leveraging consumer mobility data customize store unique need interest local consumer open new store greatest demand',
#  'finally said ai powering levi promotion analyzing stock category product likely benefit sale',
#  'noted example including midseason endofseason sale well black friday sale u europe',
#  'web3 brand',
#  'web3 brand already implementing ai creative process',
#  'charli cohen founder 2yearold web3 brand rtlss said studio used generative ai speed coding development work allowing ai create code optimized workflow',
#  'also using create usergenerated content',
#  'progressively integrating ai year said cohenour next drop use ai gamify minting postmint experience',
#  'ugc toolkit currently building also include backend process like validating asset managing ip protection theyll automated enhanced ai',
#  'ai used analyzean nfts blockchain transaction history ensure nft original duplicate',
#  'itcan also analyze content nft art ensure original violate copyright law',
#  'one physical fashion brand active web3tommy hilfiger experimenting ai engage customer incocreation',
#  'specifically metaverse fashion week',
#  'giving consumer opportunity design item brand signature preppy style using generative ai',
#  'fashion show',
#  'even fashion show already undergone somewhat atransformation set undergo change due ai',
#  'matthew drinkwater head emerging technology company fashion innovation agency experimenting ai us catwalk since leading aifocused course london college fashion pandemic',
#  'student able showcase final work two thousand and twenty drinkwater worked fia using archival show footage skeletal data moving model create virtual runway show',
#  'project reimagined year include photorealistic model ai released march twenty-one via linkedin',
#  'earlier catwalk huge amount manual labor work involved said drinkwater',
#  'thats say wasnt case time specific skill set required deliver tool creating kind experience much manageable',
#  'thats especially availability ai tool like text prompttovideo ai platform runway ai launched week',
#  'video component going take next level engagement',
#  'image obviously cool video people stop look take time said long',
#  'runway project year fia used ai prompt tool midjourney stable diffusionthey took image luxury brand inspired trained ai model understand look applied look one particular male model create photorealistic video',
#  'drinkwater agreed robert human element even necessary within fashion experimentation creativity ai',
#  'however said new photorealistic opportunity help facilitate mass adoption digital fashion',
#  'note ai faster implement metaverse',
#  'metaverse combination many thing come together right way create really great experience',
#  'thats case ai said robert explaining current software add feature make better',
#  'doesnt require everyone show headset create entirely new platform',
#  'thats shorter hype cycle everyone talking ai people using cforelevant impact',
#  'company aiming cut cost due recessionrelated concern ai use could leveraged cut labor cost',
#  'bottomline impact suggests something need top mind ctos cfo',
#  'many case replace repetitive part human work allowing staff carry project quickly replacement',
#  'drinkwater added combination thing put together like use machine learning artificial intelligence immersive experience start deliver nextgeneration immersive experience',
#  'image courtesy christiane lemieux',
#  'study titledhow complex system get engaged fashion design creation using artificial intelligence published journalthinking skill creativityaimed investigate practical applicability ai model implement creative fashion design work human designer',
#  'thank',
#  'gold standard business intelligence',
#  'find',
#  'download email arrive shortlywhile wait take look free recommend buyer guide',
#  'research note use ai fashion industry grown significantly recent year',
#  'example already used personalise fashion recommendation customer optimise supply chain management automate process improve sustainability reduce waste',
#  'however creative process fashion design continue human driven little research use ai fashion design designer often included research',
#  'assistant professor lead author study yoon kyung lee keen find could effective collaboration human ai purpose creative design explained time ai deeply ingrained life study started instead considering human better ai',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'study started generating new textile design using deep convolution generative adversarial network dcgans cyclegans',
#  'output model compared similar design produced design student',
#  'comparison revealed design produced similar biggest difference uniqueness originality seen human design came person experience',
#  'however use ai repetitive task could improve efficiency designer free time focus highdifficult creative work',
#  'research also suggests aigenerated design could used learning tool people lack expertise fashion want explore creativity ai could assist creating design',
#  'following study finding professor lee proposing humanai collaborative network integrates gans human creativity produce design',
#  'professor lee also defined studied various element complex system involved humanai collaborated design established humanai model designer collaborates ai create novel design idea',
#  'model allows designer share creative process idea others system interconnect evolve improve design',
#  'professor lee belief fashion industry leverage foresee change fashion industry offer recommendation cocreation service',
#  'setting xobjectives variable limit part designer job humanai collaborative design environment suggests work go beyond visual aspect instead cover variety discipline',
#  'concludes future everybody able creator designer help ai model',
#  'far professional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'download email arrive shortly',
#  'wait take look free recommend buyer guide',
#  'give business edge leading industry insight',
#  'ai fashion industry',
#  'long human started wear clothes wed desire express individuality one way achieve fashionthe fashion industry one biggest world estimated three trillion dollar two thousand and eighteen representing two percent global gdp',
#  'much brickandmortar traditional retail well online ecommerce dedicated sale clothing fashion item',
#  'much amazon acquired shoe retailer zappos one billion two thousand and ten major retailer walmart target amazon others entered fashion retail business brand brand partnership',
#  'despite established nature fashion industry ai fundamentally transforming industry way fashion company manufacture product way marketed sold',
#  'ai technology transforming fashion industry every element value chain designing manufacturing logistics marketing sale',
#  'ai helping promote sell fashion good',
#  'fashion industry much creating demand brand awareness manufacturing fashion product',
#  'clothing apparel brand constantly looking new way get good front buyer create awareness demand market',
#  'increasinglyfashion brand using ai machine learningto maximize user shopping experience improve efficiency sale system intelligent automation enhance sale process using predictive analytics guided sale process',
# ...
#  'though acne studio futuristic clothes first example ai catwalk startup playing gangenerated clothes far longer',
#  'machine learningis kind artificial intelligence us vast quantity data predict learn certain outcome without preprogrammed',
#  'aneural networkis series algorithm work bit like human brain',
#  'theyre used machine learning spot pattern comparing template new data',
#  'agenerative adverserial networkgan kind machine learning system one neural network train another',
#  'typically consists generator network creates random version image example second discriminator network judge accurate generated image according criterion',
#  'student mit experimented help ibm produce artificial intelligence idea whattommy hilfiger look like realised application could far larger',
#  'last yeartwo graduate course launched aipoweredbrand called covenai producing unconventional unique design powered gantechniques barrat used design acne studio catwalk show',
#  'another fashionstartup used google generative ai churn outtshirts made doodle data',
#  'larger scaleindian fashion business myntraused inhouse aipowered software ratatouille suggest new clothing design cutting design process six month one',
#  'throw question around relationship designer neural network say matthew drinkwater head london college fashion innovation agency',
#  'computer designing use collaborative tool',
#  'unsettling think clothes may designed something human far aspect fashion industry affected algorithm',
#  'amazon echo look announced three year ago ability algorithmically decide outfit wear many observer envisioned new era computerchosen style choice',
#  'wasnt inconceivable imagine world aipowered recommendation advice like look suggested piece aidesigned clothing range like acne studio new offering',
#  'amazon drone would carry delivery human involved process postman carrying door',
#  'even model showcased aigenerated clothes threatened becoming obsoletevirtual influencers like miquelaattract million follower ten million pound',
#  'reality uptake fashion industry large much slower',
#  'there huge universe ai category created moment fashion industry last one adapt say hasna kourda ceo founder save wardrobe',
#  'industry skeptical digital world whole ai kourda tell metrocouk',
#  'taken decade website ecommerce even landing page',
#  'however pace takeup ai machine learningpowered tech begun increase',
#  'crawl web fashion photography much like google information say kostas koukoravas ceo founder intellistyle',
#  'focus specifically fashion imagery looking image put together human stylist social medium catalogue retailer website use imagery analyze understand style mean',
#  'concept style whats considered fashion arent human anymore',
#  'instagram like twitter hashtags googledistributed display advertising influential people buy magazine editor fashion designer',
#  'tastehas always arbitrary often decided royalty cadre magazine editor difference would make decided designed machine instead',
#  'ai understanding customer styling preference quite often outperforms human stylist koukoravas tell metrocouk',
#  'london fashion week last year pitted ai choice human stylist asked audience select one like best',
#  'seventy audience preferred combination ai provided',
#  'youre preparing getting next clothing recommendation machine might want think',
#  'likely interaction might machine person assisted ai',
#  'human recommending something customer much better result say koukoravas',
#  'ai still doesnt empathy communication ability human',
#  'better picked clothes could help fast fashion industry sustainable',
#  'study mark spencer found thatadults uk regularly wear forty-four percent clothing',
#  'theory better chosen clothes suggestion wear might reduce thirty-six billion unworn clothes left nation wardrobe',
#  'looking perspective ai help make right decision say koukoravas',
#  'opposed going buying something mindless coming back home thinking hey havent got anything match',
#  'christopher wylie whistleblower turned hm data scientist told fashion conference last year producing le get',
#  'industry retailer regularlydestroy million pound worth unused stockor send mostly fossil fuelbuilt clothes landfill huge problem solve',
#  'walk store high street across country typically theyll identical product say matthew drinkwater head london college fashion innovation agency',
#  'doesnt make sense consumer one location let say west end london would buying thing perhaps south coast cornwall',
#  'product like intellistyle save wardrobe aipowered suggestive technology based clothes already aim help reduce crisis',
#  'people aware wasteful consumer behavior say save wardrobe ceo hasna kourda',
#  'theyre taking stand looking tool help make better decision',
#  'though fashion industry may slower others take ai expert predictingenormous growth coming year',
#  'really allows people focus creative aspect fashion opposed mundane repetitive work say intellistyles koukoravas',
#  'human always need creative ai support',
#  'warning large job redundancy loomed large many industry like koukoravas kourda optimistic potential change',
#  'maybe one day everybodys tool',
#  'dont know going wanted try see work say johnasson',
#  'tip way technology transforming industry',
#  'leave comment youd like u look next',
#  'privacy policy',
#  'world everevolving metaverse web3 technology artificial intelligence ai currently one talked one enigmatic form tech making round',
#  'sparking debate could considered art design innovation certainly ushered new albeit ambiguous formula creation digital age',
#  'ai combination computer science data alongside machine learning develop algorithm create system prediction analysis based inputted data',
#  'machine utilised within technology mimic human mind learn improve time order adapt process',
#  'come art design ai applied way possible create constant stream content',
#  'yet actual process producing ai imagery involves plenty trial error',
#  'entering platform creator asked provide prompt generic specific desire',
#  'machine begin learn understand asked produced image become closer closer desired output',
#  'slightest adaptation prompt transform imagery explored detailed finished product',
#  'like music art fashion design creative field become subject ai tech sector rapidly evolving line accelerating interest',
#  'expert field also currently exploring whether ai creative without human intervention look understand depth communication people machine',
#  'topic ai particularly gained traction late last year technology like chatgpt lensa ai midjourney began making round sparking debate around use ai creation',
#  'argue technology could perceived form copying potentially present range ethical issue including encouraging mass production others see new form creative outlet providing designer artist accessible tool evolve creation',
#  'similar discussion recently brought light nft space artist mason rothschild taken court hermès luxury brand accusing stealing design create digital asset made one million dollar sale',
#  'ultimately jury ruled favour french luxury brand determining rothschild indeed profited name',
#  'ruling eye expert set precedent similar case technology fashion could handled future drawing parallel ongoing ai discourse',
#  'technology evolves could advancement actually benefit industry moving forward',
#  'creatives ai opened door looking fresh way enter industry array online tool free paid allow almost anyone access technology',
#  'product heavily adopted public new breed artist designer redefining mean creator modern day',
#  'field skjellerup ai artist behind instagram account ai_clothingdaily exactly title profile say creating daily ai clothing',
#  'design realistic comment page filled people asking order piece',
#  'look range ai iteration nike shoe complete heavy embellishment intricate embroidery full runway outfit donned similarly artificial model',
#  'noted skjellerups first venture fashion world',
#  'creator also operates research platform marketplace luckynumber8 collect often sell vintage archival garment',
#  'closely link ai work draw inspiration past designer runway collection well material would like experiment',
#  'speaking fashionunited said process working ai way collaborative approach give input wait generative image respond accordingly',
#  'even initial idea outcome could totally different depending ai responds',
#  'really enjoy sense mystery surrounding tool',
#  'skjellerups eye ai important tool design belief technology doesnt take away artist instead enhances creative potential',
#  'added ability rapidly generate large group image make initial concept stage highly productive push idea beyond could become otherwise',
#  'would like see ai design tool democratisation design process',
#  'see role designer consumer blur one',
#  'fashion much top industry blurring role could lead exciting possibility',
#  'criticism format presently unavoidable individual within outside sector say constitutes design',
#  'also something skjellerup acutely aware however perception remains resilient',
#  'asked view possibility misconception surrounding topic said heard people within industry refer assisted creativity tool become accessible see become norm',
#  'feel like people either havent tried ai creative tool ready pas judgement scared possibility job loss within sector',
#  'think valid concern must remember job loss come people position power making decision tool',
#  'hesitancy surrounding ai place design become increasingly analysed recent study expert look investigate practical applicability ai creative design process',
#  'concept yoon kyung lee professor pusan national university korea explored study thinking skill creativity',
#  'carry research lee started generating textile design using ai software compared model work design student',
#  'result found design similar however distinct uniqueness originality seen humanmade design often derived person experience',
#  'lee note use ai repetitive task could improve efficiency process provide good learning tool lack expertise industry',
#  'professor proposed humanai collaborative work therefore effective instance particularly work link variety discipline beyond visual aspect gone begin developing process model applied',
#  'speaking report lee said future everybody able creator designer help ai model',
#  'far progressional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'lee deduced isnt clothing design ai serf purpose',
#  'retailer increasingly implementing technology ecommerce online marketing strategy taking advantage ability enhance customer experience possibly ensure sustainable production process',
#  'particularly popular among ongoing ecommerce evolution often applied retailer website provide accurate product recommendation data collection make search discovery efficient',
#  'surge company putting use technology order provide retailer solution look expand consumer experience',
#  'one perfect corp tech firm offer aipowered tryon experience ecommerce allowing consumer try product comfort home',
#  'feature enables fast analysis offer shopper customised product recommendation efficiently matching product consumer need heightening confidence purchase',
#  'speaking fashionunited alice chang ceo founder perfect corp noted benefit product stating fashion brand provide customer personalised shopping experience boost customer satisfaction decreasing product return',
#  'solution also enable sustainable business operation allowing brand reach esg goal decreasing excess waste emission generated product sampling return process',
#  'chang perspective implementing technology also crucial staying relevant today shopper increasingly leaning personalised digital advancement make purchasing decision',
#  'chang added advancement ai recent year greatly accelerated allowing brand transform consumer journey improving sale engagement customer loyalty',
#  'consumer shopping habit shifting happening across multiple channel retail space',
#  'look future ai grow play larger role across industry empowering consumer shop personalised interactive way',
#  'plan levi test virtual clothing model generated artificial intelligence drew swift backlash industry late last month',
#  'furor mainly focused diversity concern retailer proposal also stirred anxiety simmering industry year',
#  'critic levi strauss co partnership ai design firm lalalandai aimed show online shopper different type people wearing levi garment accused retailer looking inexpensively address issue representation potentially pushing professional model job process',
#  'hire model book agency stylist makeup feed set cost money said shawn grain carter professor fashion business management fashion institute technology new york',
#  'let make mistake levi save money',
#  'levi spokesperson referred statement companydenied intention save costswith project',
#  'retailer said ai model planned introduce would supplement replace photoshoots live model',
#  'lalaland didnt respond request comment',
#  'worry technology displacing human labor nothing new theyre far distinct fashion workforce',
#  'ai used fashion year worker watching expansion space growing alarm',
#  'yanii gough model founder yanii model work one hundred model said many still dying get back consistency industry reemerges pandemicrelated disruption',
#  'rise ai modeling firm client simply send email agency say hey exactly im looking someone find person said referring company book model everything photoshoots fitting',
#  'precedent concern like goughs',
#  'shudu created two thousand and seventeen thought world first digital supermodel booked gig within past year highend brand asbmwandlouis vuitton',
#  'shudu designed black woman alsodrew criticismtoward diigitals ai modeling agency created founder cameronjames wilson white',
#  'today option continue expand brand advertiser looking use ai help market sell clothes',
#  'addition lalaland there also deep agency new ai startup allows user create virtual photoshoot either synthetic model ai version real person',
#  'gough said also worry model image used without permission via ai concern sara ziff founder nonprofit advocacy group called model alliance said hearing well',
#  'fit model may replaced ai body scan said adding model try clothes designer manufacturer check sizing silhouette already calling organization growing number',
#  'ziff said complained company hiring conduct body scan form basis product development without knowledge receiving compensation',
#  'theyre able design clothes virtually using scan model body rather actually book model person said ziff declined provide example citing model alliance policy maintaining anonymous hotline industry worker flag complaint',
#  'fashion brand defended ai effort addons benefit shopper ai design studio agency working space similarly describe effort supplemental',
#  'lalalands founder example said created company sustainably increase representation fashion',
#  'agent management company book model type job ziff described dont legally tell body scan could used project without compensation said',
#  'ziff advocating proposed fashion worker act new york said would force agency fully disclose scope work pay',
#  'current law leaf gray area around model right organize union ziff added resulting limited labor protection',
#  'model considered independent contractor many face heightened risk sued retaliated agency',
#  'representative professional creative field like thewriters guild america power propose standard best practice ai use industry',
#  'meanwhile ai model become realistic already impossible many consumer distinguish image human',
#  'ashley france influencer criticized levi partnership lalaland said hope regulator step',
#  'way put psa somethings ad somethings dietary supplement thankfully something photoshopped feel like type regulation france said',
#  'sara ruberg associate producer nbc news']

# %%
website19 = 'https://fashionunited.uk/news/fashion/how-ai-is-transforming-the-fashion-industry/2019081344722'
class19 = 'css-1s0my6s e15wwp330'
text19 = scrape_clean(website19, class19)
sentences.extend(text19)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability',
#  'digital fashion look like today',
#  'question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one',
#  'taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution',
#  'digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research',
#  'fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one',
#  'response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment',
#  'speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem',
#  'hype cooled two thousand and twenty-two critic quick slate web3 nonfungible token nfts metaverse dead marco marchesi chief technology officer fabricant belief industry still show sign life',
#  'technology take lot cycle new idea take adopted',
#  'reality completely figured yet going take lot cycle find steady ground say',
#  'educating audience technicality digital fashion bolster credibility',
#  'there assumption around craft digital fashion dont realize technically challenging practice digital artist stephy fung say',
#  'dani loftus founder digital fashion house draup also argues clunky earlystage technology prevented widespread adoption',
#  'lot people exposed digital fashion first time ever last year loftus say',
#  'youre making digital dress arm fall people going see confirmation bias',
#  'doesnt perform well people turn away',
#  'evolution gaming platform social hub business goldmine potentially biggest seismic shift brand reach audience today',
#  'gen z gen alpha come age unleash spending power brand longer rely outdated marketing tactic magazine campaign celebrity partnership attract eyeball',
#  'key consumer demographic residing gaming destination like fornite roblox early adopter reaping benefit translating identity robust presence space',
#  'gaming space sartorial space play philippa morgan chief content officer savant say',
#  'brand planting seed space reach audience',
#  'attract younger consumer youre going advertise parking lot youre going go kid play',
#  'today brand need willing fully engage new ecosystem shy away experimenting image play',
#  'year saw unprecedented boom generative ai technology potential still yet fully realized fashion',
#  'remains fundamental issue industry approach machine learning',
#  'brand dont get bandwagon product like ai theyll left dust marchesi say discussing brand reticence towards generative system',
#  'fashion slowly surely actively reshaped ai',
#  'september fashion week alone saw coperni collina strada ganni deploy burgeoning tech runway',
#  'question whether ai replace creative role like designer pattern cutter image maker remains hot topic',
#  'fung belief tech cant wont replace human touch',
#  'use ai might take role art director creative director ai cant replicate whats inside brain',
#  'curation come u say',
#  'beyond creative scope machine learning also assisting brand making much productive decision across supply chain efficiency environmental standpoint',
#  'sasha mcfarlane executive director future proof fashion highlight trend cycle moving record speed traditional manufacturing roadmaps cant keep rapid turnover consumer demand',
#  'generative ai disrupting process predicting trend customer behavior month advance helping supplier scale waste',
#  'size global augmented reality virtual reality market estimated thirty-eight billion two thousand and twenty-two projected hit around three hundred and seventy-two billion two thousand and thirty-two according toprecedence research',
#  'trailblazer zero10 fffaceme paving way augmented realitypowered experience retail',
#  'effort havent gone unnoticed',
#  'year brand including tiffany co tommy hilfiger coach jd sport tapped ar capture consumer eyeball',
#  'beyond novelness moin robertsislam technology development manager fashion innovation agency explains ar emerged premium tool collecting data driving consumer loyalty',
#  'speaking one initiative latest ar activation robertsislam note consumer expressed brand loyalty immersive experience',
#  'ninety percent audience said would pay product understood better valued',
#  'digital fashion landscape remains fertile ground emerging technology like ar ai web3 already process overturning industry',
#  'brand still turning blind eye potential run risk selfsabotage',
#  'even understanding basic soon indispensable tool loftus argues',
#  'learning use something like discord server absolutely monumental',
#  'valuable asset say',
#  'there use entering increasingly digitized world without authenticity',
#  'marchesi highlight longterm wellintentioned goal behind every digital activation',
#  'create revenue youre trying create revenue say',
#  'there use trying jump bandwagon reason reason solely making profit',
#  'two hundred fashion designer showcase digital collection designed help ai tool modelled avatar theworlds first ai fashion weekin new york thursday',
#  'twoday event hosted ai creative agency maison meta give three winner deal produce design condition physically manufactured',
#  'predictive tool slash material waste virtual fitting room ai increasingly used manufacturing retail fashion sector',
#  'ai reshaping industry people feel',
#  'sixty designer participating ai fashion week used texttoimage generator midjourney produce image based written prompt help design collection',
#  'explain texture length emotion specific better result said alena stepanova whose collection ai fashion week inspired colour landscape nature native kazakhstan',
#  'digital design allows see one item look different body shape told context',
#  'datadriven ai also used inform design predicting trend fashion giving insight consumer preferred colour style',
#  'american designer tommy hilfiger partnered hardware service company ibm fashion institute technology use ai todesign clothes based dataabout consumer trend',
#  'retail side ai used detect fake optimise pricing clothing resale site help shopper try clothes virtually even choose buy tool uniqlo store recommends product aftermeasuring shopper reaction clothing',
#  'consultancy mckinsey found company excel personalisation generate40 profitthan',
#  'aigenerated model also increasingly used editorial shoot vogue singapore online edition vogue brazil choosing useavatars coversof spring edition year',
#  'ai could add to275 billionto apparel fashion luxury sector operating profit according mckinsey report published march',
#  'ai model agency lalaland said using ai model is90 fasterthan photoshoots requires sample helping brand reduce waste well save time',
#  'ai help company predict inventory needed thus minimising overstocking also reduce return rate helping consumer find bettersuited product according holger harreis senior partner mckinsey',
#  'designer even hope move fashion industry online entirely cutting physical sample',
#  'digital fashion house fabricant creates sell fashion collection nonfungible token nfts kind digital asset often linked image piece artwork usually bought cryptocurrencies',
#  'say using digital sample instead physical garment design development phase clothing canreduce brand carbon footprint thirty',
#  'boom ai tool like chatgpt automate certain area work data entry customer service sparked fear thatrobots could poach job',
#  'use avatar place human model raising similar concern fashion industry makeup artist hair stylist photographer behindthescenes creatives could lose use ai model',
#  'new york city model manager greg chan said hard tell much work missed opportunity may completely bypass agency go straight ai',
#  'model losing job computer fact software able slightly change people skin colour slide switch said chan worry ai manipulate ethnicity reinforce unrealistic beauty standard',
#  'apparel company levi strauss announced march would partner ai model agency create personal inclusive shopping experience prompting online backlash critic said company hire real model promote diversity',
#  'company responded partnership would address business efficiency conflated diversity inclusion strategy',
#  'calvin wong head laboratory artificial intelligence design hong kong said ai used assistant rather something creates design maintain agency designer ensure creation manufacturable',
#  'lab hasdesigned ai toolthat allows designer upload draft sketch material colour palette generate design tweaked',
#  'need treasure originality inspiration fashion designer wong said',
#  'reporting beatrice tridimas editing zoe tabary',
#  'get top trend brand industry news fashion beauty wellness straight inbox daily',
#  'sign glossy daily newsletterhere',
#  'generative aiproduced picture imaginary nike collaborationsneakershave circled social medium week',
#  'thats one example ai used fashion us already valuable vast spanning marketing engineering immersive experience',
#  'ai stirred buzz last month thanks new increasingly userfriendly ai tool',
#  'last week march twenty image editor adobe firefly graphic design platform canva rolled new ai technologysupportingtexttovideo andbrand design respectively',
#  'specific launch prove ai usefulness forvisual content creation',
#  'thats start',
#  'industry expert predict ai tool allow quicker seamless workflow allowing worker across field including marketing operation engineering focus creative problemsolving task',
#  'one fastest moving potentially impactful trend see tech landscape today said roger robert partner consultancy mckinsey coauthor december two thousand and twenty-two generative ai herereport',
#  'hyperpersonalization',
#  'nextlevel personalization product experience consumer ecommerce site targeted ad instore experience among use case set benefit retailer',
#  'date personalization largely done microsegmentation grouping customer according interest age group location',
#  'youre going see lot automation want deliver hyperpersonalizationsaid brian long ceo personalized mobile messaging platform attentive',
#  'monday company announced attentive ai tool allowing brand create complete multichannel campaign using ai insight effective content fourteen trillion attentive data point',
#  'far major retail brand using tool beta reporting one hundred and forty-eight revenue increase',
#  'lot brand going generative imagemaking platform generate marketing image leverage product product catalog paired background foreground imagery based text prompt enter',
#  'theyre personalizing image setting lighting element said long',
#  'ai us database image paired text prompt select fitting setting element',
#  'case result productionready image send',
#  'case help figure theyre looking final shoot long said tool allows brand customize marketing imagery different geographical region almost cost',
#  'attentive ai develops copy campaign wellour biggest challenge always getting marketing copy completed timely manner said jason edward director ecommerce streetwear brand hat club',
#  'main surprise close final attentive ai allows u get copy step finalize',
#  'able significantly cut content creation time turn allow u build better campaign better segment customer',
#  'visual merchandising collection creation',
#  'ai could also solve problem visual merchandising',
#  'brand open store location need visual merchandising express brand identity globally also tailored context store',
#  'head visual merchandiser rarely lay every store brand fleet due cost time constraint',
#  'able train learning program based instinct intuition best virtual visual merchandiser using ai could bring voice style capability shop door season said robert',
#  'robert also noted creative application ai business',
#  'brand able use generative ai technology synthesize note sketch idea collection',
#  'ai combined operational financial perspective well merchandising marketing create collection price margin sustainable brand good customer',
#  'apart levi strauss co using ai show wider range diversemodelson website channelswere also using ai enhance differentiate loyalty program offering personalized benefit member helping u achieve meaningful growth enrollment revenue app registrationssaid dr amy gershkoff bolles global head digital emerging technology strategy levi strauss cofor example personalized benefit include localized discount based popular product area',
#  'since expanding loyalty program europe last year brand reached five million member worldwide',
#  'ai help u provide personalized product recommendation website mobile app based consumer data specific market said gershkoff bolles',
#  'also leveraging consumer mobility data customize store unique need interest local consumer open new store greatest demand',
#  'finally said ai powering levi promotion analyzing stock category product likely benefit sale',
#  'noted example including midseason endofseason sale well black friday sale u europe',
#  'web3 brand',
#  'web3 brand already implementing ai creative process',
#  'charli cohen founder 2yearold web3 brand rtlss said studio used generative ai speed coding development work allowing ai create code optimized workflow',
#  'also using create usergenerated content',
#  'progressively integrating ai year said cohenour next drop use ai gamify minting postmint experience',
#  'ugc toolkit currently building also include backend process like validating asset managing ip protection theyll automated enhanced ai',
#  'ai used analyzean nfts blockchain transaction history ensure nft original duplicate',
#  'itcan also analyze content nft art ensure original violate copyright law',
#  'one physical fashion brand active web3tommy hilfiger experimenting ai engage customer incocreation',
#  'specifically metaverse fashion week',
#  'giving consumer opportunity design item brand signature preppy style using generative ai',
#  'fashion show',
#  'even fashion show already undergone somewhat atransformation set undergo change due ai',
#  'matthew drinkwater head emerging technology company fashion innovation agency experimenting ai us catwalk since leading aifocused course london college fashion pandemic',
#  'student able showcase final work two thousand and twenty drinkwater worked fia using archival show footage skeletal data moving model create virtual runway show',
#  'project reimagined year include photorealistic model ai released march twenty-one via linkedin',
#  'earlier catwalk huge amount manual labor work involved said drinkwater',
#  'thats say wasnt case time specific skill set required deliver tool creating kind experience much manageable',
#  'thats especially availability ai tool like text prompttovideo ai platform runway ai launched week',
#  'video component going take next level engagement',
#  'image obviously cool video people stop look take time said long',
#  'runway project year fia used ai prompt tool midjourney stable diffusionthey took image luxury brand inspired trained ai model understand look applied look one particular male model create photorealistic video',
#  'drinkwater agreed robert human element even necessary within fashion experimentation creativity ai',
#  'however said new photorealistic opportunity help facilitate mass adoption digital fashion',
#  'note ai faster implement metaverse',
#  'metaverse combination many thing come together right way create really great experience',
#  'thats case ai said robert explaining current software add feature make better',
#  'doesnt require everyone show headset create entirely new platform',
#  'thats shorter hype cycle everyone talking ai people using cforelevant impact',
#  'company aiming cut cost due recessionrelated concern ai use could leveraged cut labor cost',
#  'bottomline impact suggests something need top mind ctos cfo',
#  'many case replace repetitive part human work allowing staff carry project quickly replacement',
#  'drinkwater added combination thing put together like use machine learning artificial intelligence immersive experience start deliver nextgeneration immersive experience',
#  'image courtesy christiane lemieux',
#  'study titledhow complex system get engaged fashion design creation using artificial intelligence published journalthinking skill creativityaimed investigate practical applicability ai model implement creative fashion design work human designer',
#  'thank',
#  'gold standard business intelligence',
#  'find',
#  'download email arrive shortlywhile wait take look free recommend buyer guide',
#  'research note use ai fashion industry grown significantly recent year',
#  'example already used personalise fashion recommendation customer optimise supply chain management automate process improve sustainability reduce waste',
#  'however creative process fashion design continue human driven little research use ai fashion design designer often included research',
#  'assistant professor lead author study yoon kyung lee keen find could effective collaboration human ai purpose creative design explained time ai deeply ingrained life study started instead considering human better ai',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'study started generating new textile design using deep convolution generative adversarial network dcgans cyclegans',
#  'output model compared similar design produced design student',
#  'comparison revealed design produced similar biggest difference uniqueness originality seen human design came person experience',
#  'however use ai repetitive task could improve efficiency designer free time focus highdifficult creative work',
#  'research also suggests aigenerated design could used learning tool people lack expertise fashion want explore creativity ai could assist creating design',
#  'following study finding professor lee proposing humanai collaborative network integrates gans human creativity produce design',
#  'professor lee also defined studied various element complex system involved humanai collaborated design established humanai model designer collaborates ai create novel design idea',
#  'model allows designer share creative process idea others system interconnect evolve improve design',
#  'professor lee belief fashion industry leverage foresee change fashion industry offer recommendation cocreation service',
#  'setting xobjectives variable limit part designer job humanai collaborative design environment suggests work go beyond visual aspect instead cover variety discipline',
#  'concludes future everybody able creator designer help ai model',
#  'far professional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'download email arrive shortly',
#  'wait take look free recommend buyer guide',
#  'give business edge leading industry insight',
#  'ai fashion industry',
#  'long human started wear clothes wed desire express individuality one way achieve fashionthe fashion industry one biggest world estimated three trillion dollar two thousand and eighteen representing two percent global gdp',
#  'much brickandmortar traditional retail well online ecommerce dedicated sale clothing fashion item',
#  'much amazon acquired shoe retailer zappos one billion two thousand and ten major retailer walmart target amazon others entered fashion retail business brand brand partnership',
#  'despite established nature fashion industry ai fundamentally transforming industry way fashion company manufacture product way marketed sold',
#  'ai technology transforming fashion industry every element value chain designing manufacturing logistics marketing sale',
#  'ai helping promote sell fashion good',
#  'fashion industry much creating demand brand awareness manufacturing fashion product',
#  'clothing apparel brand constantly looking new way get good front buyer create awareness demand market',
#  'increasinglyfashion brand using ai machine learningto maximize user shopping experience improve efficiency sale system intelligent automation enhance sale process using predictive analytics guided sale process',
# ...
#  'reality uptake fashion industry large much slower',
#  'there huge universe ai category created moment fashion industry last one adapt say hasna kourda ceo founder save wardrobe',
#  'industry skeptical digital world whole ai kourda tell metrocouk',
#  'taken decade website ecommerce even landing page',
#  'however pace takeup ai machine learningpowered tech begun increase',
#  'crawl web fashion photography much like google information say kostas koukoravas ceo founder intellistyle',
#  'focus specifically fashion imagery looking image put together human stylist social medium catalogue retailer website use imagery analyze understand style mean',
#  'concept style whats considered fashion arent human anymore',
#  'instagram like twitter hashtags googledistributed display advertising influential people buy magazine editor fashion designer',
#  'tastehas always arbitrary often decided royalty cadre magazine editor difference would make decided designed machine instead',
#  'ai understanding customer styling preference quite often outperforms human stylist koukoravas tell metrocouk',
#  'london fashion week last year pitted ai choice human stylist asked audience select one like best',
#  'seventy audience preferred combination ai provided',
#  'youre preparing getting next clothing recommendation machine might want think',
#  'likely interaction might machine person assisted ai',
#  'human recommending something customer much better result say koukoravas',
#  'ai still doesnt empathy communication ability human',
#  'better picked clothes could help fast fashion industry sustainable',
#  'study mark spencer found thatadults uk regularly wear forty-four percent clothing',
#  'theory better chosen clothes suggestion wear might reduce thirty-six billion unworn clothes left nation wardrobe',
#  'looking perspective ai help make right decision say koukoravas',
#  'opposed going buying something mindless coming back home thinking hey havent got anything match',
#  'christopher wylie whistleblower turned hm data scientist told fashion conference last year producing le get',
#  'industry retailer regularlydestroy million pound worth unused stockor send mostly fossil fuelbuilt clothes landfill huge problem solve',
#  'walk store high street across country typically theyll identical product say matthew drinkwater head london college fashion innovation agency',
#  'doesnt make sense consumer one location let say west end london would buying thing perhaps south coast cornwall',
#  'product like intellistyle save wardrobe aipowered suggestive technology based clothes already aim help reduce crisis',
#  'people aware wasteful consumer behavior say save wardrobe ceo hasna kourda',
#  'theyre taking stand looking tool help make better decision',
#  'though fashion industry may slower others take ai expert predictingenormous growth coming year',
#  'really allows people focus creative aspect fashion opposed mundane repetitive work say intellistyles koukoravas',
#  'human always need creative ai support',
#  'warning large job redundancy loomed large many industry like koukoravas kourda optimistic potential change',
#  'maybe one day everybodys tool',
#  'dont know going wanted try see work say johnasson',
#  'tip way technology transforming industry',
#  'leave comment youd like u look next',
#  'privacy policy',
#  'world everevolving metaverse web3 technology artificial intelligence ai currently one talked one enigmatic form tech making round',
#  'sparking debate could considered art design innovation certainly ushered new albeit ambiguous formula creation digital age',
#  'ai combination computer science data alongside machine learning develop algorithm create system prediction analysis based inputted data',
#  'machine utilised within technology mimic human mind learn improve time order adapt process',
#  'come art design ai applied way possible create constant stream content',
#  'yet actual process producing ai imagery involves plenty trial error',
#  'entering platform creator asked provide prompt generic specific desire',
#  'machine begin learn understand asked produced image become closer closer desired output',
#  'slightest adaptation prompt transform imagery explored detailed finished product',
#  'like music art fashion design creative field become subject ai tech sector rapidly evolving line accelerating interest',
#  'expert field also currently exploring whether ai creative without human intervention look understand depth communication people machine',
#  'topic ai particularly gained traction late last year technology like chatgpt lensa ai midjourney began making round sparking debate around use ai creation',
#  'argue technology could perceived form copying potentially present range ethical issue including encouraging mass production others see new form creative outlet providing designer artist accessible tool evolve creation',
#  'similar discussion recently brought light nft space artist mason rothschild taken court hermès luxury brand accusing stealing design create digital asset made one million dollar sale',
#  'ultimately jury ruled favour french luxury brand determining rothschild indeed profited name',
#  'ruling eye expert set precedent similar case technology fashion could handled future drawing parallel ongoing ai discourse',
#  'technology evolves could advancement actually benefit industry moving forward',
#  'creatives ai opened door looking fresh way enter industry array online tool free paid allow almost anyone access technology',
#  'product heavily adopted public new breed artist designer redefining mean creator modern day',
#  'field skjellerup ai artist behind instagram account ai_clothingdaily exactly title profile say creating daily ai clothing',
#  'design realistic comment page filled people asking order piece',
#  'look range ai iteration nike shoe complete heavy embellishment intricate embroidery full runway outfit donned similarly artificial model',
#  'noted skjellerups first venture fashion world',
#  'creator also operates research platform marketplace luckynumber8 collect often sell vintage archival garment',
#  'closely link ai work draw inspiration past designer runway collection well material would like experiment',
#  'speaking fashionunited said process working ai way collaborative approach give input wait generative image respond accordingly',
#  'even initial idea outcome could totally different depending ai responds',
#  'really enjoy sense mystery surrounding tool',
#  'skjellerups eye ai important tool design belief technology doesnt take away artist instead enhances creative potential',
#  'added ability rapidly generate large group image make initial concept stage highly productive push idea beyond could become otherwise',
#  'would like see ai design tool democratisation design process',
#  'see role designer consumer blur one',
#  'fashion much top industry blurring role could lead exciting possibility',
#  'criticism format presently unavoidable individual within outside sector say constitutes design',
#  'also something skjellerup acutely aware however perception remains resilient',
#  'asked view possibility misconception surrounding topic said heard people within industry refer assisted creativity tool become accessible see become norm',
#  'feel like people either havent tried ai creative tool ready pas judgement scared possibility job loss within sector',
#  'think valid concern must remember job loss come people position power making decision tool',
#  'hesitancy surrounding ai place design become increasingly analysed recent study expert look investigate practical applicability ai creative design process',
#  'concept yoon kyung lee professor pusan national university korea explored study thinking skill creativity',
#  'carry research lee started generating textile design using ai software compared model work design student',
#  'result found design similar however distinct uniqueness originality seen humanmade design often derived person experience',
#  'lee note use ai repetitive task could improve efficiency process provide good learning tool lack expertise industry',
#  'professor proposed humanai collaborative work therefore effective instance particularly work link variety discipline beyond visual aspect gone begin developing process model applied',
#  'speaking report lee said future everybody able creator designer help ai model',
#  'far progressional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'lee deduced isnt clothing design ai serf purpose',
#  'retailer increasingly implementing technology ecommerce online marketing strategy taking advantage ability enhance customer experience possibly ensure sustainable production process',
#  'particularly popular among ongoing ecommerce evolution often applied retailer website provide accurate product recommendation data collection make search discovery efficient',
#  'surge company putting use technology order provide retailer solution look expand consumer experience',
#  'one perfect corp tech firm offer aipowered tryon experience ecommerce allowing consumer try product comfort home',
#  'feature enables fast analysis offer shopper customised product recommendation efficiently matching product consumer need heightening confidence purchase',
#  'speaking fashionunited alice chang ceo founder perfect corp noted benefit product stating fashion brand provide customer personalised shopping experience boost customer satisfaction decreasing product return',
#  'solution also enable sustainable business operation allowing brand reach esg goal decreasing excess waste emission generated product sampling return process',
#  'chang perspective implementing technology also crucial staying relevant today shopper increasingly leaning personalised digital advancement make purchasing decision',
#  'chang added advancement ai recent year greatly accelerated allowing brand transform consumer journey improving sale engagement customer loyalty',
#  'consumer shopping habit shifting happening across multiple channel retail space',
#  'look future ai grow play larger role across industry empowering consumer shop personalised interactive way',
#  'plan levi test virtual clothing model generated artificial intelligence drew swift backlash industry late last month',
#  'furor mainly focused diversity concern retailer proposal also stirred anxiety simmering industry year',
#  'critic levi strauss co partnership ai design firm lalalandai aimed show online shopper different type people wearing levi garment accused retailer looking inexpensively address issue representation potentially pushing professional model job process',
#  'hire model book agency stylist makeup feed set cost money said shawn grain carter professor fashion business management fashion institute technology new york',
#  'let make mistake levi save money',
#  'levi spokesperson referred statement companydenied intention save costswith project',
#  'retailer said ai model planned introduce would supplement replace photoshoots live model',
#  'lalaland didnt respond request comment',
#  'worry technology displacing human labor nothing new theyre far distinct fashion workforce',
#  'ai used fashion year worker watching expansion space growing alarm',
#  'yanii gough model founder yanii model work one hundred model said many still dying get back consistency industry reemerges pandemicrelated disruption',
#  'rise ai modeling firm client simply send email agency say hey exactly im looking someone find person said referring company book model everything photoshoots fitting',
#  'precedent concern like goughs',
#  'shudu created two thousand and seventeen thought world first digital supermodel booked gig within past year highend brand asbmwandlouis vuitton',
#  'shudu designed black woman alsodrew criticismtoward diigitals ai modeling agency created founder cameronjames wilson white',
#  'today option continue expand brand advertiser looking use ai help market sell clothes',
#  'addition lalaland there also deep agency new ai startup allows user create virtual photoshoot either synthetic model ai version real person',
#  'gough said also worry model image used without permission via ai concern sara ziff founder nonprofit advocacy group called model alliance said hearing well',
#  'fit model may replaced ai body scan said adding model try clothes designer manufacturer check sizing silhouette already calling organization growing number',
#  'ziff said complained company hiring conduct body scan form basis product development without knowledge receiving compensation',
#  'theyre able design clothes virtually using scan model body rather actually book model person said ziff declined provide example citing model alliance policy maintaining anonymous hotline industry worker flag complaint',
#  'fashion brand defended ai effort addons benefit shopper ai design studio agency working space similarly describe effort supplemental',
#  'lalalands founder example said created company sustainably increase representation fashion',
#  'agent management company book model type job ziff described dont legally tell body scan could used project without compensation said',
#  'ziff advocating proposed fashion worker act new york said would force agency fully disclose scope work pay',
#  'current law leaf gray area around model right organize union ziff added resulting limited labor protection',
#  'model considered independent contractor many face heightened risk sued retaliated agency',
#  'representative professional creative field like thewriters guild america power propose standard best practice ai use industry',
#  'meanwhile ai model become realistic already impossible many consumer distinguish image human',
#  'ashley france influencer criticized levi partnership lalaland said hope regulator step',
#  'way put psa somethings ad somethings dietary supplement thankfully something photoshopped feel like type regulation france said',
#  'sara ruberg associate producer nbc news',
#  'may human responsible design machine forecasting trend informing product decision',
#  'fact ai becoming integral part technology apparel industry substantiated growth annual spending predicted nearly quadruple two billion dollar two thousand and eighteen seventy-three billion dollar two thousand and twenty-two according juniper research',
#  'forecasting one example using artificial intelligence fashion industry',
#  'new technology helping retailer manage inventory using aipowered tool gauge demand',
#  'chatbots new fashion advisor offering two hundred and forty-seven connection customer help make purchasing decision',
#  'savvy ai algorithm help tailor product recommendation allow retailer create collection customer want buy',
#  'edited retail technology company based london produce realtime data analytics software give retailer access full market data touch button',
#  'platform help retailer brand trade faster let look entire global market right colour shape pattern used company wide ranging boohoo farfetch tommy hilfiger marni',
#  'geoff watt edited ceo stated ai helping retailer number way cut core retailer decide stock price fundamental part retail thats real ai benefit layer',
#  'data marketer keen tell u everything',
#  'ai quietly transforming fashion industry end consumer doesnt necessarily fathom online behaviour monitored recorded analysed',
#  'example hm us ai keep popular item wellstocked analysing receipt return gauge store need',
#  'marketing mode many brand analysing social medium data monitor fashion conversation allowing social data inform latest trend market prioritise segment interesting brand',
#  'one company makersights us data analytics combine factor search query social medium activity ecommerce sellthroughs consumer feedback provide clue likely become trend',
#  'data limit',
#  'data exceptionally useful detect rising trend hit mass adoption anticipate decline trend andrea bell head insight trend forecasting agency wgsn told vogue business',
#  'cant invent trend',
#  'good design come inspiration human touch still irreplaceable',
#  'photo courtesy edited']

# %%
website20 = 'https://www.just-style.com/news/signal-generative-ai-worth-risk-to-amplify-fashions-creative-process/?cf-view'
class20 = 'cell large-8 main-content'
text20 = scrape_clean(website20, class20)
sentences.extend(text20)
sentences
# Out:
# ['impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception',
#  'monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor',
#  'head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole',
#  'opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get',
#  'tool allowing people different background begin foothold industry',
#  'feel really new exciting said',
#  'brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste',
#  'many brand also using ai help design process image clothes generated typed prompt visualising different material pattern',
#  'allows designer make informed decision physically producing clothes',
#  'consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year',
#  'predicting future fashion trend creating virtual tryons using ai also predicted around corner',
#  'drinkwater working team look ai could change industry testing generative ai ability create clothing year',
#  'scraping website try get lot data could create dress forty thousand image',
#  'actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said',
#  'typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added',
#  'april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line',
#  'winner able collection physically manufactured sold online retailer revolve',
#  'industry ai come associated job redundancy critic argue creative artistry could wiped',
#  'foiret argues little fear',
#  'ai powerful tool amplifying creativity',
#  'people thinking job going reduce shouldnt think like',
#  'need get accustomed tool tool without person behind use said',
#  'sign tofashion statement',
#  'style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved',
#  'newsletter promotion',
#  'arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion',
#  'transparent ai help people afraid allows comfortable still feel control transformation mindset human important said',
#  'ai evolve technology either way need evolve alongside havent come terminator stage yet least',
#  'tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity',
#  'need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said',
#  'already seen performer uk image voice likeness reproduced ai technology without consent',
#  'cant afford become norm industry',
#  'thats urgently need fresh regulation protect worker creativity copyright',
#  'alexsandrah never really wanted model',
#  'first scouted thirteen young adult turned initial two opportunity',
#  'finally decided give go',
#  'got lose',
#  'see go told',
#  'full time industry londonbased model taking another chance career creating virtual aigenerated version',
#  'hope secure future modelling',
#  'ai version kind keep safe explains',
#  'benefit literally ai version im cut anything',
#  'proceeds proceeds made coming',
#  'dont travel dont airport run dont anything',
#  'give people opportunity also live life thing two place time add',
#  'alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai',
#  'nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four',
#  'quarter said already used creative design development',
#  'behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals',
#  'company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel',
#  'counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism',
#  'time created shudu created huge amount comment white person could create black virtual character cameron explains',
#  'happened really made think creating character ethical way implication future',
#  'online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears',
#  'trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say',
#  'protection job something group representing industry model makeup artist hairstylist want see',
#  'read story artificial intelligence',
#  'equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer',
#  'encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group',
#  'meanwhile british fashion model agent association urge caution growth ai',
#  'burying head sand ai coming industry need prepared adapt business model reflect say director john horner',
#  'perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model',
#  'anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism',
#  'levi backtracked said committed using ai technology equitably transparently',
#  'josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry',
#  'work done last year diversity representing woman men different body shape different size different look say',
#  'ai version model taking away',
#  'backwards move',
#  'going back using ideal standard model',
#  'real dress size',
#  'real skin',
#  'real beauty',
#  'think going damaging people modelling',
#  'there denying demand virtual model influencers growing',
#  'october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls',
#  'reportssuggest celebrity paid much 5m â396m likeness',
#  'brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson',
#  'one latest client charity down syndrome international',
#  'worked create world first virtual influencer down syndrome kami',
#  'along one hundred different woman down syndrome community explains',
#  'try create character looking ethical perspective',
#  'bring awareness space',
#  'impact space better',
#  'summary piece examines extensive influence ai fashion industry creative sector depth supply chain',
#  'highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain',
#  'insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm',
#  'artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem',
#  'brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization',
#  'generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation',
#  'fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact',
#  'ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic',
#  'hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement',
#  'importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda',
#  'artificial intelligence fashion industry',
#  'fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field',
#  'infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement',
#  'incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage',
#  'industry market forecast',
#  'market forecast predict ai fashion industry continue grow impressive rate',
#  'surge online shopping customized offering demand seamless customer experience driving expansion',
#  'according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty',
#  'influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint',
#  'leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice',
#  'issue fashion industry',
#  'however proliferation ai also raise several issue',
#  'ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer',
#  'addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand',
#  'sustainability another critical issue',
#  'although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process',
#  'brand tasked balancing innovation responsibility environment society',
#  'conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension',
#  'ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly',
#  'interested broader trend research within industry valuable resource found visiting official website global industry group market research firm',
#  'credible source fashion industry news analysis accessed thebusiness fashionwebsite',
#  'learn global market insight forecast consider visiting site renowned market research firm asgrand view research',
#  'embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight',
#  'jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design',
#  'work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology',
#  'lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training',
#  'expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application',
#  'new york city usa last week fashion world descended new york city new york fashion week nyfw',
#  'biannual event celebrated best industry showcased hottest trend season',
#  'nyfw massive money maker city fashion industry large',
#  'average event brings staggering 600m annually',
#  'regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future',
#  'behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness',
#  'body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement',
#  'yve edmond model based new york city',
#  'say new era aidriven modelling lot room exploitation',
#  'people industry body scanned photo collected year gone create virtual self yet ownership',
#  'claim edmond told al jazeera',
#  'shes worried could undermine work opportunity model near future',
#  'model image measurement posture body shape brand',
#  'many case somebody take ownership brand without knowledge without compensation',
#  'literally competing market edmond added',
#  'edmond among many model eager reform pushing fashion worker act new york state',
#  'among larger change would provide new safeguard would protect model client may try use image without permission',
#  'act would require model give clear written consent digital replica respective likeness',
#  'would also require client outline intend use image',
#  'mind behind legislation model alliance',
#  'introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight',
#  'misuse generative ai present new challenge allow go unregulated ziff model alliance said',
#  'bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan',
#  'model argue would also protect signing onto unfair contract alternative work',
#  'dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera',
#  'passed would statelevel law help set stage global push',
#  'use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool',
#  'yet reflected data',
#  'according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone',
#  'concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour',
#  'model like bovell fought inclusivity fashion voiced concern',
#  'youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said',
#  'might brand profiting marginalised identity community without actually pay bovell added',
#  'thats exactly happened levi strauss last year',
#  'brand launched partnership dutch company lalalandai allows customised aigenerated model',
#  'release company said',
#  'lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone',
#  'bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer',
#  'move met public backlash critic referred problematic racist',
#  'clothing company later updated statement',
#  'scaling back plan live photo shoot use live model commitment working diverse model',
#  'authentic storytelling always part weve connected fan human model collaborator core experience',
#  'company taking model picture completely',
#  'last year vogue brasil vogue singapore included aigenerated model respective cover place human model',
#  'company like deep agency created aigenerated model model clothes',
#  'danny postma made tool said post social medium platform known x help marketer social medium influencers',
#  'response thread substantial public backlash among applause',
#  'critic said concept deeply unethical undermined work model involved process like photographer',
#  'others accused company cash grab also referred move dystopian',
#  'one user called postma saying',
#  'im sure also strong proposal aid everyone whod lose job tech like succeeds right',
#  'everything alright long make cash',
#  'good solution brings even problem attempt solve',
#  'tool longer open beta testing',
#  'postma according linkedin profile experience fashion photography created string ai product',
#  'tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine',
#  'receive email shortly',
#  'please check download report',
#  'gold standard business intelligence',
#  'find',
#  'research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai',
#  'report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste',
#  'although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience',
#  'martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing',
#  'removing lot labourintensive drudge work giving people rewarding opportunity drive success business',
#  'emotional intelligence always human trait',
#  'replicated authentically machine improve strength trait backing evidence',
#  'year particular feel like ai come age technology powerful human judgement oversight important ever',
#  'according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three',
#  'ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted',
#  'global macro outlook job lead way period',
#  'certainly seeing ai growing prominence come apparel industry',
#  'amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed',
#  'receive email shortly',
#  'please check download report',
#  'chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty',
#  'era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge',
#  'captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective',
#  'ai transcended buzzword status become driving force marketing fashion lifestyle brand',
#  'fusion ai fashion isnt convenience creating meaningful connection',
#  'way ive found technology effective',
#  'aigenerated content one example help make difference reshape fashion lifestyle industry',
#  'many marketer already using ai content creation curation least looking',
#  'crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling',
#  'fusion art science resonates aesthetically driven audience save professional time effort',
#  'look like action',
#  'sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second',
#  'collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline',
#  'breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process',
#  'beyond personalization trendits consumer expectation',
#  'statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern',
#  'enables fashion brand offer hyperpersonalized recommendation predicting consumer want want',
#  'might wondering ai utilized offer personalized interaction turn help meet goal',
#  'option wideranging',
#  'externally brand employ virtual tryon technology consider smart personalized shopping feature',
#  'latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire',
#  'level personalization resonates deeply digitalsavvy audience making feel understood valued',
#  'internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric',
#  'help benchmark result use data inform future strategy confidence',
#  'today online landscape understanding audience paramount',
#  'segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest',
#  'foundation upon personalized campaign built help create content speaks directly target audience',
#  'way tailored content key successful personalization',
#  'whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact',
#  'ensuring successful transition requires quality data',
#  'data isnt buzzword cornerstone modern marketing fuel informed decision',
#  'fashion lifestyle industry datadriven decision help ensure brand stay relevant',
#  'data offer invaluable insight consumer preference shopping habit trend',
#  'brand make informed decision product development even marketing strategy',
#  'benchmarking competitor example strategic move best powered quality data',
#  'gathering prescriptive insight ensure data clean accurate free error',
#  'involves removing duplicate handling missing value correcting inconsistency',
#  'still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse',
#  'critical reflect company need getting started',
#  'considering new ai software important review current technological need real benefit holistic tool could bring',
#  'avoid wasted investment give idea current business capability',
#  'start pinpointing area department youre facing challenge inefficiency',
#  'sample management process leading financial loss impacting medium relationship',
#  'marketing team unable grasp strategic nuance new global market',
#  'inhouse pr team constantly missing important coverage piece',
#  'next evaluate volume limitation current data',
#  'complex offering',
#  'team handle high volume data difficult identify trend pull actionable insight',
#  'able make confident future prediction',
#  'ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast',
#  'next compare current resource ai potential return investment',
#  'review budget infrastructure determine whether resource align business need',
#  'analysis current challenge reveal return ai could bring brand',
#  'dig deep current pitfall establish whether ai drive cost saving growth process efficiency',
#  'youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut',
#  'review competition',
#  'fashion luxury landscape broad consumer demand trend vary across region',
#  'competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive',
#  'keep eye fellow brand ass leveraging ai',
#  'finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand',
#  'considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider',
#  'decisionmakers best placed understand implication investment ask right question',
#  'sharing challenge gap process upfront ensure tool implement fit purpose',
#  'ensure provider train team intricacy software early',
#  'way technology utilized full potential immediately team get best fully supported underpinned confident capable system',
#  'digitalsavvy consumer today demand product seek experience connection',
#  'many way ai personalization datadriven strategy become linchpin meet expectation',
#  'industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer',
#  'foster brand loyalty drive brand performance',
#  'effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era',
#  'forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify',
#  'cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint',
#  'however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development',
#  'challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission',
#  'achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation',
#  'fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet',
#  'hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market',
#  'besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai',
#  'technology could indeed transform various aspect supply chain design retail recyclingwaste management',
#  'today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity',
#  'however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology',
#  'technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability',
#  'digital fashion look like today',
#  'question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one',
#  'taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution',
#  'digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research',
#  'fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one',
#  'response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment',
#  'speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem',
#  'hype cooled two thousand and twenty-two critic quick slate web3 nonfungible token nfts metaverse dead marco marchesi chief technology officer fabricant belief industry still show sign life',
#  'technology take lot cycle new idea take adopted',
#  'reality completely figured yet going take lot cycle find steady ground say',
#  'educating audience technicality digital fashion bolster credibility',
#  'there assumption around craft digital fashion dont realize technically challenging practice digital artist stephy fung say',
#  'dani loftus founder digital fashion house draup also argues clunky earlystage technology prevented widespread adoption',
#  'lot people exposed digital fashion first time ever last year loftus say',
#  'youre making digital dress arm fall people going see confirmation bias',
#  'doesnt perform well people turn away',
#  'evolution gaming platform social hub business goldmine potentially biggest seismic shift brand reach audience today',
#  'gen z gen alpha come age unleash spending power brand longer rely outdated marketing tactic magazine campaign celebrity partnership attract eyeball',
#  'key consumer demographic residing gaming destination like fornite roblox early adopter reaping benefit translating identity robust presence space',
#  'gaming space sartorial space play philippa morgan chief content officer savant say',
#  'brand planting seed space reach audience',
#  'attract younger consumer youre going advertise parking lot youre going go kid play',
#  'today brand need willing fully engage new ecosystem shy away experimenting image play',
#  'year saw unprecedented boom generative ai technology potential still yet fully realized fashion',
#  'remains fundamental issue industry approach machine learning',
#  'brand dont get bandwagon product like ai theyll left dust marchesi say discussing brand reticence towards generative system',
#  'fashion slowly surely actively reshaped ai',
#  'september fashion week alone saw coperni collina strada ganni deploy burgeoning tech runway',
#  'question whether ai replace creative role like designer pattern cutter image maker remains hot topic',
#  'fung belief tech cant wont replace human touch',
#  'use ai might take role art director creative director ai cant replicate whats inside brain',
#  'curation come u say',
#  'beyond creative scope machine learning also assisting brand making much productive decision across supply chain efficiency environmental standpoint',
#  'sasha mcfarlane executive director future proof fashion highlight trend cycle moving record speed traditional manufacturing roadmaps cant keep rapid turnover consumer demand',
#  'generative ai disrupting process predicting trend customer behavior month advance helping supplier scale waste',
#  'size global augmented reality virtual reality market estimated thirty-eight billion two thousand and twenty-two projected hit around three hundred and seventy-two billion two thousand and thirty-two according toprecedence research',
#  'trailblazer zero10 fffaceme paving way augmented realitypowered experience retail',
#  'effort havent gone unnoticed',
#  'year brand including tiffany co tommy hilfiger coach jd sport tapped ar capture consumer eyeball',
#  'beyond novelness moin robertsislam technology development manager fashion innovation agency explains ar emerged premium tool collecting data driving consumer loyalty',
#  'speaking one initiative latest ar activation robertsislam note consumer expressed brand loyalty immersive experience',
#  'ninety percent audience said would pay product understood better valued',
#  'digital fashion landscape remains fertile ground emerging technology like ar ai web3 already process overturning industry',
#  'brand still turning blind eye potential run risk selfsabotage',
#  'even understanding basic soon indispensable tool loftus argues',
#  'learning use something like discord server absolutely monumental',
#  'valuable asset say',
#  'there use entering increasingly digitized world without authenticity',
#  'marchesi highlight longterm wellintentioned goal behind every digital activation',
#  'create revenue youre trying create revenue say',
#  'there use trying jump bandwagon reason reason solely making profit',
#  'two hundred fashion designer showcase digital collection designed help ai tool modelled avatar theworlds first ai fashion weekin new york thursday',
#  'twoday event hosted ai creative agency maison meta give three winner deal produce design condition physically manufactured',
#  'predictive tool slash material waste virtual fitting room ai increasingly used manufacturing retail fashion sector',
#  'ai reshaping industry people feel',
#  'sixty designer participating ai fashion week used texttoimage generator midjourney produce image based written prompt help design collection',
#  'explain texture length emotion specific better result said alena stepanova whose collection ai fashion week inspired colour landscape nature native kazakhstan',
#  'digital design allows see one item look different body shape told context',
#  'datadriven ai also used inform design predicting trend fashion giving insight consumer preferred colour style',
#  'american designer tommy hilfiger partnered hardware service company ibm fashion institute technology use ai todesign clothes based dataabout consumer trend',
#  'retail side ai used detect fake optimise pricing clothing resale site help shopper try clothes virtually even choose buy tool uniqlo store recommends product aftermeasuring shopper reaction clothing',
#  'consultancy mckinsey found company excel personalisation generate40 profitthan',
#  'aigenerated model also increasingly used editorial shoot vogue singapore online edition vogue brazil choosing useavatars coversof spring edition year',
#  'ai could add to275 billionto apparel fashion luxury sector operating profit according mckinsey report published march',
#  'ai model agency lalaland said using ai model is90 fasterthan photoshoots requires sample helping brand reduce waste well save time',
#  'ai help company predict inventory needed thus minimising overstocking also reduce return rate helping consumer find bettersuited product according holger harreis senior partner mckinsey',
#  'designer even hope move fashion industry online entirely cutting physical sample',
#  'digital fashion house fabricant creates sell fashion collection nonfungible token nfts kind digital asset often linked image piece artwork usually bought cryptocurrencies',
#  'say using digital sample instead physical garment design development phase clothing canreduce brand carbon footprint thirty',
#  'boom ai tool like chatgpt automate certain area work data entry customer service sparked fear thatrobots could poach job',
#  'use avatar place human model raising similar concern fashion industry makeup artist hair stylist photographer behindthescenes creatives could lose use ai model',
#  'new york city model manager greg chan said hard tell much work missed opportunity may completely bypass agency go straight ai',
#  'model losing job computer fact software able slightly change people skin colour slide switch said chan worry ai manipulate ethnicity reinforce unrealistic beauty standard',
#  'apparel company levi strauss announced march would partner ai model agency create personal inclusive shopping experience prompting online backlash critic said company hire real model promote diversity',
#  'company responded partnership would address business efficiency conflated diversity inclusion strategy',
#  'calvin wong head laboratory artificial intelligence design hong kong said ai used assistant rather something creates design maintain agency designer ensure creation manufacturable',
#  'lab hasdesigned ai toolthat allows designer upload draft sketch material colour palette generate design tweaked',
#  'need treasure originality inspiration fashion designer wong said',
#  'reporting beatrice tridimas editing zoe tabary',
#  'get top trend brand industry news fashion beauty wellness straight inbox daily',
#  'sign glossy daily newsletterhere',
#  'generative aiproduced picture imaginary nike collaborationsneakershave circled social medium week',
#  'thats one example ai used fashion us already valuable vast spanning marketing engineering immersive experience',
#  'ai stirred buzz last month thanks new increasingly userfriendly ai tool',
#  'last week march twenty image editor adobe firefly graphic design platform canva rolled new ai technologysupportingtexttovideo andbrand design respectively',
#  'specific launch prove ai usefulness forvisual content creation',
#  'thats start',
#  'industry expert predict ai tool allow quicker seamless workflow allowing worker across field including marketing operation engineering focus creative problemsolving task',
#  'one fastest moving potentially impactful trend see tech landscape today said roger robert partner consultancy mckinsey coauthor december two thousand and twenty-two generative ai herereport',
#  'hyperpersonalization',
#  'nextlevel personalization product experience consumer ecommerce site targeted ad instore experience among use case set benefit retailer',
#  'date personalization largely done microsegmentation grouping customer according interest age group location',
#  'youre going see lot automation want deliver hyperpersonalizationsaid brian long ceo personalized mobile messaging platform attentive',
#  'monday company announced attentive ai tool allowing brand create complete multichannel campaign using ai insight effective content fourteen trillion attentive data point',
#  'far major retail brand using tool beta reporting one hundred and forty-eight revenue increase',
#  'lot brand going generative imagemaking platform generate marketing image leverage product product catalog paired background foreground imagery based text prompt enter',
#  'theyre personalizing image setting lighting element said long',
#  'ai us database image paired text prompt select fitting setting element',
#  'case result productionready image send',
#  'case help figure theyre looking final shoot long said tool allows brand customize marketing imagery different geographical region almost cost',
#  'attentive ai develops copy campaign wellour biggest challenge always getting marketing copy completed timely manner said jason edward director ecommerce streetwear brand hat club',
#  'main surprise close final attentive ai allows u get copy step finalize',
#  'able significantly cut content creation time turn allow u build better campaign better segment customer',
#  'visual merchandising collection creation',
#  'ai could also solve problem visual merchandising',
#  'brand open store location need visual merchandising express brand identity globally also tailored context store',
#  'head visual merchandiser rarely lay every store brand fleet due cost time constraint',
#  'able train learning program based instinct intuition best virtual visual merchandiser using ai could bring voice style capability shop door season said robert',
#  'robert also noted creative application ai business',
#  'brand able use generative ai technology synthesize note sketch idea collection',
#  'ai combined operational financial perspective well merchandising marketing create collection price margin sustainable brand good customer',
#  'apart levi strauss co using ai show wider range diversemodelson website channelswere also using ai enhance differentiate loyalty program offering personalized benefit member helping u achieve meaningful growth enrollment revenue app registrationssaid dr amy gershkoff bolles global head digital emerging technology strategy levi strauss cofor example personalized benefit include localized discount based popular product area',
#  'since expanding loyalty program europe last year brand reached five million member worldwide',
#  'ai help u provide personalized product recommendation website mobile app based consumer data specific market said gershkoff bolles',
#  'also leveraging consumer mobility data customize store unique need interest local consumer open new store greatest demand',
#  'finally said ai powering levi promotion analyzing stock category product likely benefit sale',
#  'noted example including midseason endofseason sale well black friday sale u europe',
#  'web3 brand',
#  'web3 brand already implementing ai creative process',
#  'charli cohen founder 2yearold web3 brand rtlss said studio used generative ai speed coding development work allowing ai create code optimized workflow',
#  'also using create usergenerated content',
#  'progressively integrating ai year said cohenour next drop use ai gamify minting postmint experience',
#  'ugc toolkit currently building also include backend process like validating asset managing ip protection theyll automated enhanced ai',
#  'ai used analyzean nfts blockchain transaction history ensure nft original duplicate',
#  'itcan also analyze content nft art ensure original violate copyright law',
#  'one physical fashion brand active web3tommy hilfiger experimenting ai engage customer incocreation',
#  'specifically metaverse fashion week',
#  'giving consumer opportunity design item brand signature preppy style using generative ai',
#  'fashion show',
#  'even fashion show already undergone somewhat atransformation set undergo change due ai',
#  'matthew drinkwater head emerging technology company fashion innovation agency experimenting ai us catwalk since leading aifocused course london college fashion pandemic',
#  'student able showcase final work two thousand and twenty drinkwater worked fia using archival show footage skeletal data moving model create virtual runway show',
#  'project reimagined year include photorealistic model ai released march twenty-one via linkedin',
#  'earlier catwalk huge amount manual labor work involved said drinkwater',
#  'thats say wasnt case time specific skill set required deliver tool creating kind experience much manageable',
#  'thats especially availability ai tool like text prompttovideo ai platform runway ai launched week',
#  'video component going take next level engagement',
#  'image obviously cool video people stop look take time said long',
#  'runway project year fia used ai prompt tool midjourney stable diffusionthey took image luxury brand inspired trained ai model understand look applied look one particular male model create photorealistic video',
#  'drinkwater agreed robert human element even necessary within fashion experimentation creativity ai',
#  'however said new photorealistic opportunity help facilitate mass adoption digital fashion',
#  'note ai faster implement metaverse',
#  'metaverse combination many thing come together right way create really great experience',
#  'thats case ai said robert explaining current software add feature make better',
#  'doesnt require everyone show headset create entirely new platform',
#  'thats shorter hype cycle everyone talking ai people using cforelevant impact',
#  'company aiming cut cost due recessionrelated concern ai use could leveraged cut labor cost',
#  'bottomline impact suggests something need top mind ctos cfo',
#  'many case replace repetitive part human work allowing staff carry project quickly replacement',
#  'drinkwater added combination thing put together like use machine learning artificial intelligence immersive experience start deliver nextgeneration immersive experience',
#  'image courtesy christiane lemieux',
#  'study titledhow complex system get engaged fashion design creation using artificial intelligence published journalthinking skill creativityaimed investigate practical applicability ai model implement creative fashion design work human designer',
#  'thank',
#  'gold standard business intelligence',
#  'find',
#  'download email arrive shortlywhile wait take look free recommend buyer guide',
#  'research note use ai fashion industry grown significantly recent year',
#  'example already used personalise fashion recommendation customer optimise supply chain management automate process improve sustainability reduce waste',
#  'however creative process fashion design continue human driven little research use ai fashion design designer often included research',
#  'assistant professor lead author study yoon kyung lee keen find could effective collaboration human ai purpose creative design explained time ai deeply ingrained life study started instead considering human better ai',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'study started generating new textile design using deep convolution generative adversarial network dcgans cyclegans',
#  'output model compared similar design produced design student',
#  'comparison revealed design produced similar biggest difference uniqueness originality seen human design came person experience',
#  'however use ai repetitive task could improve efficiency designer free time focus highdifficult creative work',
#  'research also suggests aigenerated design could used learning tool people lack expertise fashion want explore creativity ai could assist creating design',
#  'following study finding professor lee proposing humanai collaborative network integrates gans human creativity produce design',
#  'professor lee also defined studied various element complex system involved humanai collaborated design established humanai model designer collaborates ai create novel design idea',
#  'model allows designer share creative process idea others system interconnect evolve improve design',
#  'professor lee belief fashion industry leverage foresee change fashion industry offer recommendation cocreation service',
#  'setting xobjectives variable limit part designer job humanai collaborative design environment suggests work go beyond visual aspect instead cover variety discipline',
#  'concludes future everybody able creator designer help ai model',
#  'far professional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'download email arrive shortly',
#  'wait take look free recommend buyer guide',
#  'give business edge leading industry insight',
#  'ai fashion industry',
#  'long human started wear clothes wed desire express individuality one way achieve fashionthe fashion industry one biggest world estimated three trillion dollar two thousand and eighteen representing two percent global gdp',
#  'much brickandmortar traditional retail well online ecommerce dedicated sale clothing fashion item',
#  'much amazon acquired shoe retailer zappos one billion two thousand and ten major retailer walmart target amazon others entered fashion retail business brand brand partnership',
#  'despite established nature fashion industry ai fundamentally transforming industry way fashion company manufacture product way marketed sold',
#  'ai technology transforming fashion industry every element value chain designing manufacturing logistics marketing sale',
#  'ai helping promote sell fashion good',
#  'fashion industry much creating demand brand awareness manufacturing fashion product',
#  'clothing apparel brand constantly looking new way get good front buyer create awareness demand market',
#  'increasinglyfashion brand using ai machine learningto maximize user shopping experience improve efficiency sale system intelligent automation enhance sale process using predictive analytics guided sale process',
# ...
#  'like music art fashion design creative field become subject ai tech sector rapidly evolving line accelerating interest',
#  'expert field also currently exploring whether ai creative without human intervention look understand depth communication people machine',
#  'topic ai particularly gained traction late last year technology like chatgpt lensa ai midjourney began making round sparking debate around use ai creation',
#  'argue technology could perceived form copying potentially present range ethical issue including encouraging mass production others see new form creative outlet providing designer artist accessible tool evolve creation',
#  'similar discussion recently brought light nft space artist mason rothschild taken court hermès luxury brand accusing stealing design create digital asset made one million dollar sale',
#  'ultimately jury ruled favour french luxury brand determining rothschild indeed profited name',
#  'ruling eye expert set precedent similar case technology fashion could handled future drawing parallel ongoing ai discourse',
#  'technology evolves could advancement actually benefit industry moving forward',
#  'creatives ai opened door looking fresh way enter industry array online tool free paid allow almost anyone access technology',
#  'product heavily adopted public new breed artist designer redefining mean creator modern day',
#  'field skjellerup ai artist behind instagram account ai_clothingdaily exactly title profile say creating daily ai clothing',
#  'design realistic comment page filled people asking order piece',
#  'look range ai iteration nike shoe complete heavy embellishment intricate embroidery full runway outfit donned similarly artificial model',
#  'noted skjellerups first venture fashion world',
#  'creator also operates research platform marketplace luckynumber8 collect often sell vintage archival garment',
#  'closely link ai work draw inspiration past designer runway collection well material would like experiment',
#  'speaking fashionunited said process working ai way collaborative approach give input wait generative image respond accordingly',
#  'even initial idea outcome could totally different depending ai responds',
#  'really enjoy sense mystery surrounding tool',
#  'skjellerups eye ai important tool design belief technology doesnt take away artist instead enhances creative potential',
#  'added ability rapidly generate large group image make initial concept stage highly productive push idea beyond could become otherwise',
#  'would like see ai design tool democratisation design process',
#  'see role designer consumer blur one',
#  'fashion much top industry blurring role could lead exciting possibility',
#  'criticism format presently unavoidable individual within outside sector say constitutes design',
#  'also something skjellerup acutely aware however perception remains resilient',
#  'asked view possibility misconception surrounding topic said heard people within industry refer assisted creativity tool become accessible see become norm',
#  'feel like people either havent tried ai creative tool ready pas judgement scared possibility job loss within sector',
#  'think valid concern must remember job loss come people position power making decision tool',
#  'hesitancy surrounding ai place design become increasingly analysed recent study expert look investigate practical applicability ai creative design process',
#  'concept yoon kyung lee professor pusan national university korea explored study thinking skill creativity',
#  'carry research lee started generating textile design using ai software compared model work design student',
#  'result found design similar however distinct uniqueness originality seen humanmade design often derived person experience',
#  'lee note use ai repetitive task could improve efficiency process provide good learning tool lack expertise industry',
#  'professor proposed humanai collaborative work therefore effective instance particularly work link variety discipline beyond visual aspect gone begin developing process model applied',
#  'speaking report lee said future everybody able creator designer help ai model',
#  'far progressional fashion designer able design showcase clothes',
#  'future possible anyone design clothes want showcase creativity',
#  'lee deduced isnt clothing design ai serf purpose',
#  'retailer increasingly implementing technology ecommerce online marketing strategy taking advantage ability enhance customer experience possibly ensure sustainable production process',
#  'particularly popular among ongoing ecommerce evolution often applied retailer website provide accurate product recommendation data collection make search discovery efficient',
#  'surge company putting use technology order provide retailer solution look expand consumer experience',
#  'one perfect corp tech firm offer aipowered tryon experience ecommerce allowing consumer try product comfort home',
#  'feature enables fast analysis offer shopper customised product recommendation efficiently matching product consumer need heightening confidence purchase',
#  'speaking fashionunited alice chang ceo founder perfect corp noted benefit product stating fashion brand provide customer personalised shopping experience boost customer satisfaction decreasing product return',
#  'solution also enable sustainable business operation allowing brand reach esg goal decreasing excess waste emission generated product sampling return process',
#  'chang perspective implementing technology also crucial staying relevant today shopper increasingly leaning personalised digital advancement make purchasing decision',
#  'chang added advancement ai recent year greatly accelerated allowing brand transform consumer journey improving sale engagement customer loyalty',
#  'consumer shopping habit shifting happening across multiple channel retail space',
#  'look future ai grow play larger role across industry empowering consumer shop personalised interactive way',
#  'plan levi test virtual clothing model generated artificial intelligence drew swift backlash industry late last month',
#  'furor mainly focused diversity concern retailer proposal also stirred anxiety simmering industry year',
#  'critic levi strauss co partnership ai design firm lalalandai aimed show online shopper different type people wearing levi garment accused retailer looking inexpensively address issue representation potentially pushing professional model job process',
#  'hire model book agency stylist makeup feed set cost money said shawn grain carter professor fashion business management fashion institute technology new york',
#  'let make mistake levi save money',
#  'levi spokesperson referred statement companydenied intention save costswith project',
#  'retailer said ai model planned introduce would supplement replace photoshoots live model',
#  'lalaland didnt respond request comment',
#  'worry technology displacing human labor nothing new theyre far distinct fashion workforce',
#  'ai used fashion year worker watching expansion space growing alarm',
#  'yanii gough model founder yanii model work one hundred model said many still dying get back consistency industry reemerges pandemicrelated disruption',
#  'rise ai modeling firm client simply send email agency say hey exactly im looking someone find person said referring company book model everything photoshoots fitting',
#  'precedent concern like goughs',
#  'shudu created two thousand and seventeen thought world first digital supermodel booked gig within past year highend brand asbmwandlouis vuitton',
#  'shudu designed black woman alsodrew criticismtoward diigitals ai modeling agency created founder cameronjames wilson white',
#  'today option continue expand brand advertiser looking use ai help market sell clothes',
#  'addition lalaland there also deep agency new ai startup allows user create virtual photoshoot either synthetic model ai version real person',
#  'gough said also worry model image used without permission via ai concern sara ziff founder nonprofit advocacy group called model alliance said hearing well',
#  'fit model may replaced ai body scan said adding model try clothes designer manufacturer check sizing silhouette already calling organization growing number',
#  'ziff said complained company hiring conduct body scan form basis product development without knowledge receiving compensation',
#  'theyre able design clothes virtually using scan model body rather actually book model person said ziff declined provide example citing model alliance policy maintaining anonymous hotline industry worker flag complaint',
#  'fashion brand defended ai effort addons benefit shopper ai design studio agency working space similarly describe effort supplemental',
#  'lalalands founder example said created company sustainably increase representation fashion',
#  'agent management company book model type job ziff described dont legally tell body scan could used project without compensation said',
#  'ziff advocating proposed fashion worker act new york said would force agency fully disclose scope work pay',
#  'current law leaf gray area around model right organize union ziff added resulting limited labor protection',
#  'model considered independent contractor many face heightened risk sued retaliated agency',
#  'representative professional creative field like thewriters guild america power propose standard best practice ai use industry',
#  'meanwhile ai model become realistic already impossible many consumer distinguish image human',
#  'ashley france influencer criticized levi partnership lalaland said hope regulator step',
#  'way put psa somethings ad somethings dietary supplement thankfully something photoshopped feel like type regulation france said',
#  'sara ruberg associate producer nbc news',
#  'may human responsible design machine forecasting trend informing product decision',
#  'fact ai becoming integral part technology apparel industry substantiated growth annual spending predicted nearly quadruple two billion dollar two thousand and eighteen seventy-three billion dollar two thousand and twenty-two according juniper research',
#  'forecasting one example using artificial intelligence fashion industry',
#  'new technology helping retailer manage inventory using aipowered tool gauge demand',
#  'chatbots new fashion advisor offering two hundred and forty-seven connection customer help make purchasing decision',
#  'savvy ai algorithm help tailor product recommendation allow retailer create collection customer want buy',
#  'edited retail technology company based london produce realtime data analytics software give retailer access full market data touch button',
#  'platform help retailer brand trade faster let look entire global market right colour shape pattern used company wide ranging boohoo farfetch tommy hilfiger marni',
#  'geoff watt edited ceo stated ai helping retailer number way cut core retailer decide stock price fundamental part retail thats real ai benefit layer',
#  'data marketer keen tell u everything',
#  'ai quietly transforming fashion industry end consumer doesnt necessarily fathom online behaviour monitored recorded analysed',
#  'example hm us ai keep popular item wellstocked analysing receipt return gauge store need',
#  'marketing mode many brand analysing social medium data monitor fashion conversation allowing social data inform latest trend market prioritise segment interesting brand',
#  'one company makersights us data analytics combine factor search query social medium activity ecommerce sellthroughs consumer feedback provide clue likely become trend',
#  'data limit',
#  'data exceptionally useful detect rising trend hit mass adoption anticipate decline trend andrea bell head insight trend forecasting agency wgsn told vogue business',
#  'cant invent trend',
#  'good design come inspiration human touch still irreplaceable',
#  'photo courtesy edited',
#  'two thousand and twenty-three breakout year generative ai use case emerging across fashion sector potential augment accelerate automate fashion business capability writing code amplifying creative process',
#  'according tomckinsey co latest report overall financial impact gen ai fashion industry significant much quarter value expected driven use case design product development stage value chain',
#  'gold standard business intelligence',
#  'find',
#  'business fashionmckinseystate fashion two thousand and twenty-four survey global fashion executive found seventy-three fashion executive said generative ai priority business two thousand and twenty-four le third twenty-eight tried using creative process design product development',
#  'mckinsey suggests highlight fashion company yet capturing value creative process',
#  'report read caution understandable',
#  'technology could impact job workflow',
#  'fashion industry also seen fair share technologicalenthusiasm swiftly sputtered notably metaverse',
#  'last year started much enthusiasm metaverse since died however mckinseys report suggests generative ai practical application making attractive business investor',
#  'access comprehensive company profile market powered globaldata',
#  'save hour research',
#  'gain competitive edge',
#  'download email arrive shortly',
#  'confident unique quality company profile',
#  'however want make beneficial decision business offer free sample download submitting form',
#  'example equity funding generative aifocused startup skyrocketed reaching 141bn first half two thousand and twenty-three alone compared 25bn two thousand and twenty-two',
#  'fashion sector focus generative ai far oneoff use case cost efficiency customer experience advantage',
#  'technology also offer potential wider industry disruption',
#  'ai already making mark online shopping assistance online retailerzalandoannouncing launch beta chatgptbased natural languagepowered shopping assistant earlier year allows online customer ask question get answer well customised product recommendation',
#  'u fashion conglomeratekeringand online marketplaceshopifyhave also introduced ai chatbots brand adore methe lingeriecompany recently acquired victoria secret using technology write product description site',
#  'report add ultimately greatest value may lie using gen ai endtoend way enables enhances creativity',
#  'example fast fashion gen ai could accelerate design process inject agility trend detection product development leverage analytics data rapidly produce large number new design',
#  'spanish brand desigual already launched ondemand collection designed using ai tool',
#  'company developing generative ai software fashion sector claim technology reduce manual task take day mere hour even second',
#  'new technology could free designer manual task allowing focus creative work',
#  'human designer remain key generative ai enable role oriented around curation according report',
#  'however report also note word caution potential must communicated clearly creatives ensure technology adopted without undermining role designer',
#  'continues implemented effectively technology benefit amplify creative process thus augmenting human capability retaining artistic skill knowledge designer',
#  'ultimately say expert humancentred innovation likely important use ai',
#  'source globaldata',
#  'globaldatas job database suggests last three year december two thousand and twenty december two thousand and twenty-three interest employing individual generative ai grown',
#  'online giantamazonis leading way five hundred and thirty-seven job posted time period followed u supermarket retailerwalmartwith thirty-eight job posted',
#  'company exploring generative ai role according globaldata include luxury u fashion conglomeratetapestryand u fashion brandabercrombie fitch',
#  'signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company',
#  'signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed']

# %%
for i in sentences:
  print(f'{i}\n')
# Out:
# impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception
#
# monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor
#
# head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole
#
# opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get
#
# tool allowing people different background begin foothold industry
#
# feel really new exciting said
#
# brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste
#
# many brand also using ai help design process image clothes generated typed prompt visualising different material pattern
#
# allows designer make informed decision physically producing clothes
#
# consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year
#
# predicting future fashion trend creating virtual tryons using ai also predicted around corner
#
# drinkwater working team look ai could change industry testing generative ai ability create clothing year
#
# scraping website try get lot data could create dress forty thousand image
#
# actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said
#
# typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added
#
# april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line
#
# winner able collection physically manufactured sold online retailer revolve
#
# industry ai come associated job redundancy critic argue creative artistry could wiped
#
# foiret argues little fear
#
# ai powerful tool amplifying creativity
#
# people thinking job going reduce shouldnt think like
#
# need get accustomed tool tool without person behind use said
#
# sign tofashion statement
#
# style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved
#
# newsletter promotion
#
# arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion
#
# transparent ai help people afraid allows comfortable still feel control transformation mindset human important said
#
# ai evolve technology either way need evolve alongside havent come terminator stage yet least
#
# tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity
#
# need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said
#
# already seen performer uk image voice likeness reproduced ai technology without consent
#
# cant afford become norm industry
#
# thats urgently need fresh regulation protect worker creativity copyright
#
# alexsandrah never really wanted model
#
# first scouted thirteen young adult turned initial two opportunity
#
# finally decided give go
#
# got lose
#
# see go told
#
# full time industry londonbased model taking another chance career creating virtual aigenerated version
#
# hope secure future modelling
#
# ai version kind keep safe explains
#
# benefit literally ai version im cut anything
#
# proceeds proceeds made coming
#
# dont travel dont airport run dont anything
#
# give people opportunity also live life thing two place time add
#
# alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai
#
# nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four
#
# quarter said already used creative design development
#
# behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals
#
# company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel
#
# counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism
#
# time created shudu created huge amount comment white person could create black virtual character cameron explains
#
# happened really made think creating character ethical way implication future
#
# online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears
#
# trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say
#
# protection job something group representing industry model makeup artist hairstylist want see
#
# read story artificial intelligence
#
# equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer
#
# encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group
#
# meanwhile british fashion model agent association urge caution growth ai
#
# burying head sand ai coming industry need prepared adapt business model reflect say director john horner
#
# perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model
#
# anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism
#
# levi backtracked said committed using ai technology equitably transparently
#
# josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry
#
# work done last year diversity representing woman men different body shape different size different look say
#
# ai version model taking away
#
# backwards move
#
# going back using ideal standard model
#
# real dress size
#
# real skin
#
# real beauty
#
# think going damaging people modelling
#
# there denying demand virtual model influencers growing
#
# october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls
#
# reportssuggest celebrity paid much 5m â396m likeness
#
# brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson
#
# one latest client charity down syndrome international
#
# worked create world first virtual influencer down syndrome kami
#
# along one hundred different woman down syndrome community explains
#
# try create character looking ethical perspective
#
# bring awareness space
#
# impact space better
#
# summary piece examines extensive influence ai fashion industry creative sector depth supply chain
#
# highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain
#
# insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm
#
# artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem
#
# brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization
#
# generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation
#
# fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact
#
# ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic
#
# hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement
#
# importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda
#
# artificial intelligence fashion industry
#
# fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field
#
# infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement
#
# incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage
#
# industry market forecast
#
# market forecast predict ai fashion industry continue grow impressive rate
#
# surge online shopping customized offering demand seamless customer experience driving expansion
#
# according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty
#
# influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint
#
# leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice
#
# issue fashion industry
#
# however proliferation ai also raise several issue
#
# ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer
#
# addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand
#
# sustainability another critical issue
#
# although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process
#
# brand tasked balancing innovation responsibility environment society
#
# conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension
#
# ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly
#
# interested broader trend research within industry valuable resource found visiting official website global industry group market research firm
#
# credible source fashion industry news analysis accessed thebusiness fashionwebsite
#
# learn global market insight forecast consider visiting site renowned market research firm asgrand view research
#
# embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight
#
# jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design
#
# work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology
#
# lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training
#
# expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application
#
# new york city usa last week fashion world descended new york city new york fashion week nyfw
#
# biannual event celebrated best industry showcased hottest trend season
#
# nyfw massive money maker city fashion industry large
#
# average event brings staggering 600m annually
#
# regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future
#
# behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness
#
# body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement
#
# yve edmond model based new york city
#
# say new era aidriven modelling lot room exploitation
#
# people industry body scanned photo collected year gone create virtual self yet ownership
#
# claim edmond told al jazeera
#
# shes worried could undermine work opportunity model near future
#
# model image measurement posture body shape brand
#
# many case somebody take ownership brand without knowledge without compensation
#
# literally competing market edmond added
#
# edmond among many model eager reform pushing fashion worker act new york state
#
# among larger change would provide new safeguard would protect model client may try use image without permission
#
# act would require model give clear written consent digital replica respective likeness
#
# would also require client outline intend use image
#
# mind behind legislation model alliance
#
# introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight
#
# misuse generative ai present new challenge allow go unregulated ziff model alliance said
#
# bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan
#
# model argue would also protect signing onto unfair contract alternative work
#
# dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera
#
# passed would statelevel law help set stage global push
#
# use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool
#
# yet reflected data
#
# according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone
#
# concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour
#
# model like bovell fought inclusivity fashion voiced concern
#
# youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said
#
# might brand profiting marginalised identity community without actually pay bovell added
#
# thats exactly happened levi strauss last year
#
# brand launched partnership dutch company lalalandai allows customised aigenerated model
#
# release company said
#
# lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone
#
# bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer
#
# move met public backlash critic referred problematic racist
#
# clothing company later updated statement
#
# scaling back plan live photo shoot use live model commitment working diverse model
#
# authentic storytelling always part weve connected fan human model collaborator core experience
#
# company taking model picture completely
#
# last year vogue brasil vogue singapore included aigenerated model respective cover place human model
#
# company like deep agency created aigenerated model model clothes
#
# danny postma made tool said post social medium platform known x help marketer social medium influencers
#
# response thread substantial public backlash among applause
#
# critic said concept deeply unethical undermined work model involved process like photographer
#
# others accused company cash grab also referred move dystopian
#
# one user called postma saying
#
# im sure also strong proposal aid everyone whod lose job tech like succeeds right
#
# everything alright long make cash
#
# good solution brings even problem attempt solve
#
# tool longer open beta testing
#
# postma according linkedin profile experience fashion photography created string ai product
#
# tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine
#
# receive email shortly
#
# please check download report
#
# gold standard business intelligence
#
# find
#
# research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai
#
# report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste
#
# although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience
#
# martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role
#
# access comprehensive company profile market powered globaldata
#
# save hour research
#
# gain competitive edge
#
# download email arrive shortly
#
# confident unique quality company profile
#
# however want make beneficial decision business offer free sample download submitting form
#
# martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing
#
# removing lot labourintensive drudge work giving people rewarding opportunity drive success business
#
# emotional intelligence always human trait
#
# replicated authentically machine improve strength trait backing evidence
#
# year particular feel like ai come age technology powerful human judgement oversight important ever
#
# according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three
#
# ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted
#
# global macro outlook job lead way period
#
# certainly seeing ai growing prominence come apparel industry
#
# amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control
#
# signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company
#
# signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed
#
# receive email shortly
#
# please check download report
#
# chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty
#
# era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge
#
# captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective
#
# ai transcended buzzword status become driving force marketing fashion lifestyle brand
#
# fusion ai fashion isnt convenience creating meaningful connection
#
# way ive found technology effective
#
# aigenerated content one example help make difference reshape fashion lifestyle industry
#
# many marketer already using ai content creation curation least looking
#
# crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling
#
# fusion art science resonates aesthetically driven audience save professional time effort
#
# look like action
#
# sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second
#
# collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline
#
# breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process
#
# beyond personalization trendits consumer expectation
#
# statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern
#
# enables fashion brand offer hyperpersonalized recommendation predicting consumer want want
#
# might wondering ai utilized offer personalized interaction turn help meet goal
#
# option wideranging
#
# externally brand employ virtual tryon technology consider smart personalized shopping feature
#
# latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire
#
# level personalization resonates deeply digitalsavvy audience making feel understood valued
#
# internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric
#
# help benchmark result use data inform future strategy confidence
#
# today online landscape understanding audience paramount
#
# segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest
#
# foundation upon personalized campaign built help create content speaks directly target audience
#
# way tailored content key successful personalization
#
# whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact
#
# ensuring successful transition requires quality data
#
# data isnt buzzword cornerstone modern marketing fuel informed decision
#
# fashion lifestyle industry datadriven decision help ensure brand stay relevant
#
# data offer invaluable insight consumer preference shopping habit trend
#
# brand make informed decision product development even marketing strategy
#
# benchmarking competitor example strategic move best powered quality data
#
# gathering prescriptive insight ensure data clean accurate free error
#
# involves removing duplicate handling missing value correcting inconsistency
#
# still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse
#
# critical reflect company need getting started
#
# considering new ai software important review current technological need real benefit holistic tool could bring
#
# avoid wasted investment give idea current business capability
#
# start pinpointing area department youre facing challenge inefficiency
#
# sample management process leading financial loss impacting medium relationship
#
# marketing team unable grasp strategic nuance new global market
#
# inhouse pr team constantly missing important coverage piece
#
# next evaluate volume limitation current data
#
# complex offering
#
# team handle high volume data difficult identify trend pull actionable insight
#
# able make confident future prediction
#
# ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast
#
# next compare current resource ai potential return investment
#
# review budget infrastructure determine whether resource align business need
#
# analysis current challenge reveal return ai could bring brand
#
# dig deep current pitfall establish whether ai drive cost saving growth process efficiency
#
# youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut
#
# review competition
#
# fashion luxury landscape broad consumer demand trend vary across region
#
# competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive
#
# keep eye fellow brand ass leveraging ai
#
# finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand
#
# considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider
#
# decisionmakers best placed understand implication investment ask right question
#
# sharing challenge gap process upfront ensure tool implement fit purpose
#
# ensure provider train team intricacy software early
#
# way technology utilized full potential immediately team get best fully supported underpinned confident capable system
#
# digitalsavvy consumer today demand product seek experience connection
#
# many way ai personalization datadriven strategy become linchpin meet expectation
#
# industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer
#
# foster brand loyalty drive brand performance
#
# effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era
#
# forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify
#
# cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint
#
# however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development
#
# challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission
#
# achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation
#
# fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet
#
# hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market
#
# besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai
#
# technology could indeed transform various aspect supply chain design retail recyclingwaste management
#
# today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity
#
# however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology
#
# technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability
#
# digital fashion look like today
#
# question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one
#
# taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution
#
# digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research
#
# fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one
#
# response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment
#
# speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem
#
# hype cooled two thousand and twenty-two critic quick slate web3 nonfungible token nfts metaverse dead marco marchesi chief technology officer fabricant belief industry still show sign life
#
# technology take lot cycle new idea take adopted
#
# reality completely figured yet going take lot cycle find steady ground say
#
# educating audience technicality digital fashion bolster credibility
#
# there assumption around craft digital fashion dont realize technically challenging practice digital artist stephy fung say
#
# dani loftus founder digital fashion house draup also argues clunky earlystage technology prevented widespread adoption
#
# lot people exposed digital fashion first time ever last year loftus say
#
# youre making digital dress arm fall people going see confirmation bias
#
# doesnt perform well people turn away
#
# evolution gaming platform social hub business goldmine potentially biggest seismic shift brand reach audience today
#
# gen z gen alpha come age unleash spending power brand longer rely outdated marketing tactic magazine campaign celebrity partnership attract eyeball
#
# key consumer demographic residing gaming destination like fornite roblox early adopter reaping benefit translating identity robust presence space
#
# gaming space sartorial space play philippa morgan chief content officer savant say
#
# brand planting seed space reach audience
#
# attract younger consumer youre going advertise parking lot youre going go kid play
#
# today brand need willing fully engage new ecosystem shy away experimenting image play
#
# year saw unprecedented boom generative ai technology potential still yet fully realized fashion
#
# remains fundamental issue industry approach machine learning
#
# brand dont get bandwagon product like ai theyll left dust marchesi say discussing brand reticence towards generative system
#
# fashion slowly surely actively reshaped ai
#
# september fashion week alone saw coperni collina strada ganni deploy burgeoning tech runway
#
# question whether ai replace creative role like designer pattern cutter image maker remains hot topic
#
# fung belief tech cant wont replace human touch
#
# use ai might take role art director creative director ai cant replicate whats inside brain
#
# curation come u say
#
# beyond creative scope machine learning also assisting brand making much productive decision across supply chain efficiency environmental standpoint
#
# sasha mcfarlane executive director future proof fashion highlight trend cycle moving record speed traditional manufacturing roadmaps cant keep rapid turnover consumer demand
#
# generative ai disrupting process predicting trend customer behavior month advance helping supplier scale waste
#
# size global augmented reality virtual reality market estimated thirty-eight billion two thousand and twenty-two projected hit around three hundred and seventy-two billion two thousand and thirty-two according toprecedence research
#
# trailblazer zero10 fffaceme paving way augmented realitypowered experience retail
#
# effort havent gone unnoticed
#
# year brand including tiffany co tommy hilfiger coach jd sport tapped ar capture consumer eyeball
#
# beyond novelness moin robertsislam technology development manager fashion innovation agency explains ar emerged premium tool collecting data driving consumer loyalty
#
# speaking one initiative latest ar activation robertsislam note consumer expressed brand loyalty immersive experience
#
# ninety percent audience said would pay product understood better valued
#
# digital fashion landscape remains fertile ground emerging technology like ar ai web3 already process overturning industry
#
# brand still turning blind eye potential run risk selfsabotage
#
# even understanding basic soon indispensable tool loftus argues
#
# learning use something like discord server absolutely monumental
#
# valuable asset say
#
# there use entering increasingly digitized world without authenticity
#
# marchesi highlight longterm wellintentioned goal behind every digital activation
#
# create revenue youre trying create revenue say
#
# there use trying jump bandwagon reason reason solely making profit
#
# two hundred fashion designer showcase digital collection designed help ai tool modelled avatar theworlds first ai fashion weekin new york thursday
#
# twoday event hosted ai creative agency maison meta give three winner deal produce design condition physically manufactured
#
# predictive tool slash material waste virtual fitting room ai increasingly used manufacturing retail fashion sector
#
# ai reshaping industry people feel
#
# sixty designer participating ai fashion week used texttoimage generator midjourney produce image based written prompt help design collection
#
# explain texture length emotion specific better result said alena stepanova whose collection ai fashion week inspired colour landscape nature native kazakhstan
#
# digital design allows see one item look different body shape told context
#
# datadriven ai also used inform design predicting trend fashion giving insight consumer preferred colour style
#
# american designer tommy hilfiger partnered hardware service company ibm fashion institute technology use ai todesign clothes based dataabout consumer trend
#
# retail side ai used detect fake optimise pricing clothing resale site help shopper try clothes virtually even choose buy tool uniqlo store recommends product aftermeasuring shopper reaction clothing
#
# consultancy mckinsey found company excel personalisation generate40 profitthan
#
# aigenerated model also increasingly used editorial shoot vogue singapore online edition vogue brazil choosing useavatars coversof spring edition year
#
# ai could add to275 billionto apparel fashion luxury sector operating profit according mckinsey report published march
#
# ai model agency lalaland said using ai model is90 fasterthan photoshoots requires sample helping brand reduce waste well save time
#
# ai help company predict inventory needed thus minimising overstocking also reduce return rate helping consumer find bettersuited product according holger harreis senior partner mckinsey
#
# designer even hope move fashion industry online entirely cutting physical sample
#
# digital fashion house fabricant creates sell fashion collection nonfungible token nfts kind digital asset often linked image piece artwork usually bought cryptocurrencies
#
# say using digital sample instead physical garment design development phase clothing canreduce brand carbon footprint thirty
#
# boom ai tool like chatgpt automate certain area work data entry customer service sparked fear thatrobots could poach job
#
# use avatar place human model raising similar concern fashion industry makeup artist hair stylist photographer behindthescenes creatives could lose use ai model
#
# new york city model manager greg chan said hard tell much work missed opportunity may completely bypass agency go straight ai
#
# model losing job computer fact software able slightly change people skin colour slide switch said chan worry ai manipulate ethnicity reinforce unrealistic beauty standard
#
# apparel company levi strauss announced march would partner ai model agency create personal inclusive shopping experience prompting online backlash critic said company hire real model promote diversity
#
# company responded partnership would address business efficiency conflated diversity inclusion strategy
#
# calvin wong head laboratory artificial intelligence design hong kong said ai used assistant rather something creates design maintain agency designer ensure creation manufacturable
#
# lab hasdesigned ai toolthat allows designer upload draft sketch material colour palette generate design tweaked
#
# need treasure originality inspiration fashion designer wong said
#
# reporting beatrice tridimas editing zoe tabary
#
# get top trend brand industry news fashion beauty wellness straight inbox daily
#
# sign glossy daily newsletterhere
#
# generative aiproduced picture imaginary nike collaborationsneakershave circled social medium week
#
# thats one example ai used fashion us already valuable vast spanning marketing engineering immersive experience
#
# ai stirred buzz last month thanks new increasingly userfriendly ai tool
#
# last week march twenty image editor adobe firefly graphic design platform canva rolled new ai technologysupportingtexttovideo andbrand design respectively
#
# specific launch prove ai usefulness forvisual content creation
#
# thats start
#
# industry expert predict ai tool allow quicker seamless workflow allowing worker across field including marketing operation engineering focus creative problemsolving task
#
# one fastest moving potentially impactful trend see tech landscape today said roger robert partner consultancy mckinsey coauthor december two thousand and twenty-two generative ai herereport
#
# hyperpersonalization
#
# nextlevel personalization product experience consumer ecommerce site targeted ad instore experience among use case set benefit retailer
#
# date personalization largely done microsegmentation grouping customer according interest age group location
#
# youre going see lot automation want deliver hyperpersonalizationsaid brian long ceo personalized mobile messaging platform attentive
#
# monday company announced attentive ai tool allowing brand create complete multichannel campaign using ai insight effective content fourteen trillion attentive data point
#
# far major retail brand using tool beta reporting one hundred and forty-eight revenue increase
#
# lot brand going generative imagemaking platform generate marketing image leverage product product catalog paired background foreground imagery based text prompt enter
#
# theyre personalizing image setting lighting element said long
#
# ai us database image paired text prompt select fitting setting element
#
# case result productionready image send
#
# case help figure theyre looking final shoot long said tool allows brand customize marketing imagery different geographical region almost cost
#
# attentive ai develops copy campaign wellour biggest challenge always getting marketing copy completed timely manner said jason edward director ecommerce streetwear brand hat club
#
# main surprise close final attentive ai allows u get copy step finalize
#
# able significantly cut content creation time turn allow u build better campaign better segment customer
#
# visual merchandising collection creation
#
# ai could also solve problem visual merchandising
#
# brand open store location need visual merchandising express brand identity globally also tailored context store
#
# head visual merchandiser rarely lay every store brand fleet due cost time constraint
#
# able train learning program based instinct intuition best virtual visual merchandiser using ai could bring voice style capability shop door season said robert
#
# robert also noted creative application ai business
#
# brand able use generative ai technology synthesize note sketch idea collection
#
# ai combined operational financial perspective well merchandising marketing create collection price margin sustainable brand good customer
#
# apart levi strauss co using ai show wider range diversemodelson website channelswere also using ai enhance differentiate loyalty program offering personalized benefit member helping u achieve meaningful growth enrollment revenue app registrationssaid dr amy gershkoff bolles global head digital emerging technology strategy levi strauss cofor example personalized benefit include localized discount based popular product area
#
# since expanding loyalty program europe last year brand reached five million member worldwide
#
# ai help u provide personalized product recommendation website mobile app based consumer data specific market said gershkoff bolles
#
# also leveraging consumer mobility data customize store unique need interest local consumer open new store greatest demand
#
# finally said ai powering levi promotion analyzing stock category product likely benefit sale
#
# noted example including midseason endofseason sale well black friday sale u europe
#
# web3 brand
#
# web3 brand already implementing ai creative process
#
# charli cohen founder 2yearold web3 brand rtlss said studio used generative ai speed coding development work allowing ai create code optimized workflow
#
# also using create usergenerated content
#
# progressively integrating ai year said cohenour next drop use ai gamify minting postmint experience
#
# ugc toolkit currently building also include backend process like validating asset managing ip protection theyll automated enhanced ai
#
# ai used analyzean nfts blockchain transaction history ensure nft original duplicate
#
# itcan also analyze content nft art ensure original violate copyright law
#
# one physical fashion brand active web3tommy hilfiger experimenting ai engage customer incocreation
#
# specifically metaverse fashion week
#
# giving consumer opportunity design item brand signature preppy style using generative ai
#
# fashion show
#
# even fashion show already undergone somewhat atransformation set undergo change due ai
#
# matthew drinkwater head emerging technology company fashion innovation agency experimenting ai us catwalk since leading aifocused course london college fashion pandemic
#
# student able showcase final work two thousand and twenty drinkwater worked fia using archival show footage skeletal data moving model create virtual runway show
#
# project reimagined year include photorealistic model ai released march twenty-one via linkedin
#
# earlier catwalk huge amount manual labor work involved said drinkwater
#
# thats say wasnt case time specific skill set required deliver tool creating kind experience much manageable
#
# thats especially availability ai tool like text prompttovideo ai platform runway ai launched week
#
# video component going take next level engagement
#
# image obviously cool video people stop look take time said long
#
# runway project year fia used ai prompt tool midjourney stable diffusionthey took image luxury brand inspired trained ai model understand look applied look one particular male model create photorealistic video
#
# drinkwater agreed robert human element even necessary within fashion experimentation creativity ai
#
# however said new photorealistic opportunity help facilitate mass adoption digital fashion
#
# note ai faster implement metaverse
#
# metaverse combination many thing come together right way create really great experience
#
# thats case ai said robert explaining current software add feature make better
#
# doesnt require everyone show headset create entirely new platform
#
# thats shorter hype cycle everyone talking ai people using cforelevant impact
#
# company aiming cut cost due recessionrelated concern ai use could leveraged cut labor cost
#
# bottomline impact suggests something need top mind ctos cfo
#
# many case replace repetitive part human work allowing staff carry project quickly replacement
#
# drinkwater added combination thing put together like use machine learning artificial intelligence immersive experience start deliver nextgeneration immersive experience
#
# image courtesy christiane lemieux
#
# study titledhow complex system get engaged fashion design creation using artificial intelligence published journalthinking skill creativityaimed investigate practical applicability ai model implement creative fashion design work human designer
#
# thank
#
# gold standard business intelligence
#
# find
#
# download email arrive shortlywhile wait take look free recommend buyer guide
#
# research note use ai fashion industry grown significantly recent year
#
# example already used personalise fashion recommendation customer optimise supply chain management automate process improve sustainability reduce waste
#
# however creative process fashion design continue human driven little research use ai fashion design designer often included research
#
# assistant professor lead author study yoon kyung lee keen find could effective collaboration human ai purpose creative design explained time ai deeply ingrained life study started instead considering human better ai
#
# access comprehensive company profile market powered globaldata
#
# save hour research
#
# gain competitive edge
#
# download email arrive shortly
#
# confident unique quality company profile
#
# however want make beneficial decision business offer free sample download submitting form
#
# study started generating new textile design using deep convolution generative adversarial network dcgans cyclegans
#
# output model compared similar design produced design student
#
# comparison revealed design produced similar biggest difference uniqueness originality seen human design came person experience
#
# however use ai repetitive task could improve efficiency designer free time focus highdifficult creative work
#
# research also suggests aigenerated design could used learning tool people lack expertise fashion want explore creativity ai could assist creating design
#
# following study finding professor lee proposing humanai collaborative network integrates gans human creativity produce design
#
# professor lee also defined studied various element complex system involved humanai collaborated design established humanai model designer collaborates ai create novel design idea
#
# model allows designer share creative process idea others system interconnect evolve improve design
#
# professor lee belief fashion industry leverage foresee change fashion industry offer recommendation cocreation service
#
# setting xobjectives variable limit part designer job humanai collaborative design environment suggests work go beyond visual aspect instead cover variety discipline
#
# concludes future everybody able creator designer help ai model
#
# far professional fashion designer able design showcase clothes
#
# future possible anyone design clothes want showcase creativity
#
# download email arrive shortly
#
# wait take look free recommend buyer guide
#
# give business edge leading industry insight
#
# ai fashion industry
#
# long human started wear clothes wed desire express individuality one way achieve fashionthe fashion industry one biggest world estimated three trillion dollar two thousand and eighteen representing two percent global gdp
#
# much brickandmortar traditional retail well online ecommerce dedicated sale clothing fashion item
#
# much amazon acquired shoe retailer zappos one billion two thousand and ten major retailer walmart target amazon others entered fashion retail business brand brand partnership
#
# despite established nature fashion industry ai fundamentally transforming industry way fashion company manufacture product way marketed sold
#
# ai technology transforming fashion industry every element value chain designing manufacturing logistics marketing sale
#
# ai helping promote sell fashion good
#
# fashion industry much creating demand brand awareness manufacturing fashion product
#
# clothing apparel brand constantly looking new way get good front buyer create awareness demand market
#
# increasinglyfashion brand using ai machine learningto maximize user shopping experience improve efficiency sale system intelligent automation enhance sale process using predictive analytics guided sale process
#
# fashion brand also starting leverage conversational assistant chatbots voice assistant device amazon alexa apple siri google home microsoft cortana
#
# using conversational interface fashion brand gather data asking customer question understanding customer desire trend diving deeper purchase pattern suggesting related addon item
#
# example customer need new shoe dress instead interacting website mobile app simply conversation intelligent conversational agent
#
# back forth dialog customer find optimal fashion product accessory item
#
# interaction provides greater satisfaction customer much valuable information fashion brand
#
# addition conversational system ai making way ecommerce mobile apps
#
# customer able take picture clothing like style want imitate smart image recognition system match photo real life item available sale
#
# additionally aienabled shopping apps allow customer take screenshots clothes see online identify shoppable apparel accessory photo find outfit shop similar style
#
# aienhanced fashion design manufacturing
#
# documentary minimalism share beup fifty-two season clothing
#
# given constant change fashion design retailer need consistently keep current trend predict consumer preference next season
#
# traditionally retailer base estimate current year sale data prior year
#
# always accurate sale influenced many factor hard predict changing trend
#
# ...
#
# come art design ai applied way possible create constant stream content
#
# yet actual process producing ai imagery involves plenty trial error
#
# entering platform creator asked provide prompt generic specific desire
#
# machine begin learn understand asked produced image become closer closer desired output
#
# slightest adaptation prompt transform imagery explored detailed finished product
#
# like music art fashion design creative field become subject ai tech sector rapidly evolving line accelerating interest
#
# expert field also currently exploring whether ai creative without human intervention look understand depth communication people machine
#
# topic ai particularly gained traction late last year technology like chatgpt lensa ai midjourney began making round sparking debate around use ai creation
#
# argue technology could perceived form copying potentially present range ethical issue including encouraging mass production others see new form creative outlet providing designer artist accessible tool evolve creation
#
# similar discussion recently brought light nft space artist mason rothschild taken court hermès luxury brand accusing stealing design create digital asset made one million dollar sale
#
# ultimately jury ruled favour french luxury brand determining rothschild indeed profited name
#
# ruling eye expert set precedent similar case technology fashion could handled future drawing parallel ongoing ai discourse
#
# technology evolves could advancement actually benefit industry moving forward
#
# creatives ai opened door looking fresh way enter industry array online tool free paid allow almost anyone access technology
#
# product heavily adopted public new breed artist designer redefining mean creator modern day
#
# field skjellerup ai artist behind instagram account ai_clothingdaily exactly title profile say creating daily ai clothing
#
# design realistic comment page filled people asking order piece
#
# look range ai iteration nike shoe complete heavy embellishment intricate embroidery full runway outfit donned similarly artificial model
#
# noted skjellerups first venture fashion world
#
# creator also operates research platform marketplace luckynumber8 collect often sell vintage archival garment
#
# closely link ai work draw inspiration past designer runway collection well material would like experiment
#
# speaking fashionunited said process working ai way collaborative approach give input wait generative image respond accordingly
#
# even initial idea outcome could totally different depending ai responds
#
# really enjoy sense mystery surrounding tool
#
# skjellerups eye ai important tool design belief technology doesnt take away artist instead enhances creative potential
#
# added ability rapidly generate large group image make initial concept stage highly productive push idea beyond could become otherwise
#
# would like see ai design tool democratisation design process
#
# see role designer consumer blur one
#
# fashion much top industry blurring role could lead exciting possibility
#
# criticism format presently unavoidable individual within outside sector say constitutes design
#
# also something skjellerup acutely aware however perception remains resilient
#
# asked view possibility misconception surrounding topic said heard people within industry refer assisted creativity tool become accessible see become norm
#
# feel like people either havent tried ai creative tool ready pas judgement scared possibility job loss within sector
#
# think valid concern must remember job loss come people position power making decision tool
#
# hesitancy surrounding ai place design become increasingly analysed recent study expert look investigate practical applicability ai creative design process
#
# concept yoon kyung lee professor pusan national university korea explored study thinking skill creativity
#
# carry research lee started generating textile design using ai software compared model work design student
#
# result found design similar however distinct uniqueness originality seen humanmade design often derived person experience
#
# lee note use ai repetitive task could improve efficiency process provide good learning tool lack expertise industry
#
# professor proposed humanai collaborative work therefore effective instance particularly work link variety discipline beyond visual aspect gone begin developing process model applied
#
# speaking report lee said future everybody able creator designer help ai model
#
# far progressional fashion designer able design showcase clothes
#
# future possible anyone design clothes want showcase creativity
#
# lee deduced isnt clothing design ai serf purpose
#
# retailer increasingly implementing technology ecommerce online marketing strategy taking advantage ability enhance customer experience possibly ensure sustainable production process
#
# particularly popular among ongoing ecommerce evolution often applied retailer website provide accurate product recommendation data collection make search discovery efficient
#
# surge company putting use technology order provide retailer solution look expand consumer experience
#
# one perfect corp tech firm offer aipowered tryon experience ecommerce allowing consumer try product comfort home
#
# feature enables fast analysis offer shopper customised product recommendation efficiently matching product consumer need heightening confidence purchase
#
# speaking fashionunited alice chang ceo founder perfect corp noted benefit product stating fashion brand provide customer personalised shopping experience boost customer satisfaction decreasing product return
#
# solution also enable sustainable business operation allowing brand reach esg goal decreasing excess waste emission generated product sampling return process
#
# chang perspective implementing technology also crucial staying relevant today shopper increasingly leaning personalised digital advancement make purchasing decision
#
# chang added advancement ai recent year greatly accelerated allowing brand transform consumer journey improving sale engagement customer loyalty
#
# consumer shopping habit shifting happening across multiple channel retail space
#
# look future ai grow play larger role across industry empowering consumer shop personalised interactive way
#
# plan levi test virtual clothing model generated artificial intelligence drew swift backlash industry late last month
#
# furor mainly focused diversity concern retailer proposal also stirred anxiety simmering industry year
#
# critic levi strauss co partnership ai design firm lalalandai aimed show online shopper different type people wearing levi garment accused retailer looking inexpensively address issue representation potentially pushing professional model job process
#
# hire model book agency stylist makeup feed set cost money said shawn grain carter professor fashion business management fashion institute technology new york
#
# let make mistake levi save money
#
# levi spokesperson referred statement companydenied intention save costswith project
#
# retailer said ai model planned introduce would supplement replace photoshoots live model
#
# lalaland didnt respond request comment
#
# worry technology displacing human labor nothing new theyre far distinct fashion workforce
#
# ai used fashion year worker watching expansion space growing alarm
#
# yanii gough model founder yanii model work one hundred model said many still dying get back consistency industry reemerges pandemicrelated disruption
#
# rise ai modeling firm client simply send email agency say hey exactly im looking someone find person said referring company book model everything photoshoots fitting
#
# precedent concern like goughs
#
# shudu created two thousand and seventeen thought world first digital supermodel booked gig within past year highend brand asbmwandlouis vuitton
#
# shudu designed black woman alsodrew criticismtoward diigitals ai modeling agency created founder cameronjames wilson white
#
# today option continue expand brand advertiser looking use ai help market sell clothes
#
# addition lalaland there also deep agency new ai startup allows user create virtual photoshoot either synthetic model ai version real person
#
# gough said also worry model image used without permission via ai concern sara ziff founder nonprofit advocacy group called model alliance said hearing well
#
# fit model may replaced ai body scan said adding model try clothes designer manufacturer check sizing silhouette already calling organization growing number
#
# ziff said complained company hiring conduct body scan form basis product development without knowledge receiving compensation
#
# theyre able design clothes virtually using scan model body rather actually book model person said ziff declined provide example citing model alliance policy maintaining anonymous hotline industry worker flag complaint
#
# fashion brand defended ai effort addons benefit shopper ai design studio agency working space similarly describe effort supplemental
#
# lalalands founder example said created company sustainably increase representation fashion
#
# agent management company book model type job ziff described dont legally tell body scan could used project without compensation said
#
# ziff advocating proposed fashion worker act new york said would force agency fully disclose scope work pay
#
# current law leaf gray area around model right organize union ziff added resulting limited labor protection
#
# model considered independent contractor many face heightened risk sued retaliated agency
#
# representative professional creative field like thewriters guild america power propose standard best practice ai use industry
#
# meanwhile ai model become realistic already impossible many consumer distinguish image human
#
# ashley france influencer criticized levi partnership lalaland said hope regulator step
#
# way put psa somethings ad somethings dietary supplement thankfully something photoshopped feel like type regulation france said
#
# sara ruberg associate producer nbc news
#
# may human responsible design machine forecasting trend informing product decision
#
# fact ai becoming integral part technology apparel industry substantiated growth annual spending predicted nearly quadruple two billion dollar two thousand and eighteen seventy-three billion dollar two thousand and twenty-two according juniper research
#
# forecasting one example using artificial intelligence fashion industry
#
# new technology helping retailer manage inventory using aipowered tool gauge demand
#
# chatbots new fashion advisor offering two hundred and forty-seven connection customer help make purchasing decision
#
# savvy ai algorithm help tailor product recommendation allow retailer create collection customer want buy
#
# edited retail technology company based london produce realtime data analytics software give retailer access full market data touch button
#
# platform help retailer brand trade faster let look entire global market right colour shape pattern used company wide ranging boohoo farfetch tommy hilfiger marni
#
# geoff watt edited ceo stated ai helping retailer number way cut core retailer decide stock price fundamental part retail thats real ai benefit layer
#
# data marketer keen tell u everything
#
# ai quietly transforming fashion industry end consumer doesnt necessarily fathom online behaviour monitored recorded analysed
#
# example hm us ai keep popular item wellstocked analysing receipt return gauge store need
#
# marketing mode many brand analysing social medium data monitor fashion conversation allowing social data inform latest trend market prioritise segment interesting brand
#
# one company makersights us data analytics combine factor search query social medium activity ecommerce sellthroughs consumer feedback provide clue likely become trend
#
# data limit
#
# data exceptionally useful detect rising trend hit mass adoption anticipate decline trend andrea bell head insight trend forecasting agency wgsn told vogue business
#
# cant invent trend
#
# good design come inspiration human touch still irreplaceable
#
# photo courtesy edited
#
# two thousand and twenty-three breakout year generative ai use case emerging across fashion sector potential augment accelerate automate fashion business capability writing code amplifying creative process
#
# according tomckinsey co latest report overall financial impact gen ai fashion industry significant much quarter value expected driven use case design product development stage value chain
#
# gold standard business intelligence
#
# find
#
# business fashionmckinseystate fashion two thousand and twenty-four survey global fashion executive found seventy-three fashion executive said generative ai priority business two thousand and twenty-four le third twenty-eight tried using creative process design product development
#
# mckinsey suggests highlight fashion company yet capturing value creative process
#
# report read caution understandable
#
# technology could impact job workflow
#
# fashion industry also seen fair share technologicalenthusiasm swiftly sputtered notably metaverse
#
# last year started much enthusiasm metaverse since died however mckinseys report suggests generative ai practical application making attractive business investor
#
# access comprehensive company profile market powered globaldata
#
# save hour research
#
# gain competitive edge
#
# download email arrive shortly
#
# confident unique quality company profile
#
# however want make beneficial decision business offer free sample download submitting form
#
# example equity funding generative aifocused startup skyrocketed reaching 141bn first half two thousand and twenty-three alone compared 25bn two thousand and twenty-two
#
# fashion sector focus generative ai far oneoff use case cost efficiency customer experience advantage
#
# technology also offer potential wider industry disruption
#
# ai already making mark online shopping assistance online retailerzalandoannouncing launch beta chatgptbased natural languagepowered shopping assistant earlier year allows online customer ask question get answer well customised product recommendation
#
# u fashion conglomeratekeringand online marketplaceshopifyhave also introduced ai chatbots brand adore methe lingeriecompany recently acquired victoria secret using technology write product description site
#
# report add ultimately greatest value may lie using gen ai endtoend way enables enhances creativity
#
# example fast fashion gen ai could accelerate design process inject agility trend detection product development leverage analytics data rapidly produce large number new design
#
# spanish brand desigual already launched ondemand collection designed using ai tool
#
# company developing generative ai software fashion sector claim technology reduce manual task take day mere hour even second
#
# new technology could free designer manual task allowing focus creative work
#
# human designer remain key generative ai enable role oriented around curation according report
#
# however report also note word caution potential must communicated clearly creatives ensure technology adopted without undermining role designer
#
# continues implemented effectively technology benefit amplify creative process thus augmenting human capability retaining artistic skill knowledge designer
#
# ultimately say expert humancentred innovation likely important use ai
#
# source globaldata
#
# globaldatas job database suggests last three year december two thousand and twenty december two thousand and twenty-three interest employing individual generative ai grown
#
# online giantamazonis leading way five hundred and thirty-seven job posted time period followed u supermarket retailerwalmartwith thirty-eight job posted
#
# company exploring generative ai role according globaldata include luxury u fashion conglomeratetapestryand u fashion brandabercrombie fitch
#
# signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company
#
# signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed

# %%
# Use Vader library to get the polarity of the sentence
def getPolarity(text):
    polarity = SentimentIntensityAnalyzer().polarity_scores(text)
    if polarity['compound'] > 0:
      sentiment = 'postive'
    elif polarity['compound'] < 0:
      sentiment = 'negative'
    else:
      sentiment = 'neutral'
    return sentiment,polarity

# %%
for sentence in sentences:
  sentiment, polarity = getPolarity(sentence)
  print('\n', sentence)
  print(f"{sentiment}, {polarity}")
# Out:
#  impact artificial intelligence creative industry subject prompted widespread anxiety job loss death imagination world fashion exception
# negative, {'neg': 0.317, 'neu': 0.442, 'pos': 0.241, 'compound': -0.2263}
#
#  monthslondon fashion week marking event 40th anniversary showcase host aigenerated outfit industry insider expressed growing optimism technology sector improving diversity shortening path design desk shop floor
# postive, {'neg': 0.0, 'neu': 0.742, 'pos': 0.258, 'compound': 0.7906}
#
#  head london college fashionsinnovation agency matthew drinkwater belief ai prove hugely beneficial tool creative process industry whole
# postive, {'neg': 0.0, 'neu': 0.702, 'pos': 0.298, 'compound': 0.7474}
#
#  opened door nontraditional pathway fashion industry people couldnt get let face industry perception feeling quite elitist quite exclusive expensive industry get
# postive, {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'compound': 0.3729}
#
#  tool allowing people different background begin foothold industry
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  feel really new exciting said
# postive, {'neg': 0.0, 'neu': 0.535, 'pos': 0.465, 'compound': 0.539}
#
#  brand heliot emil zara hm already using ai control supply chain say promotes sustainability reducing overstock waste
# negative, {'neg': 0.139, 'neu': 0.743, 'pos': 0.119, 'compound': -0.1027}
#
#  many brand also using ai help design process image clothes generated typed prompt visualising different material pattern
# postive, {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4019}
#
#  allows designer make informed decision physically producing clothes
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  consultancymckinsey predictedlast year generative ai term technology produce convincing image text audio simple human prompt could add 150bn 275bn 120bn 220bn operating profit fashion luxury sector within next three five year
# postive, {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.6808}
#
#  predicting future fashion trend creating virtual tryons using ai also predicted around corner
# postive, {'neg': 0.0, 'neu': 0.845, 'pos': 0.155, 'compound': 0.296}
#
#  drinkwater working team look ai could change industry testing generative ai ability create clothing year
# postive, {'neg': 0.0, 'neu': 0.747, 'pos': 0.253, 'compound': 0.5267}
#
#  scraping website try get lot data could create dress forty thousand image
# postive, {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compound': 0.2732}
#
#  actually really hard work four year ago open laptop even smartphones start generating image quickly drinkwater said
# negative, {'neg': 0.096, 'neu': 0.904, 'pos': 0.0, 'compound': -0.1761}
#
#  typically take stuff maybe three five year away commercialisation begin show research project around future industry might move added
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  april last year cyril foirets generative ai studio maison meta hosted first ai fashion week new york included competition aspiring designer use ai create fashion line
# postive, {'neg': 0.0, 'neu': 0.923, 'pos': 0.077, 'compound': 0.2732}
#
#  winner able collection physically manufactured sold online retailer revolve
# postive, {'neg': 0.0, 'neu': 0.678, 'pos': 0.322, 'compound': 0.5859}
#
#  industry ai come associated job redundancy critic argue creative artistry could wiped
# negative, {'neg': 0.274, 'neu': 0.549, 'pos': 0.177, 'compound': -0.1531}
#
#  foiret argues little fear
# negative, {'neg': 0.734, 'neu': 0.266, 'pos': 0.0, 'compound': -0.6712}
#
#  ai powerful tool amplifying creativity
# postive, {'neg': 0.0, 'neu': 0.357, 'pos': 0.643, 'compound': 0.6597}
#
#  people thinking job going reduce shouldnt think like
# negative, {'neg': 0.232, 'neu': 0.768, 'pos': 0.0, 'compound': -0.2755}
#
#  need get accustomed tool tool without person behind use said
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  sign tofashion statement
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  style substance whats really trending week roundup best fashion journalism wardrobe dilemma solved
# postive, {'neg': 0.094, 'neu': 0.556, 'pos': 0.35, 'compound': 0.6808}
#
#  newsletter promotion
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  arti zeighami former chief data analytics officer hm senior adviser ai consulting firm bcg agrees ai used force good within fashion
# postive, {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.5719}
#
#  transparent ai help people afraid allows comfortable still feel control transformation mindset human important said
# postive, {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.7783}
#
#  ai evolve technology either way need evolve alongside havent come terminator stage yet least
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  tucs ai lead mary tower said ai could useful aid worker creative sector shouldnt hijacked replace human creativity
# postive, {'neg': 0.0, 'neu': 0.641, 'pos': 0.359, 'compound': 0.8126}
#
#  need new law ensure worker art including fashion consulted properly compensated work intellectual property used ai said
# postive, {'neg': 0.0, 'neu': 0.718, 'pos': 0.282, 'compound': 0.7096}
#
#  already seen performer uk image voice likeness reproduced ai technology without consent
# negative, {'neg': 0.132, 'neu': 0.868, 'pos': 0.0, 'compound': -0.1695}
#
#  cant afford become norm industry
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  thats urgently need fresh regulation protect worker creativity copyright
# postive, {'neg': 0.0, 'neu': 0.444, 'pos': 0.556, 'compound': 0.7579}
#
#  alexsandrah never really wanted model
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  first scouted thirteen young adult turned initial two opportunity
# postive, {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.4215}
#
#  finally decided give go
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  got lose
# negative, {'neg': 0.73, 'neu': 0.27, 'pos': 0.0, 'compound': -0.4019}
#
#  see go told
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  full time industry londonbased model taking another chance career creating virtual aigenerated version
# postive, {'neg': 0.0, 'neu': 0.724, 'pos': 0.276, 'compound': 0.4939}
#
#  hope secure future modelling
# postive, {'neg': 0.0, 'neu': 0.274, 'pos': 0.726, 'compound': 0.6486}
#
#  ai version kind keep safe explains
# postive, {'neg': 0.0, 'neu': 0.388, 'pos': 0.612, 'compound': 0.743}
#
#  benefit literally ai version im cut anything
# postive, {'neg': 0.208, 'neu': 0.495, 'pos': 0.297, 'compound': 0.2263}
#
#  proceeds proceeds made coming
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  dont travel dont airport run dont anything
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  give people opportunity also live life thing two place time add
# postive, {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.4215}
#
#  alexsandrah say one first market virtual version client industry become one latest keep watchful overtheshoulder eye growth ai
# postive, {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'compound': 0.3818}
#
#  nearly three quarter fashion executive survey published management consultancymckinseyin november last year said ai priority company two thousand and twenty-four
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  quarter said already used creative design development
# postive, {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.4404}
#
#  behind alexsandrahs virtual twin cameron wilson founder chief executive ai 3d modelling agency diigitals
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  company found first taste global success two thousand and seventeen launch shudu marketed world first digital supermodel
# postive, {'neg': 0.0, 'neu': 0.812, 'pos': 0.188, 'compound': 0.5719}
#
#  counting two hundred and fifty thousand people among instagram follower shudu virtual influencer fronted campaign balenciaga lexus balmain without criticism
# postive, {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'compound': 0.3412}
#
#  time created shudu created huge amount comment white person could create black virtual character cameron explains
# postive, {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.7506}
#
#  happened really made think creating character ethical way implication future
# postive, {'neg': 0.0, 'neu': 0.581, 'pos': 0.419, 'compound': 0.6969}
#
#  online backlash shaped latest work alexsandrah paid image used campaign photoshoots ai twin appears
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  trying show business brand magazine still use ai real model together encourage fair use ai rather doom gloom job taken away say
# negative, {'neg': 0.211, 'neu': 0.602, 'pos': 0.187, 'compound': -0.1779}
#
#  protection job something group representing industry model makeup artist hairstylist want see
# postive, {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.0772}
#
#  read story artificial intelligence
# postive, {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.4767}
#
#  equity represents fashion model uk tell bbc lobbying uk government bring law strengthen right performer
# postive, {'neg': 0.078, 'neu': 0.783, 'pos': 0.139, 'compound': 0.25}
#
#  encourage member sign away right ensure image used based fair pay fair condition usage say spokesperson group
# postive, {'neg': 0.059, 'neu': 0.502, 'pos': 0.439, 'compound': 0.8442}
#
#  meanwhile british fashion model agent association urge caution growth ai
# postive, {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.3818}
#
#  burying head sand ai coming industry need prepared adapt business model reflect say director john horner
# postive, {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'compound': 0.2263}
#
#  perceived threat ai fashion industry came head last year fashion brand levi announced would using ai generate model diverse body type skin tone increase representation product model
# negative, {'neg': 0.111, 'neu': 0.814, 'pos': 0.075, 'compound': -0.2732}
#
#  anger within modelling worldfollowedwith accusation laziness levelled brand online describing technology perpetuating racism
# negative, {'neg': 0.495, 'neu': 0.505, 'pos': 0.0, 'compound': -0.8689}
#
#  levi backtracked said committed using ai technology equitably transparently
# postive, {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'compound': 0.2732}
#
#  josephine markham webster bos mentor model agency sheffield voice anger time think ai generated model step backward industry
# negative, {'neg': 0.179, 'neu': 0.821, 'pos': 0.0, 'compound': -0.5719}
#
#  work done last year diversity representing woman men different body shape different size different look say
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  ai version model taking away
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  backwards move
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  going back using ideal standard model
# postive, {'neg': 0.0, 'neu': 0.595, 'pos': 0.405, 'compound': 0.5267}
#
#  real dress size
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  real skin
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  real beauty
# postive, {'neg': 0.0, 'neu': 0.208, 'pos': 0.792, 'compound': 0.5859}
#
#  think going damaging people modelling
# negative, {'neg': 0.452, 'neu': 0.548, 'pos': 0.0, 'compound': -0.5106}
#
#  there denying demand virtual model influencers growing
# negative, {'neg': 0.406, 'neu': 0.417, 'pos': 0.177, 'compound': -0.296}
#
#  october last year facebook instagram owner meta announced latest attempt merge real virtual world introducing team ai chatbots modelled celebrity including snoop dogg kendall jenner bear grylls
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  reportssuggest celebrity paid much 5m â396m likeness
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  brand really looking character exist social medium really engage audience often bring awareness certain thing say mr wilson
# postive, {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.5849}
#
#  one latest client charity down syndrome international
# postive, {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.4215}
#
#  worked create world first virtual influencer down syndrome kami
# postive, {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'compound': 0.2732}
#
#  along one hundred different woman down syndrome community explains
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  try create character looking ethical perspective
# postive, {'neg': 0.0, 'neu': 0.426, 'pos': 0.574, 'compound': 0.6597}
#
#  bring awareness space
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  impact space better
# postive, {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
#
#  summary piece examines extensive influence ai fashion industry creative sector depth supply chain
# postive, {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.4404}
#
#  highlight ai significance new frontier enterprise technology offering invaluable strategic advantage various fashion domain
# postive, {'neg': 0.0, 'neu': 0.629, 'pos': 0.371, 'compound': 0.6705}
#
#  insightful analysis uncovers nongenerative application ai promise revolutionize standard practice addressing creative logistical concern explores implication sustainability ethical discourse within hightech fashion realm
# postive, {'neg': 0.0, 'neu': 0.702, 'pos': 0.298, 'compound': 0.8176}
#
#  artificial intelligence reshaping creative aspect fashion image video generation poised transform entire fashion ecosystem
# postive, {'neg': 0.0, 'neu': 0.579, 'pos': 0.421, 'compound': 0.7906}
#
#  brand designer supplier look ai competitive edge scope influence vast touching area chemistry inventory planning garment production customer personalization
# postive, {'neg': 0.0, 'neu': 0.914, 'pos': 0.086, 'compound': 0.1779}
#
#  generative ai garner much attention revolutionizing design promotional content understated counterpart nongenerative ai hold immense potential revolutionize backend operation
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  fashion industry delf deeper ai capability stakeholder seeking comprehensive knowledge spanning history deep learning ethical legal impact
# postive, {'neg': 0.0, 'neu': 0.673, 'pos': 0.327, 'compound': 0.7003}
#
#  ass critical development ben hanson editorinchief interline led 45minute discussion educate address question surrounding pressing topic
# negative, {'neg': 0.293, 'neu': 0.707, 'pos': 0.0, 'compound': -0.7003}
#
#  hansons talk promised enlightening overview ai rapid escalation importance providing fashion professional insight ai current application glimpse future advancement
# postive, {'neg': 0.0, 'neu': 0.658, 'pos': 0.342, 'compound': 0.8074}
#
#  importantly session encouraged dialogue surrounding ai role sustainability ethical challenge issue forefront modern fashion agenda
# postive, {'neg': 0.0, 'neu': 0.539, 'pos': 0.461, 'compound': 0.8126}
#
#  artificial intelligence fashion industry
# postive, {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.4767}
#
#  fashion industry one dynamic sector global economy advent artificial intelligence brought unprecedented change vibrant field
# postive, {'neg': 0.0, 'neu': 0.569, 'pos': 0.431, 'compound': 0.8442}
#
#  infiltration ai span entire value chainfrom design conception trend forecasting supply chain management customer engagement
# postive, {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.6597}
#
#  incorporating ai allows business harness power datadriven decisionmaking predictive analytics automated process thereby providing substantial strategic advantage
# postive, {'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'compound': 0.4215}
#
#  industry market forecast
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  market forecast predict ai fashion industry continue grow impressive rate
# postive, {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.5106}
#
#  surge online shopping customized offering demand seamless customer experience driving expansion
# negative, {'neg': 0.13, 'neu': 0.87, 'pos': 0.0, 'compound': -0.128}
#
#  according various research report global ai fashion market projected reach multibillion dollar figure mid2020s growing compound annual growth rate twenty
# postive, {'neg': 0.0, 'neu': 0.759, 'pos': 0.241, 'compound': 0.5267}
#
#  influence ai extends sustainable fashion technology help brand monitor optimize environmental footprint
# postive, {'neg': 0.0, 'neu': 0.549, 'pos': 0.451, 'compound': 0.7506}
#
#  leveraging ai material selection production method waste management fashion company setting new benchmark ecofriendly practice
# negative, {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.4215}
#
#  issue fashion industry
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  however proliferation ai also raise several issue
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  ethical concern regarding data privacy biased algorithm job displacement increasingly scrutiny industry expert policymakers consumer
# postive, {'neg': 0.114, 'neu': 0.707, 'pos': 0.179, 'compound': 0.296}
#
#  addition high cost implementing cuttingedge ai technology pose significant challenge smaller brand
# postive, {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.2732}
#
#  sustainability another critical issue
# negative, {'neg': 0.434, 'neu': 0.566, 'pos': 0.0, 'compound': -0.3182}
#
#  although ai potential contribute sustainable practice ongoing debate overall environmental impact data center machine learning process
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  brand tasked balancing innovation responsibility environment society
# postive, {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.3818}
#
#  conversation ai role fashion industry dynamic multifaceted addressing creative logistical ethical dimension
# postive, {'neg': 0.0, 'neu': 0.506, 'pos': 0.494, 'compound': 0.8316}
#
#  ben hansons discussion editorinchief interline underscore need continuous education sharing knowledge navigate complexity introduced aia reflection industry commitment evolving responsibly
# postive, {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.6597}
#
#  interested broader trend research within industry valuable resource found visiting official website global industry group market research firm
# postive, {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.7003}
#
#  credible source fashion industry news analysis accessed thebusiness fashionwebsite
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  learn global market insight forecast consider visiting site renowned market research firm asgrand view research
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  embracing ai fashion industry signifies monumental shift promising new horizon also compelling sector navigate intricacy hightech future wisdom foresight
# postive, {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.7906}
#
#  jerzy lewandowski visionary realm virtual reality augmented reality technology made significant contribution field pioneering research innovative design
# postive, {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.7964}
#
#  work primarily focus enhancing user experience interaction within virtual environment pushing boundary immersive technology
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  lewandowskis groundbreaking project gained recognition ability merge digital physical world offering new possibility gaming education professional training
# postive, {'neg': 0.0, 'neu': 0.754, 'pos': 0.246, 'compound': 0.5994}
#
#  expertise forwardthinking approach mark key influencer shaping future virtual augmented reality application
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  new york city usa last week fashion world descended new york city new york fashion week nyfw
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  biannual event celebrated best industry showcased hottest trend season
# postive, {'neg': 0.0, 'neu': 0.47, 'pos': 0.53, 'compound': 0.836}
#
#  nyfw massive money maker city fashion industry large
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  average event brings staggering 600m annually
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  regardless stark economic cultural value event brings overshadowed existential threat hitting sector like medium tech artificial intelligence eroding existing job limiting work opportunity future
# postive, {'neg': 0.102, 'neu': 0.572, 'pos': 0.325, 'compound': 0.7506}
#
#  behind glitz glamour lie fear large part led writer guild screen actor guild strike past year protection one likeness
# negative, {'neg': 0.195, 'neu': 0.664, 'pos': 0.141, 'compound': -0.0772}
#
#  body business image manipulated sold without permission violation right sara ziff founder executive director model alliance said statement
# postive, {'neg': 0.122, 'neu': 0.754, 'pos': 0.124, 'compound': 0.0072}
#
#  yve edmond model based new york city
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  say new era aidriven modelling lot room exploitation
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  people industry body scanned photo collected year gone create virtual self yet ownership
# postive, {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.2732}
#
#  claim edmond told al jazeera
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  shes worried could undermine work opportunity model near future
# negative, {'neg': 0.333, 'neu': 0.455, 'pos': 0.212, 'compound': -0.1531}
#
#  model image measurement posture body shape brand
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  many case somebody take ownership brand without knowledge without compensation
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  literally competing market edmond added
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  edmond among many model eager reform pushing fashion worker act new york state
# postive, {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.3612}
#
#  among larger change would provide new safeguard would protect model client may try use image without permission
# postive, {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.6369}
#
#  act would require model give clear written consent digital replica respective likeness
# postive, {'neg': 0.0, 'neu': 0.552, 'pos': 0.448, 'compound': 0.743}
#
#  would also require client outline intend use image
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  mind behind legislation model alliance
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  introduced fashion worker act create basic labour protection model content creator working industry infamously operates without oversight
# postive, {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.2732}
#
#  misuse generative ai present new challenge allow go unregulated ziff model alliance said
# postive, {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.296}
#
#  bill authored state senator brad hoylmansigal would change fashion industry work one single iconic fashion city world rivalling city like paris milan
# postive, {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.3612}
#
#  model argue would also protect signing onto unfair contract alternative work
# negative, {'neg': 0.342, 'neu': 0.497, 'pos': 0.161, 'compound': -0.4404}
#
#  dont want end world model feel like forced give consent wont get paid model sinead bovell told al jazeera
# postive, {'neg': 0.179, 'neu': 0.635, 'pos': 0.186, 'compound': 0.0459}
#
#  passed would statelevel law help set stage global push
# postive, {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.4019}
#
#  use ai spread across sector ranging medium customer service business leader argue help improve workflow help worker job get easier help new tool
# postive, {'neg': 0.072, 'neu': 0.512, 'pos': 0.416, 'compound': 0.886}
#
#  yet reflected data
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  according november survey resume builderroughly onethirdof business leader say ai lead layoff year alone
# negative, {'neg': 0.133, 'neu': 0.867, 'pos': 0.0, 'compound': -0.25}
#
#  concern flaring global fashion ai pose existential threat undermining work opportunity around globe especially community colour
# negative, {'neg': 0.272, 'neu': 0.599, 'pos': 0.129, 'compound': -0.4767}
#
#  model like bovell fought inclusivity fashion voiced concern
# postive, {'neg': 0.213, 'neu': 0.556, 'pos': 0.231, 'compound': 0.0516}
#
#  youre going company take advantage sacrifice real human model instead kind generate diverse identity front end bovell said
# postive, {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.6597}
#
#  might brand profiting marginalised identity community without actually pay bovell added
# postive, {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.4397}
#
#  thats exactly happened levi strauss last year
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  brand launched partnership dutch company lalalandai allows customised aigenerated model
# postive, {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.128}
#
#  release company said
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  lalalandai us advanced artificial intelligence enable fashion brand retailer create hyperrealistic model every body type age size skin tone
# postive, {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.7351}
#
#  bodyinclusive avatar company aim create inclusive personal sustainable shopping experience fashion brand retailer customer
# postive, {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.2732}
#
#  move met public backlash critic referred problematic racist
# negative, {'neg': 0.643, 'neu': 0.357, 'pos': 0.0, 'compound': -0.8402}
#
#  clothing company later updated statement
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  scaling back plan live photo shoot use live model commitment working diverse model
# postive, {'neg': 0.15, 'neu': 0.688, 'pos': 0.163, 'compound': 0.0516}
#
#  authentic storytelling always part weve connected fan human model collaborator core experience
# postive, {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.3182}
#
#  company taking model picture completely
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  last year vogue brasil vogue singapore included aigenerated model respective cover place human model
# postive, {'neg': 0.0, 'neu': 0.823, 'pos': 0.177, 'compound': 0.4215}
#
#  company like deep agency created aigenerated model model clothes
# postive, {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'compound': 0.5423}
#
#  danny postma made tool said post social medium platform known x help marketer social medium influencers
# postive, {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4019}
#
#  response thread substantial public backlash among applause
# postive, {'neg': 0.0, 'neu': 0.521, 'pos': 0.479, 'compound': 0.5574}
#
#  critic said concept deeply unethical undermined work model involved process like photographer
# negative, {'neg': 0.447, 'neu': 0.422, 'pos': 0.132, 'compound': -0.7159}
#
#  others accused company cash grab also referred move dystopian
# negative, {'neg': 0.216, 'neu': 0.784, 'pos': 0.0, 'compound': -0.296}
#
#  one user called postma saying
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  im sure also strong proposal aid everyone whod lose job tech like succeeds right
# postive, {'neg': 0.117, 'neu': 0.391, 'pos': 0.491, 'compound': 0.8225}
#
#  everything alright long make cash
# postive, {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.25}
#
#  good solution brings even problem attempt solve
# postive, {'neg': 0.213, 'neu': 0.236, 'pos': 0.551, 'compound': 0.5106}
#
#  tool longer open beta testing
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  postma according linkedin profile experience fashion photography created string ai product
# postive, {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.25}
#
#  tanksai reportindicated fashion aiready industry highest proportion airelated role four hundred and forty-four retail ecommerce sector lowest proportion requiring ai nine
# negative, {'neg': 0.115, 'neu': 0.885, 'pos': 0.0, 'compound': -0.3818}
#
#  receive email shortly
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  please check download report
# postive, {'neg': 0.0, 'neu': 0.566, 'pos': 0.434, 'compound': 0.3182}
#
#  gold standard business intelligence
# postive, {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.4767}
#
#  find
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  research claim fashion leading brigade encompassing element design buying tank add surprise given sector fastpaced competitive leading company embrace ai
# postive, {'neg': 0.0, 'neu': 0.736, 'pos': 0.264, 'compound': 0.6249}
#
#  report detail use data analytics fuelled ai also solve fashion sector biggest challenge like speeding design production proactively identifying new trend aligning supply demand reduce waste
# postive, {'neg': 0.139, 'neu': 0.68, 'pos': 0.181, 'compound': 0.0772}
#
#  although retail ecommerce ranked bottom report highlight retailer incorporate ai element drive sale loyalty whether sell online instore datadriven insight assisting retailer improving forecasting capability protecting margin transforming customer experience
# postive, {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.8271}
#
#  martin harris head digital tank belief like numeracy literacy likely see data ai literacy become requirement many technical nontechnical role
# postive, {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.3612}
#
#  access comprehensive company profile market powered globaldata
# postive, {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.25}
#
#  save hour research
# postive, {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.4939}
#
#  gain competitive edge
# postive, {'neg': 0.0, 'neu': 0.164, 'pos': 0.836, 'compound': 0.6249}
#
#  download email arrive shortly
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  confident unique quality company profile
# postive, {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.4939}
#
#  however want make beneficial decision business offer free sample download submitting form
# postive, {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.7579}
#
#  martin harris head digital tank said there doubt ai transforming employment landscape id argue good thing
# negative, {'neg': 0.236, 'neu': 0.625, 'pos': 0.139, 'compound': -0.25}
#
#  removing lot labourintensive drudge work giving people rewarding opportunity drive success business
# postive, {'neg': 0.0, 'neu': 0.394, 'pos': 0.606, 'compound': 0.9062}
#
#  emotional intelligence always human trait
# postive, {'neg': 0.0, 'neu': 0.39, 'pos': 0.61, 'compound': 0.5719}
#
#  replicated authentically machine improve strength trait backing evidence
# postive, {'neg': 0.0, 'neu': 0.41, 'pos': 0.59, 'compound': 0.7351}
#
#  year particular feel like ai come age technology powerful human judgement oversight important ever
# postive, {'neg': 0.0, 'neu': 0.608, 'pos': 0.392, 'compound': 0.7269}
#
#  according job filing data shared globaldata apparel industry posted eight thousand, eight hundred and sixty-five active job related requiring theme artificial intelligence ai period november two thousand and nineteen november two thousand and twenty-three
# postive, {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.802}
#
#  ai secondmost sought theme followed u macro outlook eight thousand, five hundred and ninety-nine job posted
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  global macro outlook job lead way period
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  certainly seeing ai growing prominence come apparel industry
# postive, {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.4767}
#
#  amckinsey co reportcalled overallfinancial impact gen ai fashion industry significantand recently theus customer border protection cbp asked report ai used trace supply chain custom control
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed
# postive, {'neg': 0.225, 'neu': 0.395, 'pos': 0.379, 'compound': 0.5994}
#
#  receive email shortly
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  please check download report
# postive, {'neg': 0.0, 'neu': 0.566, 'pos': 0.434, 'compound': 0.3182}
#
#  chief marketing officer atlaunchmetrics leading brand performance cloud fashion lifestyle beauty
# postive, {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.5859}
#
#  era digital native reign supreme digital landscape continues rapidly evolve fashion lifestyle brand facing unique set challenge
# postive, {'neg': 0.0, 'neu': 0.754, 'pos': 0.246, 'compound': 0.5994}
#
#  captivate attention today techsavvy consumer company harnessing transformative power artificial intelligence ai personalization datadriven strategy effective
# postive, {'neg': 0.0, 'neu': 0.693, 'pos': 0.307, 'compound': 0.7351}
#
#  ai transcended buzzword status become driving force marketing fashion lifestyle brand
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  fusion ai fashion isnt convenience creating meaningful connection
# negative, {'neg': 0.391, 'neu': 0.609, 'pos': 0.0, 'compound': -0.431}
#
#  way ive found technology effective
# postive, {'neg': 0.0, 'neu': 0.563, 'pos': 0.437, 'compound': 0.4767}
#
#  aigenerated content one example help make difference reshape fashion lifestyle industry
# postive, {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019}
#
#  many marketer already using ai content creation curation least looking
# postive, {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.2732}
#
#  crafting compelling product description generating fashionforward content ai collaborates human creativity fuel brand storytelling
# postive, {'neg': 0.0, 'neu': 0.727, 'pos': 0.273, 'compound': 0.5423}
#
#  fusion art science resonates aesthetically driven audience save professional time effort
# postive, {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.4939}
#
#  look like action
# postive, {'neg': 0.0, 'neu': 0.444, 'pos': 0.556, 'compound': 0.3612}
#
#  sophisticated ai drum snappy engaging copy content strategy inspiration flash backed extensive global online research take place second
# postive, {'neg': 0.0, 'neu': 0.571, 'pos': 0.429, 'compound': 0.8591}
#
#  collate thought fresh take topical industry news might missed underpinning journey building thought leader status increasing campaign content interaction online offline
# negative, {'neg': 0.154, 'neu': 0.75, 'pos': 0.096, 'compound': -0.1027}
#
#  breath must employ considered proofing approach avoid ai bias hallucination way keep full control brand story deliver correct message evoking desired response process
# negative, {'neg': 0.14, 'neu': 0.778, 'pos': 0.082, 'compound': -0.128}
#
#  beyond personalization trendits consumer expectation
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  statistic show that71 consumersexpect company provide personalized interactionsais prowess lie ability analyze vast data set understand consumer behavioral pattern
# postive, {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'compound': 0.3182}
#
#  enables fashion brand offer hyperpersonalized recommendation predicting consumer want want
# postive, {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.1531}
#
#  might wondering ai utilized offer personalized interaction turn help meet goal
# postive, {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019}
#
#  option wideranging
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  externally brand employ virtual tryon technology consider smart personalized shopping feature
# postive, {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019}
#
#  latter ai built recognize consumer body shape purchase online interaction offering curated content thats tailored style preference fully adaptable future shifting desire
# postive, {'neg': 0.0, 'neu': 0.886, 'pos': 0.114, 'compound': 0.4019}
#
#  level personalization resonates deeply digitalsavvy audience making feel understood valued
# postive, {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.4404}
#
#  internally ai powerful enough enhance social medium analytics predict optimize inventory management bolster brand performance holistic onestopshop metric
# postive, {'neg': 0.0, 'neu': 0.727, 'pos': 0.273, 'compound': 0.7184}
#
#  help benchmark result use data inform future strategy confidence
# postive, {'neg': 0.0, 'neu': 0.538, 'pos': 0.462, 'compound': 0.7184}
#
#  today online landscape understanding audience paramount
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  segmentation enabled ai help brand divide consumer base distinct group based demographic behavior interest
# postive, {'neg': 0.0, 'neu': 0.678, 'pos': 0.322, 'compound': 0.6908}
#
#  foundation upon personalized campaign built help create content speaks directly target audience
# postive, {'neg': 0.0, 'neu': 0.676, 'pos': 0.324, 'compound': 0.5859}
#
#  way tailored content key successful personalization
# postive, {'neg': 0.0, 'neu': 0.568, 'pos': 0.432, 'compound': 0.5859}
#
#  whether recommending curated collection suggesting complementary product delivering content resonates specific segment personalized strategy create lasting impact
# postive, {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.2732}
#
#  ensuring successful transition requires quality data
# postive, {'neg': 0.0, 'neu': 0.404, 'pos': 0.596, 'compound': 0.7096}
#
#  data isnt buzzword cornerstone modern marketing fuel informed decision
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  fashion lifestyle industry datadriven decision help ensure brand stay relevant
# postive, {'neg': 0.0, 'neu': 0.602, 'pos': 0.398, 'compound': 0.6486}
#
#  data offer invaluable insight consumer preference shopping habit trend
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  brand make informed decision product development even marketing strategy
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  benchmarking competitor example strategic move best powered quality data
# postive, {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.6369}
#
#  gathering prescriptive insight ensure data clean accurate free error
# postive, {'neg': 0.166, 'neu': 0.307, 'pos': 0.528, 'compound': 0.7096}
#
#  involves removing duplicate handling missing value correcting inconsistency
# postive, {'neg': 0.208, 'neu': 0.566, 'pos': 0.226, 'compound': 0.0516}
#
#  still big data computing often requires sophisticated ai machine learning algorithm difficult build inhouse
# postive, {'neg': 0.138, 'neu': 0.663, 'pos': 0.199, 'compound': 0.2732}
#
#  critical reflect company need getting started
# negative, {'neg': 0.315, 'neu': 0.685, 'pos': 0.0, 'compound': -0.3182}
#
#  considering new ai software important review current technological need real benefit holistic tool could bring
# postive, {'neg': 0.0, 'neu': 0.73, 'pos': 0.27, 'compound': 0.5859}
#
#  avoid wasted investment give idea current business capability
# negative, {'neg': 0.474, 'neu': 0.526, 'pos': 0.0, 'compound': -0.6597}
#
#  start pinpointing area department youre facing challenge inefficiency
# postive, {'neg': 0.0, 'neu': 0.843, 'pos': 0.157, 'compound': 0.0772}
#
#  sample management process leading financial loss impacting medium relationship
# negative, {'neg': 0.223, 'neu': 0.777, 'pos': 0.0, 'compound': -0.3182}
#
#  marketing team unable grasp strategic nuance new global market
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  inhouse pr team constantly missing important coverage piece
# negative, {'neg': 0.22, 'neu': 0.6, 'pos': 0.18, 'compound': -0.1027}
#
#  next evaluate volume limitation current data
# negative, {'neg': 0.306, 'neu': 0.694, 'pos': 0.0, 'compound': -0.296}
#
#  complex offering
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  team handle high volume data difficult identify trend pull actionable insight
# negative, {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.3612}
#
#  able make confident future prediction
# postive, {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.4939}
#
#  ai fast adept come decisionmaking taking pressure team affording time utilize finding forecast
# negative, {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'compound': -0.296}
#
#  next compare current resource ai potential return investment
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  review budget infrastructure determine whether resource align business need
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  analysis current challenge reveal return ai could bring brand
# postive, {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compound': 0.0772}
#
#  dig deep current pitfall establish whether ai drive cost saving growth process efficiency
# postive, {'neg': 0.0, 'neu': 0.683, 'pos': 0.317, 'compound': 0.6249}
#
#  youre using outdated technology looking drive brand performance gain competitive edge result may lean toward ai investment justifying investment become clearcut
# postive, {'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'compound': 0.6249}
#
#  review competition
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  fashion luxury landscape broad consumer demand trend vary across region
# negative, {'neg': 0.143, 'neu': 0.857, 'pos': 0.0, 'compound': -0.128}
#
#  competitor brand adopting ai technology improve marketing effort operation important consider similar option stay competitive
# postive, {'neg': 0.0, 'neu': 0.652, 'pos': 0.348, 'compound': 0.6597}
#
#  keep eye fellow brand ass leveraging ai
# negative, {'neg': 0.368, 'neu': 0.632, 'pos': 0.0, 'compound': -0.5423}
#
#  finally today industry expert offer suite tool datadriven solution tailored fashion lifestyle brand
# postive, {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3182}
#
#  considering external assistance uncover competitor strategy identify emerging trend measure impact marketing campaign effectivelyits important right people reviewing potential provider
# postive, {'neg': 0.0, 'neu': 0.913, 'pos': 0.087, 'compound': 0.2023}
#
#  decisionmakers best placed understand implication investment ask right question
# postive, {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.6369}
#
#  sharing challenge gap process upfront ensure tool implement fit purpose
# postive, {'neg': 0.0, 'neu': 0.395, 'pos': 0.605, 'compound': 0.802}
#
#  ensure provider train team intricacy software early
# postive, {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.3818}
#
#  way technology utilized full potential immediately team get best fully supported underpinned confident capable system
# postive, {'neg': 0.0, 'neu': 0.461, 'pos': 0.539, 'compound': 0.9162}
#
#  digitalsavvy consumer today demand product seek experience connection
# negative, {'neg': 0.176, 'neu': 0.824, 'pos': 0.0, 'compound': -0.128}
#
#  many way ai personalization datadriven strategy become linchpin meet expectation
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  industry leader continue shape way brand navigate landscape fashion lifestyle company better equipped ever ensure message resonates modern digital consumer
# postive, {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'compound': 0.6705}
#
#  foster brand loyalty drive brand performance
# postive, {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.5423}
#
#  effectively understanding implementing transformative strategy help better connect modern digital consumer propel brand forefront everevolving digital era
# postive, {'neg': 0.0, 'neu': 0.622, 'pos': 0.378, 'compound': 0.8176}
#
#  forbes communication councilis invitationonly community executive successful public relation medium strategy creative advertising agenciesdo qualify
# postive, {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.7717}
#
#  cop28 recently concluded dubai promising commitment fashion player undeniable acceleration pace towards positive change across industry since pandemic growing number market player improving effort term diversity inclusion taking measure address negative environmental footprint
# postive, {'neg': 0.083, 'neu': 0.586, 'pos': 0.331, 'compound': 0.8402}
#
#  however change witnessed since two thousand and twenty step right direction fashion player still generally behind sustainability commitment target implement goal paris agreement two thousand and thirty un agenda sustainable development
# postive, {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.7003}
#
#  challenge ahead multiple multifaceted production cost affordability end consumer lack unified reporting standard difficulty trace origin material tackle scope three emission
# negative, {'neg': 0.184, 'neu': 0.664, 'pos': 0.152, 'compound': -0.2023}
#
#  achieve sustainability brand company stakeholder need join force including consumer advocacy group policymakers well government ensure vulnerable economy left behind race climate change adaptation
# postive, {'neg': 0.066, 'neu': 0.694, 'pos': 0.24, 'compound': 0.6124}
#
#  fact higher cost typically involved sustainable fashion significant intention gap consumer company say sustainability action actually take reduce negative impact planet
# negative, {'neg': 0.151, 'neu': 0.776, 'pos': 0.073, 'compound': -0.4404}
#
#  hence real shift need take place business strategy consumption pattern policymakers aim force via stringent standard fashion item approved sale market
# postive, {'neg': 0.0, 'neu': 0.877, 'pos': 0.123, 'compound': 0.4215}
#
#  besides policy maker europe u trying force change via legislation another driving force could game changer pursuit sustainability fashion implementation gen ai
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  technology could indeed transform various aspect supply chain design retail recyclingwaste management
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  today gen ai become top investment priority many market player fashion industry beyond powerful tool streamlines process foster innovation creativity
# postive, {'neg': 0.0, 'neu': 0.62, 'pos': 0.38, 'compound': 0.8316}
#
#  however critical address ethical consideration bias algorithm environmental impact increased digitalisation industry embrace technology
# postive, {'neg': 0.181, 'neu': 0.441, 'pos': 0.377, 'compound': 0.6124}
#
#  technology continues evolve collaboration market player policymakers ai developer essential harness full potential technology application pursuit sustainability
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  digital fashion look like today
# postive, {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.3612}
#
#  question populated panel week inaugural new code digital fashion summit ran october three thousand and thirty-one
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  taking place london mayfairs royal institute expert insider across fashion design artificial intelligence emerging technology textile gaming industry gathered discus next chapter fashion creative renaissance role web3 play evolution
# postive, {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.8126}
#
#  digital fashion arena expected reach forty-eight billion two thousand and thirty-one according toallied research
# postive, {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'compound': 0.0258}
#
#  fledgling landscape struggled find place wider highly speculative fashion industry peaking hype two thousand and twenty-one
# negative, {'neg': 0.133, 'neu': 0.774, 'pos': 0.094, 'compound': -0.1796}
#
#  response year since seen brand builder alike streamline potential 3d augmented reality ar artificial intelligence ai web3 accelerating paradigm shift across entire segment
# postive, {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.4767}
#
#  speaker fabricant van drest outlier venturesjing dailybreaks key takeaway twoday event brand harness rapidly developing ecosystem
# ...
#
#  look future ai grow play larger role across industry empowering consumer shop personalised interactive way
# postive, {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'compound': 0.34}
#
#  plan levi test virtual clothing model generated artificial intelligence drew swift backlash industry late last month
# postive, {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.5994}
#
#  furor mainly focused diversity concern retailer proposal also stirred anxiety simmering industry year
# postive, {'neg': 0.111, 'neu': 0.719, 'pos': 0.17, 'compound': 0.2263}
#
#  critic levi strauss co partnership ai design firm lalalandai aimed show online shopper different type people wearing levi garment accused retailer looking inexpensively address issue representation potentially pushing professional model job process
# negative, {'neg': 0.125, 'neu': 0.875, 'pos': 0.0, 'compound': -0.5106}
#
#  hire model book agency stylist makeup feed set cost money said shawn grain carter professor fashion business management fashion institute technology new york
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  let make mistake levi save money
# postive, {'neg': 0.25, 'neu': 0.417, 'pos': 0.333, 'compound': 0.2023}
#
#  levi spokesperson referred statement companydenied intention save costswith project
# postive, {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.4939}
#
#  retailer said ai model planned introduce would supplement replace photoshoots live model
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  lalaland didnt respond request comment
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  worry technology displacing human labor nothing new theyre far distinct fashion workforce
# negative, {'neg': 0.209, 'neu': 0.791, 'pos': 0.0, 'compound': -0.4404}
#
#  ai used fashion year worker watching expansion space growing alarm
# negative, {'neg': 0.198, 'neu': 0.661, 'pos': 0.14, 'compound': -0.1779}
#
#  yanii gough model founder yanii model work one hundred model said many still dying get back consistency industry reemerges pandemicrelated disruption
# negative, {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'compound': -0.3612}
#
#  rise ai modeling firm client simply send email agency say hey exactly im looking someone find person said referring company book model everything photoshoots fitting
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  precedent concern like goughs
# postive, {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.3612}
#
#  shudu created two thousand and seventeen thought world first digital supermodel booked gig within past year highend brand asbmwandlouis vuitton
# postive, {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'compound': 0.25}
#
#  shudu designed black woman alsodrew criticismtoward diigitals ai modeling agency created founder cameronjames wilson white
# postive, {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'compound': 0.25}
#
#  today option continue expand brand advertiser looking use ai help market sell clothes
# postive, {'neg': 0.0, 'neu': 0.688, 'pos': 0.312, 'compound': 0.6124}
#
#  addition lalaland there also deep agency new ai startup allows user create virtual photoshoot either synthetic model ai version real person
# postive, {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'compound': 0.2732}
#
#  gough said also worry model image used without permission via ai concern sara ziff founder nonprofit advocacy group called model alliance said hearing well
# negative, {'neg': 0.107, 'neu': 0.815, 'pos': 0.078, 'compound': -0.2023}
#
#  fit model may replaced ai body scan said adding model try clothes designer manufacturer check sizing silhouette already calling organization growing number
# postive, {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.5423}
#
#  ziff said complained company hiring conduct body scan form basis product development without knowledge receiving compensation
# negative, {'neg': 0.153, 'neu': 0.847, 'pos': 0.0, 'compound': -0.4019}
#
#  theyre able design clothes virtually using scan model body rather actually book model person said ziff declined provide example citing model alliance policy maintaining anonymous hotline industry worker flag complaint
# negative, {'neg': 0.071, 'neu': 0.929, 'pos': 0.0, 'compound': -0.296}
#
#  fashion brand defended ai effort addons benefit shopper ai design studio agency working space similarly describe effort supplemental
# postive, {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.4588}
#
#  lalalands founder example said created company sustainably increase representation fashion
# postive, {'neg': 0.0, 'neu': 0.65, 'pos': 0.35, 'compound': 0.5106}
#
#  agent management company book model type job ziff described dont legally tell body scan could used project without compensation said
# negative, {'neg': 0.064, 'neu': 0.936, 'pos': 0.0, 'compound': -0.0762}
#
#  ziff advocating proposed fashion worker act new york said would force agency fully disclose scope work pay
# negative, {'neg': 0.08, 'neu': 0.92, 'pos': 0.0, 'compound': -0.1027}
#
#  current law leaf gray area around model right organize union ziff added resulting limited labor protection
# negative, {'neg': 0.112, 'neu': 0.888, 'pos': 0.0, 'compound': -0.2263}
#
#  model considered independent contractor many face heightened risk sued retaliated agency
# negative, {'neg': 0.174, 'neu': 0.826, 'pos': 0.0, 'compound': -0.2732}
#
#  representative professional creative field like thewriters guild america power propose standard best practice ai use industry
# postive, {'neg': 0.0, 'neu': 0.575, 'pos': 0.425, 'compound': 0.8625}
#
#  meanwhile ai model become realistic already impossible many consumer distinguish image human
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  ashley france influencer criticized levi partnership lalaland said hope regulator step
# postive, {'neg': 0.174, 'neu': 0.625, 'pos': 0.201, 'compound': 0.1027}
#
#  way put psa somethings ad somethings dietary supplement thankfully something photoshopped feel like type regulation france said
# postive, {'neg': 0.0, 'neu': 0.739, 'pos': 0.261, 'compound': 0.6486}
#
#  sara ruberg associate producer nbc news
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  may human responsible design machine forecasting trend informing product decision
# postive, {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.3182}
#
#  fact ai becoming integral part technology apparel industry substantiated growth annual spending predicted nearly quadruple two billion dollar two thousand and eighteen seventy-three billion dollar two thousand and twenty-two according juniper research
# postive, {'neg': 0.0, 'neu': 0.923, 'pos': 0.077, 'compound': 0.3818}
#
#  forecasting one example using artificial intelligence fashion industry
# postive, {'neg': 0.0, 'neu': 0.693, 'pos': 0.307, 'compound': 0.4767}
#
#  new technology helping retailer manage inventory using aipowered tool gauge demand
# postive, {'neg': 0.118, 'neu': 0.709, 'pos': 0.173, 'compound': 0.1779}
#
#  chatbots new fashion advisor offering two hundred and forty-seven connection customer help make purchasing decision
# postive, {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4019}
#
#  savvy ai algorithm help tailor product recommendation allow retailer create collection customer want buy
# postive, {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.7184}
#
#  edited retail technology company based london produce realtime data analytics software give retailer access full market data touch button
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  platform help retailer brand trade faster let look entire global market right colour shape pattern used company wide ranging boohoo farfetch tommy hilfiger marni
# postive, {'neg': 0.0, 'neu': 0.895, 'pos': 0.105, 'compound': 0.4019}
#
#  geoff watt edited ceo stated ai helping retailer number way cut core retailer decide stock price fundamental part retail thats real ai benefit layer
# postive, {'neg': 0.073, 'neu': 0.699, 'pos': 0.227, 'compound': 0.5267}
#
#  data marketer keen tell u everything
# postive, {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.3612}
#
#  ai quietly transforming fashion industry end consumer doesnt necessarily fathom online behaviour monitored recorded analysed
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  example hm us ai keep popular item wellstocked analysing receipt return gauge store need
# postive, {'neg': 0.0, 'neu': 0.823, 'pos': 0.177, 'compound': 0.4215}
#
#  marketing mode many brand analysing social medium data monitor fashion conversation allowing social data inform latest trend market prioritise segment interesting brand
# postive, {'neg': 0.0, 'neu': 0.886, 'pos': 0.114, 'compound': 0.4019}
#
#  one company makersights us data analytics combine factor search query social medium activity ecommerce sellthroughs consumer feedback provide clue likely become trend
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  data limit
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  data exceptionally useful detect rising trend hit mass adoption anticipate decline trend andrea bell head insight trend forecasting agency wgsn told vogue business
# postive, {'neg': 0.0, 'neu': 0.873, 'pos': 0.127, 'compound': 0.4927}
#
#  cant invent trend
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  good design come inspiration human touch still irreplaceable
# postive, {'neg': 0.0, 'neu': 0.488, 'pos': 0.512, 'compound': 0.743}
#
#  photo courtesy edited
# postive, {'neg': 0.0, 'neu': 0.444, 'pos': 0.556, 'compound': 0.3612}
#
#  two thousand and twenty-three breakout year generative ai use case emerging across fashion sector potential augment accelerate automate fashion business capability writing code amplifying creative process
# postive, {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'compound': 0.4404}
#
#  according tomckinsey co latest report overall financial impact gen ai fashion industry significant much quarter value expected driven use case design product development stage value chain
# postive, {'neg': 0.0, 'neu': 0.777, 'pos': 0.223, 'compound': 0.6808}
#
#  gold standard business intelligence
# postive, {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.4767}
#
#  find
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  business fashionmckinseystate fashion two thousand and twenty-four survey global fashion executive found seventy-three fashion executive said generative ai priority business two thousand and twenty-four le third twenty-eight tried using creative process design product development
# postive, {'neg': 0.0, 'neu': 0.919, 'pos': 0.081, 'compound': 0.4404}
#
#  mckinsey suggests highlight fashion company yet capturing value creative process
# postive, {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'compound': 0.7717}
#
#  report read caution understandable
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  technology could impact job workflow
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  fashion industry also seen fair share technologicalenthusiasm swiftly sputtered notably metaverse
# postive, {'neg': 0.0, 'neu': 0.544, 'pos': 0.456, 'compound': 0.6908}
#
#  last year started much enthusiasm metaverse since died however mckinseys report suggests generative ai practical application making attractive business investor
# postive, {'neg': 0.136, 'neu': 0.644, 'pos': 0.22, 'compound': 0.296}
#
#  access comprehensive company profile market powered globaldata
# postive, {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.25}
#
#  save hour research
# postive, {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.4939}
#
#  gain competitive edge
# postive, {'neg': 0.0, 'neu': 0.164, 'pos': 0.836, 'compound': 0.6249}
#
#  download email arrive shortly
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  confident unique quality company profile
# postive, {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.4939}
#
#  however want make beneficial decision business offer free sample download submitting form
# postive, {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.7579}
#
#  example equity funding generative aifocused startup skyrocketed reaching 141bn first half two thousand and twenty-three alone compared 25bn two thousand and twenty-two
# negative, {'neg': 0.084, 'neu': 0.84, 'pos': 0.076, 'compound': -0.0516}
#
#  fashion sector focus generative ai far oneoff use case cost efficiency customer experience advantage
# postive, {'neg': 0.0, 'neu': 0.727, 'pos': 0.273, 'compound': 0.5423}
#
#  technology also offer potential wider industry disruption
# negative, {'neg': 0.294, 'neu': 0.706, 'pos': 0.0, 'compound': -0.3612}
#
#  ai already making mark online shopping assistance online retailerzalandoannouncing launch beta chatgptbased natural languagepowered shopping assistant earlier year allows online customer ask question get answer well customised product recommendation
# postive, {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'compound': 0.5574}
#
#  u fashion conglomeratekeringand online marketplaceshopifyhave also introduced ai chatbots brand adore methe lingeriecompany recently acquired victoria secret using technology write product description site
# postive, {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'compound': 0.5574}
#
#  report add ultimately greatest value may lie using gen ai endtoend way enables enhances creativity
# postive, {'neg': 0.0, 'neu': 0.566, 'pos': 0.434, 'compound': 0.8481}
#
#  example fast fashion gen ai could accelerate design process inject agility trend detection product development leverage analytics data rapidly produce large number new design
# postive, {'neg': 0.0, 'neu': 0.947, 'pos': 0.053, 'compound': 0.0772}
#
#  spanish brand desigual already launched ondemand collection designed using ai tool
# postive, {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.128}
#
#  company developing generative ai software fashion sector claim technology reduce manual task take day mere hour even second
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  new technology could free designer manual task allowing focus creative work
# postive, {'neg': 0.0, 'neu': 0.592, 'pos': 0.408, 'compound': 0.7351}
#
#  human designer remain key generative ai enable role oriented around curation according report
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  however report also note word caution potential must communicated clearly creatives ensure technology adopted without undermining role designer
# postive, {'neg': 0.0, 'neu': 0.669, 'pos': 0.331, 'compound': 0.7514}
#
#  continues implemented effectively technology benefit amplify creative process thus augmenting human capability retaining artistic skill knowledge designer
# postive, {'neg': 0.0, 'neu': 0.614, 'pos': 0.386, 'compound': 0.8316}
#
#  ultimately say expert humancentred innovation likely important use ai
# postive, {'neg': 0.0, 'neu': 0.614, 'pos': 0.386, 'compound': 0.5267}
#
#  source globaldata
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  globaldatas job database suggests last three year december two thousand and twenty december two thousand and twenty-three interest employing individual generative ai grown
# postive, {'neg': 0.0, 'neu': 0.88, 'pos': 0.12, 'compound': 0.4588}
#
#  online giantamazonis leading way five hundred and thirty-seven job posted time period followed u supermarket retailerwalmartwith thirty-eight job posted
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  company exploring generative ai role according globaldata include luxury u fashion conglomeratetapestryand u fashion brandabercrombie fitch
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  signal coverage powered byglobaldatas thematic engine tag million data item across six alternative datasets patent job deal company filing social medium mention news theme sector company
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  signal enhance predictive capability helping u identify disruptive threat across sector cover company best placed succeed
# postive, {'neg': 0.225, 'neu': 0.395, 'pos': 0.379, 'compound': 0.5994}

# %%
data = [] #List to store dictioneries
for sentence in sentences:
  sentiment, polarity = getPolarity(sentence)
  new_item = {'sentence' : sentence, 'sentiment' : sentiment, 'category' : 'Fashion'}
  data.append(new_item)

df = pd.DataFrame(data)

df.to_csv('Fashion (no numbers) - Vader ver.csv', index=False)
