# %%
# Downloading libraries for web-scraping
# !pip install requests
# !pip install beautifulsoup4==4.9.3
# !pip install bs4
# !pip install html5lib
# !pip install num2words
# !pip install vaderSentiment

# Importing libraries for web-scraping and tokenization purposes
from bs4 import BeautifulSoup as bs
import requests
import nltk
import pandas as pd
import re
from textblob import TextBlob
from num2words import num2words
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# The list of common words such as "a", "an", etc.
nltk.download('stopwords')
# Download a collection of popular resources from the NLTK library
nltk.download('popular', quiet=True)
# Sentence tokenization (Splitting a text into individual senteces)
nltk.download('punkt')
# English vocabulary database
nltk.download('wordnet')
# Used for training language models or evaluating nlp algothms
nltk.download('brown')
# Used for performing sentiment analysis on text
nltk.download('vader_lexicon')

from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize

lemmatizer = WordNetLemmatizer()
analyzer = SentimentIntensityAnalyzer()
stemmer = SnowballStemmer("english")
stop_words = stopwords.words("english")
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Collecting beautifulsoup4==4.9.3
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.8/115.8 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4==4.9.3) (2.5)
# Installing collected packages: beautifulsoup4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.3
#     Uninstalling beautifulsoup4-4.12.3:
#       Successfully uninstalled beautifulsoup4-4.12.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yfinance 0.2.37 requires beautifulsoup4>=4.11.1, but you have beautifulsoup4 4.9.3 which is incompatible.
# Successfully installed beautifulsoup4-4.9.3
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib) (0.5.1)
# Collecting num2words
#   Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 3.4 MB/s eta 0:00:00
# Collecting docopt>=0.6.2 (from num2words)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=4fd29f259e5360bac7547ebe1a408ae7cc21a671b8b273f5dab1136290350c91
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: docopt, num2words
# Successfully installed docopt-0.6.2 num2words-0.5.13
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2024.2.2)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
sentences = []

def scrape_clean (url, div_class,id_name=None):
  # Load the website
  website = requests.get(url).text
  soup = bs(website,'html.parser')

  # Find the div section that is the parent of all paragraphs
  div = soup.find_all('div', attrs={'class':div_class, 'id':id_name})

  # Get the text from paragraphs
  extracted_text = []
  for div in div:
      paragraphs = div.find_all('p')
      for paragraph in paragraphs:
          extracted_text.append(paragraph.get_text(strip=True))  # Remove leading/trailing whitespace

  # Splitting the text into sentences, remove the stopwords and punctuations, and save the cleaned version in a list
  sentences = []
  for text in extracted_text:
    sentence = sent_tokenize(text)
    for item in sentence:
      # Convert to lowercase
      text_lowercase = item.lower()
      # Remove punctuation
      text_without_punctuation = re.sub(r"[^\w\s]", "", text_lowercase)
      # Remove stopwords and stem words
      tokens = word_tokenize(text_without_punctuation)
      new_tokens = []
      for word in tokens:
        if word.isnumeric():
          word = num2words(word)
          new_tokens.append(lemmatizer.lemmatize(word))
          continue
        elif word not in stop_words:
          new_tokens.append(lemmatizer.lemmatize(word))
          continue
      # Join tokens back into a string
      cleaned_text = " ".join(new_tokens)
      sentences.append(cleaned_text)

  return sentences

# %%
website1 = 'https://educationhub.blog.gov.uk/2023/12/06/artificial-intelligence-in-schools-everything-you-need-to-know/'
class1 = 'entry-content'
text1 = scrape_clean(website1, class1)
sentences.extend(text1)

# %%
website2 = 'https://www.linkedin.com/pulse/review-ai-education-huzaifa-khan-rktgf'
class2 = 'counter-list'
text2 = scrape_clean(website2, class2)
sentences.extend(text2)

# %%
website3 = 'https://slidesgo.com/slidesgo-school/news/ai-in-education-survey-exclusive-slidesgo-insights-of-ai-tools-for-education'
class3 = 'counter-list'
id3 = None
text3 = scrape_clean(website3, class3, id3)
sentences.extend(text3)

# %%
website4 = 'https://www.insidehighered.com/news/student-success/life-after-college/2024/01/10/survey-college-students-thoughts-ai-and-careers'
class4 = 'node-content'
id4 = None
text4 = scrape_clean(website4, class4, id4)
sentences.extend(text4)

# %%
website5 = 'https://today.yougov.com/technology/articles/45607-most-think-schools-should-teach-about-ai-poll'
class5 = 'app-container ng-tns-c2792280337-0 ng-trigger ng-trigger-routeAnimation'
id5 = None
text5 = scrape_clean(website5, class5, id5)
sentences.extend(text5)

# %%
website6 = 'https://www.the74million.org/article/how-do-teachers-feel-about-their-jobs-the-impact-of-ai-new-survey-has-answers/'
class6 = 'article_content'
id6 = None
text6 = scrape_clean(website6, class6, id6)
sentences.extend(text6)

# %%
website7 = 'https://www.theguardian.com/technology/2024/feb/01/more-than-half-uk-undergraduates-ai-essays-artificial-intelligence'
class7 = 'dcr-lw02qf'
id7 = "maincontent"
text7 = scrape_clean(website7, class7, id7)
sentences.extend(text7)

# %%
website8 = 'https://www.forbes.com/sites/nickmorrison/2023/05/31/half-of-teachers-believe-ai-will-change-education-for-the-better/'
class8 = 'article-body fs-article fs-responsive-text current-article'
id8 = None
text8 = scrape_clean(website8, class8, id8)
sentences.extend(text8)

# %%
website9 = 'https://www.learner.com/blog/ai-education-survey'
class9 = 'w-node-_6b677d7e-03e7-913b-97b5-19c037c52658-3294f5cd'
id9 = 'content'
text9 = scrape_clean(website9, class9, id9)
sentences.extend(text9)

# %%
website10 = 'https://doodlelearning.com/us/math/guides/ai-in-education'
class10 = 'elementor-widget-container'
id10 = None
text10 = scrape_clean(website10, class10, id10)
sentences.extend(text10)

# %%
website11 = 'https://www.the74million.org/article/national-chatgpt-survey-teachers-accepting-ai-into-classrooms-workflow-even-more-than-'
class11 = None
id11 = 'content'
text11 = scrape_clean(website11, class11, id11)
sentences.extend(text11)

# %%
website12 = 'https://thetutorsassociation.org.uk/2023/09/27/students-begin-to-embrace-ai-for-learning-survey-shows/'
class12 = 'entry-content clear'
id12 = None
text12 = scrape_clean(website12, class12, id12)
sentences.extend(text12)

# %%
website13 = 'https://thetutorsassociation.org.uk/2023/09/27/students-begin-to-embrace-ai-for-learning-survey-shows/'
class13 = 'entry-content clear'
id13 = None
text13 = scrape_clean(website13, class13, id13)
sentences.extend(text13)

# %%
website14 = 'https://www.fenews.co.uk/skills/new-research-ai-for-education-in-the-uk-does-the-potential-outweigh-the-risk/'
class14 = 'entry-content'
id14 = None
text14 = scrape_clean(website14, class14, id14)
sentences.extend(text14)

# %%
website15 = 'https://www.theguardian.com/commentisfree/2023/jul/14/ai-artificial-intelligence-disrupt-education-creativity-critical-thinking'
class15 = 'dcr-lw02qf'
id15 = 'maincontent'
text15 = scrape_clean(website15, class15, id15)
sentences.extend(text15)

# %%
for i in sentences:
  print(f'{i}\n')
# Out:
# artificial intelligence ai stay already positive impact across society including education sector
#
# believe could used improve education system example early research suggests could used free teacher time provide personalised support pupil
#
# want make emerging technology need understand risk well opportunity
#
# set develop artificial intelligence education safely explore could benefit teacher young people
#
# investing ai tool gathering evidence teacher pupil using ai already investigating take advantage ai education
#
# first step already
#
# understand education already use generative ai including use produce content text imagery audio launched call evidence gather view educational professional academic edtech sector risk possibility
#
# result show ai already used reduce administrative task optimistic potential
#
# organised twoday hackathon teacher andschool leader across england allowed teacher school leader work data scientist come solution use ai tackle reallife issue like teacher workload
#
# result hackathon published next year
#
# boost oak national academy online learning platform help develop new free resource teacher powered ai lesson planner classroom quiz
#
# still early stage exploring possibility ai could benefit teacher
#
# one area looking includes using ai tool tocut teacher workloadby providing teacher virtual assistant
#
# drafting curriculum plan producing highquality teaching resource ai potential reduce amount time teacher spend administrative task focus best teaching supporting pupil
#
# absolutely
#
# teacher irreplaceable ai could never substitute teacher professional judgement personal relationship pupil
#
# aiming develop ai serve teacher better take away unique role play
#
# also making sure ai tool teacher always charge always human loop
#
# example wouldnt support use ai draft personalised plan guidance without expert human involvement
#
# much work done explore ai could enhance pupil learn know concern around risk young people especially new form technology
#
# development ai tool young people would prioritise safety security
#
# includes ensuring child young people accessing creating harmful inappropriate content online generative ai data intellectual property protected
#
# ai tool interactive easily personalised could used provide young people virtual tutor
#
# name one example ai could help provide pupil bespoke workplan based marking assessment teacher
#
# many positive us ai tool know parent teacher concerned pupil using homework cheat exam
#
# result call evidence hackathon provide base future policy ai including school work around possibility student using cheat
#
# statement begin right
#
# well707 surveyed teachersfind ai tool beneficial education sector
#
# among seven hundred and fifty teacher question consider generative artificial intelligence tool beneficial detrimental education seven ten answered beneficial
#
# artificial intelligence helping daily work natural embrace new resource
#
# consider ai education beneficial well get later
#
# order use ai must first know exist
#
# surveyed teacher
#
# six hundred and fifteen answered used generative ai tool last three month
#
# perhaps fact knew slidesgo helping factor since already offer ai tool user
#
# maybe
#
# weve already said seven hundred and seven surveyed teacher find ai beneficial
#
# quality daily work teacher
#
# improve71of think
#
# think several reason better planning getting idea lesson
#
# themain reason use ai tool answer mixed bag wed like highlight popular answer saving time
#
# find ai useful finding inspiration others state ai tool help minimize blankpage syndromeyou know moment life need start writing paper article slide even though idea mind seem put word
#
# latter seems related timesaving concept conclude clock higher threat ai
#
# joke aside here infographics showing data
#
# alright
#
# know teacher use ai
#
# theyre slowly becoming one tool repertoire like pen notebook blackboard chalk presentationswe cant forget presentation
#
# first thing majority surveyed teacher stated thatgenerative ai tool education used enhance interaction student
#
# theyre leveraging power advanced tool create highly personalized educational content tailored meet unique learning need student
#
# isnt amazing know knowing student need ai help fine tune lesson make
#
# there little misconception need take care work teacher isnt limited teaching
#
# gosh
#
# picture hundred teacher shaking head right administrative task big part teacher work enthusiastic nod efficiency ai notable735of surveyed teacher reported thatai instrumental reducing time spend task
#
# scheduling planning seem le tedious thing using ai
#
# benefit derived clear teacher able channel newfound time energy enhancing learning experience student
#
# seems little bit overthetop highlight teacher didnt answer question
#
# gave u opinion word help u understand theyre thinking
#
# heartily felt leaving work time statement
#
# hectic world like today finding right balance work family difficult
#
# outside people might realize work behind scene teacher carry
#
# simply leave school giving last lesson day
#
# testimonial hint ai helping teacher find air breathe metaphorically speaking
#
# doubt ai streamlining teacher work definitely helping save precious time
#
# take moment imagine world teacher use ai tool create engaging content also smoothly run class draw inspiration assignment even whip riveting presentation
#
# wait isnt present time
#
# going back survey weve asked teacher use ai tool
#
# plain simple
#
# textbook great student shouldnt limit memorizing appears
#
# there
#
# teacher tell topic subject day lesson
#
# five hundred and thirty-five surveyed teacher answered theirmain use ai education organize class
#
# second thought it465of also answered ai help find inspiration preparing assignment student
#
# combined creativity teacher end result interesting project student may need complete
#
# also encourages student think outside box bit proactive well creative completing assignment
#
# thats great isnt
#
# wont memorizing machine critical thinker
#
# slidesgo
#
# main content
#
# presentation
#
# already know good part user base composed people education world
#
# many mostpopular templatesare used lessonsgoes without saying even havereadymade presentationsfor various educational level available different language
#
# template essential come saving time
#
# saving time
#
# pattern clear u decided introduce ai presentation maker world two main reason helping user save time excuse u sounding like broken record lending hand techsavvy
#
# survey also say teacher take one two hour create presentation class
#
# much
#
# thing create presentation faster without noticing drop quality plus
#
# happens use ourai presentation maker
#
# according time reduced thirty minute le
#
# talking
#
# impactful quote
#
# swear one surveyed people
#
# ah milliondollar question
#
# busy singing praise ai education let forget every superhero kryptonite ai challenge associated integration education sector
#
# weve gathered surveythe main reason using ai unsurprisingly knowing use
#
# yeah there chatgpt there midjourney there dalle fingertip one thing mastering another
#
# something take time already know teacher dont much spare although turn ai eventually reduce time take task
#
# perceived endless loop dont enough time learn use ai ai never able free time could used learn use ai theyre able free time didnt enough time begin
#
# applying daily task teacher another reason ai use least education
#
# perhaps ai generate interesting content something easily taught
#
# generative tool give image accurate enough regarding need teach
#
# also important note that22of surveyed teacher believe generative ai tool used teaching dont know prevent student misusing
#
# really tell whether student really learned concept ai work
#
# probably one key idea dialogue
#
# school encouraging discussion use ai education
#
# help student understand reason behind rule spark meaningful conversation ai ethic
#
# assignment carried school monitoring system put place track potential misuse ai tool
#
# could involve use analytics identify unusual pattern student work incorporation software detect aigenerated content
#
# common question popping every next job ai replace
#
# ai certainly flexing muscle realm education really think able replace human touch teacher
#
# sure ai might process vast amount data provide personalized learning experience even serve fresh content faster cafeteria lunch
#
# youll agree u teacher arent information dispenser replaced newer shinier model
#
# counselor mediator inspirer lifeguides
#
# ai replicate
#
# richard dawson feel urge say thatsurvey saysthat64of teacher took time answer question believe thatais wont replacement human educator least short term
#
# point view
#
# weve gathered thanks survey conclude ai slowly finding way daily work teacher helping administrative work also serving inspiration content generator lesson
#
# main benefit ai education mainly saving time streamlining planning process future lesson reducing mental stress teacher subject demanding field education
#
# seen threat replacement human teacher short run teacher cant help think difficulty preventing misuse ai student
#
# also find bit difficult properly get ai asked
#
# conclusion
#
# familiar generative ai possibility offer
#
# use often hand something make tremble
#
# would like hear please follow u social share opinion
#
# additionally might want check article onhow generate good prompt generate ai presentation especially youd like use ai presentation maker
#
# please note seven hundred and seventy-six teacher participated survey october thirty november thirteen two thousand and twenty-three mainly north america
#
# primary objective gather teacher educator perception ai education use ai tool enhance teaching community
#
# total seven thousand, four hundred and ninety-three respondent participated including seven hundred and seventy-six identified teacher
#
# have5articles leftsign free account log
#
# similar student say ai impacting academic plan eleven percent student new student voice survey say rise ai significantly influenced career plan
#
# additional thirty-one percent say influenced career plan somewhat
#
# poca wander stockistockgetty image plus
#
# studentslike studying university south florida muma college business center marketing sale innovation customer experience behavioral ai labare already exposed artificial intelligence help workforce
#
# lab us various technology measure brain wave eye movement otherwise understand human respond variety stimulus
#
# student get opportunity apply insight across setting sometimes partnership commercial business government agency
#
# student learning applying stateoftheart skill participating research say rob hammond center director make employable graduation
#
# even beyond specialized training nearly three four student say institution preparing ai workplace least somewhat
#
# find new flash survey one thousand, two hundred and fifty student across forty-nine four twoyear college frominside higher edand college pulse student voice series
#
# survey main takeaway
#
# asked much rise artificial intelligence influenced theyre studying plan study college fourteen percent student say influenced lot
#
# additional thirty-four percent say influenced somewhat
#
# year class two thousand and twenty-four least influenced way thirty-five percent student saying ai affected theyre studying plan study either lot somewhat
#
# class two thousand and twenty-five two thousand and twenty-six incrementally influenced majority class two thousand and twenty-seven sixty-four percent say ai least somewhat impacted academic plan
#
# difference may make sense light buzz around generative ai within last year
#
# two fouryear college student survey report equally influenced ai area
#
# student major gender financial aid status appear factor
#
# field seven percent art humanity student say ai influenced plan study compared fifteen percent natural science student seventeen percent social science student twenty-two percent student identifying interdisciplinary major
#
# gender twenty percent male student say ai significantly impacted academic plan versus ten percent woman four percent nonbinary student insufficient response show certain demographic
#
# financial aid status sixty percent student financial aid say ai influencing study plan either lot somewhat compared forty-five percent student receiving financial aid
#
# another key difference fifty-two percent continuinggeneration student say ai influencing plan study either lot somewhat compared forty-one percent firstgeneration student
#
# similar student say ai impacting academic plan eleven percent student say rise ai significantly influenced career plan
#
# additional thirty-one percent say influenced career plan somewhat
#
# year class two thousand and twenty-seven appears impacted sixty-one percent saying rise ai affected career plan either lot somewhat thirty-one percent class two thousand and twenty-four say forty-one percent class two thousand and twenty-five fifty-one percent class two thousand and twenty-six
#
# gender appears matter well fifty-two percent men study saying ai impacting career plan versus thirty-five percent woman thirty-five percent nonbinary student
#
# yet there significant difference fouryear twoyear student response relatively student without financial aid fifty-one percent forty-one percent say theyre influenced ai respect either lot somewhat
#
# relatively continuinggeneration student forty-six percent firstgeneration student thirty-four percent also say ai least somewhat impacting career plan
#
# nearly three four student say college university preparing ai workplace either lot twenty-seven percent somewhat forty-five percent
#
# newer student likely soontograduate student expect ai preparation eighty-one percent class two thousand and twenty-seven saying institution preparing least somewhat
#
# yet even sixty-six percent class two thousand and twenty-four say
#
# major student art humanity bit le likely say sixty-six percent student social science seventy-eight percent
#
# natural science share seventy percent among interdisciplinary major seventy-one percent
#
# gender seventy-seven percent men say institution readying ai work least somewhat sixty-nine percent woman nonbinary respondent
#
# seventy-six percent continuinggeneration student expect institution ready ai work least somewhat compared sixty-six percent firstgen peer
#
# institution preparing ai work
#
# one priority student taught ethic using ai nearly three four student choosing
#
#
#
# two choice sixty-two percent list five option prioritizing teaching core skill critical thinking problemsolving
#
# presumably build skill make student wouldbe job resistant ai
#
# close third choice teaching in out using ai meaning student also eager practical training sixty percent
#
# twenty-eight percent student say institution prepare ai work encouraging career path le likely impacted ai
#
# result relatively consistent across student subgroup institution type including gender major first continuinggeneration status
#
# mhammed abdous assistant vice president teaching learning technology associate director center faculty development old dominion university virginia say response strong indication transformative potential ai registering student respondent seem rightly aware ai reshaping job market many different area abdous cite reportssuggestingthat forty percent current job potentially replaceable ai adding even job wont displaced still subject change due generative ai power reshape work
#
# time ai also stimulate demand new skill require human ingenuity creativity empathy ethicsthings ai add
#
# regarding related student voice finding training student want abdous say student right target
#
# abdous suggests college university consider following
#
# suzanne helbig associate vice provost division career pathway university california irvine say institution adopt intentional practice cultivate continuouslearning mindset critical thinking skill futureproof student mean providing way student connect theyre learning classroom world work equipping faculty staff member help student identify articulate transferable skill future role
#
# institution harness workforce data industry connection inform curriculum program development add plus resource elevate campus career service address top reason student seek higher education advance career
#
# proliferation ai effect future work make career service even greater institutional imperative
#
# action institution taken help ensure student considering ai planning future career
#
# share career prep tip advicehere
#
# discover public data featuring diverse range survey result article tracker popularity ranking
#
# latest political survey indepth analysis find world think
#
# get intelligence evergrowing source consumer data twenty-four million registered panel member fifty-five market
#
# call living data
#
# discover public data featuring diverse range survey result article tracker popularity ranking
#
# latest political survey indepth analysis find world think
#
# get intelligence evergrowing source consumer data twenty-four million registered panel member fifty-five market
#
# call living data
#
# new yougov pollingfinds american divided view advance artificial intelligence ai affect k12 education system slightly saying somewhat negative impact thirty-six rather positive impact twenty-five
#
# younger american adult far optimistic ai effect education older american
#
# adult thirty likely say ai positive thirty-nine rather negative twenty-two effect k12 education people sixty-five older twice likely say effect negative forty-four rather positive eighteen
#
# regarding k12 school respond advance ai american twice likely say school focus teaching student appropriately use ai fifty-two say school focus preventing student using ai twenty-four
#
# despite younger adult greater optimism ai school likely older american back preventing student using ai
#
# one reason likely many american view airelated skill necessary student future career nineteen say learning use ai necessary forty-two say somewhat necessary
#
# people believe ai somewhat necessary future student career far likely people dont believe school focus teaching student appropriately use ai seventy v thirty
#
# one concern raised ai effect education whether render obsolete certain way evaluating student learning performance
#
# yet find american divided view ai affect takehome essay thirty saying ai make type assignment le useful past twenty-two saying make useful twenty-five saying make difference
#
# large age difference question ai affect usefulness takehome essay forty-two adult thirty say ai advance increase utility takehome essay compared eight people sixty-five older
#
# american school today would use ai assist assignment even prohibited
#
# one three say would thirty-two roughly equal share thirty-five say would
#
# rest sure preferred say
#
# two five adult thirty forty-one say would use ai assist essay school even prohibited
#
# twenty-one american sixty-five older say
#
# american likely thirty-four twenty-eight believe currently software available able accurately distinguish writing done student writing produced ai
#
# largest share thirty-eight however unsure whether software currently able
#
# carl bialik linley sander contributed article
#
# see result yougov poll
#
# methodologythis poll conducted online april thirteen twenty two thousand and twenty-three among one thousand u adult citizen
#
# respondent selected yougovs optin panel using sample matching
#
# random sample stratified gender age race education geographic region voter registration selected two thousand and nineteen american community survey
#
# sample weighted according gender age race education two thousand and twenty election turnout presidential vote baseline party identification current voter registration status
#
# demographic weighting target come two thousand and nineteen american community survey
#
# baseline party identification respondent recent answer given prior march fifteen two thousand and twenty-two weighted estimated distribution time thirty-three democratic twenty-eight republican
#
# margin error overall sample approximately three
#
# image adobe stock svitlana
#
# explore data article
#
# elementary education
#
# artificial intelligence
#
# education
#
# technology
#
# copyright two thousand and twenty-four yougov plc
#
# right reserved
#
# get story like delivered straight inboxsign seventy-four newsletter
#
# year ed tech company work forhmh conduct survey designed understand obstacle opportunity teacher administrator experience
#
# yearseducator confidence reportrevealed new insight one thousand, two hundred k12 teacher feeling profession overall well attitude toward generative artificial intelligence buzzword rapidly become practical inescapable classroom technology
#
# sentiment around profession reached alltime low two thousand and twenty-two year survey show confidence education inching increasing forty one hundred two thousand and twenty-two forty-two two thousand and twenty-three
#
# current index score correlate around c grade rise could represent stabilization following particularly challenging period educator across country
#
# encouraging see teacher beginning transition survival mode toward regaining confidence profession
#
# believe last year marked low point turning corner see teacher feeling enthusiastic staying industry case new educator joining field
#
# addition positive trend teacher surveyed year report also identified key area feel optimistic feel making positive impact state education
#
# include use digital platform improve student engagement thirty-one educator surveyed felt optimistic well increased attention student social emotional need fifty educator reported point optimism
#
# based annual survey well work thousand teacher firsthand experience school clear teaching increasingly complex job professional especially concerned wellbeing student colleague
#
# one bright spot research confidence competence educator feel knowledge technology
#
# recent experience interrupted schooling increased reliance digital tool created teaching force capitalizing promise technology
#
# technical knowhow crucial setting student success
#
# new piece technology puzzle generative ai come forefront k12 conversation past year
#
# survey find educator looking guidance using ai recognize transformative possibility
#
# half educator surveyed fifty-seven agreed generative ai inevitable harnessed positively classroom fifty-eight said would interested professional development coaching around new technology
#
# ai represents potential new era education one teacher becoming learner driving change district school
#
# majority educator surveyed ninety yet actively integrating ai classroom
#
# however early adopter ai ten eager
#
# use two hundred and two thousand, two hundred and twenty-three school year seventy-four said expect increase current school year
#
# survey made clear educator feeling new technology mixed
#
# consensus key activity teacher feel aigenerated content could accelerate achievement
#
# half fifty-one said artificial intelligence could support worksheet creation forty-eight identified assistance lesson plan forty-one pointed aid coming prompt writing assignment
#
# sixty-five teacher surveyed said time would impact wellbeing ai positioned help
#
# creating writing prompt lesson plan worksheet take time
#
# simplifying task ai give teacher time focus need foster relationship student
#
# educator starting unpack benefit generative ai
#
# proper support new technology allow thing best fostering deep learning building relationship counseling student building community learner turn improve state profession
#
# get story like delivered straight inboxsign seventy-four newsletter
#
# half undergraduate say consult artificial intelligence programme help essay school trialling use classroom
#
# survey one thousand uk undergraduate conducted higher education policy institute hepi found fifty-three using ai generate material work would marked
#
# one four using application google bard chatgpt suggest topic one eight using create content
#
# five admitted copying pasting unedited aigenerated text assessment
#
# teacher also seeking use ai streamline work education endowment foundation eef signing secondary school new research project use ai generate lesson plan teaching material well exam model answer
#
# dr andres guadamuz reader intellectual property law university sussex said surprise student adopting ai suggested institution needed explicit discussing best use study tool
#
# ive implemented policy mature conversation student generative ai
#
# share utilise guadamuz said
#
# primary concern significant number student unaware potential hallucination inaccuracy ai
#
# believe responsibility educator address issue directly
#
# hepi survey found one three student using ai know often hallucinates ie invents statistic academic citation book title fill perceives gap
#
# guadamuz said essay handed last year clearly used unedited chatgpt output given away boring style written
#
# ai usage spread survey found fewer student willing use
#
# world evolving educator need adapt establishing clear guideline policy well designing challenging assessment
#
# however difficult resourceconstrained environment academic already overburdened underpaid guadamuz said
#
# according eefs proposal use ai might instead help cut workload burden teacher well improving quality teaching
#
# gillian keegan education secretary said ai could take heavy lifting marking planning teacher
#
# half fifty-eight school inenglandtaking part eefs project given toolkit create assessment material practice question exam model answer tailor lesson specific group child
#
# aigenerated lesson plan assessed independent panel expert
#
# prof becky francis chief executive eef said there already huge anticipation around technology could transform teacher role research actual impact practice currently limited
#
# finding trial important contribution evidence base bringing u closer understanding teacher use ai
#
# half teacher think ai force good school pic getty creative
#
# half secondarylevel teacher believe ai change education better according newsurvey
#
# similar proportion say school either blocked restricted access ai one form another reflecting level turmoil already prompted education sector
#
# student using technology cheat assessment coursework quickly identified one risk education openai released chatgpt late last year
#
# one concern alongside impact student mental health identified school leader earlier month whowarnedthat ai posed real present danger education
#
# fear impact ai far confined classroom
#
# expert including sam altman ceo openai signed aletterwarning technology could lead extinction humanity
#
# openai ceo sam altman photo win mcnameegetty image
#
# signatory also included professor geoffrey hinton yoshua bengio two triumvirate described godfather ai prof bengio expressingregretover giving safety higher priority
#
# third godfather professor yann lecunn said apocalyptic warning overblown however
#
# global survey teacher found many harbor doubt impact ai majority feel potential benefit outweigh risk
#
# half fifty-two secondarylevel teacher surveyed said believed ai would change teaching profession better
#
# among perceived benefit using ai teach student interact understand ai model backed sixty teaching critical thinking fifty-six tool edit student work fifty-two
#
# half fifty-six said school curriculum assessment adapted account student using aigenerated content
#
# deep division use ai illustrated level concern among educator according survey one thousand, eight hundred secondarylevel teacher across australia finland france germany japan netherlands singapore uk u
#
# three quarter seventy-eight said shared concern negative impact ai learning outcome two third sixty-six saying feared value writing skill would diminished would limit student creativity
#
# almost half forty-eight teacher said school already blocked restricted use ai classroom
#
# teacher uk u germany finland likely positive feeling ai counterpart singapore japan france
#
# secondarylevel teacher also convinced importance student learning digital skill according survey carried consultancy firm capgemini
#
# eight ten eighty-two said education digital skill compulsory sixty-four said digital skill important help student become jobready
#
# seventy teacher said believed student possessed necessary skill confidence shared student fifty-five 1618yearolds agreeing
#
# teacher large city likely confidence student digital skill rural area eighty-three v forty urban teacher likely rural counterpart believe digital skill important ninety-four v sixty-seven
#
# conviction technology like generative ai increasingly shape world amplify criticality foundational digital skill also hold key bridging gap selfpaced learning hyperpersonalization capabilitiessaid shobha meera chief corporate responsibility officer capgemini
#
# welcome modern landscape education artificial intelligence ai isnt topic computer science class
#
# comfortable parent technological leap thats weaving childrens education
#
# recent survey learnercom reveals mix optimism curiosity concern
#
# parent eager learn
#
# school clearly need improve communication parent topic half parent surveyed unaware schoolâs policy regarding use implementation ai tool technology
#
# especially important considering that68 parent believe using ai tool cheat gain unfair advantage assignment exam least somewhat common
#
# teacher share concern
#
# melissa hargrave say âall need access internet browser easily find ai platform enter essay prompt even math question receive automatically generated answer
#
# seen student use ai wayand use continueâ
#
# â
#
# teacher jonathan peralta express similar concern certainly classroom landscape undergone significant transformation particularly activity like writing art project
#
# â
#
# â
#
# parentsâ worry go beyond cheating
#
# come ai integration school parent concerned ninety-seven parent surveyed expressed least one worrywith average three concern per parent
#
# risk misinformation overreliance technology top mind followed closely loss personal touch learning
#
# â
#
# still twelve parent believe ai related technology part high school curriculum
#
# hargrave agrees âit mandatory curriculum teach proper usage ai taking ai writes verbatim considered plagiarism
#
# teaching student take ai generated content rewording word way would reword work human essential skill student need learnâ
#
# â
#
# â
#
# â
#
# remarkably almost twothirds parent already talked kid ai reported conversation twenty-seven parent say child brought topic
#
# prof youth passive consumer technology theyre curious digital future
#
# twenty-nine parent havent yet discussed child plan sixty-five dont plan ever bringing kid
#
# although forty parent feel neither positive negative aiâs impact childâs future opportunitieshalf concernedthat ai could replace certain job career path
#
# fairly good reason support ai part high school curriculum could allow student get futureready sixty-seven parent believe developing airelated skill least important twenty-six parent believing skill important allâ
#
# peralta agrees skill important future absolutely crucial student cultivate language articulation skill needed engage ai effectively
#
# proficiency empowers prompt ai also enables navigate platform like google search engine adeptly distinguishing factual information nonfactual content critical thinking skill thats invaluable future career life informationrich world
#
# â
#
# â
#
# â
#
# lastly let dispel myth ai subject techie
#
# than60 parent surveyed rated either moderately familiar ai
#
# signal topic within realm researcher engineer increasingly entering dinnertable conversation
#
# might know neural network youve ever interacted chatbot used predictive text function chance youve engaged ai
#
# survey indicates eighty parent interacted chatbots sixty-eight used generative ai tool like chatgpt
#
# number highlight ai distant concept already part many parent daily life
#
# â
#
# ai becoming increasingly relevant life parent keenly aware presence potential impact childrens education future career
#
# many see benefit ai integration school also valid concern pitfall
#
# parent eager learn eighty-five parent surveyed least somewhat interested learning ai better support childâs learning development
#
# parent educator policymakers grapple implication ai education crucial maintain open dialogue
#
# understanding parental perspective addressing concern essential creating balanced effective approach integrating ai educational system
#
# future education undoubtedly intertwined ai technology continue evolve important parent educator work together ensure ai enhances rather hinders learning experience student
#
# gather insight parent perception artificial intelligence ai role education conducted survey among sample four hundred and twenty parent
#
# here brief overview methodology
#
# survey designwe designed structured questionnaire consisting twelve question cover various aspect ai integration education parental concern attitude
#
# âsample selection survey distributed parent within network
#
# sample size relatively small represented diverse range parent following educational institution distribution
#
# data collectionthe survey distributed electronically allowing participant complete convenience
#
# approach minimized time constraint ensured respondent sufficient time consider answer
#
# limitationsits important acknowledge limitation survey including relatively small sample size potential selfselection bias respondent network may particular interest ai education
#
# despite limitation survey provides valuable insight attitude perception parent regarding ai education
#
# finding offer starting point research discussion integration ai school implication future education
#
# â
#
# â
#
# eighty parent concern ai childrens education
#
# authortaylor hartley
#
# expert reviewerjill padfield
#
# last updated september thirteen two thousand and twenty-three
#
# eighty parent concern ai childrens education
#
# authortaylor hartley
#
# expert reviewerjill padfield
#
# last updated september thirteen two thousand and twenty-three
#
# eighty parent concern ai childrens education
#
# authortalor hartley
#
# expert reviewerjill padfield
#
# last updated september thirteen two thousand and twenty-three
#
# rapid advancement technology especially artificial intelligence ai permeated almost every aspect modern life including education
#
# tool like chatgpt serving educational aid important take look parent think feel technology impact student
#
# study show teacher student embracechatgpt ai education rarely hear parent
#
# wanted understand parent perception ai role childrens education
#
# surveyed one thousand parent aged one thousand, eight hundred and fifty-four kid school
#
# parent surveyed child prek one hundred and fifty-seven k5 grade range three hundred and seventy-seven sixty-eight grade range one hundred and sixty-seven grade nine hundred and twelve two hundred and thirty-five
#
# child college higher education least represented group sixty-four
#
# pivotal aspect ai incorporation education degree parent familiar technology
#
# overall moderate familiarity ai tool like chatgpt
#
# data revealed promising trend half five hundred and thirty-eight respondent moderately familiar ai technology like chatgpt sizable two hundred and ninety-four familiar tool
#
# hand one hundred and sixty-eight familiar
#
# artificial intelligence ai used education personalize learning provide realtime feedback automate task
#
# onerecent surveyshows chatgpt used classroom sixty school teacher
#
# still unclear teacher utilizing chatgpt technology ability answer question provide support even help grade paper
#
# ai education expands much chatgpt however
#
# numerous ai tool software powered ai exist education space
#
# ai technology help analyze student data identify trend pattern improve teaching learning
#
# aipowered virtual tutor provide personalized instruction adaptive learning platform tailor instruction student need
#
# familiarity high concern
#
# fiftyeight percent respondent moderately concerned ai influence child education twenty-two concerned
#
# contrast one hundred and ninety-nine concerned
#
# nature concern varied
#
# privacy data security paramount concern parent five hundred and eighty-nine expressing anxiety issue mirroring significant societal fear around big data privacy
#
# similarly lack personalized learning aigenerated content drew substantial apprehension four hundred and seventy-eight four hundred and eighty-eight parent questioning ai role effective educational tool
#
# hand nearly half four hundred and eighty-one wary ai implication academic integrity fearing might inadvertently encourage cheating plagiarism
#
# lastly concern ai tool education might diminish interpersonal skill evident four hundred and thirty-six parent echoing longstanding worry technology impact social development
#
# secret general public wary privacy technology
#
# study fromciscoandpew research centerfound leading concern ai data securitybased whether thats data used track movement discriminate steal identity spread misinformation
#
# ai slowly making way classroom generally used reduce workload teacher administration
#
# introduction chatgpt shifted ai used education dramatically giving student tool recently unfathomable
#
# student know type question essay give chatgpt old reason used give learning topic become irrelevant say former high school math teacher jill padfield
#
# ai tip child finger need reconsider curriculum skill topic prioritized
#
# teacher administrator grappling new technology influence skill teach school
#
# introduction calculator 1970s revolutionized math curriculum adoption ai surely influence skill mastery expected student
#
# finding balance topic must learned memorized left ai forefront many future curriculum debate
#
# one telling statistic revolves around communication
#
# three hundred and fifty-four parent discussed ai chatgpt usage child
#
# majority six hundred and forty-six yet broach topic
#
# result suggest potential gap family dialogue technology benefit potential pitfall
#
# youre unsure speak child using ai classroom tip
#
# ai thought computer brain learns information similar child learn thing school
#
# like helpful assistant certain task
#
# essential young child always ask parent teacher diving new online tool ensuring theyre engaging safe accurate resource
#
# ai fun aspect voice assistant sing answer curious question human element remains essential
#
# joy learning teacher friend experiencing emotion shared excitement cant replicated computer
#
# older child ai potential education vast offering personalized learning experience raising question safety privacy user data
#
# encouraged ask question explore reflect critically ai brings learning environment
#
# ethical consideration like fairness algorithm become important topic discussion
#
# value humandriven education focusing interpersonal skill teamwork peer discussion remains unparalleled even age advanced technology
#
# ai becomes integral part education system beneficial parent child stay updated exploring new aidriven tool collaboratively understanding potential impact learning
#
# despite concern believe potential bright future ai classroombill gate recentlycommented ai could help alleviate overworked teacher offload task allow spend time helping student oneonone
#
# study five hundred and thirty-eight parent believed ai potential impact child education positively
#
# one hundred and twelve thought opposite third thirty-five remaining unsure
#
# clearly divided albeit generally positive perception ai role learning environment
#
# education landscape undergoing profound transformation introduction ai
#
# illuminated survey parental perception reveal complex interplay enthusiasm awareness concern
#
# ensure harmonious integration ai classroom home educator technologist need address concern particularly around privacy personalization overall efficacy ai educational tool
#
# parent sign doodlemath subscription see child become math wizard
#
# offer
#
#
#
# resource
#
# quick link
#
# right reserved
#
# parent
#
# teacher
#
# student
#
# parent
#
# teacher
#
# student
#
# parent
#
# teacher
#
# parent
#
# teacher
#
# book chat team
#
# im new doodle
#
# school already using doodle
#
# im new doodle
#
# school already using doodle
#
# doodlemaths
#
# doodletables
#
# doodleenglish
#
# doodlespell
#
# youd like use doodle browser version please visit page desktop
#
# log doodle device apps
#
# find download
#
# sign free newsletter start day clearheaded reporting latest topic education
#
# get story like delivered straight inboxsign seventy-four newsletter
#
# teacher parent attitude chatgpt popular ai chatbot debuted late two thousand and twenty-two shifting slightly according new finding today polling firm impact research
#
# survey latest series commissioned walton family foundation tracking topic well attitude stem education broadly
#
# researcher say american teacher especially beginning see potential incorporating ai tool like chatgpt k12 education experience already helping student learn
#
# new finding come u federal trade commissionopens investigationinto openai chatgpts creator probing whether put personal reputation data risk
#
# ftc warned consumer protection law apply ai even biden administration congress push new regulation field
#
# openai also defendant several recent lawsuit filed author including comedian sarah silverman say technology ingested work improperly appropriating copyrighted book without author consent train ai program
#
# suit seek nearly one billion damagesthe los angeles time reported
#
# latest result based national survey one thousand k12 teacher one thousand and two student age one thousand, two hundred and eighteen eight hundred and two voter nine hundred and sixteen parent
#
# conducted impact research june twenty-three july six
#
# plusorminus margin error three percentage point teacher student result thirty-five percentage point voter result thirty-two parent response
#
# top five finding
#
# seven month firstdebuted publicly pretty much everyone know chatgpt
#
# broadly recognized eighty registered voter according new survey seventy-one parent seventy-three teacher
#
# meanwhile slightly fewer student sixty-seven tell pollster know
#
# surprisingly parent view chatbot favorably teacher sixty-one parent fine according new survey compared fifty-eight teacher fifty-four student
#
# february aprevious surveyfound thirty-three student said theyd used chatgpt school
#
# figure creeping forty-two
#
# teacher way ahead sixty-three teacher say theyve used chatbot job february fifty teacher taking advantage tool
#
# four ten forty teacher report using least week
#
# teacher use chatgpt overwhelmingly give good review
#
# fully eighty-four say positively impacted class six ten sixty-one predicting legitimate educational us ignore
#
# nearly twothirds sixty-four parent think teacher school allow use chatgpt schoolwork
#
# includes twenty-eight say tolerate encourage use
#
# lot headline since last winter touted chatgpts superior ability tohelp student cheatonessays like twenty-three teacher believe cheating likely sole use slightly spring twenty-four
#
# disclosure walton family foundation provides financial support tothe seventy-four
#
# get story like delivered straight inboxsign seventy-four newsletter
#
# greg toppois senior writer seventy-four
#
# want story shared widely possible free
#
# please view 74s republishing term
#
# bygreg toppo
#
# story first appeared atthe seventy-four nonprofit news site covering educationsign free newsletter 74to get like inbox
#
# teacher parent attitude chatgpt popular ai chatbot debuted late two thousand and twenty-two shifting slightly according new finding today polling firm impact research
#
# survey latest series commissioned walton family foundation tracking topic well attitude stem education broadly
#
# researcher say american teacher especially beginning see potential incorporating ai tool like chatgpt k12 education experience already helping student learn
#
# new finding come u federal trade commissionopens investigationinto openai chatgpts creator probing whether put personal reputation data risk
#
# ftc warned consumer protection law apply ai even biden administration congress push new regulation field
#
# openai also defendant several recent lawsuit filed author including comedian sarah silverman say technology ingested work improperly appropriating copyrighted book without author consent train ai program
#
# suit seek nearly one billion damagesthe los angeles time reported
#
# latest result based national survey one thousand k12 teacher one thousand and two student age one thousand, two hundred and eighteen eight hundred and two voter nine hundred and sixteen parent
#
# conducted impact research june twenty-three july six
#
# plusorminus margin error three percentage point teacher student result thirty-five percentage point voter result thirty-two parent response
#
# top five finding
#
# seven month firstdebuted publicly pretty much everyone know chatgpt
#
# broadly recognized eighty registered voter according new survey seventy-one parent seventy-three teacher
#
# meanwhile slightly fewer student sixty-seven tell pollster know
#
# surprisingly parent view chatbot favorably teacher sixty-one parent fine according new survey compared fifty-eight teacher fifty-four student
#
# february aprevious surveyfound thirty-three student said theyd used chatgpt school
#
# figure creeping forty-two
#
# teacher way ahead sixty-three teacher say theyve used chatbot job february fifty teacher taking advantage tool
#
# four ten forty teacher report using least week
#
# teacher use chatgpt overwhelmingly give good review
#
# fully eighty-four say positively impacted class six ten sixty-one predicting legitimate educational us ignore
#
# nearly twothirds sixty-four parent think teacher school allow use chatgpt schoolwork
#
# includes twenty-eight say tolerate encourage use
#
# lot headline since last winter touted chatgpts superior ability tohelp student cheatonessays like twenty-three teacher believe cheating likely sole use slightly spring twenty-four
#
# disclosure walton family foundation provides financial support tothe seventy-four
#
# uk student beginning welcome ai learning tool yet many student parent tutor teacher remain unsure impact technology education
#
# thats according bramble fourth annual state online tutoring survey carried summer two thousand and twenty-three
#
# total one thousand, one hundred and seventy-two took part survey forty respondent tutor twenty-six teacher twenty-seven student
#
# total one thousand, one hundred and seventy-two people took part survey
#
# eighty-two uk
#
# forty-two respondent tutor volunteer tutoring organisation twenty-six teacher twenty-seven student five parent
#
# asked thought ai system chatgpt good bad education forty-one ofstudentsbelieved positive larger proportion forty-six still undecided
#
# thirteen thought technology would detrimental impact
#
# parentsshared similar view although proportion respondent unsure ai threat opportunity thirty-seven saw positive le fifth nineteen regarded threat
#
# student fifty-four said using ai tool range purpose including revision homework classroom work well personal interest majority parent surveyed seventy said child hadnt used technology
#
# seventy oftutors teachershad heard generative ai chatgpt
#
# aware student used generative ai tool said tool used revision
#
# teacher tutor offered mixed view use ai education ranging positive concerned
#
# comment included
#
# used verify check idea answer question
#
# also used come new method teaching learning
#
# generative ai detrimentally affect development key skill including analysis evaluation articulation formulating personal opinion judgement
#
# ai teach content better many teacher freeing teacher time interactive example socratic discussion help student acquire truly deeply learn topic taught
#
# survey show many jury still use ai education clear indication ai powered technology already beginning play important part student learning
#
# asked likely would use bramble aipowered searchable lesson recording learning revision almost twothirds sixty-three student said likely likely use technology purpose
#
# many tutor see feature key tool online tutoring third thirty-three citing one main benefit live online tuition platform
#
# survey also revealed appetite full return inperson tutoring continues wane
#
# year survey eleven tutor wanted return purely inperson tuition fourteen two thousand and twenty-two
#
# nationally almost half forty-seven said would prefer mix inperson online tutoring forty-two wanting remain exclusively online three increase two thousand and twenty-two survey
#
# chamber bramble cofounder saidfrom survey finding clear teacher tutor parent still making mind ai education
#
# student however feel positively ai willing experiment technology fact beginning embrace ai powered element online platform help revise recorded learning session
#
# addedai potential truly profound impact education system
#
# impact could incredibly positive government educationalist edtech company developing ai powered technology like work together ensure technology becomes useful accurate informative supportive tool enhances learning
#
# live online tutoring platform time used ai trained dataset derived twenty-eight million hour tuition session taken place platform since two thousand and fifteen allow student quickly accurately search transcription resource past online tutoring session revision
#
# clear survey student using technology learning point clearly towards future ai likely become increasingly important learning tool
#
# bramble
#
# bramble online tutoring teaching platform currently used one hundred and thirty thousand tutor student one hundred and eighty country
#
# experience knowledge gained twenty-five million hour online tuition given bramble unique insight people teach learn onlinewwwaboutbrambleio
#
# uk student beginning welcome ai learning tool yet many student parent tutor teacher remain unsure impact technology education
#
# thats according bramble fourth annual state online tutoring survey carried summer two thousand and twenty-three
#
# total one thousand, one hundred and seventy-two took part survey forty respondent tutor twenty-six teacher twenty-seven student
#
# total one thousand, one hundred and seventy-two people took part survey
#
# eighty-two uk
#
# forty-two respondent tutor volunteer tutoring organisation twenty-six teacher twenty-seven student five parent
#
# asked thought ai system chatgpt good bad education forty-one ofstudentsbelieved positive larger proportion forty-six still undecided
#
# thirteen thought technology would detrimental impact
#
# parentsshared similar view although proportion respondent unsure ai threat opportunity thirty-seven saw positive le fifth nineteen regarded threat
#
# student fifty-four said using ai tool range purpose including revision homework classroom work well personal interest majority parent surveyed seventy said child hadnt used technology
#
# seventy oftutors teachershad heard generative ai chatgpt
#
# aware student used generative ai tool said tool used revision
#
# teacher tutor offered mixed view use ai education ranging positive concerned
#
# comment included
#
# used verify check idea answer question
#
# also used come new method teaching learning
#
# generative ai detrimentally affect development key skill including analysis evaluation articulation formulating personal opinion judgement
#
# ai teach content better many teacher freeing teacher time interactive example socratic discussion help student acquire truly deeply learn topic taught
#
# survey show many jury still use ai education clear indication ai powered technology already beginning play important part student learning
#
# asked likely would use bramble aipowered searchable lesson recording learning revision almost twothirds sixty-three student said likely likely use technology purpose
#
# many tutor see feature key tool online tutoring third thirty-three citing one main benefit live online tuition platform
#
# survey also revealed appetite full return inperson tutoring continues wane
#
# year survey eleven tutor wanted return purely inperson tuition fourteen two thousand and twenty-two
#
# nationally almost half forty-seven said would prefer mix inperson online tutoring forty-two wanting remain exclusively online three increase two thousand and twenty-two survey
#
# chamber bramble cofounder saidfrom survey finding clear teacher tutor parent still making mind ai education
#
# student however feel positively ai willing experiment technology fact beginning embrace ai powered element online platform help revise recorded learning session
#
# addedai potential truly profound impact education system
#
# impact could incredibly positive government educationalist edtech company developing ai powered technology like work together ensure technology becomes useful accurate informative supportive tool enhances learning
#
# live online tutoring platform time used ai trained dataset derived twenty-eight million hour tuition session taken place platform since two thousand and fifteen allow student quickly accurately search transcription resource past online tutoring session revision
#
# clear survey student using technology learning point clearly towards future ai likely become increasingly important learning tool
#
# bramble
#
# bramble online tutoring teaching platform currently used one hundred and thirty thousand tutor student one hundred and eighty country
#
# experience knowledge gained twenty-five million hour online tuition given bramble unique insight people teach learn onlinewwwaboutbrambleio
#
# nearly sixty teacher say interacting ai system key skill required job future however student struggle skill required 21st century workforce
#
# new generative ai tool disrupting education sector posing challenge opportunity student teacher
#
# capgemini research institute new reportfuture ready education empowering secondary school student digital skill also found student aged one thousand, six hundred and eighteen feel much le confident whether digital skill make workforceready teacher
#
# especially term digital communication data literacy
#
# education system around world already making move either accommodate exclude generative ai tool chatgpt student daytoday activity
#
# nearly half forty-eight secondary school teacher example report school either blocked restricted tool use one form another
#
# others le restrictive approach nineteen saying tool allowed specific usecases eighteen noting still evaluating applicability usefulness classroom
#
# overall half fifty-six secondary school teacher agreed curriculum assessment needed adapted account student use aigenerated content similar proportion fifty-two believe ai tool change teaching profession better
#
# many see potential generative ai tool seventy-eight secondary school teacher globally share concern negative impact generative ai tool student learning outcome including perception value writing skill diminished sixty-six tool limit student creativity sixty-six
#
# despite concern half secondary school teacher globally say potential generative ai educational tool outweighs risk
#
# perceived benefit ai tool could bring key use case highlighted teacher include using teach interact understand ai model sixty aid critical thinking exercise fifty-six tool help suggest edits student work fifty-two among others
#
# sentiment towards generative ai varies significantly across different geography teacher united state united kingdom germany finland recognize importance potential generative ai much singapore japan france
#
# almost two third sixty-four secondary school teacher convinced importance develop student digital skill make jobready vast majority eighty-two agree compulsory education digital skill would beneficial student
#
# however according report seem overestimate student confidence digital skill seventy believe student necessary skill successful today workforce eighty-three large city versus forty rural area sixty-four parent fifty-five student aged one thousand, six hundred and eighteen agree
#
# research also find teacher rural area le likely believe digital literacy priority school peer suburban urban area
#
# per research seventy-two student aged one thousand, six hundred and eighteen feel confident basic digital literacy2 le half forty-seven feel way digital communication data literacy3 attribute considered crucial success modern workplace
#
# report highlight instilling confidence key empowering student correctly identify fact misinformation online
#
# majority eighty student say confident finding information online fewer know online source trust sixty-six even le able decipher fact versus opinion online sixty-one
#
# world undergoes dual transition digital sustainable economy shortage digital talent reaching critical point widening digital dividesaid shobha meera chief corporate responsibility officer capgemini member group executive committee
#
# emergence technology generative ai must empower younger generation building capability confidence digital technology
#
# require collaborative approach business government education establishment
#
# capgemini committed play major role digital skill training two million people already benefited digital literacy program since two thousand and eighteen already hired six thousand twenty-nine thousand graduate digital academy
#
# information download report visithere
#
# methodology
#
# capgemini research institute conducted global study surveying range stakeholder within education system across australia finland france germany japan netherlands singapore united kingdom united state marchapril two thousand and twenty-three
#
# participant surveyed included one thousand, eight hundred secondary school teacher four thousand, five hundred parent secondary school student nine hundred student aged eleven eighteen year old
#
# teacher surveyed work fulltime employed public state secondary school
#
# science mathematics english language art medium humanity common area expertise subject taught among teacher surveyed
#
# parent surveyed within country representative country national population raceethnicityethnic group household income
#
# student aged eighteen surveyed consent responding parent
#
# london metropolitan college specialist provider project management course uk provider offer specialist degree apprenticeship emerging
#
# college strike secure improved staff pay offer damage student education trade union told
#
# college employer
#
# springfield training leading provider vocational education training proudly announces transformative education partnership frasers group renowned group retail business
#
# game development student burton south derbyshire college bsdc gaining insight future game design launch upgraded
#
# rhyl high school unveiled bold strategy combat 1million shortfall funding next three year
#
# headteacher claire armitstead staff
#
# new bae system digital intelligence report explores perceived barrier tech career uk providing insight industry better reach
#
# sheffield college sheffcol double finalist award scheme celebrates top educational institution north england
#
# college
#
# exam fact life student teacher control stressful scary intimidating exam may seem
#
# recent study
#
# future asset leading education initiative scotland dedicated fostering diversity inclusion within finance industry known commitment empowering
#
# datadriven analysis gatsby charitable foundation schooldash highlight stark contrast recruitment trend observed fe college sixth form college utc compared
#
# education strike heart make u human
#
# drive intellectual capacity prosperity nation
#
# developed mind took u moon eradicated previously incurable disease
#
# special status education generative ai tool chatgpt likely profoundlydisrupt sector
#
# isnt reflection intelligence failure build education system nurture value unique human intelligence
#
# duped believing ai tool arefar intelligentthan really
#
# atool like chatgpthas understanding knowledge
#
# merely collates bit word together based statistical probability produce useful text
#
# incredibly helpful assistant
#
# knowledgable wise
#
# concept word produce relate real world
#
# fact pas many form assessment merely reflects assessment designed test knowledge understanding rather test whether people collected memorised information
#
# ai could force tremendous good within education
#
# could release teacher administrative task giving opportunity spend time student
#
# however woefully equipped benefit ai flooding market
#
# like
#
# still time prepare must act quickly wisely
#
# ai used education decade
#
# aipowered system ascarnegie learningoraleks analyse student response question adapt learning material meet individual need
#
# ai tool asteachfxandedthenacan also enhance teacher training support
#
# reap benefit technology must design effective way roll ai across education system regulate properly
#
# staying ahead ai mean radically rethinking education success mean
#
# human intelligence far impressive ai system see today
#
# posse rich diverse intelligence much unrecognised current education system
#
# capable sophisticated highlevel thinking yet school curriculum particularly england take rigid approach learning prioritising memorising fact rather creative thinking
#
# student rewarded rote learning rather critical thought
#
# take english syllabus instance requires student learn quotation rule grammar
#
# timeconsuming work encourages student marshal fact rather interpret text think critically language
#
# education system recognise unique aspect human intelligence
#
# school would mean focus teaching highlevel thinking capability designing system supercharge intelligence
#
# literacy numeracy remain fundamental must add ai literacy
#
# traditional subject area history science geography become context critical thinking increased creativity knowledge mastery taught
#
# rather teaching student collate memorise information prize ability interpret fact weigh evidence make original argument
#
# failure change isnt option
#
# technology need human excel aicannotdo workplace automation complement enriches life intelligence
#
# amazing opportunity use ai become much smarter must ensure ai serf u way round
#
# mean confronting profitdriven imperative big tech company illusionist trick played silicon valley
#
# also mean carefully considering type task willing offload ai
#
# aspect intellectual activity may dispensable many
#
# silicon valley conjures next magic trick must prepare protect hold dear future generation
#
# rose luckin professor learnercentred design ucl knowledge lab london

# %%
# Use Vader library to get the polarity of the sentence
def getPolarity(text):
    polarity = SentimentIntensityAnalyzer().polarity_scores(text)
    if polarity['compound'] > 0:
      sentiment = 'postive'
    elif polarity['compound'] < 0:
      sentiment = 'negative'
    else:
      sentiment = 'neutral'
    return sentiment,polarity

# %%
for sentence in sentences:
  sentiment, polarity = getPolarity(sentence)
  print('\n', sentence)
  print(f"{sentiment}, {polarity}")
# Out:
#  artificial intelligence ai stay already positive impact across society including education sector
# postive, {'neg': 0.0, 'neu': 0.599, 'pos': 0.401, 'compound': 0.7717}
#
#  believe could used improve education system example early research suggests could used free teacher time provide personalised support pupil
# postive, {'neg': 0.0, 'neu': 0.643, 'pos': 0.357, 'compound': 0.836}
#
#  want make emerging technology need understand risk well opportunity
# postive, {'neg': 0.158, 'neu': 0.376, 'pos': 0.466, 'compound': 0.4767}
#
#  set develop artificial intelligence education safely explore could benefit teacher young people
# postive, {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.8519}
#
#  investing ai tool gathering evidence teacher pupil using ai already investigating take advantage ai education
# postive, {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'compound': 0.25}
#
#  first step already
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  understand education already use generative ai including use produce content text imagery audio launched call evidence gather view educational professional academic edtech sector risk possibility
# negative, {'neg': 0.079, 'neu': 0.865, 'pos': 0.056, 'compound': -0.1531}
#
#  result show ai already used reduce administrative task optimistic potential
# postive, {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.3182}
#
#  organised twoday hackathon teacher andschool leader across england allowed teacher school leader work data scientist come solution use ai tackle reallife issue like teacher workload
# postive, {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.5859}
#
#  result hackathon published next year
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  boost oak national academy online learning platform help develop new free resource teacher powered ai lesson planner classroom quiz
# postive, {'neg': 0.0, 'neu': 0.648, 'pos': 0.352, 'compound': 0.8271}
#
#  still early stage exploring possibility ai could benefit teacher
# postive, {'neg': 0.0, 'neu': 0.727, 'pos': 0.273, 'compound': 0.4588}
#
#  one area looking includes using ai tool tocut teacher workloadby providing teacher virtual assistant
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  drafting curriculum plan producing highquality teaching resource ai potential reduce amount time teacher spend administrative task focus best teaching supporting pupil
# postive, {'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'compound': 0.7964}
#
#  absolutely
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  teacher irreplaceable ai could never substitute teacher professional judgement personal relationship pupil
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  aiming develop ai serve teacher better take away unique role play
# postive, {'neg': 0.0, 'neu': 0.629, 'pos': 0.371, 'compound': 0.6486}
#
#  also making sure ai tool teacher always charge always human loop
# postive, {'neg': 0.0, 'neu': 0.813, 'pos': 0.187, 'compound': 0.3182}
#
#  example wouldnt support use ai draft personalised plan guidance without expert human involvement
# negative, {'neg': 0.158, 'neu': 0.842, 'pos': 0.0, 'compound': -0.3089}
#
#  much work done explore ai could enhance pupil learn know concern around risk young people especially new form technology
# negative, {'neg': 0.104, 'neu': 0.896, 'pos': 0.0, 'compound': -0.2732}
#
#  development ai tool young people would prioritise safety security
# postive, {'neg': 0.0, 'neu': 0.574, 'pos': 0.426, 'compound': 0.6369}
#
#  includes ensuring child young people accessing creating harmful inappropriate content online generative ai data intellectual property protected
# postive, {'neg': 0.0, 'neu': 0.553, 'pos': 0.447, 'compound': 0.8591}
#
#  ai tool interactive easily personalised could used provide young people virtual tutor
# postive, {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'compound': 0.34}
#
#  name one example ai could help provide pupil bespoke workplan based marking assessment teacher
# postive, {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.4019}
#
#  many positive us ai tool know parent teacher concerned pupil using homework cheat exam
# postive, {'neg': 0.161, 'neu': 0.645, 'pos': 0.194, 'compound': 0.1531}
#
#  result call evidence hackathon provide base future policy ai including school work around possibility student using cheat
# negative, {'neg': 0.158, 'neu': 0.842, 'pos': 0.0, 'compound': -0.4588}
#
#  statement begin right
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  well707 surveyed teachersfind ai tool beneficial education sector
# postive, {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.4404}
#
#  among seven hundred and fifty teacher question consider generative artificial intelligence tool beneficial detrimental education seven ten answered beneficial
# postive, {'neg': 0.0, 'neu': 0.643, 'pos': 0.357, 'compound': 0.836}
#
#  artificial intelligence helping daily work natural embrace new resource
# postive, {'neg': 0.0, 'neu': 0.331, 'pos': 0.669, 'compound': 0.8442}
#
#  consider ai education beneficial well get later
# postive, {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.6124}
#
#  order use ai must first know exist
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  surveyed teacher
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  six hundred and fifteen answered used generative ai tool last three month
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  perhaps fact knew slidesgo helping factor since already offer ai tool user
# postive, {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.296}
#
#  maybe
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  weve already said seven hundred and seven surveyed teacher find ai beneficial
# postive, {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.4404}
#
#  quality daily work teacher
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  improve71of think
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  think several reason better planning getting idea lesson
# postive, {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.4404}
#
#  themain reason use ai tool answer mixed bag wed like highlight popular answer saving time
# postive, {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'compound': 0.7717}
#
#  find ai useful finding inspiration others state ai tool help minimize blankpage syndromeyou know moment life need start writing paper article slide even though idea mind seem put word
# postive, {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.8402}
#
#  latter seems related timesaving concept conclude clock higher threat ai
# negative, {'neg': 0.274, 'neu': 0.726, 'pos': 0.0, 'compound': -0.5267}
#
#  joke aside here infographics showing data
# postive, {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'compound': 0.296}
#
#  alright
# postive, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.25}
#
#  know teacher use ai
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  theyre slowly becoming one tool repertoire like pen notebook blackboard chalk presentationswe cant forget presentation
# postive, {'neg': 0.0, 'neu': 0.757, 'pos': 0.243, 'compound': 0.4881}
#
#  first thing majority surveyed teacher stated thatgenerative ai tool education used enhance interaction student
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  theyre leveraging power advanced tool create highly personalized educational content tailored meet unique learning need student
# postive, {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'compound': 0.4767}
#
#  isnt amazing know knowing student need ai help fine tune lesson make
# postive, {'neg': 0.185, 'neu': 0.543, 'pos': 0.272, 'compound': 0.1098}
#
#  there little misconception need take care work teacher isnt limited teaching
# postive, {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.5948}
#
#  gosh
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  picture hundred teacher shaking head right administrative task big part teacher work enthusiastic nod efficiency ai notable735of surveyed teacher reported thatai instrumental reducing time spend task
# postive, {'neg': 0.056, 'neu': 0.757, 'pos': 0.188, 'compound': 0.6124}
#
#  scheduling planning seem le tedious thing using ai
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  benefit derived clear teacher able channel newfound time energy enhancing learning experience student
# postive, {'neg': 0.0, 'neu': 0.565, 'pos': 0.435, 'compound': 0.7717}
#
#  seems little bit overthetop highlight teacher didnt answer question
# postive, {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.2815}
#
#  gave u opinion word help u understand theyre thinking
# postive, {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
#
#  heartily felt leaving work time statement
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  hectic world like today finding right balance work family difficult
# neutral, {'neg': 0.192, 'neu': 0.615, 'pos': 0.192, 'compound': 0.0}
#
#  outside people might realize work behind scene teacher carry
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  simply leave school giving last lesson day
# postive, {'neg': 0.14, 'neu': 0.581, 'pos': 0.279, 'compound': 0.296}
#
#  testimonial hint ai helping teacher find air breathe metaphorically speaking
# postive, {'neg': 0.0, 'neu': 0.804, 'pos': 0.196, 'compound': 0.296}
#
#  doubt ai streamlining teacher work definitely helping save precious time
# postive, {'neg': 0.13, 'neu': 0.259, 'pos': 0.611, 'compound': 0.8519}
#
#  take moment imagine world teacher use ai tool create engaging content also smoothly run class draw inspiration assignment even whip riveting presentation
# postive, {'neg': 0.0, 'neu': 0.706, 'pos': 0.294, 'compound': 0.7845}
#
#  wait isnt present time
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  going back survey weve asked teacher use ai tool
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  plain simple
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  textbook great student shouldnt limit memorizing appears
# postive, {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.6249}
#
#  there
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  teacher tell topic subject day lesson
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  five hundred and thirty-five surveyed teacher answered theirmain use ai education organize class
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  second thought it465of also answered ai help find inspiration preparing assignment student
# postive, {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'compound': 0.7269}
#
#  combined creativity teacher end result interesting project student may need complete
# postive, {'neg': 0.0, 'neu': 0.629, 'pos': 0.371, 'compound': 0.6486}
#
#  also encourages student think outside box bit proactive well creative completing assignment
# postive, {'neg': 0.0, 'neu': 0.428, 'pos': 0.572, 'compound': 0.8658}
#
#  thats great isnt
# postive, {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.6249}
#
#  wont memorizing machine critical thinker
# postive, {'neg': 0.0, 'neu': 0.671, 'pos': 0.329, 'compound': 0.2411}
#
#  slidesgo
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  main content
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  presentation
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  already know good part user base composed people education world
# postive, {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.4404}
#
#  many mostpopular templatesare used lessonsgoes without saying even havereadymade presentationsfor various educational level available different language
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  template essential come saving time
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  saving time
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  pattern clear u decided introduce ai presentation maker world two main reason helping user save time excuse u sounding like broken record lending hand techsavvy
# postive, {'neg': 0.091, 'neu': 0.469, 'pos': 0.44, 'compound': 0.872}
#
#  survey also say teacher take one two hour create presentation class
# postive, {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.2732}
#
#  much
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  thing create presentation faster without noticing drop quality plus
# postive, {'neg': 0.0, 'neu': 0.641, 'pos': 0.359, 'compound': 0.443}
#
#  happens use ourai presentation maker
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  according time reduced thirty minute le
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  talking
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  impactful quote
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  swear one surveyed people
# negative, {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.0516}
#
#  ah milliondollar question
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  busy singing praise ai education let forget every superhero kryptonite ai challenge associated integration education sector
# postive, {'neg': 0.096, 'neu': 0.657, 'pos': 0.247, 'compound': 0.4588}
#
#  weve gathered surveythe main reason using ai unsurprisingly knowing use
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  yeah there chatgpt there midjourney there dalle fingertip one thing mastering another
# postive, {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.296}
#
#  something take time already know teacher dont much spare although turn ai eventually reduce time take task
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  perceived endless loop dont enough time learn use ai ai never able free time could used learn use ai theyre able free time didnt enough time begin
# negative, {'neg': 0.178, 'neu': 0.822, 'pos': 0.0, 'compound': -0.6602}
#
#  applying daily task teacher another reason ai use least education
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  perhaps ai generate interesting content something easily taught
# postive, {'neg': 0.0, 'neu': 0.541, 'pos': 0.459, 'compound': 0.6249}
#
#  generative tool give image accurate enough regarding need teach
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  also important note that22of surveyed teacher believe generative ai tool used teaching dont know prevent student misusing
# postive, {'neg': 0.06, 'neu': 0.839, 'pos': 0.101, 'compound': 0.1842}
#
#  really tell whether student really learned concept ai work
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  probably one key idea dialogue
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  school encouraging discussion use ai education
# postive, {'neg': 0.0, 'neu': 0.595, 'pos': 0.405, 'compound': 0.5267}
#
#  help student understand reason behind rule spark meaningful conversation ai ethic
# postive, {'neg': 0.0, 'neu': 0.537, 'pos': 0.463, 'compound': 0.7096}
#
#  assignment carried school monitoring system put place track potential misuse ai tool
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  could involve use analytics identify unusual pattern student work incorporation software detect aigenerated content
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  common question popping every next job ai replace
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  ai certainly flexing muscle realm education really think able replace human touch teacher
# postive, {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.34}
#
#  sure ai might process vast amount data provide personalized learning experience even serve fresh content faster cafeteria lunch
# postive, {'neg': 0.0, 'neu': 0.777, 'pos': 0.223, 'compound': 0.5574}
#
#  youll agree u teacher arent information dispenser replaced newer shinier model
# postive, {'neg': 0.0, 'neu': 0.783, 'pos': 0.217, 'compound': 0.3612}
#
#  counselor mediator inspirer lifeguides
# postive, {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.4939}
#
#  ai replicate
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  richard dawson feel urge say thatsurvey saysthat64of teacher took time answer question believe thatais wont replacement human educator least short term
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  point view
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  weve gathered thanks survey conclude ai slowly finding way daily work teacher helping administrative work also serving inspiration content generator lesson
# postive, {'neg': 0.0, 'neu': 0.679, 'pos': 0.321, 'compound': 0.8176}
#
#  main benefit ai education mainly saving time streamlining planning process future lesson reducing mental stress teacher subject demanding field education
# negative, {'neg': 0.19, 'neu': 0.688, 'pos': 0.121, 'compound': -0.1779}
#
#  seen threat replacement human teacher short run teacher cant help think difficulty preventing misuse ai student
# negative, {'neg': 0.325, 'neu': 0.577, 'pos': 0.098, 'compound': -0.575}
#
#  also find bit difficult properly get ai asked
# negative, {'neg': 0.263, 'neu': 0.737, 'pos': 0.0, 'compound': -0.3612}
#
#  conclusion
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  familiar generative ai possibility offer
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  use often hand something make tremble
# postive, {'neg': 0.226, 'neu': 0.43, 'pos': 0.344, 'compound': 0.2732}
#
#  would like hear please follow u social share opinion
# postive, {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.7184}
#
#  additionally might want check article onhow generate good prompt generate ai presentation especially youd like use ai presentation maker
# postive, {'neg': 0.0, 'neu': 0.696, 'pos': 0.304, 'compound': 0.7165}
#
#  please note seven hundred and seventy-six teacher participated survey october thirty november thirteen two thousand and twenty-three mainly north america
# postive, {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.3182}
#
#  primary objective gather teacher educator perception ai education use ai tool enhance teaching community
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  total seven thousand, four hundred and ninety-three respondent participated including seven hundred and seventy-six identified teacher
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  have5articles leftsign free account log
# postive, {'neg': 0.0, 'neu': 0.548, 'pos': 0.452, 'compound': 0.5106}
#
#  similar student say ai impacting academic plan eleven percent student new student voice survey say rise ai significantly influenced career plan
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  additional thirty-one percent say influenced career plan somewhat
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  poca wander stockistockgetty image plus
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  studentslike studying university south florida muma college business center marketing sale innovation customer experience behavioral ai labare already exposed artificial intelligence help workforce
# postive, {'neg': 0.045, 'neu': 0.662, 'pos': 0.293, 'compound': 0.7964}
#
#  lab us various technology measure brain wave eye movement otherwise understand human respond variety stimulus
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  student get opportunity apply insight across setting sometimes partnership commercial business government agency
# postive, {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.4215}
#
#  student learning applying stateoftheart skill participating research say rob hammond center director make employable graduation
# negative, {'neg': 0.205, 'neu': 0.795, 'pos': 0.0, 'compound': -0.5574}
#
#  even beyond specialized training nearly three four student say institution preparing ai workplace least somewhat
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  find new flash survey one thousand, two hundred and fifty student across forty-nine four twoyear college frominside higher edand college pulse student voice series
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  survey main takeaway
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  asked much rise artificial intelligence influenced theyre studying plan study college fourteen percent student say influenced lot
# postive, {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4767}
#
#  additional thirty-four percent say influenced somewhat
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  year class two thousand and twenty-four least influenced way thirty-five percent student saying ai affected theyre studying plan study either lot somewhat
# negative, {'neg': 0.071, 'neu': 0.929, 'pos': 0.0, 'compound': -0.1531}
#
#  class two thousand and twenty-five two thousand and twenty-six incrementally influenced majority class two thousand and twenty-seven sixty-four percent say ai least somewhat impacted academic plan
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  difference may make sense light buzz around generative ai within last year
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  two fouryear college student survey report equally influenced ai area
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  student major gender financial aid status appear factor
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  field seven percent art humanity student say ai influenced plan study compared fifteen percent natural science student seventeen percent social science student twenty-two percent student identifying interdisciplinary major
# postive, {'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'compound': 0.3612}
#
#  gender twenty percent male student say ai significantly impacted academic plan versus ten percent woman four percent nonbinary student insufficient response show certain demographic
# postive, {'neg': 0.0, 'neu': 0.916, 'pos': 0.084, 'compound': 0.2732}
#
#  financial aid status sixty percent student financial aid say ai influencing study plan either lot somewhat compared forty-five percent student receiving financial aid
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  another key difference fifty-two percent continuinggeneration student say ai influencing plan study either lot somewhat compared forty-one percent firstgeneration student
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  similar student say ai impacting academic plan eleven percent student say rise ai significantly influenced career plan
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  additional thirty-one percent say influenced career plan somewhat
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  year class two thousand and twenty-seven appears impacted sixty-one percent saying rise ai affected career plan either lot somewhat thirty-one percent class two thousand and twenty-four say forty-one percent class two thousand and twenty-five fifty-one percent class two thousand and twenty-six
# negative, {'neg': 0.038, 'neu': 0.962, 'pos': 0.0, 'compound': -0.1531}
#
#  gender appears matter well fifty-two percent men study saying ai impacting career plan versus thirty-five percent woman thirty-five percent nonbinary student
# postive, {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.296}
#
#  yet there significant difference fouryear twoyear student response relatively student without financial aid fifty-one percent forty-one percent say theyre influenced ai respect either lot somewhat
# postive, {'neg': 0.0, 'neu': 0.824, 'pos': 0.176, 'compound': 0.5994}
#
#  relatively continuinggeneration student forty-six percent firstgeneration student thirty-four percent also say ai least somewhat impacting career plan
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  nearly three four student say college university preparing ai workplace either lot twenty-seven percent somewhat forty-five percent
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  newer student likely soontograduate student expect ai preparation eighty-one percent class two thousand and twenty-seven saying institution preparing least somewhat
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  yet even sixty-six percent class two thousand and twenty-four say
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  major student art humanity bit le likely say sixty-six percent student social science seventy-eight percent
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  natural science share seventy percent among interdisciplinary major seventy-one percent
# postive, {'neg': 0.0, 'neu': 0.63, 'pos': 0.37, 'compound': 0.5719}
#
#  gender seventy-seven percent men say institution readying ai work least somewhat sixty-nine percent woman nonbinary respondent
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  seventy-six percent continuinggeneration student expect institution ready ai work least somewhat compared sixty-six percent firstgen peer
# postive, {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.3612}
#
#  institution preparing ai work
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  one priority student taught ethic using ai nearly three four student choosing
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#
# neutral, {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
#  two choice sixty-two percent list five option prioritizing teaching core skill critical thinking problemsolving
# negative, {'neg': 0.15, 'neu': 0.85, 'pos': 0.0, 'compound': -0.3182}
#
#  presumably build skill make student wouldbe job resistant ai
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  close third choice teaching in out using ai meaning student also eager practical training sixty percent
# postive, {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.3612}
#
#  twenty-eight percent student say institution prepare ai work encouraging career path le likely impacted ai
# postive, {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5267}
#
#  result relatively consistent across student subgroup institution type including gender major first continuinggeneration status
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  mhammed abdous assistant vice president teaching learning technology associate director center faculty development old dominion university virginia say response strong indication transformative potential ai registering student respondent seem rightly aware ai reshaping job market many different area abdous cite reportssuggestingthat forty percent current job potentially replaceable ai adding even job wont displaced still subject change due generative ai power reshape work
# postive, {'neg': 0.0, 'neu': 0.948, 'pos': 0.052, 'compound': 0.5106}
#
#  time ai also stimulate demand new skill require human ingenuity creativity empathy ethicsthings ai add
# postive, {'neg': 0.083, 'neu': 0.667, 'pos': 0.25, 'compound': 0.4588}
#
#  regarding related student voice finding training student want abdous say student right target
# postive, {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'compound': 0.0772}
#
#  abdous suggests college university consider following
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  suzanne helbig associate vice provost division career pathway university california irvine say institution adopt intentional practice cultivate continuouslearning mindset critical thinking skill futureproof student mean providing way student connect theyre learning classroom world work equipping faculty staff member help student identify articulate transferable skill future role
# postive, {'neg': 0.046, 'neu': 0.865, 'pos': 0.089, 'compound': 0.2732}
#
#  institution harness workforce data industry connection inform curriculum program development add plus resource elevate campus career service address top reason student seek higher education advance career
# postive, {'neg': 0.0, 'neu': 0.933, 'pos': 0.067, 'compound': 0.2023}
#
#  proliferation ai effect future work make career service even greater institutional imperative
# postive, {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'compound': 0.3612}
#
#  action institution taken help ensure student considering ai planning future career
# postive, {'neg': 0.0, 'neu': 0.629, 'pos': 0.371, 'compound': 0.6486}
#
#  share career prep tip advicehere
# postive, {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.296}
#
#  discover public data featuring diverse range survey result article tracker popularity ranking
# postive, {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compound': 0.4767}
#
#  latest political survey indepth analysis find world think
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  get intelligence evergrowing source consumer data twenty-four million registered panel member fifty-five market
# postive, {'neg': 0.0, 'neu': 0.795, 'pos': 0.205, 'compound': 0.4767}
#
#  call living data
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  discover public data featuring diverse range survey result article tracker popularity ranking
# postive, {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compound': 0.4767}
#
#  latest political survey indepth analysis find world think
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  get intelligence evergrowing source consumer data twenty-four million registered panel member fifty-five market
# postive, {'neg': 0.0, 'neu': 0.795, 'pos': 0.205, 'compound': 0.4767}
#
#  call living data
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  new yougov pollingfinds american divided view advance artificial intelligence ai affect k12 education system slightly saying somewhat negative impact thirty-six rather positive impact twenty-five
# postive, {'neg': 0.102, 'neu': 0.681, 'pos': 0.217, 'compound': 0.5509}
#
#  younger american adult far optimistic ai effect education older american
# postive, {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.3182}
#
#  adult thirty likely say ai positive thirty-nine rather negative twenty-two effect k12 education people sixty-five older twice likely say effect negative forty-four rather positive eighteen
# negative, {'neg': 0.208, 'neu': 0.59, 'pos': 0.202, 'compound': -0.0516}
#
#  regarding k12 school respond advance ai american twice likely say school focus teaching student appropriately use ai fifty-two say school focus preventing student using ai twenty-four
# negative, {'neg': 0.042, 'neu': 0.958, 'pos': 0.0, 'compound': -0.0258}
#
#  despite younger adult greater optimism ai school likely older american back preventing student using ai
# postive, {'neg': 0.172, 'neu': 0.641, 'pos': 0.187, 'compound': 0.316}
#
#  one reason likely many american view airelated skill necessary student future career nineteen say learning use ai necessary forty-two say somewhat necessary
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  people believe ai somewhat necessary future student career far likely people dont believe school focus teaching student appropriately use ai seventy v thirty
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  one concern raised ai effect education whether render obsolete certain way evaluating student learning performance
# negative, {'neg': 0.127, 'neu': 0.751, 'pos': 0.121, 'compound': -0.0258}
#
#  yet find american divided view ai affect takehome essay thirty saying ai make type assignment le useful past twenty-two saying make useful twenty-five saying make difference
# postive, {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.7003}
#
#  large age difference question ai affect usefulness takehome essay forty-two adult thirty say ai advance increase utility takehome essay compared eight people sixty-five older
# postive, {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.5423}
#
#  american school today would use ai assist assignment even prohibited
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  one three say would thirty-two roughly equal share thirty-five say would
# postive, {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.296}
#
#  rest sure preferred say
# postive, {'neg': 0.0, 'neu': 0.566, 'pos': 0.434, 'compound': 0.3182}
#
#  two five adult thirty forty-one say would use ai assist essay school even prohibited
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  twenty-one american sixty-five older say
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  american likely thirty-four twenty-eight believe currently software available able accurately distinguish writing done student writing produced ai
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  largest share thirty-eight however unsure whether software currently able
# postive, {'neg': 0.179, 'neu': 0.625, 'pos': 0.196, 'compound': 0.0516}
#
#  carl bialik linley sander contributed article
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  see result yougov poll
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  methodologythis poll conducted online april thirteen twenty two thousand and twenty-three among one thousand u adult citizen
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  respondent selected yougovs optin panel using sample matching
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  random sample stratified gender age race education geographic region voter registration selected two thousand and nineteen american community survey
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  sample weighted according gender age race education two thousand and twenty election turnout presidential vote baseline party identification current voter registration status
# postive, {'neg': 0.0, 'neu': 0.886, 'pos': 0.114, 'compound': 0.4019}
#
#  demographic weighting target come two thousand and nineteen american community survey
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  baseline party identification respondent recent answer given prior march fifteen two thousand and twenty-two weighted estimated distribution time thirty-three democratic twenty-eight republican
# postive, {'neg': 0.0, 'neu': 0.886, 'pos': 0.114, 'compound': 0.4019}
#
#  margin error overall sample approximately three
# negative, {'neg': 0.351, 'neu': 0.649, 'pos': 0.0, 'compound': -0.4019}
#
#  image adobe stock svitlana
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  explore data article
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  elementary education
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  artificial intelligence
# postive, {'neg': 0.0, 'neu': 0.244, 'pos': 0.756, 'compound': 0.4767}
#
#  education
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  technology
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  copyright two thousand and twenty-four yougov plc
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  right reserved
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  get story like delivered straight inboxsign seventy-four newsletter
# postive, {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'compound': 0.5267}
#
#  year ed tech company work forhmh conduct survey designed understand obstacle opportunity teacher administrator experience
# postive, {'neg': 0.137, 'neu': 0.71, 'pos': 0.153, 'compound': 0.0772}
#
#  yearseducator confidence reportrevealed new insight one thousand, two hundred k12 teacher feeling profession overall well attitude toward generative artificial intelligence buzzword rapidly become practical inescapable classroom technology
# postive, {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'compound': 0.8402}
#
#  sentiment around profession reached alltime low two thousand and twenty-two year survey show confidence education inching increasing forty one hundred two thousand and twenty-two forty-two two thousand and twenty-three
# postive, {'neg': 0.064, 'neu': 0.793, 'pos': 0.143, 'compound': 0.3818}
#
#  current index score correlate around c grade rise could represent stabilization following particularly challenging period educator across country
# postive, {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.2247}
#
#  encouraging see teacher beginning transition survival mode toward regaining confidence profession
# postive, {'neg': 0.0, 'neu': 0.573, 'pos': 0.427, 'compound': 0.7717}
#
#  believe last year marked low point turning corner see teacher feeling enthusiastic staying industry case new educator joining field
# postive, {'neg': 0.092, 'neu': 0.702, 'pos': 0.206, 'compound': 0.3818}
#
#  addition positive trend teacher surveyed year report also identified key area feel optimistic feel making positive impact state education
# postive, {'neg': 0.0, 'neu': 0.627, 'pos': 0.373, 'compound': 0.8591}
#
#  include use digital platform improve student engagement thirty-one educator surveyed felt optimistic well increased attention student social emotional need fifty educator reported point optimism
# postive, {'neg': 0.0, 'neu': 0.493, 'pos': 0.507, 'compound': 0.9382}
#
#  based annual survey well work thousand teacher firsthand experience school clear teaching increasingly complex job professional especially concerned wellbeing student colleague
# postive, {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.5719}
#
#  one bright spot research confidence competence educator feel knowledge technology
# postive, {'neg': 0.0, 'neu': 0.563, 'pos': 0.437, 'compound': 0.7351}
#
#  recent experience interrupted schooling increased reliance digital tool created teaching force capitalizing promise technology
# postive, {'neg': 0.118, 'neu': 0.538, 'pos': 0.344, 'compound': 0.4939}
#
#  technical knowhow crucial setting student success
# postive, {'neg': 0.0, 'neu': 0.575, 'pos': 0.425, 'compound': 0.5719}
#
#  new piece technology puzzle generative ai come forefront k12 conversation past year
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  survey find educator looking guidance using ai recognize transformative possibility
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  half educator surveyed fifty-seven agreed generative ai inevitable harnessed positively classroom fifty-eight said would interested professional development coaching around new technology
# postive, {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'compound': 0.802}
#
#  ai represents potential new era education one teacher becoming learner driving change district school
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  majority educator surveyed ninety yet actively integrating ai classroom
# postive, {'neg': 0.0, 'neu': 0.777, 'pos': 0.223, 'compound': 0.3182}
#
#  however early adopter ai ten eager
# postive, {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.3612}
#
#  use two hundred and two thousand, two hundred and twenty-three school year seventy-four said expect increase current school year
# postive, {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'compound': 0.3182}
#
#  survey made clear educator feeling new technology mixed
# postive, {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.4767}
#
#  consensus key activity teacher feel aigenerated content could accelerate achievement
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  half fifty-one said artificial intelligence could support worksheet creation forty-eight identified assistance lesson plan forty-one pointed aid coming prompt writing assignment
# postive, {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.7845}
#
#  sixty-five teacher surveyed said time would impact wellbeing ai positioned help
# postive, {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019}
#
#  creating writing prompt lesson plan worksheet take time
# postive, {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'compound': 0.296}
#
#  simplifying task ai give teacher time focus need foster relationship student
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  educator starting unpack benefit generative ai
# postive, {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.4588}
#
#  proper support new technology allow thing best fostering deep learning building relationship counseling student building community learner turn improve state profession
# postive, {'neg': 0.0, 'neu': 0.592, 'pos': 0.408, 'compound': 0.8934}
#
#  get story like delivered straight inboxsign seventy-four newsletter
# postive, {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'compound': 0.5267}
#
#  half undergraduate say consult artificial intelligence programme help essay school trialling use classroom
# postive, {'neg': 0.0, 'neu': 0.655, 'pos': 0.345, 'compound': 0.7003}
#
#  survey one thousand uk undergraduate conducted higher education policy institute hepi found fifty-three using ai generate material work would marked
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  one four using application google bard chatgpt suggest topic one eight using create content
# postive, {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.2732}
#
#  five admitted copying pasting unedited aigenerated text assessment
# postive, {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.1027}
#
#  teacher also seeking use ai streamline work education endowment foundation eef signing secondary school new research project use ai generate lesson plan teaching material well exam model answer
# postive, {'neg': 0.0, 'neu': 0.928, 'pos': 0.072, 'compound': 0.2732}
#
#  dr andres guadamuz reader intellectual property law university sussex said surprise student adopting ai suggested institution needed explicit discussing best use study tool
# postive, {'neg': 0.0, 'neu': 0.676, 'pos': 0.324, 'compound': 0.8625}
#
#  ive implemented policy mature conversation student generative ai
# postive, {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.4215}
#
#  share utilise guadamuz said
# postive, {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'compound': 0.296}
#
#  primary concern significant number student unaware potential hallucination inaccuracy ai
# postive, {'neg': 0.151, 'neu': 0.588, 'pos': 0.261, 'compound': 0.0772}
#
#  believe responsibility educator address issue directly
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  hepi survey found one three student using ai know often hallucinates ie invents statistic academic citation book title fill perceives gap
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  guadamuz said essay handed last year clearly used unedited chatgpt output given away boring style written
# postive, {'neg': 0.121, 'neu': 0.737, 'pos': 0.142, 'compound': 0.1027}
#
#  ai usage spread survey found fewer student willing use
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  world evolving educator need adapt establishing clear guideline policy well designing challenging assessment
# postive, {'neg': 0.0, 'neu': 0.613, 'pos': 0.387, 'compound': 0.6486}
#
#  however difficult resourceconstrained environment academic already overburdened underpaid guadamuz said
# negative, {'neg': 0.217, 'neu': 0.783, 'pos': 0.0, 'compound': -0.3612}
#
#  according eefs proposal use ai might instead help cut workload burden teacher well improving quality teaching
# postive, {'neg': 0.212, 'neu': 0.466, 'pos': 0.322, 'compound': 0.3818}
#
#  gillian keegan education secretary said ai could take heavy lifting marking planning teacher
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  half fifty-eight school inenglandtaking part eefs project given toolkit create assessment material practice question exam model answer tailor lesson specific group child
# postive, {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.2732}
#
#  aigenerated lesson plan assessed independent panel expert
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  prof becky francis chief executive eef said there already huge anticipation around technology could transform teacher role research actual impact practice currently limited
# postive, {'neg': 0.074, 'neu': 0.781, 'pos': 0.145, 'compound': 0.2023}
#
#  finding trial important contribution evidence base bringing u closer understanding teacher use ai
# postive, {'neg': 0.0, 'neu': 0.859, 'pos': 0.141, 'compound': 0.2023}
#
#  half teacher think ai force good school pic getty creative
# postive, {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.7003}
#
#  half secondarylevel teacher believe ai change education better according newsurvey
# postive, {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.4404}
#
#  similar proportion say school either blocked restricted access ai one form another reflecting level turmoil already prompted education sector
# negative, {'neg': 0.31, 'neu': 0.69, 'pos': 0.0, 'compound': -0.7351}
#
#  student using technology cheat assessment coursework quickly identified one risk education openai released chatgpt late last year
# negative, {'neg': 0.254, 'neu': 0.746, 'pos': 0.0, 'compound': -0.6249}
#
#  one concern alongside impact student mental health identified school leader earlier month whowarnedthat ai posed real present danger education
# negative, {'neg': 0.159, 'neu': 0.841, 'pos': 0.0, 'compound': -0.5267}
#
#  fear impact ai far confined classroom
# negative, {'neg': 0.39, 'neu': 0.61, 'pos': 0.0, 'compound': -0.4939}
#
#  expert including sam altman ceo openai signed aletterwarning technology could lead extinction humanity
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  openai ceo sam altman photo win mcnameegetty image
# postive, {'neg': 0.0, 'neu': 0.648, 'pos': 0.352, 'compound': 0.5859}
#
#  signatory also included professor geoffrey hinton yoshua bengio two triumvirate described godfather ai prof bengio expressingregretover giving safety higher priority
# postive, {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.6369}
#
#  third godfather professor yann lecunn said apocalyptic warning overblown however
# negative, {'neg': 0.459, 'neu': 0.541, 'pos': 0.0, 'compound': -0.7783}
#
#  global survey teacher found many harbor doubt impact ai majority feel potential benefit outweigh risk
# negative, {'neg': 0.235, 'neu': 0.612, 'pos': 0.153, 'compound': -0.1531}
#
#  half fifty-two secondarylevel teacher surveyed said believed ai would change teaching profession better
# postive, {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.4404}
#
#  among perceived benefit using ai teach student interact understand ai model backed sixty teaching critical thinking fifty-six tool edit student work fifty-two
# postive, {'neg': 0.091, 'neu': 0.748, 'pos': 0.161, 'compound': 0.2023}
#
#  half fifty-six said school curriculum assessment adapted account student using aigenerated content
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  deep division use ai illustrated level concern among educator according survey one thousand, eight hundred secondarylevel teacher across australia finland france germany japan netherlands singapore uk u
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  three quarter seventy-eight said shared concern negative impact ai learning outcome two third sixty-six saying feared value writing skill would diminished would limit student creativity
# negative, {'neg': 0.201, 'neu': 0.583, 'pos': 0.216, 'compound': -0.128}
#
#  almost half forty-eight teacher said school already blocked restricted use ai classroom
# negative, {'neg': 0.32, 'neu': 0.68, 'pos': 0.0, 'compound': -0.5719}
#
#  teacher uk u germany finland likely positive feeling ai counterpart singapore japan france
# postive, {'neg': 0.0, 'neu': 0.662, 'pos': 0.338, 'compound': 0.6249}
#
#  secondarylevel teacher also convinced importance student learning digital skill according survey carried consultancy firm capgemini
# postive, {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.6369}
#
#  eight ten eighty-two said education digital skill compulsory sixty-four said digital skill important help student become jobready
# postive, {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.5423}
#
# ...
# postive, {'neg': 0.0, 'neu': 0.587, 'pos': 0.413, 'compound': 0.92}
#
#  live online tutoring platform time used ai trained dataset derived twenty-eight million hour tuition session taken place platform since two thousand and fifteen allow student quickly accurately search transcription resource past online tutoring session revision
# postive, {'neg': 0.0, 'neu': 0.947, 'pos': 0.053, 'compound': 0.2263}
#
#  clear survey student using technology learning point clearly towards future ai likely become increasingly important learning tool
# postive, {'neg': 0.0, 'neu': 0.664, 'pos': 0.336, 'compound': 0.7269}
#
#  bramble
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  bramble online tutoring teaching platform currently used one hundred and thirty thousand tutor student one hundred and eighty country
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  experience knowledge gained twenty-five million hour online tuition given bramble unique insight people teach learn onlinewwwaboutbrambleio
# postive, {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'compound': 0.3818}
#
#  nearly sixty teacher say interacting ai system key skill required job future however student struggle skill required 21st century workforce
# negative, {'neg': 0.108, 'neu': 0.892, 'pos': 0.0, 'compound': -0.3182}
#
#  new generative ai tool disrupting education sector posing challenge opportunity student teacher
# postive, {'neg': 0.0, 'neu': 0.709, 'pos': 0.291, 'compound': 0.4767}
#
#  capgemini research institute new reportfuture ready education empowering secondary school student digital skill also found student aged one thousand, six hundred and eighteen feel much le confident whether digital skill make workforceready teacher
# postive, {'neg': 0.0, 'neu': 0.845, 'pos': 0.155, 'compound': 0.6908}
#
#  especially term digital communication data literacy
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  education system around world already making move either accommodate exclude generative ai tool chatgpt student daytoday activity
# negative, {'neg': 0.106, 'neu': 0.894, 'pos': 0.0, 'compound': -0.2263}
#
#  nearly half forty-eight secondary school teacher example report school either blocked restricted tool use one form another
# negative, {'neg': 0.239, 'neu': 0.761, 'pos': 0.0, 'compound': -0.5719}
#
#  others le restrictive approach nineteen saying tool allowed specific usecases eighteen noting still evaluating applicability usefulness classroom
# postive, {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'compound': 0.296}
#
#  overall half fifty-six secondary school teacher agreed curriculum assessment needed adapted account student use aigenerated content similar proportion fifty-two believe ai tool change teaching profession better
# postive, {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.6124}
#
#  many see potential generative ai tool seventy-eight secondary school teacher globally share concern negative impact generative ai tool student learning outcome including perception value writing skill diminished sixty-six tool limit student creativity sixty-six
# postive, {'neg': 0.093, 'neu': 0.727, 'pos': 0.18, 'compound': 0.3612}
#
#  despite concern half secondary school teacher globally say potential generative ai educational tool outweighs risk
# negative, {'neg': 0.13, 'neu': 0.87, 'pos': 0.0, 'compound': -0.2732}
#
#  perceived benefit ai tool could bring key use case highlighted teacher include using teach interact understand ai model sixty aid critical thinking exercise fifty-six tool help suggest edits student work fifty-two among others
# postive, {'neg': 0.061, 'neu': 0.789, 'pos': 0.15, 'compound': 0.5267}
#
#  sentiment towards generative ai varies significantly across different geography teacher united state united kingdom germany finland recognize importance potential generative ai much singapore japan france
# postive, {'neg': 0.0, 'neu': 0.731, 'pos': 0.269, 'compound': 0.7964}
#
#  almost two third sixty-four secondary school teacher convinced importance develop student digital skill make jobready vast majority eighty-two agree compulsory education digital skill would beneficial student
# postive, {'neg': 0.0, 'neu': 0.675, 'pos': 0.325, 'compound': 0.8625}
#
#  however according report seem overestimate student confidence digital skill seventy believe student necessary skill successful today workforce eighty-three large city versus forty rural area sixty-four parent fifty-five student aged one thousand, six hundred and eighteen agree
# postive, {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.8625}
#
#  research also find teacher rural area le likely believe digital literacy priority school peer suburban urban area
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  per research seventy-two student aged one thousand, six hundred and eighteen feel confident basic digital literacy2 le half forty-seven feel way digital communication data literacy3 attribute considered crucial success modern workplace
# postive, {'neg': 0.0, 'neu': 0.808, 'pos': 0.192, 'compound': 0.7845}
#
#  report highlight instilling confidence key empowering student correctly identify fact misinformation online
# postive, {'neg': 0.135, 'neu': 0.529, 'pos': 0.335, 'compound': 0.5267}
#
#  majority eighty student say confident finding information online fewer know online source trust sixty-six even le able decipher fact versus opinion online sixty-one
# postive, {'neg': 0.0, 'neu': 0.764, 'pos': 0.236, 'compound': 0.7579}
#
#  world undergoes dual transition digital sustainable economy shortage digital talent reaching critical point widening digital dividesaid shobha meera chief corporate responsibility officer capgemini member group executive committee
# postive, {'neg': 0.135, 'neu': 0.721, 'pos': 0.144, 'compound': 0.0772}
#
#  emergence technology generative ai must empower younger generation building capability confidence digital technology
# postive, {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'compound': 0.5106}
#
#  require collaborative approach business government education establishment
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  capgemini committed play major role digital skill training two million people already benefited digital literacy program since two thousand and eighteen already hired six thousand twenty-nine thousand graduate digital academy
# postive, {'neg': 0.0, 'neu': 0.862, 'pos': 0.138, 'compound': 0.5423}
#
#  information download report visithere
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  methodology
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  capgemini research institute conducted global study surveying range stakeholder within education system across australia finland france germany japan netherlands singapore united kingdom united state marchapril two thousand and twenty-three
# postive, {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.6808}
#
#  participant surveyed included one thousand, eight hundred secondary school teacher four thousand, five hundred parent secondary school student nine hundred student aged eleven eighteen year old
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  teacher surveyed work fulltime employed public state secondary school
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  science mathematics english language art medium humanity common area expertise subject taught among teacher surveyed
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  parent surveyed within country representative country national population raceethnicityethnic group household income
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  student aged eighteen surveyed consent responding parent
# postive, {'neg': 0.0, 'neu': 0.759, 'pos': 0.241, 'compound': 0.2263}
#
#  london metropolitan college specialist provider project management course uk provider offer specialist degree apprenticeship emerging
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  college strike secure improved staff pay offer damage student education trade union told
# postive, {'neg': 0.311, 'neu': 0.408, 'pos': 0.281, 'compound': 0.1027}
#
#  college employer
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  springfield training leading provider vocational education training proudly announces transformative education partnership frasers group renowned group retail business
# postive, {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.5574}
#
#  game development student burton south derbyshire college bsdc gaining insight future game design launch upgraded
# postive, {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.4215}
#
#  rhyl high school unveiled bold strategy combat 1million shortfall funding next three year
# postive, {'neg': 0.15, 'neu': 0.688, 'pos': 0.163, 'compound': 0.0516}
#
#  headteacher claire armitstead staff
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  new bae system digital intelligence report explores perceived barrier tech career uk providing insight industry better reach
# postive, {'neg': 0.069, 'neu': 0.602, 'pos': 0.329, 'compound': 0.6808}
#
#  sheffield college sheffcol double finalist award scheme celebrates top educational institution north england
# postive, {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.8402}
#
#  college
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  exam fact life student teacher control stressful scary intimidating exam may seem
# negative, {'neg': 0.511, 'neu': 0.489, 'pos': 0.0, 'compound': -0.8555}
#
#  recent study
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  future asset leading education initiative scotland dedicated fostering diversity inclusion within finance industry known commitment empowering
# postive, {'neg': 0.0, 'neu': 0.616, 'pos': 0.384, 'compound': 0.7964}
#
#  datadriven analysis gatsby charitable foundation schooldash highlight stark contrast recruitment trend observed fe college sixth form college utc compared
# postive, {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.6249}
#
#  education strike heart make u human
# negative, {'neg': 0.273, 'neu': 0.727, 'pos': 0.0, 'compound': -0.128}
#
#  drive intellectual capacity prosperity nation
# postive, {'neg': 0.0, 'neu': 0.548, 'pos': 0.452, 'compound': 0.5106}
#
#  developed mind took u moon eradicated previously incurable disease
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  special status education generative ai tool chatgpt likely profoundlydisrupt sector
# postive, {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.4019}
#
#  isnt reflection intelligence failure build education system nurture value unique human intelligence
# postive, {'neg': 0.26, 'neu': 0.357, 'pos': 0.383, 'compound': 0.3387}
#
#  duped believing ai tool arefar intelligentthan really
# negative, {'neg': 0.318, 'neu': 0.682, 'pos': 0.0, 'compound': -0.4215}
#
#  atool like chatgpthas understanding knowledge
# postive, {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.3612}
#
#  merely collates bit word together based statistical probability produce useful text
# postive, {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4404}
#
#  incredibly helpful assistant
# postive, {'neg': 0.0, 'neu': 0.393, 'pos': 0.607, 'compound': 0.4754}
#
#  knowledgable wise
# postive, {'neg': 0.0, 'neu': 0.244, 'pos': 0.756, 'compound': 0.4767}
#
#  concept word produce relate real world
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  fact pas many form assessment merely reflects assessment designed test knowledge understanding rather test whether people collected memorised information
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  ai could force tremendous good within education
# postive, {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.4404}
#
#  could release teacher administrative task giving opportunity spend time student
# postive, {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.6369}
#
#  however woefully equipped benefit ai flooding market
# postive, {'neg': 0.252, 'neu': 0.467, 'pos': 0.28, 'compound': 0.0772}
#
#  like
# postive, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.3612}
#
#  still time prepare must act quickly wisely
# postive, {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.4215}
#
#  ai used education decade
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  aipowered system ascarnegie learningoraleks analyse student response question adapt learning material meet individual need
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  ai tool asteachfxandedthenacan also enhance teacher training support
# postive, {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.4019}
#
#  reap benefit technology must design effective way roll ai across education system regulate properly
# postive, {'neg': 0.0, 'neu': 0.663, 'pos': 0.337, 'compound': 0.7269}
#
#  staying ahead ai mean radically rethinking education success mean
# postive, {'neg': 0.0, 'neu': 0.684, 'pos': 0.316, 'compound': 0.5719}
#
#  human intelligence far impressive ai system see today
# postive, {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.7506}
#
#  posse rich diverse intelligence much unrecognised current education system
# postive, {'neg': 0.0, 'neu': 0.511, 'pos': 0.489, 'compound': 0.7717}
#
#  capable sophisticated highlevel thinking yet school curriculum particularly england take rigid approach learning prioritising memorising fact rather creative thinking
# postive, {'neg': 0.068, 'neu': 0.58, 'pos': 0.352, 'compound': 0.8093}
#
#  student rewarded rote learning rather critical thought
# postive, {'neg': 0.219, 'neu': 0.476, 'pos': 0.305, 'compound': 0.2263}
#
#  take english syllabus instance requires student learn quotation rule grammar
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  timeconsuming work encourages student marshal fact rather interpret text think critically language
# postive, {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.4404}
#
#  education system recognise unique aspect human intelligence
# postive, {'neg': 0.0, 'neu': 0.659, 'pos': 0.341, 'compound': 0.4767}
#
#  school would mean focus teaching highlevel thinking capability designing system supercharge intelligence
# postive, {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compound': 0.4767}
#
#  literacy numeracy remain fundamental must add ai literacy
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  traditional subject area history science geography become context critical thinking increased creativity knowledge mastery taught
# postive, {'neg': 0.121, 'neu': 0.632, 'pos': 0.247, 'compound': 0.34}
#
#  rather teaching student collate memorise information prize ability interpret fact weigh evidence make original argument
# postive, {'neg': 0.117, 'neu': 0.514, 'pos': 0.369, 'compound': 0.6597}
#
#  failure change isnt option
# negative, {'neg': 0.524, 'neu': 0.476, 'pos': 0.0, 'compound': -0.5106}
#
#  technology need human excel aicannotdo workplace automation complement enriches life intelligence
# postive, {'neg': 0.0, 'neu': 0.596, 'pos': 0.404, 'compound': 0.7269}
#
#  amazing opportunity use ai become much smarter must ensure ai serf u way round
# postive, {'neg': 0.0, 'neu': 0.425, 'pos': 0.575, 'compound': 0.9042}
#
#  mean confronting profitdriven imperative big tech company illusionist trick played silicon valley
# postive, {'neg': 0.197, 'neu': 0.634, 'pos': 0.169, 'compound': 0.1531}
#
#  also mean carefully considering type task willing offload ai
# postive, {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'compound': 0.128}
#
#  aspect intellectual activity may dispensable many
# postive, {'neg': 0.0, 'neu': 0.602, 'pos': 0.398, 'compound': 0.5106}
#
#  silicon valley conjures next magic trick must prepare protect hold dear future generation
# postive, {'neg': 0.073, 'neu': 0.61, 'pos': 0.317, 'compound': 0.6124}
#
#  rose luckin professor learnercentred design ucl knowledge lab london
# neutral, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
data = []
for sentence in sentences:
  sentiment, polarity = getPolarity(sentence)
  new_item = {'sentence' : sentence, 'sentiment' : sentiment, 'category': 'Education'}
  data.append(new_item)

df = pd.DataFrame(data)

# %%
df.to_csv('Education dataset (no numbers) - Vader ver.csv', index = False)
